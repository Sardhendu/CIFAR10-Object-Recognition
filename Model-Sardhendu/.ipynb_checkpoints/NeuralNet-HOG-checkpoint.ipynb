# %%
# Import Packages:
from __future__ import print_function

import os, sys
from six.moves import cPickle as pickle
from six.moves import range
from collections import defaultdict

# Model Packeges import
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import confusion_matrix

# Get the current working directory
cwd = os.getcwd()
mydir = os.path.abspath(os.path.join(cwd, ".."))
sys.path.append(mydir)
from DataGenerator import genTrainValidFolds

# Packages for plot:
import matplotlib
from matplotlib import pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
STDbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/STD/batchData/"
EDGbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/EDG/batchData/"
HOGp1batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp1/batchData/"   # dim =162
HOGp2batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp2/batchData/"   # dim =576
HOGp3batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp3/batchData/"
HOGp4batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp4/batchData/"

featureDIR = HOGp4batch_dir

# %%
# def toOneHotVector():
def reset_graph():  # Reset the graph
    if 'sess' in globals() and sess:
        sess.close()
    tf.reset_default_graph()
    
    
def reshape_data(dataset, labels, featureSize, numLabels, sample_size=None):
    if sample_size:
        dataset = dataset[:sample_size].reshape(sample_size, featureSize) # To reshape the  
        # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
        labels = (np.arange(numLabels) == labels[:,None]).astype(np.float32)
    else:
        dataset = dataset.reshape(len(dataset), featureSize) # To reshape the  
        # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
        labels = (np.arange(numLabels) == labels[:,None]).astype(np.float32)
    return dataset, labels


def accuracy(predictions, labels):
    # Both the predictions and the labels should be in One-Hot vector format.
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))/ predictions.shape[0])


def confusionMatrix(predictions, labels):
    # Both the predictions and the labels should be in One-Hot vector format.
    return (pd.crosstab(np.argmax(labels, 1), np.argmax(predictions, 1), rownames=['True'], colnames=['Predicted'], margins=True))

# %%
class GlabalVariables(object):
    
    def __init__(self):
        super(GlabalVariables, self).__init__()

        self.seed = 2316
        self.imageSize = 32
        self.numHidden1 = 1024
        self.numHidden2 = 1280
        self.numHidden3 = 1024
#         self.numHidden4 = 1024
        self.numLabels = 2
        self.numFolds = 10
        
        # Learning Variables     
        self.epochs = 30
        self.batchSize = 1000

# %%
class BuildNeuralNet(GlabalVariables):
    
    def __init__(self, featureSize):
        super(BuildNeuralNet, self).__init__()
        
        self.featureSize = featureSize
        self.weights = {
            "hid1_wght": tf.Variable(tf.random_normal([self.featureSize, self.numHidden1], seed=1877)),
            "hid2_wght" : tf.Variable(tf.random_normal([self.numHidden1, self.numHidden2], seed=74698)),
            "hid3_wght": tf.Variable(tf.random_normal([self.numHidden2, self.numHidden3], seed=9036)),
#             "hid4_wght": tf.Variable(tf.random_normal([self.numHidden3, self.numHidden4], seed=9476)),
            "out_wght": tf.Variable(tf.random_normal([self.numHidden3, self.numLabels], seed=5664))
        }
        
        self.biases = {
            "hid1_bias": tf.Variable(tf.random_normal([self.numHidden1], seed=6353)),
            "hid2_bias": tf.Variable(tf.random_normal([self.numHidden2], seed=7476)),
            "hid3_bias": tf.Variable(tf.random_normal([self.numHidden3], seed=1322)),
#             "hid4_bias": tf.Variable(tf.random_normal([self.numHidden4], seed=8722)),
            "out_bias": tf.Variable(tf.random_normal([self.numLabels], seed=2228))
        }
        
    def hiddenLayer(self, x, w, b, keepProb=None, nlModel='RELU'):
        x = tf.matmul(x, w) + b
        if nlModel == 'RELU':
            x = tf.nn.relu(x)
        elif nlModel == 'LOGIT':
            x = tf.sigmoid(x)
            
        if dropoutProb:
            return tf.nn.dropout(x, keepProb)
        else: return x
        
        
    def outputLayer(self, x, w, b):
        x = tf.matmul(x, w) + b
        return x, tf.nn.softmax(x)
        
        
    def trainGraph(self, regularization=False):
        trainData = tf.placeholder(tf.float32, [None, self.featureSize])
        trainLabels = tf.placeholder(tf.float32, [None, self.numLabels])

        # 1st Hidden Layer State
        hid1State = self.hiddenLayer(x=trainData, w=self.weights['hid1_wght'], b=self.biases['hid1_bias'], keepProb=0.7, nlModel='RELU') 
        
        # 2nd Hidden Layer State
        hid2State = self.hiddenLayer(x=hid1State, w=self.weights['hid2_wght'], b=self.biases['hid2_bias'], keepProb=0.5, nlModel='RELU') 
        
        # 3nd Hidden Layer State
        hid3State = self.hiddenLayer(x=hid2State, w=self.weights['hid3_wght'], b=self.biases['hid3_bias'], keepProb=0.5, nlModel='RELU') 
        
        # 4rth Hidden Layer State
        # hid4State = self.hiddenLayer(x=hid2State, w=self.weights['hid4_wght'], b=self.biases['hid4_bias'], dropoutProb=0.75, nlModel='RELU') 
        
        # Output Layer State
        hidToOut, outState = self.outputLayer(x=hid3State, w=self.weights['out_wght'], b=self.biases['out_bias'])
        
        # Loss Function
        lossCE = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=hidToOut, labels=trainLabels))
        
        # Loss function using L2 Regularization
        if regularization:
            print ('Doing L2 Regularization')
            regularizers = (tf.nn.l2_loss(self.weights['hid1_wght']) 
                            + tf.nn.l2_loss(self.weights['hid2_wght']) 
                            + tf.nn.l2_loss(self.weights['hid3_wght']) 
                            + tf.nn.l2_loss(self.weights['out_wght'])
                        )
            lossCE = tf.reduce_mean(lossCE + (0.005 * regularizers))
        
        # Optimizer
        optimizer = tf.train.AdamOptimizer(learning_rate=0.008).minimize(lossCE)
#         optimizer = tf.train.GradientDescentOptimizer(0.001).minimize(lossCE)
#         optimizer = tf.train.MomentumOptimizer(0.004, 
#                                             0.5, 
#                                             use_locking=False, 
#                                             name='Momentum', 
#                                             use_nesterov=False).minimize(lossCE)
#         optimizer = tf.train.AdagradOptimizer(learning_rate=0.04).minimize(lossCE)
#         optimizer = tf.train.RMSPropOptimizer(learning_rate=0.001, momentum=0.9).minimize(lossCE)   # This setting seems to be good
    
    
        
        # Evaluate model
#         trainPred = tf.equal(tf.argmax(outState, 1), tf.argmax(trainLabels, 1))
#         trainAccuracy = tf.reduce_mean(tf.cast(trainPred, tf.float32))
        
        return dict(
            trainData = trainData, 
            trainLabels = trainLabels,
            trainPred = outState,
            optimizer = optimizer,
            lossCE = lossCE,
            wghtNew = self.weights
        )
    
    
    def validGraph(self):

        validData = tf.placeholder(tf.float32, [None, self.featureSize])
        validLabels = tf.placeholder(tf.float32, [None, self.numLabels])

        # 1st Hidden Layer State
        vhid1State = self.hiddenLayer(x=validData, w=self.weights['hid1_wght'], b=self.biases['hid1_bias'], nlModel='RELU')

        # 2nd Hidden Layer State
        vhid2State = self.hiddenLayer(x=vhid1State, w=self.weights['hid2_wght'], b=self.biases['hid2_bias'], nlModel='RELU')

        # 3nd Hidden Layer State
        vhid3State = self.hiddenLayer(x=vhid2State, w=self.weights['hid3_wght'], b=self.biases['hid3_bias'], nlModel='RELU')
        
        # 4th Hidden Layer State
        # vhid4State = self.hiddenLayer(x=vhid3State, w=self.weights['hid4_wght'], b=self.biases['hid4_bias'], nlModel='RELU')

        # Output Layer State
        _, validOutState = self.outputLayer(x=vhid3State, w=self.weights['out_wght'], b=self.biases['out_bias'])

        return dict(
            validData = validData,
            validLabels = validLabels,
            validPred = validOutState
        )

# %%
class SessionExec(GlabalVariables):
    
    def __init__(self):
        super(SessionExec, self).__init__()
        self.prevWghtDict = {}
        self.wghtChngDict = defaultdict(list)
        self.meanValidAcc = 0
        self.loss_PerEpoch_PerFold = defaultdict(list)
        self.trainacc_PerEpoch_PerFold = defaultdict(list)
        self.validacc_PerEpoch_PerFold = defaultdict(list)
        
        
    def captureWghtChange(self, wghtDict):   
        for layer, wght_arr in wghtDict.items():
#             print (layer)
#             print (np.sum(np.abs(wght_arr-self.prevWghtDict[layer])))
#             print ('********************')
            self.wghtChngDict[layer].append(np.sum(np.abs(wght_arr-self.prevWghtDict[layer])))
                
        
    def trainModel(self, trainDataIN, trainLabelsIN, sess):    
        numBatches = int(trainDataIN.shape[0]/self.batchSize)
        for numBatch in np.arange(numBatches):
            batchData = trainDataIN[numBatch*self.batchSize : (numBatch+1)*self.batchSize]
            batchLabels = trainLabelsIN[numBatch*self.batchSize : (numBatch+1)*self.batchSize]

            feed_dict = {self.trainGraphDict['trainData']: batchData,
                        self.trainGraphDict['trainLabels']: batchLabels
                        }

            _, loss, tpred, wght = sess.run([self.trainGraphDict['optimizer'],
                                            self.trainGraphDict['lossCE'],
                                            self.trainGraphDict['trainPred'],
                                            self.trainGraphDict['wghtNew']], feed_dict=feed_dict)
            
            if any(self.prevWghtDict):
                self.captureWghtChange(wght)
                self.prevWghtDict = wght
            else:
                self.prevWghtDict = wght
            
            if ((numBatch+1)%10 == 0) or ((numBatch+1) == numBatches): 
                tacc = accuracy(tpred, batchLabels)
                print ("Fold: " + str(self.foldNUM+1) + 
                       ", Epoch: " + str(self.epoch+1)+ 
                       ", Mini Batch: " + str(numBatch+1) + 
                       ", Loss= " + "{:.6f}".format(loss) + 
                       ", Training Accuracy= " + "{:.5f}".format(tacc))
    
        return loss, tacc
    
    def validModel(self, validDataIN, validLabelsIN, sess):
        feed_dict = {self.validGraphDict['validData']: validDataIN,
                     self.validGraphDict['validLabels']: validLabelsIN
                }

        vpred = sess.run(self.validGraphDict['validPred'], feed_dict=feed_dict)
        
        vacc = accuracy(vpred, validLabelsIN)
        print ("Fold: " + str(self.foldNUM+1) + 
                ", Epoch: " + str(self.epoch+1)+ 
                ", Validation Accuracy= " + "{:.5f}".format(vacc))
        
        return vpred, vacc 
        
        
    def execute(self):
        meanValidAcc = 0
        
        for foldNUM, (trainDataIN, trainLabelsIN, validDataIN, validLabelsIN, labelDict) in enumerate(genTrainValidFolds(featureDIR, oneHot=True)):   
            print ('')
            print ('##########################################################################################')

            print ('')
            print ('Validation Data and Labels shape: ', validDataIN.shape, validLabelsIN.shape)
            print ('Training Data and Labels shape: ', trainDataIN.shape, trainLabelsIN.shape)
            print ('The Label Dictionary is given as: ', labelDict)
            print ('')
            
            self.foldNUM = foldNUM

            reset_graph()

            # Create a object encapsulating the graph lineage
            objCNN = BuildNeuralNet(featureSize=trainDataIN.shape[1])
            self.trainGraphDict = objCNN.trainGraph()
            self.validGraphDict = objCNN.validGraph()
            
            with tf.Session() as sess:
                sess.run(tf.initialize_all_variables())

                for epoch in range(self.epochs): 
                    self.epoch = epoch
                    
                    # Train The model for Epochs
                    loss, tacc = self.trainModel(trainDataIN, trainLabelsIN, sess)
                    print ('')

                    # Validate the model for Epochs
                    vpred, vacc = self.validModel(validDataIN, validLabelsIN, sess)
                    print ('')
                    
                    self.loss_PerEpoch_PerFold[foldNUM+1].append(loss)
                    self.trainacc_PerEpoch_PerFold[foldNUM+1].append(tacc)
                    self.validacc_PerEpoch_PerFold[foldNUM+1].append(vacc)

                    if (epoch+1)%10 ==0:
                        validCM = confusionMatrix(validLabelsIN,vpred)
                        print ('Confusion Matrix CrossValid Set')
                        print (validCM)
                        print ('')
                    
                    
            self.meanValidAcc += vpred
            
            if foldNUM == self.numFolds-1:
                break
            
        return (self.wghtChngDict, 
                self.meanValidAcc/self.numFolds, 
                self.loss_PerEpoch_PerFold, 
                self.trainacc_PerEpoch_PerFold, 
                self.validacc_PerEpoch_PerFold)

(out, meanValidAcc, lossPerEpochPerFold, taccPerEpochPerFold, vaccPerEpochPerFold) = SessionExec().execute()  


print ('############*****************####################>>>>>>>>>>>>>>##############<<<<<<<<<<<<<<###############.................############')
print ('The mean validation Accuracy is: ', meanValidAcc)
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 1, Epoch: 1, Mini Batch: 9, Loss= 22039.812500, Training Accuracy= 72.00000
#
# Fold: 1, Epoch: 1, Validation Accuracy= 83.50000
#
# Fold: 1, Epoch: 2, Mini Batch: 9, Loss= 12397.375977, Training Accuracy= 75.10000
#
# Fold: 1, Epoch: 2, Validation Accuracy= 85.10000
#
# Fold: 1, Epoch: 3, Mini Batch: 9, Loss= 7345.046875, Training Accuracy= 79.00000
#
# Fold: 1, Epoch: 3, Validation Accuracy= 84.20000
#
# Fold: 1, Epoch: 4, Mini Batch: 9, Loss= 6989.699707, Training Accuracy= 79.10000
#
# Fold: 1, Epoch: 4, Validation Accuracy= 81.50000
#
# Fold: 1, Epoch: 5, Mini Batch: 9, Loss= 5045.783203, Training Accuracy= 80.60000
#
# Fold: 1, Epoch: 5, Validation Accuracy= 85.50000
#
# Fold: 1, Epoch: 6, Mini Batch: 9, Loss= 4291.895996, Training Accuracy= 79.80000
#
# Fold: 1, Epoch: 6, Validation Accuracy= 85.60000
#
# Fold: 1, Epoch: 7, Mini Batch: 9, Loss= 3648.275391, Training Accuracy= 82.60000
#
# Fold: 1, Epoch: 7, Validation Accuracy= 85.40000
#
# Fold: 1, Epoch: 8, Mini Batch: 9, Loss= 3546.719482, Training Accuracy= 81.60000
#
# Fold: 1, Epoch: 8, Validation Accuracy= 85.10000
#
# Fold: 1, Epoch: 9, Mini Batch: 9, Loss= 2973.475586, Training Accuracy= 83.30000
#
# Fold: 1, Epoch: 9, Validation Accuracy= 86.10000
#
# Fold: 1, Epoch: 10, Mini Batch: 9, Loss= 2857.417725, Training Accuracy= 81.70000
#
# Fold: 1, Epoch: 10, Validation Accuracy= 85.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          407   48   455
# 1           93  452   545
# All        500  500  1000
#
# Fold: 1, Epoch: 11, Mini Batch: 9, Loss= 2661.028076, Training Accuracy= 82.60000
#
# Fold: 1, Epoch: 11, Validation Accuracy= 86.80000
#
# Fold: 1, Epoch: 12, Mini Batch: 9, Loss= 2152.223145, Training Accuracy= 84.10000
#
# Fold: 1, Epoch: 12, Validation Accuracy= 86.30000
#
# Fold: 1, Epoch: 13, Mini Batch: 9, Loss= 2080.026855, Training Accuracy= 82.90000
#
# Fold: 1, Epoch: 13, Validation Accuracy= 86.70000
#
# Fold: 1, Epoch: 14, Mini Batch: 9, Loss= 1972.377075, Training Accuracy= 84.50000
#
# Fold: 1, Epoch: 14, Validation Accuracy= 86.60000
#
# Fold: 1, Epoch: 15, Mini Batch: 9, Loss= 1782.032593, Training Accuracy= 84.20000
#
# Fold: 1, Epoch: 15, Validation Accuracy= 86.10000
#
# Fold: 1, Epoch: 16, Mini Batch: 9, Loss= 1759.021606, Training Accuracy= 85.30000
#
# Fold: 1, Epoch: 16, Validation Accuracy= 85.50000
#
# Fold: 1, Epoch: 17, Mini Batch: 9, Loss= 1435.567383, Training Accuracy= 85.10000
#
# Fold: 1, Epoch: 17, Validation Accuracy= 85.10000
#
# Fold: 1, Epoch: 18, Mini Batch: 9, Loss= 1397.394653, Training Accuracy= 85.80000
#
# Fold: 1, Epoch: 18, Validation Accuracy= 86.10000
#
# Fold: 1, Epoch: 19, Mini Batch: 9, Loss= 1461.471924, Training Accuracy= 84.40000
#
# Fold: 1, Epoch: 19, Validation Accuracy= 86.00000
#
# Fold: 1, Epoch: 20, Mini Batch: 9, Loss= 1340.422729, Training Accuracy= 84.80000
#
# Fold: 1, Epoch: 20, Validation Accuracy= 85.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          416   57   473
# 1           84  443   527
# All        500  500  1000
#
# Fold: 1, Epoch: 21, Mini Batch: 9, Loss= 1166.977661, Training Accuracy= 85.20000
#
# Fold: 1, Epoch: 21, Validation Accuracy= 85.60000
#
# Fold: 1, Epoch: 22, Mini Batch: 9, Loss= 867.977173, Training Accuracy= 86.30000
#
# Fold: 1, Epoch: 22, Validation Accuracy= 85.00000
#
# Fold: 1, Epoch: 23, Mini Batch: 9, Loss= 920.200989, Training Accuracy= 86.00000
#
# Fold: 1, Epoch: 23, Validation Accuracy= 85.80000
#
# Fold: 1, Epoch: 24, Mini Batch: 9, Loss= 819.110779, Training Accuracy= 87.30000
#
# Fold: 1, Epoch: 24, Validation Accuracy= 85.60000
#
# Fold: 1, Epoch: 25, Mini Batch: 9, Loss= 923.436768, Training Accuracy= 86.50000
#
# Fold: 1, Epoch: 25, Validation Accuracy= 86.60000
#
# Fold: 1, Epoch: 26, Mini Batch: 9, Loss= 931.219971, Training Accuracy= 86.40000
#
# Fold: 1, Epoch: 26, Validation Accuracy= 86.00000
#
# Fold: 1, Epoch: 27, Mini Batch: 9, Loss= 757.375305, Training Accuracy= 86.40000
#
# Fold: 1, Epoch: 27, Validation Accuracy= 86.30000
#
# Fold: 1, Epoch: 28, Mini Batch: 9, Loss= 759.080872, Training Accuracy= 88.10000
#
# Fold: 1, Epoch: 28, Validation Accuracy= 86.00000
#
# Fold: 1, Epoch: 29, Mini Batch: 9, Loss= 683.675903, Training Accuracy= 87.10000
#
# Fold: 1, Epoch: 29, Validation Accuracy= 86.10000
#
# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 726.682129, Training Accuracy= 88.20000
#
# Fold: 1, Epoch: 30, Validation Accuracy= 86.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          412   52   464
# 1           88  448   536
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 2, Epoch: 1, Mini Batch: 9, Loss= 26229.718750, Training Accuracy= 68.80000
#
# Fold: 2, Epoch: 1, Validation Accuracy= 82.30000
#
# Fold: 2, Epoch: 2, Mini Batch: 9, Loss= 12842.338867, Training Accuracy= 74.10000
#
# Fold: 2, Epoch: 2, Validation Accuracy= 83.40000
#
# Fold: 2, Epoch: 3, Mini Batch: 9, Loss= 8544.008789, Training Accuracy= 77.80000
#
# Fold: 2, Epoch: 3, Validation Accuracy= 82.70000
#
# Fold: 2, Epoch: 4, Mini Batch: 9, Loss= 6914.994629, Training Accuracy= 80.10000
#
# Fold: 2, Epoch: 4, Validation Accuracy= 82.40000
#
# Fold: 2, Epoch: 5, Mini Batch: 9, Loss= 5246.666016, Training Accuracy= 79.10000
#
# Fold: 2, Epoch: 5, Validation Accuracy= 86.70000
#
# Fold: 2, Epoch: 6, Mini Batch: 9, Loss= 4489.503906, Training Accuracy= 80.00000
#
# Fold: 2, Epoch: 6, Validation Accuracy= 85.60000
#
# Fold: 2, Epoch: 7, Mini Batch: 9, Loss= 3784.324463, Training Accuracy= 83.90000
#
# Fold: 2, Epoch: 7, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 8, Mini Batch: 9, Loss= 3626.374756, Training Accuracy= 80.80000
#
# Fold: 2, Epoch: 8, Validation Accuracy= 87.00000
#
# Fold: 2, Epoch: 9, Mini Batch: 9, Loss= 3194.061768, Training Accuracy= 82.00000
#
# Fold: 2, Epoch: 9, Validation Accuracy= 86.70000
#
# Fold: 2, Epoch: 10, Mini Batch: 9, Loss= 2705.093018, Training Accuracy= 82.90000
#
# Fold: 2, Epoch: 10, Validation Accuracy= 87.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          416   42   458
# 1           84  458   542
# All        500  500  1000
#
# Fold: 2, Epoch: 11, Mini Batch: 9, Loss= 2813.531982, Training Accuracy= 82.90000
#
# Fold: 2, Epoch: 11, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 12, Mini Batch: 9, Loss= 2158.349609, Training Accuracy= 83.10000
#
# Fold: 2, Epoch: 12, Validation Accuracy= 86.80000
#
# Fold: 2, Epoch: 13, Mini Batch: 9, Loss= 2205.970215, Training Accuracy= 81.40000
#
# Fold: 2, Epoch: 13, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 14, Mini Batch: 9, Loss= 1971.774536, Training Accuracy= 84.00000
#
# Fold: 2, Epoch: 14, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 15, Mini Batch: 9, Loss= 1823.528931, Training Accuracy= 83.00000
#
# Fold: 2, Epoch: 15, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 16, Mini Batch: 9, Loss= 1672.461182, Training Accuracy= 83.50000
#
# Fold: 2, Epoch: 16, Validation Accuracy= 87.50000
#
# Fold: 2, Epoch: 17, Mini Batch: 9, Loss= 1585.477783, Training Accuracy= 85.70000
#
# Fold: 2, Epoch: 17, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 18, Mini Batch: 9, Loss= 1351.710449, Training Accuracy= 86.00000
#
# Fold: 2, Epoch: 18, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 19, Mini Batch: 9, Loss= 1516.936035, Training Accuracy= 83.20000
#
# Fold: 2, Epoch: 19, Validation Accuracy= 87.80000
#
# Fold: 2, Epoch: 20, Mini Batch: 9, Loss= 1355.054810, Training Accuracy= 84.10000
#
# Fold: 2, Epoch: 20, Validation Accuracy= 87.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          417   39   456
# 1           83  461   544
# All        500  500  1000
#
# Fold: 2, Epoch: 21, Mini Batch: 9, Loss= 1133.272461, Training Accuracy= 86.50000
#
# Fold: 2, Epoch: 21, Validation Accuracy= 86.80000
#
# Fold: 2, Epoch: 22, Mini Batch: 9, Loss= 1020.917236, Training Accuracy= 85.40000
#
# Fold: 2, Epoch: 22, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 23, Mini Batch: 9, Loss= 1156.542236, Training Accuracy= 85.90000
#
# Fold: 2, Epoch: 23, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 24, Mini Batch: 9, Loss= 728.841614, Training Accuracy= 87.70000
#
# Fold: 2, Epoch: 24, Validation Accuracy= 87.70000
#
# Fold: 2, Epoch: 25, Mini Batch: 9, Loss= 834.325134, Training Accuracy= 86.30000
#
# Fold: 2, Epoch: 25, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 26, Mini Batch: 9, Loss= 954.792480, Training Accuracy= 86.30000
#
# Fold: 2, Epoch: 26, Validation Accuracy= 86.80000
#
# Fold: 2, Epoch: 27, Mini Batch: 9, Loss= 672.542358, Training Accuracy= 86.60000
#
# Fold: 2, Epoch: 27, Validation Accuracy= 87.00000
#
# Fold: 2, Epoch: 28, Mini Batch: 9, Loss= 767.833191, Training Accuracy= 87.30000
#
# Fold: 2, Epoch: 28, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 29, Mini Batch: 9, Loss= 643.919128, Training Accuracy= 87.10000
#
# Fold: 2, Epoch: 29, Validation Accuracy= 87.40000
#
# Fold: 2, Epoch: 30, Mini Batch: 9, Loss= 739.594421, Training Accuracy= 87.00000
#
# Fold: 2, Epoch: 30, Validation Accuracy= 87.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          416   46   462
# 1           84  454   538
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 3, Epoch: 1, Mini Batch: 9, Loss= 26862.878906, Training Accuracy= 68.40000
#
# Fold: 3, Epoch: 1, Validation Accuracy= 79.60000
#
# Fold: 3, Epoch: 2, Mini Batch: 9, Loss= 12622.806641, Training Accuracy= 75.70000
#
# Fold: 3, Epoch: 2, Validation Accuracy= 82.70000
#
# Fold: 3, Epoch: 3, Mini Batch: 9, Loss= 9175.742188, Training Accuracy= 77.70000
#
# Fold: 3, Epoch: 3, Validation Accuracy= 81.20000
#
# Fold: 3, Epoch: 4, Mini Batch: 9, Loss= 6579.638184, Training Accuracy= 78.30000
#
# Fold: 3, Epoch: 4, Validation Accuracy= 83.20000
#
# Fold: 3, Epoch: 5, Mini Batch: 9, Loss= 4853.183594, Training Accuracy= 79.70000
#
# Fold: 3, Epoch: 5, Validation Accuracy= 84.00000
#
# Fold: 3, Epoch: 6, Mini Batch: 9, Loss= 4471.445801, Training Accuracy= 80.30000
#
# Fold: 3, Epoch: 6, Validation Accuracy= 84.70000
#
# Fold: 3, Epoch: 7, Mini Batch: 9, Loss= 3849.304932, Training Accuracy= 81.50000
#
# Fold: 3, Epoch: 7, Validation Accuracy= 84.60000
#
# Fold: 3, Epoch: 8, Mini Batch: 9, Loss= 3742.736084, Training Accuracy= 81.70000
#
# Fold: 3, Epoch: 8, Validation Accuracy= 84.90000
#
# Fold: 3, Epoch: 9, Mini Batch: 9, Loss= 3036.177490, Training Accuracy= 82.70000
#
# Fold: 3, Epoch: 9, Validation Accuracy= 85.50000
#
# Fold: 3, Epoch: 10, Mini Batch: 9, Loss= 2813.303955, Training Accuracy= 82.00000
#
# Fold: 3, Epoch: 10, Validation Accuracy= 85.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          411   53   464
# 1           89  447   536
# All        500  500  1000
#
# Fold: 3, Epoch: 11, Mini Batch: 9, Loss= 2812.186035, Training Accuracy= 82.30000
#
# Fold: 3, Epoch: 11, Validation Accuracy= 85.30000
#
# Fold: 3, Epoch: 12, Mini Batch: 9, Loss= 2326.888916, Training Accuracy= 83.00000
#
# Fold: 3, Epoch: 12, Validation Accuracy= 85.70000
#
# Fold: 3, Epoch: 13, Mini Batch: 9, Loss= 2233.410889, Training Accuracy= 82.90000
#
# Fold: 3, Epoch: 13, Validation Accuracy= 85.80000
#
# Fold: 3, Epoch: 14, Mini Batch: 9, Loss= 2097.525635, Training Accuracy= 84.10000
#
# Fold: 3, Epoch: 14, Validation Accuracy= 86.40000
#
# Fold: 3, Epoch: 15, Mini Batch: 9, Loss= 1783.886963, Training Accuracy= 83.20000
#
# Fold: 3, Epoch: 15, Validation Accuracy= 86.40000
#
# Fold: 3, Epoch: 16, Mini Batch: 9, Loss= 1635.103760, Training Accuracy= 83.40000
#
# Fold: 3, Epoch: 16, Validation Accuracy= 86.40000
#
# Fold: 3, Epoch: 17, Mini Batch: 9, Loss= 1490.614258, Training Accuracy= 86.20000
#
# Fold: 3, Epoch: 17, Validation Accuracy= 86.70000
#
# Fold: 3, Epoch: 18, Mini Batch: 9, Loss= 1400.803101, Training Accuracy= 84.10000
#
# Fold: 3, Epoch: 18, Validation Accuracy= 87.20000
#
# Fold: 3, Epoch: 19, Mini Batch: 9, Loss= 1574.690796, Training Accuracy= 84.90000
#
# Fold: 3, Epoch: 19, Validation Accuracy= 86.40000
#
# Fold: 3, Epoch: 20, Mini Batch: 9, Loss= 1393.177490, Training Accuracy= 85.80000
#
# Fold: 3, Epoch: 20, Validation Accuracy= 86.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          421   53   474
# 1           79  447   526
# All        500  500  1000
#
# Fold: 3, Epoch: 21, Mini Batch: 9, Loss= 1265.456299, Training Accuracy= 86.50000
#
# Fold: 3, Epoch: 21, Validation Accuracy= 87.00000
#
# Fold: 3, Epoch: 22, Mini Batch: 9, Loss= 898.260559, Training Accuracy= 86.90000
#
# Fold: 3, Epoch: 22, Validation Accuracy= 86.20000
#
# Fold: 3, Epoch: 23, Mini Batch: 9, Loss= 1137.780396, Training Accuracy= 84.20000
#
# Fold: 3, Epoch: 23, Validation Accuracy= 86.20000
#
# Fold: 3, Epoch: 24, Mini Batch: 9, Loss= 709.379150, Training Accuracy= 87.90000
#
# Fold: 3, Epoch: 24, Validation Accuracy= 86.40000
#
# Fold: 3, Epoch: 25, Mini Batch: 9, Loss= 868.277039, Training Accuracy= 87.30000
#
# Fold: 3, Epoch: 25, Validation Accuracy= 86.10000
#
# Fold: 3, Epoch: 26, Mini Batch: 9, Loss= 892.969543, Training Accuracy= 87.20000
#
# Fold: 3, Epoch: 26, Validation Accuracy= 86.40000
#
# Fold: 3, Epoch: 27, Mini Batch: 9, Loss= 660.291626, Training Accuracy= 86.90000
#
# Fold: 3, Epoch: 27, Validation Accuracy= 86.70000
#
# Fold: 3, Epoch: 28, Mini Batch: 9, Loss= 777.851807, Training Accuracy= 87.10000
#
# Fold: 3, Epoch: 28, Validation Accuracy= 86.10000
#
# Fold: 3, Epoch: 29, Mini Batch: 9, Loss= 602.434753, Training Accuracy= 89.00000
#
# Fold: 3, Epoch: 29, Validation Accuracy= 85.90000
#
# Fold: 3, Epoch: 30, Mini Batch: 9, Loss= 745.256714, Training Accuracy= 87.30000
#
# Fold: 3, Epoch: 30, Validation Accuracy= 85.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          425   70   495
# 1           75  430   505
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 4, Epoch: 1, Mini Batch: 9, Loss= 25734.996094, Training Accuracy= 68.80000
#
# Fold: 4, Epoch: 1, Validation Accuracy= 81.00000
#
# Fold: 4, Epoch: 2, Mini Batch: 9, Loss= 12892.719727, Training Accuracy= 75.00000
#
# Fold: 4, Epoch: 2, Validation Accuracy= 81.60000
#
# Fold: 4, Epoch: 3, Mini Batch: 9, Loss= 8532.024414, Training Accuracy= 77.80000
#
# Fold: 4, Epoch: 3, Validation Accuracy= 82.80000
#
# Fold: 4, Epoch: 4, Mini Batch: 9, Loss= 6916.806152, Training Accuracy= 78.70000
#
# Fold: 4, Epoch: 4, Validation Accuracy= 83.50000
#
# Fold: 4, Epoch: 5, Mini Batch: 9, Loss= 4805.282227, Training Accuracy= 79.60000
#
# Fold: 4, Epoch: 5, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 6, Mini Batch: 9, Loss= 4208.327148, Training Accuracy= 81.50000
#
# Fold: 4, Epoch: 6, Validation Accuracy= 84.90000
#
# Fold: 4, Epoch: 7, Mini Batch: 9, Loss= 3685.109863, Training Accuracy= 83.30000
#
# Fold: 4, Epoch: 7, Validation Accuracy= 86.40000
#
# Fold: 4, Epoch: 8, Mini Batch: 9, Loss= 3681.446045, Training Accuracy= 81.00000
#
# Fold: 4, Epoch: 8, Validation Accuracy= 86.80000
#
# Fold: 4, Epoch: 9, Mini Batch: 9, Loss= 2981.708740, Training Accuracy= 82.70000
#
# Fold: 4, Epoch: 9, Validation Accuracy= 86.80000
#
# Fold: 4, Epoch: 10, Mini Batch: 9, Loss= 2765.631348, Training Accuracy= 82.40000
#
# Fold: 4, Epoch: 10, Validation Accuracy= 86.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   52   470
# 1           82  448   530
# All        500  500  1000
#
# Fold: 4, Epoch: 11, Mini Batch: 9, Loss= 2815.676025, Training Accuracy= 81.40000
#
# Fold: 4, Epoch: 11, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 12, Mini Batch: 9, Loss= 2120.004883, Training Accuracy= 84.20000
#
# Fold: 4, Epoch: 12, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 13, Mini Batch: 9, Loss= 2187.187012, Training Accuracy= 83.20000
#
# Fold: 4, Epoch: 13, Validation Accuracy= 85.90000
#
# Fold: 4, Epoch: 14, Mini Batch: 9, Loss= 1986.733765, Training Accuracy= 83.50000
#
# Fold: 4, Epoch: 14, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 15, Mini Batch: 9, Loss= 1775.965820, Training Accuracy= 84.00000
#
# Fold: 4, Epoch: 15, Validation Accuracy= 86.60000
#
# Fold: 4, Epoch: 16, Mini Batch: 9, Loss= 1669.494507, Training Accuracy= 84.80000
#
# Fold: 4, Epoch: 16, Validation Accuracy= 85.70000
#
# Fold: 4, Epoch: 17, Mini Batch: 9, Loss= 1621.228760, Training Accuracy= 84.80000
#
# Fold: 4, Epoch: 17, Validation Accuracy= 86.60000
#
# Fold: 4, Epoch: 18, Mini Batch: 9, Loss= 1206.161255, Training Accuracy= 87.30000
#
# Fold: 4, Epoch: 18, Validation Accuracy= 87.00000
#
# Fold: 4, Epoch: 19, Mini Batch: 9, Loss= 1613.472778, Training Accuracy= 84.20000
#
# Fold: 4, Epoch: 19, Validation Accuracy= 86.70000
#
# Fold: 4, Epoch: 20, Mini Batch: 9, Loss= 1226.610962, Training Accuracy= 86.40000
#
# Fold: 4, Epoch: 20, Validation Accuracy= 87.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          422   51   473
# 1           78  449   527
# All        500  500  1000
#
# Fold: 4, Epoch: 21, Mini Batch: 9, Loss= 1105.601807, Training Accuracy= 86.50000
#
# Fold: 4, Epoch: 21, Validation Accuracy= 87.10000
#
# Fold: 4, Epoch: 22, Mini Batch: 9, Loss= 982.261536, Training Accuracy= 86.10000
#
# Fold: 4, Epoch: 22, Validation Accuracy= 86.90000
#
# Fold: 4, Epoch: 23, Mini Batch: 9, Loss= 1059.644531, Training Accuracy= 86.30000
#
# Fold: 4, Epoch: 23, Validation Accuracy= 86.80000
#
# Fold: 4, Epoch: 24, Mini Batch: 9, Loss= 788.287231, Training Accuracy= 88.20000
#
# Fold: 4, Epoch: 24, Validation Accuracy= 87.10000
#
# Fold: 4, Epoch: 25, Mini Batch: 9, Loss= 925.621521, Training Accuracy= 86.50000
#
# Fold: 4, Epoch: 25, Validation Accuracy= 86.60000
#
# Fold: 4, Epoch: 26, Mini Batch: 9, Loss= 847.386047, Training Accuracy= 87.00000
#
# Fold: 4, Epoch: 26, Validation Accuracy= 86.90000
#
# Fold: 4, Epoch: 27, Mini Batch: 9, Loss= 697.684753, Training Accuracy= 85.70000
#
# Fold: 4, Epoch: 27, Validation Accuracy= 86.80000
#
# Fold: 4, Epoch: 28, Mini Batch: 9, Loss= 750.190552, Training Accuracy= 88.40000
#
# Fold: 4, Epoch: 28, Validation Accuracy= 87.00000
#
# Fold: 4, Epoch: 29, Mini Batch: 9, Loss= 566.236633, Training Accuracy= 89.00000
#
# Fold: 4, Epoch: 29, Validation Accuracy= 87.50000
#
# Fold: 4, Epoch: 30, Mini Batch: 9, Loss= 707.950500, Training Accuracy= 87.80000
#
# Fold: 4, Epoch: 30, Validation Accuracy= 86.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          422   55   477
# 1           78  445   523
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 5, Epoch: 1, Mini Batch: 9, Loss= 26014.662109, Training Accuracy= 69.10000
#
# Fold: 5, Epoch: 1, Validation Accuracy= 82.40000
#
# Fold: 5, Epoch: 2, Mini Batch: 9, Loss= 12523.975586, Training Accuracy= 75.80000
#
# Fold: 5, Epoch: 2, Validation Accuracy= 84.80000
#
# Fold: 5, Epoch: 3, Mini Batch: 9, Loss= 9048.225586, Training Accuracy= 78.50000
#
# Fold: 5, Epoch: 3, Validation Accuracy= 81.20000
#
# Fold: 5, Epoch: 4, Mini Batch: 9, Loss= 6263.293945, Training Accuracy= 79.30000
#
# Fold: 5, Epoch: 4, Validation Accuracy= 83.80000
#
# Fold: 5, Epoch: 5, Mini Batch: 9, Loss= 4996.187500, Training Accuracy= 80.10000
#
# Fold: 5, Epoch: 5, Validation Accuracy= 85.90000
#
# Fold: 5, Epoch: 6, Mini Batch: 9, Loss= 4174.634277, Training Accuracy= 81.50000
#
# Fold: 5, Epoch: 6, Validation Accuracy= 85.30000
#
# Fold: 5, Epoch: 7, Mini Batch: 9, Loss= 3688.809326, Training Accuracy= 83.00000
#
# Fold: 5, Epoch: 7, Validation Accuracy= 86.00000
#
# Fold: 5, Epoch: 8, Mini Batch: 9, Loss= 3574.354248, Training Accuracy= 81.50000
#
# Fold: 5, Epoch: 8, Validation Accuracy= 85.80000
#
# Fold: 5, Epoch: 9, Mini Batch: 9, Loss= 2851.988037, Training Accuracy= 82.50000
#
# Fold: 5, Epoch: 9, Validation Accuracy= 86.30000
#
# Fold: 5, Epoch: 10, Mini Batch: 9, Loss= 2823.958984, Training Accuracy= 83.10000
#
# Fold: 5, Epoch: 10, Validation Accuracy= 86.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          412   52   464
# 1           88  448   536
# All        500  500  1000
#
# Fold: 5, Epoch: 11, Mini Batch: 9, Loss= 2809.065674, Training Accuracy= 83.00000
#
# Fold: 5, Epoch: 11, Validation Accuracy= 85.80000
#
# Fold: 5, Epoch: 12, Mini Batch: 9, Loss= 2171.789062, Training Accuracy= 84.60000
#
# Fold: 5, Epoch: 12, Validation Accuracy= 87.80000
#
# Fold: 5, Epoch: 13, Mini Batch: 9, Loss= 2107.003906, Training Accuracy= 83.40000
#
# Fold: 5, Epoch: 13, Validation Accuracy= 87.60000
#
# Fold: 5, Epoch: 14, Mini Batch: 9, Loss= 2220.487793, Training Accuracy= 82.30000
#
# Fold: 5, Epoch: 14, Validation Accuracy= 87.40000
#
# Fold: 5, Epoch: 15, Mini Batch: 9, Loss= 1839.757446, Training Accuracy= 83.60000
#
# Fold: 5, Epoch: 15, Validation Accuracy= 87.30000
#
# Fold: 5, Epoch: 16, Mini Batch: 9, Loss= 1730.379395, Training Accuracy= 85.50000
#
# Fold: 5, Epoch: 16, Validation Accuracy= 87.80000
#
# Fold: 5, Epoch: 17, Mini Batch: 9, Loss= 1747.887085, Training Accuracy= 85.20000
#
# Fold: 5, Epoch: 17, Validation Accuracy= 87.10000
#
# Fold: 5, Epoch: 18, Mini Batch: 9, Loss= 1362.095703, Training Accuracy= 85.50000
#
# Fold: 5, Epoch: 18, Validation Accuracy= 86.40000
#
# Fold: 5, Epoch: 19, Mini Batch: 9, Loss= 1616.864990, Training Accuracy= 85.50000
#
# Fold: 5, Epoch: 19, Validation Accuracy= 86.90000
#
# Fold: 5, Epoch: 20, Mini Batch: 9, Loss= 1503.934692, Training Accuracy= 83.50000
#
# Fold: 5, Epoch: 20, Validation Accuracy= 86.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          419   50   469
# 1           81  450   531
# All        500  500  1000
#
# Fold: 5, Epoch: 21, Mini Batch: 9, Loss= 1182.402222, Training Accuracy= 86.40000
#
# Fold: 5, Epoch: 21, Validation Accuracy= 87.40000
#
# Fold: 5, Epoch: 22, Mini Batch: 9, Loss= 1000.111511, Training Accuracy= 84.70000
#
# Fold: 5, Epoch: 22, Validation Accuracy= 86.60000
#
# Fold: 5, Epoch: 23, Mini Batch: 9, Loss= 995.391113, Training Accuracy= 86.90000
#
# Fold: 5, Epoch: 23, Validation Accuracy= 87.40000
#
# Fold: 5, Epoch: 24, Mini Batch: 9, Loss= 779.837585, Training Accuracy= 87.80000
#
# Fold: 5, Epoch: 24, Validation Accuracy= 87.60000
#
# Fold: 5, Epoch: 25, Mini Batch: 9, Loss= 943.469482, Training Accuracy= 86.30000
#
# Fold: 5, Epoch: 25, Validation Accuracy= 87.90000
#
# Fold: 5, Epoch: 26, Mini Batch: 9, Loss= 805.296936, Training Accuracy= 86.80000
#
# Fold: 5, Epoch: 26, Validation Accuracy= 86.70000
#
# Fold: 5, Epoch: 27, Mini Batch: 9, Loss= 673.124878, Training Accuracy= 88.90000
#
# Fold: 5, Epoch: 27, Validation Accuracy= 87.10000
#
# Fold: 5, Epoch: 28, Mini Batch: 9, Loss= 768.883118, Training Accuracy= 87.80000
#
# Fold: 5, Epoch: 28, Validation Accuracy= 86.90000
#
# Fold: 5, Epoch: 29, Mini Batch: 9, Loss= 683.016296, Training Accuracy= 87.30000
#
# Fold: 5, Epoch: 29, Validation Accuracy= 87.60000
#
# Fold: 5, Epoch: 30, Mini Batch: 9, Loss= 785.245972, Training Accuracy= 86.60000
#
# Fold: 5, Epoch: 30, Validation Accuracy= 88.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          428   47   475
# 1           72  453   525
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 6, Epoch: 1, Mini Batch: 9, Loss= 25502.111328, Training Accuracy= 69.60000
#
# Fold: 6, Epoch: 1, Validation Accuracy= 81.90000
#
# Fold: 6, Epoch: 2, Mini Batch: 9, Loss= 12329.111328, Training Accuracy= 75.00000
#
# Fold: 6, Epoch: 2, Validation Accuracy= 84.40000
#
# Fold: 6, Epoch: 3, Mini Batch: 9, Loss= 8684.583008, Training Accuracy= 78.40000
#
# Fold: 6, Epoch: 3, Validation Accuracy= 82.10000
#
# Fold: 6, Epoch: 4, Mini Batch: 9, Loss= 6918.286133, Training Accuracy= 79.10000
#
# Fold: 6, Epoch: 4, Validation Accuracy= 83.30000
#
# Fold: 6, Epoch: 5, Mini Batch: 9, Loss= 5061.247070, Training Accuracy= 80.00000
#
# Fold: 6, Epoch: 5, Validation Accuracy= 86.90000
#
# Fold: 6, Epoch: 6, Mini Batch: 9, Loss= 4383.513184, Training Accuracy= 80.00000
#
# Fold: 6, Epoch: 6, Validation Accuracy= 86.30000
#
# Fold: 6, Epoch: 7, Mini Batch: 9, Loss= 3885.781006, Training Accuracy= 80.70000
#
# Fold: 6, Epoch: 7, Validation Accuracy= 88.20000
#
# Fold: 6, Epoch: 8, Mini Batch: 9, Loss= 3934.317383, Training Accuracy= 80.50000
#
# Fold: 6, Epoch: 8, Validation Accuracy= 87.70000
#
# Fold: 6, Epoch: 9, Mini Batch: 9, Loss= 2951.803955, Training Accuracy= 81.10000
#
# Fold: 6, Epoch: 9, Validation Accuracy= 86.90000
#
# Fold: 6, Epoch: 10, Mini Batch: 9, Loss= 2620.005615, Training Accuracy= 83.00000
#
# Fold: 6, Epoch: 10, Validation Accuracy= 87.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          422   47   469
# 1           78  453   531
# All        500  500  1000
#
# Fold: 6, Epoch: 11, Mini Batch: 9, Loss= 2965.885254, Training Accuracy= 82.50000
#
# Fold: 6, Epoch: 11, Validation Accuracy= 87.10000
#
# Fold: 6, Epoch: 12, Mini Batch: 9, Loss= 2177.400391, Training Accuracy= 84.10000
#
# Fold: 6, Epoch: 12, Validation Accuracy= 87.10000
#
# Fold: 6, Epoch: 13, Mini Batch: 9, Loss= 2276.970215, Training Accuracy= 82.50000
#
# Fold: 6, Epoch: 13, Validation Accuracy= 87.50000
#
# Fold: 6, Epoch: 14, Mini Batch: 9, Loss= 2159.419189, Training Accuracy= 81.20000
#
# Fold: 6, Epoch: 14, Validation Accuracy= 87.60000
#
# Fold: 6, Epoch: 15, Mini Batch: 9, Loss= 1694.000610, Training Accuracy= 83.70000
#
# Fold: 6, Epoch: 15, Validation Accuracy= 88.50000
#
# Fold: 6, Epoch: 16, Mini Batch: 9, Loss= 1713.056396, Training Accuracy= 84.90000
#
# Fold: 6, Epoch: 16, Validation Accuracy= 88.30000
#
# Fold: 6, Epoch: 17, Mini Batch: 9, Loss= 1661.044434, Training Accuracy= 84.80000
#
# Fold: 6, Epoch: 17, Validation Accuracy= 87.80000
#
# Fold: 6, Epoch: 18, Mini Batch: 9, Loss= 1220.947144, Training Accuracy= 86.10000
#
# Fold: 6, Epoch: 18, Validation Accuracy= 88.20000
#
# Fold: 6, Epoch: 19, Mini Batch: 9, Loss= 1661.667480, Training Accuracy= 84.00000
#
# Fold: 6, Epoch: 19, Validation Accuracy= 87.20000
#
# Fold: 6, Epoch: 20, Mini Batch: 9, Loss= 1277.770264, Training Accuracy= 84.80000
#
# Fold: 6, Epoch: 20, Validation Accuracy= 87.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          414   37   451
# 1           86  463   549
# All        500  500  1000
#
# Fold: 6, Epoch: 21, Mini Batch: 9, Loss= 1137.897339, Training Accuracy= 86.40000
#
# Fold: 6, Epoch: 21, Validation Accuracy= 87.80000
#
# Fold: 6, Epoch: 22, Mini Batch: 9, Loss= 1034.072510, Training Accuracy= 85.70000
#
# Fold: 6, Epoch: 22, Validation Accuracy= 88.40000
#
# Fold: 6, Epoch: 23, Mini Batch: 9, Loss= 1010.174744, Training Accuracy= 86.20000
#
# Fold: 6, Epoch: 23, Validation Accuracy= 87.20000
#
# Fold: 6, Epoch: 24, Mini Batch: 9, Loss= 699.558350, Training Accuracy= 87.90000
#
# Fold: 6, Epoch: 24, Validation Accuracy= 87.80000
#
# Fold: 6, Epoch: 25, Mini Batch: 9, Loss= 857.080872, Training Accuracy= 84.90000
#
# Fold: 6, Epoch: 25, Validation Accuracy= 88.10000
#
# Fold: 6, Epoch: 26, Mini Batch: 9, Loss= 786.866028, Training Accuracy= 86.50000
#
# Fold: 6, Epoch: 26, Validation Accuracy= 87.90000
#
# Fold: 6, Epoch: 27, Mini Batch: 9, Loss= 778.183167, Training Accuracy= 86.10000
#
# Fold: 6, Epoch: 27, Validation Accuracy= 88.90000
#
# Fold: 6, Epoch: 28, Mini Batch: 9, Loss= 704.327148, Training Accuracy= 87.90000
#
# Fold: 6, Epoch: 28, Validation Accuracy= 88.50000
#
# Fold: 6, Epoch: 29, Mini Batch: 9, Loss= 696.066284, Training Accuracy= 88.60000
#
# Fold: 6, Epoch: 29, Validation Accuracy= 88.10000
#
# Fold: 6, Epoch: 30, Mini Batch: 9, Loss= 755.178650, Training Accuracy= 87.00000
#
# Fold: 6, Epoch: 30, Validation Accuracy= 87.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   42   460
# 1           82  458   540
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 7, Epoch: 1, Mini Batch: 9, Loss= 25291.667969, Training Accuracy= 69.60000
#
# Fold: 7, Epoch: 1, Validation Accuracy= 80.90000
#
# Fold: 7, Epoch: 2, Mini Batch: 9, Loss= 12334.469727, Training Accuracy= 75.80000
#
# Fold: 7, Epoch: 2, Validation Accuracy= 84.50000
#
# Fold: 7, Epoch: 3, Mini Batch: 9, Loss= 8388.914062, Training Accuracy= 78.60000
#
# Fold: 7, Epoch: 3, Validation Accuracy= 82.60000
#
# Fold: 7, Epoch: 4, Mini Batch: 9, Loss= 6831.089844, Training Accuracy= 79.80000
#
# Fold: 7, Epoch: 4, Validation Accuracy= 83.60000
#
# Fold: 7, Epoch: 5, Mini Batch: 9, Loss= 4718.616211, Training Accuracy= 80.30000
#
# Fold: 7, Epoch: 5, Validation Accuracy= 86.60000
#
# Fold: 7, Epoch: 6, Mini Batch: 9, Loss= 4093.424316, Training Accuracy= 81.10000
#
# Fold: 7, Epoch: 6, Validation Accuracy= 86.50000
#
# Fold: 7, Epoch: 7, Mini Batch: 9, Loss= 3888.645508, Training Accuracy= 82.60000
#
# Fold: 7, Epoch: 7, Validation Accuracy= 86.40000
#
# Fold: 7, Epoch: 8, Mini Batch: 9, Loss= 3671.275879, Training Accuracy= 80.90000
#
# Fold: 7, Epoch: 8, Validation Accuracy= 86.00000
#
# Fold: 7, Epoch: 9, Mini Batch: 9, Loss= 2755.681885, Training Accuracy= 82.40000
#
# Fold: 7, Epoch: 9, Validation Accuracy= 86.30000
#
# Fold: 7, Epoch: 10, Mini Batch: 9, Loss= 2623.083740, Training Accuracy= 82.80000
#
# Fold: 7, Epoch: 10, Validation Accuracy= 86.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          417   54   471
# 1           83  446   529
# All        500  500  1000
#
# Fold: 7, Epoch: 11, Mini Batch: 9, Loss= 2673.189209, Training Accuracy= 82.10000
#
# Fold: 7, Epoch: 11, Validation Accuracy= 85.70000
#
# Fold: 7, Epoch: 12, Mini Batch: 9, Loss= 2005.368530, Training Accuracy= 85.00000
#
# Fold: 7, Epoch: 12, Validation Accuracy= 85.30000
#
# Fold: 7, Epoch: 13, Mini Batch: 9, Loss= 2094.528076, Training Accuracy= 80.60000
#
# Fold: 7, Epoch: 13, Validation Accuracy= 85.30000
#
# Fold: 7, Epoch: 14, Mini Batch: 9, Loss= 2332.041260, Training Accuracy= 81.40000
#
# Fold: 7, Epoch: 14, Validation Accuracy= 86.00000
#
# Fold: 7, Epoch: 15, Mini Batch: 9, Loss= 1818.569580, Training Accuracy= 83.60000
#
# Fold: 7, Epoch: 15, Validation Accuracy= 85.90000
#
# Fold: 7, Epoch: 16, Mini Batch: 9, Loss= 1832.088623, Training Accuracy= 83.90000
#
# Fold: 7, Epoch: 16, Validation Accuracy= 85.20000
#
# Fold: 7, Epoch: 17, Mini Batch: 9, Loss= 1661.463623, Training Accuracy= 85.50000
#
# Fold: 7, Epoch: 17, Validation Accuracy= 84.90000
#
# Fold: 7, Epoch: 18, Mini Batch: 9, Loss= 1278.754150, Training Accuracy= 85.00000
#
# Fold: 7, Epoch: 18, Validation Accuracy= 84.90000
#
# Fold: 7, Epoch: 19, Mini Batch: 9, Loss= 1504.365356, Training Accuracy= 83.70000
#
# Fold: 7, Epoch: 19, Validation Accuracy= 84.70000
#
# Fold: 7, Epoch: 20, Mini Batch: 9, Loss= 1296.931519, Training Accuracy= 84.90000
#
# Fold: 7, Epoch: 20, Validation Accuracy= 85.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          424   73   497
# 1           76  427   503
# All        500  500  1000
#
# Fold: 7, Epoch: 21, Mini Batch: 9, Loss= 1115.715332, Training Accuracy= 86.40000
#
# Fold: 7, Epoch: 21, Validation Accuracy= 84.90000
#
# Fold: 7, Epoch: 22, Mini Batch: 9, Loss= 895.585144, Training Accuracy= 86.00000
#
# Fold: 7, Epoch: 22, Validation Accuracy= 86.30000
#
# Fold: 7, Epoch: 23, Mini Batch: 9, Loss= 1023.517212, Training Accuracy= 86.90000
#
# Fold: 7, Epoch: 23, Validation Accuracy= 85.70000
#
# Fold: 7, Epoch: 24, Mini Batch: 9, Loss= 722.911011, Training Accuracy= 88.20000
#
# Fold: 7, Epoch: 24, Validation Accuracy= 86.90000
#
# Fold: 7, Epoch: 25, Mini Batch: 9, Loss= 855.391479, Training Accuracy= 87.50000
#
# Fold: 7, Epoch: 25, Validation Accuracy= 85.40000
#
# Fold: 7, Epoch: 26, Mini Batch: 9, Loss= 779.006104, Training Accuracy= 88.20000
#
# Fold: 7, Epoch: 26, Validation Accuracy= 85.50000
#
# Fold: 7, Epoch: 27, Mini Batch: 9, Loss= 740.969727, Training Accuracy= 87.00000
#
# Fold: 7, Epoch: 27, Validation Accuracy= 85.50000
#
# Fold: 7, Epoch: 28, Mini Batch: 9, Loss= 719.928101, Training Accuracy= 87.90000
#
# Fold: 7, Epoch: 28, Validation Accuracy= 85.60000
#
# Fold: 7, Epoch: 29, Mini Batch: 9, Loss= 648.047241, Training Accuracy= 88.20000
#
# Fold: 7, Epoch: 29, Validation Accuracy= 84.70000
#
# Fold: 7, Epoch: 30, Mini Batch: 9, Loss= 737.167297, Training Accuracy= 87.60000
#
# Fold: 7, Epoch: 30, Validation Accuracy= 85.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          426   76   502
# 1           74  424   498
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 8, Epoch: 1, Mini Batch: 9, Loss= 24916.855469, Training Accuracy= 70.70000
#
# Fold: 8, Epoch: 1, Validation Accuracy= 81.90000
#
# Fold: 8, Epoch: 2, Mini Batch: 9, Loss= 11786.734375, Training Accuracy= 76.40000
#
# Fold: 8, Epoch: 2, Validation Accuracy= 85.60000
#
# Fold: 8, Epoch: 3, Mini Batch: 9, Loss= 8675.436523, Training Accuracy= 78.70000
#
# Fold: 8, Epoch: 3, Validation Accuracy= 83.90000
#
# Fold: 8, Epoch: 4, Mini Batch: 9, Loss= 6754.336914, Training Accuracy= 79.90000
#
# Fold: 8, Epoch: 4, Validation Accuracy= 84.80000
#
# Fold: 8, Epoch: 5, Mini Batch: 9, Loss= 4760.090332, Training Accuracy= 80.10000
#
# Fold: 8, Epoch: 5, Validation Accuracy= 87.30000
#
# Fold: 8, Epoch: 6, Mini Batch: 9, Loss= 4386.558105, Training Accuracy= 80.30000
#
# Fold: 8, Epoch: 6, Validation Accuracy= 87.50000
#
# Fold: 8, Epoch: 7, Mini Batch: 9, Loss= 4035.427002, Training Accuracy= 81.40000
#
# Fold: 8, Epoch: 7, Validation Accuracy= 87.10000
#
# Fold: 8, Epoch: 8, Mini Batch: 9, Loss= 3891.701416, Training Accuracy= 78.60000
#
# Fold: 8, Epoch: 8, Validation Accuracy= 87.30000
#
# Fold: 8, Epoch: 9, Mini Batch: 9, Loss= 2589.510986, Training Accuracy= 83.70000
#
# Fold: 8, Epoch: 9, Validation Accuracy= 87.30000
#
# Fold: 8, Epoch: 10, Mini Batch: 9, Loss= 2681.427979, Training Accuracy= 82.50000
#
# Fold: 8, Epoch: 10, Validation Accuracy= 87.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          421   48   469
# 1           79  452   531
# All        500  500  1000
#
# Fold: 8, Epoch: 11, Mini Batch: 9, Loss= 2588.584717, Training Accuracy= 84.40000
#
# Fold: 8, Epoch: 11, Validation Accuracy= 87.00000
#
# Fold: 8, Epoch: 12, Mini Batch: 9, Loss= 2038.078003, Training Accuracy= 82.90000
#
# Fold: 8, Epoch: 12, Validation Accuracy= 87.90000
#
# Fold: 8, Epoch: 13, Mini Batch: 9, Loss= 2133.419922, Training Accuracy= 81.60000
#
# Fold: 8, Epoch: 13, Validation Accuracy= 87.90000
#
# Fold: 8, Epoch: 14, Mini Batch: 9, Loss= 2008.552002, Training Accuracy= 82.60000
#
# Fold: 8, Epoch: 14, Validation Accuracy= 87.50000
#
# Fold: 8, Epoch: 15, Mini Batch: 9, Loss= 1758.791504, Training Accuracy= 82.00000
#
# Fold: 8, Epoch: 15, Validation Accuracy= 88.00000
#
# Fold: 8, Epoch: 16, Mini Batch: 9, Loss= 1654.120117, Training Accuracy= 83.50000
#
# Fold: 8, Epoch: 16, Validation Accuracy= 87.80000
#
# Fold: 8, Epoch: 17, Mini Batch: 9, Loss= 1655.917358, Training Accuracy= 84.60000
#
# Fold: 8, Epoch: 17, Validation Accuracy= 88.10000
#
# Fold: 8, Epoch: 18, Mini Batch: 9, Loss= 1261.827026, Training Accuracy= 85.80000
#
# Fold: 8, Epoch: 18, Validation Accuracy= 88.50000
#
# Fold: 8, Epoch: 19, Mini Batch: 9, Loss= 1391.609009, Training Accuracy= 84.10000
#
# Fold: 8, Epoch: 19, Validation Accuracy= 88.80000
#
# Fold: 8, Epoch: 20, Mini Batch: 9, Loss= 1254.978760, Training Accuracy= 85.10000
#
# Fold: 8, Epoch: 20, Validation Accuracy= 88.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          428   45   473
# 1           72  455   527
# All        500  500  1000
#
# Fold: 8, Epoch: 21, Mini Batch: 9, Loss= 1130.620972, Training Accuracy= 85.90000
#
# Fold: 8, Epoch: 21, Validation Accuracy= 88.00000
#
# Fold: 8, Epoch: 22, Mini Batch: 9, Loss= 948.964417, Training Accuracy= 85.70000
#
# Fold: 8, Epoch: 22, Validation Accuracy= 88.10000
#
# Fold: 8, Epoch: 23, Mini Batch: 9, Loss= 1093.348267, Training Accuracy= 86.00000
#
# Fold: 8, Epoch: 23, Validation Accuracy= 88.30000
#
# Fold: 8, Epoch: 24, Mini Batch: 9, Loss= 758.629456, Training Accuracy= 87.30000
#
# Fold: 8, Epoch: 24, Validation Accuracy= 89.00000
#
# Fold: 8, Epoch: 25, Mini Batch: 9, Loss= 819.353577, Training Accuracy= 86.60000
#
# Fold: 8, Epoch: 25, Validation Accuracy= 89.10000
#
# Fold: 8, Epoch: 26, Mini Batch: 9, Loss= 862.697510, Training Accuracy= 86.90000
#
# Fold: 8, Epoch: 26, Validation Accuracy= 88.20000
#
# Fold: 8, Epoch: 27, Mini Batch: 9, Loss= 766.276123, Training Accuracy= 86.90000
#
# Fold: 8, Epoch: 27, Validation Accuracy= 88.20000
#
# Fold: 8, Epoch: 28, Mini Batch: 9, Loss= 735.427490, Training Accuracy= 85.90000
#
# Fold: 8, Epoch: 28, Validation Accuracy= 88.40000
#
# Fold: 8, Epoch: 29, Mini Batch: 9, Loss= 688.009338, Training Accuracy= 87.40000
#
# Fold: 8, Epoch: 29, Validation Accuracy= 88.20000
#
# Fold: 8, Epoch: 30, Mini Batch: 9, Loss= 658.143799, Training Accuracy= 86.20000
#
# Fold: 8, Epoch: 30, Validation Accuracy= 89.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          444   54   498
# 1           56  446   502
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 9, Epoch: 1, Mini Batch: 9, Loss= 24450.648438, Training Accuracy= 70.80000
#
# Fold: 9, Epoch: 1, Validation Accuracy= 81.80000
#
# Fold: 9, Epoch: 2, Mini Batch: 9, Loss= 12021.835938, Training Accuracy= 76.00000
#
# Fold: 9, Epoch: 2, Validation Accuracy= 83.40000
#
# Fold: 9, Epoch: 3, Mini Batch: 9, Loss= 8598.860352, Training Accuracy= 77.00000
#
# Fold: 9, Epoch: 3, Validation Accuracy= 80.80000
#
# Fold: 9, Epoch: 4, Mini Batch: 9, Loss= 6556.538086, Training Accuracy= 79.50000
#
# Fold: 9, Epoch: 4, Validation Accuracy= 81.70000
#
# Fold: 9, Epoch: 5, Mini Batch: 9, Loss= 4648.779785, Training Accuracy= 81.10000
#
# Fold: 9, Epoch: 5, Validation Accuracy= 84.10000
#
# Fold: 9, Epoch: 6, Mini Batch: 9, Loss= 4551.126465, Training Accuracy= 81.30000
#
# Fold: 9, Epoch: 6, Validation Accuracy= 84.40000
#
# Fold: 9, Epoch: 7, Mini Batch: 9, Loss= 3976.683105, Training Accuracy= 82.30000
#
# Fold: 9, Epoch: 7, Validation Accuracy= 83.80000
#
# Fold: 9, Epoch: 8, Mini Batch: 9, Loss= 3696.663086, Training Accuracy= 81.20000
#
# Fold: 9, Epoch: 8, Validation Accuracy= 83.70000
#
# Fold: 9, Epoch: 9, Mini Batch: 9, Loss= 2692.669922, Training Accuracy= 81.90000
#
# Fold: 9, Epoch: 9, Validation Accuracy= 83.80000
#
# Fold: 9, Epoch: 10, Mini Batch: 9, Loss= 2807.232910, Training Accuracy= 82.40000
#
# Fold: 9, Epoch: 10, Validation Accuracy= 84.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          393   47   440
# 1          107  453   560
# All        500  500  1000
#
# Fold: 9, Epoch: 11, Mini Batch: 9, Loss= 2786.749023, Training Accuracy= 82.60000
#
# Fold: 9, Epoch: 11, Validation Accuracy= 85.20000
#
# Fold: 9, Epoch: 12, Mini Batch: 9, Loss= 2080.591553, Training Accuracy= 83.50000
#
# Fold: 9, Epoch: 12, Validation Accuracy= 84.60000
#
# Fold: 9, Epoch: 13, Mini Batch: 9, Loss= 1933.676758, Training Accuracy= 84.30000
#
# Fold: 9, Epoch: 13, Validation Accuracy= 85.40000
#
# Fold: 9, Epoch: 14, Mini Batch: 9, Loss= 2206.364502, Training Accuracy= 82.50000
#
# Fold: 9, Epoch: 14, Validation Accuracy= 84.40000
#
# Fold: 9, Epoch: 15, Mini Batch: 9, Loss= 1952.897827, Training Accuracy= 83.60000
#
# Fold: 9, Epoch: 15, Validation Accuracy= 84.70000
#
# Fold: 9, Epoch: 16, Mini Batch: 9, Loss= 1784.860229, Training Accuracy= 84.50000
#
# Fold: 9, Epoch: 16, Validation Accuracy= 84.50000
#
# Fold: 9, Epoch: 17, Mini Batch: 9, Loss= 1658.045532, Training Accuracy= 84.10000
#
# Fold: 9, Epoch: 17, Validation Accuracy= 85.40000
#
# Fold: 9, Epoch: 18, Mini Batch: 9, Loss= 1371.875000, Training Accuracy= 85.40000
#
# Fold: 9, Epoch: 18, Validation Accuracy= 85.30000
#
# Fold: 9, Epoch: 19, Mini Batch: 9, Loss= 1483.520264, Training Accuracy= 84.20000
#
# Fold: 9, Epoch: 19, Validation Accuracy= 85.40000
#
# Fold: 9, Epoch: 20, Mini Batch: 9, Loss= 1349.098511, Training Accuracy= 85.40000
#
# Fold: 9, Epoch: 20, Validation Accuracy= 85.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          397   46   443
# 1          103  454   557
# All        500  500  1000
#
# Fold: 9, Epoch: 21, Mini Batch: 9, Loss= 1219.230103, Training Accuracy= 86.20000
#
# Fold: 9, Epoch: 21, Validation Accuracy= 85.50000
#
# Fold: 9, Epoch: 22, Mini Batch: 9, Loss= 1000.913513, Training Accuracy= 86.30000
#
# Fold: 9, Epoch: 22, Validation Accuracy= 85.70000
#
# Fold: 9, Epoch: 23, Mini Batch: 9, Loss= 1055.762695, Training Accuracy= 85.90000
#
# Fold: 9, Epoch: 23, Validation Accuracy= 86.00000
#
# Fold: 9, Epoch: 24, Mini Batch: 9, Loss= 713.077087, Training Accuracy= 87.90000
#
# Fold: 9, Epoch: 24, Validation Accuracy= 85.30000
#
# Fold: 9, Epoch: 25, Mini Batch: 9, Loss= 874.580627, Training Accuracy= 85.90000
#
# Fold: 9, Epoch: 25, Validation Accuracy= 85.70000
#
# Fold: 9, Epoch: 26, Mini Batch: 9, Loss= 844.424805, Training Accuracy= 87.70000
#
# Fold: 9, Epoch: 26, Validation Accuracy= 84.90000
#
# Fold: 9, Epoch: 27, Mini Batch: 9, Loss= 733.566101, Training Accuracy= 87.20000
#
# Fold: 9, Epoch: 27, Validation Accuracy= 85.50000
#
# Fold: 9, Epoch: 28, Mini Batch: 9, Loss= 830.780396, Training Accuracy= 86.70000
#
# Fold: 9, Epoch: 28, Validation Accuracy= 85.20000
#
# Fold: 9, Epoch: 29, Mini Batch: 9, Loss= 708.944275, Training Accuracy= 87.50000
#
# Fold: 9, Epoch: 29, Validation Accuracy= 85.20000
#
# Fold: 9, Epoch: 30, Mini Batch: 9, Loss= 707.327209, Training Accuracy= 87.00000
#
# Fold: 9, Epoch: 30, Validation Accuracy= 85.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          427   73   500
# 1           73  427   500
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 10, Epoch: 1, Mini Batch: 9, Loss= 25194.660156, Training Accuracy= 68.70000
#
# Fold: 10, Epoch: 1, Validation Accuracy= 82.90000
#
# Fold: 10, Epoch: 2, Mini Batch: 9, Loss= 13688.876953, Training Accuracy= 75.00000
#
# Fold: 10, Epoch: 2, Validation Accuracy= 84.30000
#
# Fold: 10, Epoch: 3, Mini Batch: 9, Loss= 9556.711914, Training Accuracy= 77.30000
#
# Fold: 10, Epoch: 3, Validation Accuracy= 82.40000
#
# Fold: 10, Epoch: 4, Mini Batch: 9, Loss= 7099.956055, Training Accuracy= 79.70000
#
# Fold: 10, Epoch: 4, Validation Accuracy= 83.90000
#
# Fold: 10, Epoch: 5, Mini Batch: 9, Loss= 6048.191895, Training Accuracy= 78.20000
#
# Fold: 10, Epoch: 5, Validation Accuracy= 86.10000
#
# Fold: 10, Epoch: 6, Mini Batch: 9, Loss= 5009.492188, Training Accuracy= 81.30000
#
# Fold: 10, Epoch: 6, Validation Accuracy= 86.40000
#
# Fold: 10, Epoch: 7, Mini Batch: 9, Loss= 4599.375977, Training Accuracy= 79.20000
#
# Fold: 10, Epoch: 7, Validation Accuracy= 86.50000
#
# Fold: 10, Epoch: 8, Mini Batch: 9, Loss= 4677.488770, Training Accuracy= 78.90000
#
# Fold: 10, Epoch: 8, Validation Accuracy= 86.30000
#
# Fold: 10, Epoch: 9, Mini Batch: 9, Loss= 3381.956299, Training Accuracy= 80.80000
#
# Fold: 10, Epoch: 9, Validation Accuracy= 86.20000
#
# Fold: 10, Epoch: 10, Mini Batch: 9, Loss= 3002.190918, Training Accuracy= 81.10000
#
# Fold: 10, Epoch: 10, Validation Accuracy= 86.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          408   44   452
# 1           92  456   548
# All        500  500  1000
#
# Fold: 10, Epoch: 11, Mini Batch: 9, Loss= 3142.894287, Training Accuracy= 81.50000
#
# Fold: 10, Epoch: 11, Validation Accuracy= 86.40000
#
# Fold: 10, Epoch: 12, Mini Batch: 9, Loss= 2281.333984, Training Accuracy= 83.30000
#
# Fold: 10, Epoch: 12, Validation Accuracy= 87.10000
#
# Fold: 10, Epoch: 13, Mini Batch: 9, Loss= 2459.623535, Training Accuracy= 81.90000
#
# Fold: 10, Epoch: 13, Validation Accuracy= 87.10000
#
# Fold: 10, Epoch: 14, Mini Batch: 9, Loss= 2129.169434, Training Accuracy= 83.00000
#
# Fold: 10, Epoch: 14, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 15, Mini Batch: 9, Loss= 2008.143433, Training Accuracy= 83.50000
#
# Fold: 10, Epoch: 15, Validation Accuracy= 86.90000
#
# Fold: 10, Epoch: 16, Mini Batch: 9, Loss= 1957.056274, Training Accuracy= 83.50000
#
# Fold: 10, Epoch: 16, Validation Accuracy= 86.10000
#
# Fold: 10, Epoch: 17, Mini Batch: 9, Loss= 1782.543701, Training Accuracy= 83.90000
#
# Fold: 10, Epoch: 17, Validation Accuracy= 86.20000
#
# Fold: 10, Epoch: 18, Mini Batch: 9, Loss= 1660.394653, Training Accuracy= 83.80000
#
# Fold: 10, Epoch: 18, Validation Accuracy= 86.00000
#
# Fold: 10, Epoch: 19, Mini Batch: 9, Loss= 1807.370728, Training Accuracy= 81.80000
#
# Fold: 10, Epoch: 19, Validation Accuracy= 86.20000
#
# Fold: 10, Epoch: 20, Mini Batch: 9, Loss= 1396.323364, Training Accuracy= 84.50000
#
# Fold: 10, Epoch: 20, Validation Accuracy= 86.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   58   476
# 1           82  442   524
# All        500  500  1000
#
# Fold: 10, Epoch: 21, Mini Batch: 9, Loss= 1178.882568, Training Accuracy= 86.10000
#
# Fold: 10, Epoch: 21, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 22, Mini Batch: 9, Loss= 1105.723511, Training Accuracy= 85.70000
#
# Fold: 10, Epoch: 22, Validation Accuracy= 87.10000
#
# Fold: 10, Epoch: 23, Mini Batch: 9, Loss= 1123.668579, Training Accuracy= 85.20000
#
# Fold: 10, Epoch: 23, Validation Accuracy= 86.90000
#
# Fold: 10, Epoch: 24, Mini Batch: 9, Loss= 1035.341797, Training Accuracy= 86.00000
#
# Fold: 10, Epoch: 24, Validation Accuracy= 86.50000
#
# Fold: 10, Epoch: 25, Mini Batch: 9, Loss= 1017.624268, Training Accuracy= 85.20000
#
# Fold: 10, Epoch: 25, Validation Accuracy= 86.60000
#
# Fold: 10, Epoch: 26, Mini Batch: 9, Loss= 1003.340942, Training Accuracy= 86.30000
#
# Fold: 10, Epoch: 26, Validation Accuracy= 86.40000
#
# Fold: 10, Epoch: 27, Mini Batch: 9, Loss= 902.610168, Training Accuracy= 85.20000
#
# Fold: 10, Epoch: 27, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 28, Mini Batch: 9, Loss= 920.569763, Training Accuracy= 86.40000
#
# Fold: 10, Epoch: 28, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 29, Mini Batch: 9, Loss= 680.395142, Training Accuracy= 86.20000
#
# Fold: 10, Epoch: 29, Validation Accuracy= 86.50000
#
# Fold: 10, Epoch: 30, Mini Batch: 9, Loss= 698.791443, Training Accuracy= 87.80000
#
# Fold: 10, Epoch: 30, Validation Accuracy= 86.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          430   62   492
# 1           70  438   508
# All        500  500  1000
#
# ############*****************####################>>>>>>>>>>>>>>##############<<<<<<<<<<<<<<###############.................############
# The mean validation Accuracy is:  [[ 0.80000001  0.2       ]
#  [ 1.          0.        ]
#  [ 0.80000001  0.2       ]
#  ...,
#  [ 0.          1.        ]
#  [ 0.          1.        ]
#  [ 0.          1.        ]]

# %%
# self.seed = 2316
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 50
# self.batchSize = 1000


########  Best Till Now
# Fold: 1, Epoch: 50, Mini Batch: 9, Loss= 27.389086, Training Accuracy= 94.40000

# Fold: 1, Epoch: 50, Validation Accuracy= 88.20000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          437   55   492
# 1           63  445   508
# All        500  500  1000

# optimizer = tf.train.RMSPropOptimizer(learning_rate=0.001, momentum=0.8).minimize(lossCE)

# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.5
# hid1 = dropoutProb=0.5


ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# self.seed = 2316
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 50
# self.batchSize = 1000


# Fold: 1, Epoch: 50, Mini Batch: 9, Loss= 43.558125, Training Accuracy= 97.50000

# Fold: 1, Epoch: 50, Validation Accuracy= 88.30000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          452   69   521
# 1           48  431   479
# All        500  500  1000

# optimizer = tf.train.RMSPropOptimizer(learning_rate=0.0005, momentum=0.9).minimize(lossCE) 


ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 50
# self.batchSize = 1000


# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 249.902252, Training Accuracy= 92.40000

# Fold: 1, Epoch: 30, Validation Accuracy= 88.60000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          452   66   518
# 1           48  434   482
# All        500  500  1000

# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

# optimizer = tf.train.RMSPropOptimizer(learning_rate=0.0008, momentum=0.8).minimize(lossCE)

ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# learning_rate = 0.01
# momentum = 0.8


# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 249.902252, Training Accuracy= 92.40000

# Fold: 1, Epoch: 30, Validation Accuracy= 88.60000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          452   66   518
# 1           48  434   482
# All        500  500  1000

# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# learning_rate = 0.01
# momentum = 0.8


# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 131.296799, Training Accuracy= 94.40000

# Fold: 1, Epoch: 30, Validation Accuracy= 87.80000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          442   64   506
# 1           58  436   494
# All        500  500  1000

# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# learning_rate = 0.01
# momentum = 0.7


# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 332.687378, Training Accuracy= 91.20000

# Fold: 1, Epoch: 30, Validation Accuracy= 87.30000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          452   79   531
# 1           48  421   469
# All        500  500  1000

# hid1 = dropoutProb=0.5
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1024
# self.numHidden3 = 1024
# self.numLabels = 2
# self.momentum = 0.5        # Momentum for momentum Optimizer
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# learning_rate=0.001, momentum=0.8

# Fold: 1, Epoch: 30, Validation Accuracy= 86.90000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          446   77   523
# 1           54  423   477
# All        500  500  1000

# hid1 = dropoutProb=0.5
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75


ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with Adam Optimizer:

# Learning_rate = 0.001
# self.seed = 2316
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000


# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          425   55   480
# 1           75  445   520
# All        500  500  1000


# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

x = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with Adam Optimizer:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1024
# self.numHidden3 = 1024
# self.numLabels = 2
# self.alpha = 0.001          # Learning Rate 
# self.momentum = 0.9        # Momentum for momentum Optimizer
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# Fold: 1, Epoch: 30, Validation Accuracy= 87.70000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          421   44   465
# 1           79  456   535
# All        500  500  1000

# hid1 = dropoutProb=0.5
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75


ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer for LOGIT units:

# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1024
# self.numHidden3 = 1024
# self.numLabels = 2
# self.alpha = 0.001          # Learning Rate 
# self.momentum = 0.9        # Momentum for momentum Optimizer
# self.numFolds = 10
# self.dropout = 0.5

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# Fold: 1, Epoch: 30, Validation Accuracy= 83.10000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          359   28   387
# 1          141  472   613
# All        500  500  1000

# hid1 = dropoutProb=0.5
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75


ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Import Packages:
from __future__ import print_function

import os, sys
from six.moves import cPickle as pickle
from six.moves import range

# Model Packeges import
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import confusion_matrix

# Get the current working directory
cwd = os.getcwd()
mydir = os.path.abspath(os.path.join(cwd, ".."))
sys.path.append(mydir)
from DataGenerator import genTrainValidFolds

# %%
STDbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/STD/batchData/"
EDGbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/EDG/batchData/"
HOGp1batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp1/batchData/"   # dim =162
HOGp2batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp2/batchData/"   # dim =576
HOGp3batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp3/batchData/"

featureDIR = HOGp3batch_dir

# %%
# def toOneHotVector():
def reset_graph():  # Reset the graph
    if 'sess' in globals() and sess:
        sess.close()
    tf.reset_default_graph()
    
    
def reshape_data(dataset, labels, featureSize, numLabels, sample_size=None):
    if sample_size:
        dataset = dataset[:sample_size].reshape(sample_size, featureSize) # To reshape the  
        # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
        labels = (np.arange(numLabels) == labels[:,None]).astype(np.float32)
    else:
        dataset = dataset.reshape(len(dataset), featureSize) # To reshape the  
        # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
        labels = (np.arange(numLabels) == labels[:,None]).astype(np.float32)
    return dataset, labels


def accuracy(predictions, labels):
    # Both the predictions and the labels should be in One-Hot vector format.
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))/ predictions.shape[0])


def confusionMatrix(predictions, labels):
    # Both the predictions and the labels should be in One-Hot vector format.
    return (pd.crosstab(np.argmax(labels, 1), np.argmax(predictions, 1), rownames=['True'], colnames=['Predicted'], margins=True))

# %%
class GlabalVariables(object):
    
    def __init__(self):
        super(GlabalVariables, self).__init__()

        self.seed = 2316
        self.imageSize = 32
#         self.featureSize = 1098     # Note to change the featureSize when using a new Feature Set
        self.numHidden1 = 1024
        self.numHidden2 = 1024
        self.numHidden3 = 1024
        self.numLabels = 2
        self.alpha = 0.006          # Learning Rate 
#         self.beta = 0.001           # Penalty for regularization
        self.momentum = 0.9        # Momentum for momentum Optimizer
        self.numFolds = 10
        self.dropout = 0.5
        
        # Learning Variables     
        self.epochs = 60
        self.batchSize = 500

# %%
class BuildNeuralNet(GlabalVariables):
    
    def __init__(self, featureSize):
        super(BuildNeuralNet, self).__init__()
        
        self.featureSize = featureSize
        self.weights = {
            "inp_to_hid1_wght": tf.Variable(tf.random_normal([self.featureSize, self.numHidden1], seed=self.seed)),
            "hid1_to_hid2_wght" : tf.Variable(tf.random_normal([self.numHidden1, self.numHidden2], seed=self.seed)),
            "hid2_to_hid3_wght": tf.Variable(tf.random_normal([self.numHidden2, self.numHidden3], seed=self.seed)),
            "hid3_to_out_wght": tf.Variable(tf.random_normal([self.numHidden3, self.numLabels], seed=self.seed))
        }
        
        self.biases = {
            "hid1_bias": tf.Variable(tf.random_normal([self.numHidden1], seed=self.seed)),
            "hid2_bias": tf.Variable(tf.random_normal([self.numHidden2], seed=self.seed)),
            "hid3_bias": tf.Variable(tf.random_normal([self.numHidden3], seed=self.seed)),
            "out_bias": tf.Variable(tf.random_normal([self.numLabels], seed=self.seed))
        }
        
        
    def trainGraph(self, regularization=False):
        trainData = tf.placeholder(tf.float32, [None, self.featureSize])
        trainLabels = tf.placeholder(tf.float32, [None, self.numLabels])

        # 1st Hidden Layer State
        inp_to_hid1 = tf.matmul(trainData, self.weights['inp_to_hid1_wght']) + self.biases['hid1_bias']
#         hid1State = tf.sigmoid(inp_to_hid1)
        hid1State = tf.nn.relu(inp_to_hid1)
        hid1State = tf.nn.dropout(hid1State, self.dropout)
        
        # 2nd Hidden Layer State
        hid1_to_hid2 = tf.matmul(hid1State, self.weights['hid1_to_hid2_wght']) + self.biases['hid2_bias']
#         hid2State = tf.sigmoid(hid1_to_hid2)
        hid2State = tf.nn.relu(hid1_to_hid2)
        hid2State = tf.nn.dropout(hid2State, self.dropout)
        
        # 3nd Hidden Layer State
        hid2_to_hid3 = tf.matmul(hid2State, self.weights['hid2_to_hid3_wght']) + self.biases['hid3_bias']
#         hid3State = tf.sigmoid(hid2_to_hid3)
        hid3State = tf.nn.relu(hid2_to_hid3)
#         hid3State = tf.nn.dropout(hid3State, self.dropout)
        
        # Output Layer State
        hid3_to_out = tf.matmul(hid3State, self.weights['hid3_to_out_wght']) + self.biases['out_bias']
        outState = tf.nn.softmax(hid3_to_out)
        
        # Loss Function
        lossCE = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=hid3_to_out, labels=trainLabels))
        
        # Loss function using L2 Regularization
        if regularization:
            regularizers = (tf.nn.l2_loss(self.weights['inp_to_hid1_wght']) 
                            + tf.nn.l2_loss(self.weights['hid1_to_hid2_wght']) 
                            + tf.nn.l2_loss(self.weights['hid2_to_hid3_wght']) 
                            + tf.nn.l2_loss(self.weights['hid3_to_out_wght'])
                        )
            lossCE = tf.reduce_mean(lossCE + (self.beta * regularizers))
        
        # Optimizer
        optimizer = tf.train.AdamOptimizer(learning_rate=0.001).minimize(lossCE)
#         optimizer = tf.train.GradientDescentOptimizer(0.5).minimize(lossCE)
#         optimizer = tf.train.MomentumOptimizer(self.alpha, 
#                                             self.momentum, 
#                                             use_locking=False, 
#                                             name='Momentum', 
#                                             use_nesterov=True).minimize(lossCE)
#         optimizer = tf.train.AdagradOptimizer(learning_rate=0.04).minimize(lossCE)
#         optimizer = tf.train.RMSPropOptimizer(learning_rate=0.01, momentum=0.9).minimize(lossCE)   # This setting seems to be good
    
    
        
        # Evaluate model
#         trainPred = tf.equal(tf.argmax(outState, 1), tf.argmax(trainLabels, 1))
#         trainAccuracy = tf.reduce_mean(tf.cast(trainPred, tf.float32))
        
        return dict(
            trainData = trainData, 
            trainLabels = trainLabels,
            trainPred = outState,
            optimizer = optimizer,
            lossCE = lossCE
        )
    
    
    def validGraph(self):

        validData = tf.placeholder(tf.float32, [None, self.featureSize])
        validLabels = tf.placeholder(tf.float32, [None, self.numLabels])

        # 1st Hidden Layer State
        valid_hid1State = tf.sigmoid(tf.matmul(validData, self.weights['inp_to_hid1_wght']) + self.biases['hid1_bias'])

        # 2nd Hidden Layer State
        valid_hid2State = tf.sigmoid(tf.matmul(valid_hid1State, self.weights['hid1_to_hid2_wght']) + self.biases['hid2_bias'])

        # 3nd Hidden Layer State
        valid_hid3State = tf.sigmoid(tf.matmul(valid_hid2State, self.weights['hid2_to_hid3_wght']) + self.biases['hid3_bias'])

        # Output Layer State
        validOutState = tf.nn.softmax(tf.matmul(valid_hid3State, self.weights['hid3_to_out_wght']) + self.biases['out_bias'])

        return dict(
            validData = validData,
            validLabels = validLabels,
            validPred = validOutState
        )

# %%
class SessionExec(GlabalVariables):
    
    def __init__(self):
        super(SessionExec, self).__init__()
        
    def trainModel(self, trainDataIN, trainLabelsIN, sess):    
        numBatches = int(trainDataIN.shape[0]/self.batchSize)
        for numBatch in np.arange(numBatches):
            batchData = trainDataIN[numBatch*self.batchSize : (numBatch+1)*self.batchSize]
            batchLabels = trainLabelsIN[numBatch*self.batchSize : (numBatch+1)*self.batchSize]

            feed_dict = {self.trainGraphDict['trainData']: batchData,
                        self.trainGraphDict['trainLabels']: batchLabels
                        }

            _, loss, tpred = sess.run([self.trainGraphDict['optimizer'],
                                        self.trainGraphDict['lossCE'],
                                        self.trainGraphDict['trainPred']], feed_dict=feed_dict)
            
            if ((numBatch+1)%10 == 0) or ((numBatch+1) == numBatches): 
                tacc = accuracy(tpred, batchLabels)
                print ("Fold: " + str(self.foldNUM+1) + 
                       ", Epoch: " + str(self.epoch+1)+ 
                       ", Mini Batch: " + str(numBatch+1) + 
                       ", Loss= " + "{:.6f}".format(loss) + 
                       ", Training Accuracy= " + "{:.5f}".format(tacc))
    

    
    def validModel(self, validDataIN, validLabelsIN, sess):
#         print ('yyyyyytytytytytytytytytytytytytytytyty')
        feed_dict = {self.validGraphDict['validData']: validDataIN,
                     self.validGraphDict['validLabels']: validLabelsIN
                }

        vpred = sess.run(self.validGraphDict['validPred'], feed_dict=feed_dict)
        
        vacc = accuracy(vpred, validLabelsIN)
        print ("Fold: " + str(self.foldNUM+1) + 
                ", Epoch: " + str(self.epoch+1)+ 
                ", Validation Accuracy= " + "{:.5f}".format(vacc))
        
        return vpred 
        
        
    def execute(self):
        meanValidAcc = 0
        
        for foldNUM, (trainDataIN, trainLabelsIN, validDataIN, validLabelsIN, labelDict) in enumerate(genTrainValidFolds(featureDIR, oneHot=True)):   
            print ('')
            print ('##########################################################################################')

            print ('')
            print ('Validation Data and Labels shape: ', validDataIN.shape, validLabelsIN.shape)
            print ('Training Data and Labels shape: ', trainDataIN.shape, trainLabelsIN.shape)
            print ('The Label Dictionary is given as: ', labelDict)
            print ('')
            
            self.foldNUM = foldNUM

            reset_graph()

            # Create a object encapsulating the graph lineage
            objCNN = BuildNeuralNet(featureSize=trainDataIN.shape[1])
            self.trainGraphDict = objCNN.trainGraph()
            self.validGraphDict = objCNN.validGraph()
            
            with tf.Session() as sess:
                sess.run(tf.initialize_all_variables())

                for epoch in range(self.epochs): 
                    self.epoch = epoch
                    
                    # Train The model for Epochs
                    self.trainModel(trainDataIN, trainLabelsIN, sess)
                    print ('')

                    # Validate the model for Epochs
                    vpred = self.validModel(validDataIN, validLabelsIN, sess)
                    print ('')

                    if (epoch+1)%10 ==0:
                        validCM = confusionMatrix(validLabelsIN,vpred)
                        print ('Confusion Matrix CrossValid Set')
                        print (validCM)
                        print ('')
                    
            if foldNUM == 2:
                break

SessionExec().execute()
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1098) (1000, 2)
# Training Data and Labels shape:  (9000, 1098) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 1, Epoch: 1, Mini Batch: 10, Loss= 20027.324219, Training Accuracy= 60.80000
# Fold: 1, Epoch: 1, Mini Batch: 18, Loss= 13659.005859, Training Accuracy= 70.20000
#
# Fold: 1, Epoch: 1, Validation Accuracy= 50.80000
#
# Fold: 1, Epoch: 2, Mini Batch: 10, Loss= 11783.561523, Training Accuracy= 73.80000
# Fold: 1, Epoch: 2, Mini Batch: 18, Loss= 11499.842773, Training Accuracy= 75.20000
#
# Fold: 1, Epoch: 2, Validation Accuracy= 51.40000
#
# Fold: 1, Epoch: 3, Mini Batch: 10, Loss= 9190.345703, Training Accuracy= 76.00000
# Fold: 1, Epoch: 3, Mini Batch: 18, Loss= 8943.444336, Training Accuracy= 79.60000
#
# Fold: 1, Epoch: 3, Validation Accuracy= 50.90000
#
# Fold: 1, Epoch: 4, Mini Batch: 10, Loss= 7354.202148, Training Accuracy= 79.20000
# Fold: 1, Epoch: 4, Mini Batch: 18, Loss= 6812.782227, Training Accuracy= 78.20000
#
# Fold: 1, Epoch: 4, Validation Accuracy= 50.50000
#
# Fold: 1, Epoch: 5, Mini Batch: 10, Loss= 6425.373047, Training Accuracy= 81.40000
# Fold: 1, Epoch: 5, Mini Batch: 18, Loss= 6125.212402, Training Accuracy= 81.20000
#
# Fold: 1, Epoch: 5, Validation Accuracy= 50.80000
#
# Fold: 1, Epoch: 6, Mini Batch: 10, Loss= 7733.819824, Training Accuracy= 79.80000
# Fold: 1, Epoch: 6, Mini Batch: 18, Loss= 6522.002930, Training Accuracy= 80.00000
#
# Fold: 1, Epoch: 6, Validation Accuracy= 50.30000
#
# Fold: 1, Epoch: 7, Mini Batch: 10, Loss= 7605.980957, Training Accuracy= 77.80000
# Fold: 1, Epoch: 7, Mini Batch: 18, Loss= 5143.075684, Training Accuracy= 83.40000
#
# Fold: 1, Epoch: 7, Validation Accuracy= 52.10000
#
# Fold: 1, Epoch: 8, Mini Batch: 10, Loss= 5285.537109, Training Accuracy= 82.00000
# Fold: 1, Epoch: 8, Mini Batch: 18, Loss= 5469.371582, Training Accuracy= 81.00000
#
# Fold: 1, Epoch: 8, Validation Accuracy= 51.40000
#
# Fold: 1, Epoch: 9, Mini Batch: 10, Loss= 5269.674805, Training Accuracy= 79.80000
# Fold: 1, Epoch: 9, Mini Batch: 18, Loss= 4993.212891, Training Accuracy= 80.60000
#
# Fold: 1, Epoch: 9, Validation Accuracy= 51.60000
#
# Fold: 1, Epoch: 10, Mini Batch: 10, Loss= 5793.578125, Training Accuracy= 79.40000
# Fold: 1, Epoch: 10, Mini Batch: 18, Loss= 4460.520996, Training Accuracy= 83.60000
#
# Fold: 1, Epoch: 10, Validation Accuracy= 52.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          500  480   980
# 1            0   20    20
# All        500  500  1000
#
# Fold: 1, Epoch: 11, Mini Batch: 10, Loss= 5027.369629, Training Accuracy= 81.40000
# Fold: 1, Epoch: 11, Mini Batch: 18, Loss= 3805.794678, Training Accuracy= 81.80000
#
# Fold: 1, Epoch: 11, Validation Accuracy= 52.40000
#
# Fold: 1, Epoch: 12, Mini Batch: 10, Loss= 4588.150879, Training Accuracy= 83.20000
# Fold: 1, Epoch: 12, Mini Batch: 18, Loss= 4428.078613, Training Accuracy= 80.60000
#
# Fold: 1, Epoch: 12, Validation Accuracy= 53.30000
#
# Fold: 1, Epoch: 13, Mini Batch: 10, Loss= 4879.124512, Training Accuracy= 80.60000
# Fold: 1, Epoch: 13, Mini Batch: 18, Loss= 4232.903809, Training Accuracy= 84.40000
#
# Fold: 1, Epoch: 13, Validation Accuracy= 53.30000
#
# Fold: 1, Epoch: 14, Mini Batch: 10, Loss= 5631.880859, Training Accuracy= 80.40000
# Fold: 1, Epoch: 14, Mini Batch: 18, Loss= 3378.499023, Training Accuracy= 84.00000
#
# Fold: 1, Epoch: 14, Validation Accuracy= 52.40000
#
# Fold: 1, Epoch: 15, Mini Batch: 10, Loss= 3929.241699, Training Accuracy= 81.80000
# Fold: 1, Epoch: 15, Mini Batch: 18, Loss= 3428.327881, Training Accuracy= 83.60000
#
# Fold: 1, Epoch: 15, Validation Accuracy= 53.30000
#
# Fold: 1, Epoch: 16, Mini Batch: 10, Loss= 3302.159668, Training Accuracy= 85.20000
# Fold: 1, Epoch: 16, Mini Batch: 18, Loss= 3589.790771, Training Accuracy= 82.00000
#
# Fold: 1, Epoch: 16, Validation Accuracy= 54.30000
#
# Fold: 1, Epoch: 17, Mini Batch: 10, Loss= 3129.596924, Training Accuracy= 85.20000
# Fold: 1, Epoch: 17, Mini Batch: 18, Loss= 3138.724854, Training Accuracy= 82.20000
#
# Fold: 1, Epoch: 17, Validation Accuracy= 53.40000
#
# Fold: 1, Epoch: 18, Mini Batch: 10, Loss= 3326.083008, Training Accuracy= 85.00000
# Fold: 1, Epoch: 18, Mini Batch: 18, Loss= 3101.611084, Training Accuracy= 85.00000
#
# Fold: 1, Epoch: 18, Validation Accuracy= 53.60000
#
# Fold: 1, Epoch: 19, Mini Batch: 10, Loss= 3757.719482, Training Accuracy= 81.60000
# Fold: 1, Epoch: 19, Mini Batch: 18, Loss= 1851.955078, Training Accuracy= 87.20000
#
# Fold: 1, Epoch: 19, Validation Accuracy= 53.70000
#
# Fold: 1, Epoch: 20, Mini Batch: 10, Loss= 2535.063477, Training Accuracy= 84.40000
# Fold: 1, Epoch: 20, Mini Batch: 18, Loss= 2258.798584, Training Accuracy= 87.20000
#
# Fold: 1, Epoch: 20, Validation Accuracy= 55.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          500  449   949
# 1            0   51    51
# All        500  500  1000
#
# Fold: 1, Epoch: 21, Mini Batch: 10, Loss= 2777.844482, Training Accuracy= 83.60000
# Fold: 1, Epoch: 21, Mini Batch: 18, Loss= 2802.936035, Training Accuracy= 86.20000
#
# Fold: 1, Epoch: 21, Validation Accuracy= 54.30000
#
# Fold: 1, Epoch: 22, Mini Batch: 10, Loss= 3574.102051, Training Accuracy= 82.80000
# Fold: 1, Epoch: 22, Mini Batch: 18, Loss= 2975.568848, Training Accuracy= 83.60000
#
# Fold: 1, Epoch: 22, Validation Accuracy= 54.40000
#
# Fold: 1, Epoch: 23, Mini Batch: 10, Loss= 2945.733643, Training Accuracy= 81.40000
# Fold: 1, Epoch: 23, Mini Batch: 18, Loss= 2251.661133, Training Accuracy= 84.20000
#
# Fold: 1, Epoch: 23, Validation Accuracy= 53.40000
#
# Fold: 1, Epoch: 24, Mini Batch: 10, Loss= 2896.303223, Training Accuracy= 84.00000
# Fold: 1, Epoch: 24, Mini Batch: 18, Loss= 2290.305176, Training Accuracy= 84.40000
#
# Fold: 1, Epoch: 24, Validation Accuracy= 56.40000
#
# Fold: 1, Epoch: 25, Mini Batch: 10, Loss= 3040.500244, Training Accuracy= 83.20000
# Fold: 1, Epoch: 25, Mini Batch: 18, Loss= 2515.768066, Training Accuracy= 84.80000
#
# Fold: 1, Epoch: 25, Validation Accuracy= 56.70000
#
# Fold: 1, Epoch: 26, Mini Batch: 10, Loss= 2471.274414, Training Accuracy= 84.80000
# Fold: 1, Epoch: 26, Mini Batch: 18, Loss= 2595.113770, Training Accuracy= 85.40000
#
# Fold: 1, Epoch: 26, Validation Accuracy= 57.00000
#
# Fold: 1, Epoch: 27, Mini Batch: 10, Loss= 2764.666504, Training Accuracy= 84.80000
# Fold: 1, Epoch: 27, Mini Batch: 18, Loss= 2200.117432, Training Accuracy= 85.00000
#
# Fold: 1, Epoch: 27, Validation Accuracy= 58.80000
#
# Fold: 1, Epoch: 28, Mini Batch: 10, Loss= 2293.806641, Training Accuracy= 83.00000
# Fold: 1, Epoch: 28, Mini Batch: 18, Loss= 1915.241211, Training Accuracy= 84.80000
#
# Fold: 1, Epoch: 28, Validation Accuracy= 59.10000
#
# Fold: 1, Epoch: 29, Mini Batch: 10, Loss= 2438.720703, Training Accuracy= 85.80000
# Fold: 1, Epoch: 29, Mini Batch: 18, Loss= 1640.256714, Training Accuracy= 87.20000
#
# Fold: 1, Epoch: 29, Validation Accuracy= 62.00000
#
# Fold: 1, Epoch: 30, Mini Batch: 10, Loss= 2251.570312, Training Accuracy= 84.40000
# Fold: 1, Epoch: 30, Mini Batch: 18, Loss= 1719.034058, Training Accuracy= 87.20000
#
# Fold: 1, Epoch: 30, Validation Accuracy= 60.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          498  392   890
# 1            2  108   110
# All        500  500  1000
#
# Fold: 1, Epoch: 31, Mini Batch: 10, Loss= 2586.753906, Training Accuracy= 84.20000
# Fold: 1, Epoch: 31, Mini Batch: 18, Loss= 1448.765259, Training Accuracy= 85.40000
#
# Fold: 1, Epoch: 31, Validation Accuracy= 62.60000
#
# Fold: 1, Epoch: 32, Mini Batch: 10, Loss= 1791.683960, Training Accuracy= 85.80000
# Fold: 1, Epoch: 32, Mini Batch: 18, Loss= 1743.290771, Training Accuracy= 86.60000
#
# Fold: 1, Epoch: 32, Validation Accuracy= 60.90000
#
# Fold: 1, Epoch: 33, Mini Batch: 10, Loss= 2205.931396, Training Accuracy= 85.40000
# Fold: 1, Epoch: 33, Mini Batch: 18, Loss= 1696.567505, Training Accuracy= 86.40000
#
# Fold: 1, Epoch: 33, Validation Accuracy= 63.00000
#
# Fold: 1, Epoch: 34, Mini Batch: 10, Loss= 1862.277710, Training Accuracy= 87.20000
# Fold: 1, Epoch: 34, Mini Batch: 18, Loss= 1966.063965, Training Accuracy= 85.40000
#
# Fold: 1, Epoch: 34, Validation Accuracy= 61.70000
#
# Fold: 1, Epoch: 35, Mini Batch: 10, Loss= 1395.588501, Training Accuracy= 88.60000
# Fold: 1, Epoch: 35, Mini Batch: 18, Loss= 1506.969727, Training Accuracy= 87.60000
#
# Fold: 1, Epoch: 35, Validation Accuracy= 60.40000
#
# Fold: 1, Epoch: 36, Mini Batch: 10, Loss= 2080.080322, Training Accuracy= 87.00000
# Fold: 1, Epoch: 36, Mini Batch: 18, Loss= 1688.152832, Training Accuracy= 85.60000
#
# Fold: 1, Epoch: 36, Validation Accuracy= 61.60000
#
# Fold: 1, Epoch: 37, Mini Batch: 10, Loss= 1947.740845, Training Accuracy= 85.60000
# Fold: 1, Epoch: 37, Mini Batch: 18, Loss= 1515.240234, Training Accuracy= 88.80000
#
# Fold: 1, Epoch: 37, Validation Accuracy= 60.80000
#
# Fold: 1, Epoch: 38, Mini Batch: 10, Loss= 1813.576050, Training Accuracy= 86.80000
# Fold: 1, Epoch: 38, Mini Batch: 18, Loss= 1648.956665, Training Accuracy= 87.60000
#
# Fold: 1, Epoch: 38, Validation Accuracy= 59.50000
#
# Fold: 1, Epoch: 39, Mini Batch: 10, Loss= 1153.140015, Training Accuracy= 89.00000
# Fold: 1, Epoch: 39, Mini Batch: 18, Loss= 1184.066040, Training Accuracy= 90.40000
#
# Fold: 1, Epoch: 39, Validation Accuracy= 58.40000
#
# Fold: 1, Epoch: 40, Mini Batch: 10, Loss= 1415.399292, Training Accuracy= 88.00000
# Fold: 1, Epoch: 40, Mini Batch: 18, Loss= 1050.622803, Training Accuracy= 89.40000
#
# Fold: 1, Epoch: 40, Validation Accuracy= 60.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          495  394   889
# 1            5  106   111
# All        500  500  1000
#
# Fold: 1, Epoch: 41, Mini Batch: 10, Loss= 1847.150024, Training Accuracy= 85.60000
# Fold: 1, Epoch: 41, Mini Batch: 18, Loss= 1636.121460, Training Accuracy= 87.60000
#
# Fold: 1, Epoch: 41, Validation Accuracy= 60.30000
#
# Fold: 1, Epoch: 42, Mini Batch: 10, Loss= 1518.513672, Training Accuracy= 86.80000
# Fold: 1, Epoch: 42, Mini Batch: 18, Loss= 1098.412598, Training Accuracy= 88.40000
#
# Fold: 1, Epoch: 42, Validation Accuracy= 57.20000
#
# Fold: 1, Epoch: 43, Mini Batch: 10, Loss= 1714.363159, Training Accuracy= 87.60000
# Fold: 1, Epoch: 43, Mini Batch: 18, Loss= 1424.341675, Training Accuracy= 89.00000
#
# Fold: 1, Epoch: 43, Validation Accuracy= 58.30000
#
# Fold: 1, Epoch: 44, Mini Batch: 10, Loss= 1230.258911, Training Accuracy= 88.00000
# Fold: 1, Epoch: 44, Mini Batch: 18, Loss= 1341.573730, Training Accuracy= 88.00000
#
# Fold: 1, Epoch: 44, Validation Accuracy= 57.10000
#
# Fold: 1, Epoch: 45, Mini Batch: 10, Loss= 1715.374878, Training Accuracy= 86.40000
# Fold: 1, Epoch: 45, Mini Batch: 18, Loss= 1267.021729, Training Accuracy= 88.20000
#
# Fold: 1, Epoch: 45, Validation Accuracy= 57.40000
#
# Fold: 1, Epoch: 46, Mini Batch: 10, Loss= 1678.587280, Training Accuracy= 88.20000
# Fold: 1, Epoch: 46, Mini Batch: 18, Loss= 1118.172974, Training Accuracy= 89.60000
#
# Fold: 1, Epoch: 46, Validation Accuracy= 57.90000
#
# Fold: 1, Epoch: 47, Mini Batch: 10, Loss= 1213.682739, Training Accuracy= 88.00000
# Fold: 1, Epoch: 47, Mini Batch: 18, Loss= 1295.107056, Training Accuracy= 88.60000
#
# Fold: 1, Epoch: 47, Validation Accuracy= 59.00000
#
# Fold: 1, Epoch: 48, Mini Batch: 10, Loss= 1528.457031, Training Accuracy= 88.20000
# Fold: 1, Epoch: 48, Mini Batch: 18, Loss= 1228.871338, Training Accuracy= 89.40000
#
# Fold: 1, Epoch: 48, Validation Accuracy= 60.10000
#
# Fold: 1, Epoch: 49, Mini Batch: 10, Loss= 851.962769, Training Accuracy= 91.00000
# Fold: 1, Epoch: 49, Mini Batch: 18, Loss= 1104.852295, Training Accuracy= 88.00000
#
# Fold: 1, Epoch: 49, Validation Accuracy= 61.60000
#
# Fold: 1, Epoch: 50, Mini Batch: 10, Loss= 1046.061157, Training Accuracy= 88.40000
# Fold: 1, Epoch: 50, Mini Batch: 18, Loss= 984.580994, Training Accuracy= 89.60000
#
# Fold: 1, Epoch: 50, Validation Accuracy= 57.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          500  424   924
# 1            0   76    76
# All        500  500  1000
#
# Fold: 1, Epoch: 51, Mini Batch: 10, Loss= 1149.283447, Training Accuracy= 87.40000
# Fold: 1, Epoch: 51, Mini Batch: 18, Loss= 1126.532715, Training Accuracy= 86.80000
#
# Fold: 1, Epoch: 51, Validation Accuracy= 59.70000
#
# Fold: 1, Epoch: 52, Mini Batch: 10, Loss= 1433.460205, Training Accuracy= 86.80000
# Fold: 1, Epoch: 52, Mini Batch: 18, Loss= 1102.158691, Training Accuracy= 88.60000
#
# Fold: 1, Epoch: 52, Validation Accuracy= 62.50000
#
# Fold: 1, Epoch: 53, Mini Batch: 10, Loss= 1266.105469, Training Accuracy= 87.60000
# Fold: 1, Epoch: 53, Mini Batch: 18, Loss= 997.380249, Training Accuracy= 90.80000
#
# Fold: 1, Epoch: 53, Validation Accuracy= 62.80000
#
# Fold: 1, Epoch: 54, Mini Batch: 10, Loss= 1172.489746, Training Accuracy= 88.20000
# Fold: 1, Epoch: 54, Mini Batch: 18, Loss= 1011.285278, Training Accuracy= 89.00000
#
# Fold: 1, Epoch: 54, Validation Accuracy= 60.80000
#
# Fold: 1, Epoch: 55, Mini Batch: 10, Loss= 1053.139526, Training Accuracy= 89.40000
# Fold: 1, Epoch: 55, Mini Batch: 18, Loss= 948.298950, Training Accuracy= 88.00000
#
# Fold: 1, Epoch: 55, Validation Accuracy= 60.40000
#
# Fold: 1, Epoch: 56, Mini Batch: 10, Loss= 1095.131958, Training Accuracy= 89.60000
# Fold: 1, Epoch: 56, Mini Batch: 18, Loss= 885.350830, Training Accuracy= 90.80000
#
# Fold: 1, Epoch: 56, Validation Accuracy= 60.40000
#
# Fold: 1, Epoch: 57, Mini Batch: 10, Loss= 1452.494263, Training Accuracy= 88.20000
# Fold: 1, Epoch: 57, Mini Batch: 18, Loss= 815.006104, Training Accuracy= 90.60000
#
# Fold: 1, Epoch: 57, Validation Accuracy= 62.00000
#
# Fold: 1, Epoch: 58, Mini Batch: 10, Loss= 950.048096, Training Accuracy= 90.40000
# Fold: 1, Epoch: 58, Mini Batch: 18, Loss= 905.236633, Training Accuracy= 90.40000
#
# Fold: 1, Epoch: 58, Validation Accuracy= 61.50000
#
# Fold: 1, Epoch: 59, Mini Batch: 10, Loss= 866.098267, Training Accuracy= 89.80000
# Fold: 1, Epoch: 59, Mini Batch: 18, Loss= 745.288757, Training Accuracy= 90.60000
#
# Fold: 1, Epoch: 59, Validation Accuracy= 62.60000
#
# Fold: 1, Epoch: 60, Mini Batch: 10, Loss= 836.977600, Training Accuracy= 90.60000
# Fold: 1, Epoch: 60, Mini Batch: 18, Loss= 901.313660, Training Accuracy= 90.40000
#
# Fold: 1, Epoch: 60, Validation Accuracy= 61.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          490  373   863
# 1           10  127   137
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1098) (1000, 2)
# Training Data and Labels shape:  (9000, 1098) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 2, Epoch: 1, Mini Batch: 10, Loss= 20298.984375, Training Accuracy= 63.20000
# Fold: 2, Epoch: 1, Mini Batch: 18, Loss= 16536.638672, Training Accuracy= 67.80000
#
# Fold: 2, Epoch: 1, Validation Accuracy= 51.60000
#
# Fold: 2, Epoch: 2, Mini Batch: 10, Loss= 10592.718750, Training Accuracy= 73.60000
# Fold: 2, Epoch: 2, Mini Batch: 18, Loss= 11523.368164, Training Accuracy= 76.40000
#
# Fold: 2, Epoch: 2, Validation Accuracy= 52.20000
#
# Fold: 2, Epoch: 3, Mini Batch: 10, Loss= 10046.796875, Training Accuracy= 77.20000
# Fold: 2, Epoch: 3, Mini Batch: 18, Loss= 7440.471680, Training Accuracy= 80.60000
#
# Fold: 2, Epoch: 3, Validation Accuracy= 51.60000
#
# Fold: 2, Epoch: 4, Mini Batch: 10, Loss= 7341.116211, Training Accuracy= 78.00000
# Fold: 2, Epoch: 4, Mini Batch: 18, Loss= 7503.021973, Training Accuracy= 78.20000
#
# Fold: 2, Epoch: 4, Validation Accuracy= 50.80000
#
# Fold: 2, Epoch: 5, Mini Batch: 10, Loss= 6624.622070, Training Accuracy= 81.00000
# Fold: 2, Epoch: 5, Mini Batch: 18, Loss= 6545.206055, Training Accuracy= 79.60000
#
# Fold: 2, Epoch: 5, Validation Accuracy= 50.40000
#
# Fold: 2, Epoch: 6, Mini Batch: 10, Loss= 7515.725098, Training Accuracy= 77.80000
# Fold: 2, Epoch: 6, Mini Batch: 18, Loss= 7668.018066, Training Accuracy= 79.80000
#
# Fold: 2, Epoch: 6, Validation Accuracy= 50.80000
#
# Fold: 2, Epoch: 7, Mini Batch: 10, Loss= 7504.342285, Training Accuracy= 78.60000
# Fold: 2, Epoch: 7, Mini Batch: 18, Loss= 4698.831055, Training Accuracy= 80.60000
#
# Fold: 2, Epoch: 7, Validation Accuracy= 50.70000
#
# Fold: 2, Epoch: 8, Mini Batch: 10, Loss= 5587.791992, Training Accuracy= 80.80000
# Fold: 2, Epoch: 8, Mini Batch: 18, Loss= 5176.637207, Training Accuracy= 81.20000
#
# Fold: 2, Epoch: 8, Validation Accuracy= 51.20000
#
# Fold: 2, Epoch: 9, Mini Batch: 10, Loss= 5279.373047, Training Accuracy= 81.00000
# Fold: 2, Epoch: 9, Mini Batch: 18, Loss= 4607.440918, Training Accuracy= 82.00000
#
# Fold: 2, Epoch: 9, Validation Accuracy= 50.60000
#
# Fold: 2, Epoch: 10, Mini Batch: 10, Loss= 6003.482910, Training Accuracy= 81.00000
# Fold: 2, Epoch: 10, Mini Batch: 18, Loss= 4794.000977, Training Accuracy= 80.40000
#
# Fold: 2, Epoch: 10, Validation Accuracy= 50.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          500  492   992
# 1            0    8     8
# All        500  500  1000
#
# Fold: 2, Epoch: 11, Mini Batch: 10, Loss= 6072.078125, Training Accuracy= 79.20000
# Fold: 2, Epoch: 11, Mini Batch: 18, Loss= 4892.449707, Training Accuracy= 81.20000
#
# Fold: 2, Epoch: 11, Validation Accuracy= 51.30000
#
# Fold: 2, Epoch: 12, Mini Batch: 10, Loss= 5388.036133, Training Accuracy= 80.60000
# Fold: 2, Epoch: 12, Mini Batch: 18, Loss= 3699.417480, Training Accuracy= 81.00000
#
# Fold: 2, Epoch: 12, Validation Accuracy= 51.10000
#
# Fold: 2, Epoch: 13, Mini Batch: 10, Loss= 3926.136230, Training Accuracy= 83.80000
# Fold: 2, Epoch: 13, Mini Batch: 18, Loss= 4758.029785, Training Accuracy= 82.00000
#
# Fold: 2, Epoch: 13, Validation Accuracy= 52.10000
#
# Fold: 2, Epoch: 14, Mini Batch: 10, Loss= 3383.867432, Training Accuracy= 82.40000
# Fold: 2, Epoch: 14, Mini Batch: 18, Loss= 4638.272461, Training Accuracy= 80.40000
#
# Fold: 2, Epoch: 14, Validation Accuracy= 53.40000
#
# Fold: 2, Epoch: 15, Mini Batch: 10, Loss= 4107.702637, Training Accuracy= 82.00000
# Fold: 2, Epoch: 15, Mini Batch: 18, Loss= 3525.396484, Training Accuracy= 82.60000
#
# Fold: 2, Epoch: 15, Validation Accuracy= 53.60000
#
# Fold: 2, Epoch: 16, Mini Batch: 10, Loss= 4414.298828, Training Accuracy= 81.40000
# Fold: 2, Epoch: 16, Mini Batch: 18, Loss= 4306.372559, Training Accuracy= 81.60000
#
# Fold: 2, Epoch: 16, Validation Accuracy= 54.70000
#
# Fold: 2, Epoch: 17, Mini Batch: 10, Loss= 3747.545410, Training Accuracy= 82.40000
# Fold: 2, Epoch: 17, Mini Batch: 18, Loss= 3228.257080, Training Accuracy= 83.80000
#
# Fold: 2, Epoch: 17, Validation Accuracy= 54.10000
#
# Fold: 2, Epoch: 18, Mini Batch: 10, Loss= 3232.269531, Training Accuracy= 84.20000
# Fold: 2, Epoch: 18, Mini Batch: 18, Loss= 2945.624512, Training Accuracy= 84.00000
#
# Fold: 2, Epoch: 18, Validation Accuracy= 54.70000
#
# Fold: 2, Epoch: 19, Mini Batch: 10, Loss= 3516.569580, Training Accuracy= 83.40000
# Fold: 2, Epoch: 19, Mini Batch: 18, Loss= 3017.713379, Training Accuracy= 84.00000
#
# Fold: 2, Epoch: 19, Validation Accuracy= 55.00000
#
# Fold: 2, Epoch: 20, Mini Batch: 10, Loss= 3120.880859, Training Accuracy= 81.80000
# Fold: 2, Epoch: 20, Mini Batch: 18, Loss= 2621.482666, Training Accuracy= 83.20000
#
# Fold: 2, Epoch: 20, Validation Accuracy= 55.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          500  444   944
# 1            0   56    56
# All        500  500  1000
#
# Fold: 2, Epoch: 21, Mini Batch: 10, Loss= 2940.450928, Training Accuracy= 82.80000
# Fold: 2, Epoch: 21, Mini Batch: 18, Loss= 2497.821533, Training Accuracy= 84.80000
#
# Fold: 2, Epoch: 21, Validation Accuracy= 54.20000
#
# Fold: 2, Epoch: 22, Mini Batch: 10, Loss= 3011.355957, Training Accuracy= 82.60000
# Fold: 2, Epoch: 22, Mini Batch: 18, Loss= 2765.214355, Training Accuracy= 83.60000
#
# Fold: 2, Epoch: 22, Validation Accuracy= 55.50000
#
# Fold: 2, Epoch: 23, Mini Batch: 10, Loss= 2911.038086, Training Accuracy= 84.80000
# Fold: 2, Epoch: 23, Mini Batch: 18, Loss= 2361.403564, Training Accuracy= 83.20000
#
# Fold: 2, Epoch: 23, Validation Accuracy= 54.90000
#
# Fold: 2, Epoch: 24, Mini Batch: 10, Loss= 2785.143799, Training Accuracy= 85.40000
# Fold: 2, Epoch: 24, Mini Batch: 18, Loss= 2663.781738, Training Accuracy= 85.80000
#
# Fold: 2, Epoch: 24, Validation Accuracy= 56.00000
#
# Fold: 2, Epoch: 25, Mini Batch: 10, Loss= 2480.112549, Training Accuracy= 82.00000
# Fold: 2, Epoch: 25, Mini Batch: 18, Loss= 1913.343994, Training Accuracy= 85.60000
#
# Fold: 2, Epoch: 25, Validation Accuracy= 55.40000
#
# Fold: 2, Epoch: 26, Mini Batch: 10, Loss= 2992.227051, Training Accuracy= 83.40000
# Fold: 2, Epoch: 26, Mini Batch: 18, Loss= 2116.819580, Training Accuracy= 85.20000
#
# Fold: 2, Epoch: 26, Validation Accuracy= 56.40000
#
# Fold: 2, Epoch: 27, Mini Batch: 10, Loss= 2636.667969, Training Accuracy= 82.20000
# Fold: 2, Epoch: 27, Mini Batch: 18, Loss= 2642.538574, Training Accuracy= 83.80000
#
# Fold: 2, Epoch: 27, Validation Accuracy= 55.10000
#
# Fold: 2, Epoch: 28, Mini Batch: 10, Loss= 2843.553223, Training Accuracy= 83.40000
# Fold: 2, Epoch: 28, Mini Batch: 18, Loss= 1916.881592, Training Accuracy= 87.20000
#
# Fold: 2, Epoch: 28, Validation Accuracy= 56.60000
#
# Fold: 2, Epoch: 29, Mini Batch: 10, Loss= 2752.647461, Training Accuracy= 83.20000
# Fold: 2, Epoch: 29, Mini Batch: 18, Loss= 2023.077393, Training Accuracy= 86.20000
#
# Fold: 2, Epoch: 29, Validation Accuracy= 57.00000
#
# Fold: 2, Epoch: 30, Mini Batch: 10, Loss= 2290.650879, Training Accuracy= 85.00000
# Fold: 2, Epoch: 30, Mini Batch: 18, Loss= 1449.876343, Training Accuracy= 87.40000
#
# Fold: 2, Epoch: 30, Validation Accuracy= 55.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          499  440   939
# 1            1   60    61
# All        500  500  1000
#
# Fold: 2, Epoch: 31, Mini Batch: 10, Loss= 2044.762695, Training Accuracy= 86.20000
# Fold: 2, Epoch: 31, Mini Batch: 18, Loss= 1721.309082, Training Accuracy= 87.20000
#
# Fold: 2, Epoch: 31, Validation Accuracy= 55.80000
#
# Fold: 2, Epoch: 32, Mini Batch: 10, Loss= 1829.818726, Training Accuracy= 86.00000
# Fold: 2, Epoch: 32, Mini Batch: 18, Loss= 2168.179932, Training Accuracy= 82.40000
#
# Fold: 2, Epoch: 32, Validation Accuracy= 56.40000
#
# Fold: 2, Epoch: 33, Mini Batch: 10, Loss= 2109.225098, Training Accuracy= 84.40000
# Fold: 2, Epoch: 33, Mini Batch: 18, Loss= 1707.473633, Training Accuracy= 86.40000
#
# Fold: 2, Epoch: 33, Validation Accuracy= 55.50000
#
# Fold: 2, Epoch: 34, Mini Batch: 10, Loss= 2405.999023, Training Accuracy= 83.00000
# Fold: 2, Epoch: 34, Mini Batch: 18, Loss= 1641.819458, Training Accuracy= 87.40000
#
# Fold: 2, Epoch: 34, Validation Accuracy= 56.20000
#
# Fold: 2, Epoch: 35, Mini Batch: 10, Loss= 2262.069092, Training Accuracy= 85.80000
# Fold: 2, Epoch: 35, Mini Batch: 18, Loss= 1476.988770, Training Accuracy= 86.40000
#
# Fold: 2, Epoch: 35, Validation Accuracy= 56.50000
#
# Fold: 2, Epoch: 36, Mini Batch: 10, Loss= 1973.874512, Training Accuracy= 86.20000
# Fold: 2, Epoch: 36, Mini Batch: 18, Loss= 1380.265259, Training Accuracy= 87.60000
#
# Fold: 2, Epoch: 36, Validation Accuracy= 55.80000
#
# Fold: 2, Epoch: 37, Mini Batch: 10, Loss= 1873.206055, Training Accuracy= 87.20000
# Fold: 2, Epoch: 37, Mini Batch: 18, Loss= 1654.950806, Training Accuracy= 86.60000
#
# Fold: 2, Epoch: 37, Validation Accuracy= 58.70000
#
# Fold: 2, Epoch: 38, Mini Batch: 10, Loss= 2177.035889, Training Accuracy= 84.00000
# Fold: 2, Epoch: 38, Mini Batch: 18, Loss= 1388.944336, Training Accuracy= 86.80000
#
# Fold: 2, Epoch: 38, Validation Accuracy= 57.40000
#
# Fold: 2, Epoch: 39, Mini Batch: 10, Loss= 1792.703491, Training Accuracy= 86.80000
# Fold: 2, Epoch: 39, Mini Batch: 18, Loss= 1179.115479, Training Accuracy= 88.60000
#
# Fold: 2, Epoch: 39, Validation Accuracy= 58.10000
#
# Fold: 2, Epoch: 40, Mini Batch: 10, Loss= 1332.332520, Training Accuracy= 89.00000
# Fold: 2, Epoch: 40, Mini Batch: 18, Loss= 1217.531616, Training Accuracy= 88.60000
#
# Fold: 2, Epoch: 40, Validation Accuracy= 58.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          499  415   914
# 1            1   85    86
# All        500  500  1000
#
# Fold: 2, Epoch: 41, Mini Batch: 10, Loss= 1946.957397, Training Accuracy= 83.80000
# Fold: 2, Epoch: 41, Mini Batch: 18, Loss= 1296.350586, Training Accuracy= 87.80000
#
# Fold: 2, Epoch: 41, Validation Accuracy= 57.10000
#
# Fold: 2, Epoch: 42, Mini Batch: 10, Loss= 1210.432495, Training Accuracy= 88.60000
# Fold: 2, Epoch: 42, Mini Batch: 18, Loss= 1410.956909, Training Accuracy= 88.20000
#
# Fold: 2, Epoch: 42, Validation Accuracy= 59.40000
#
# Fold: 2, Epoch: 43, Mini Batch: 10, Loss= 1370.527466, Training Accuracy= 86.80000
# Fold: 2, Epoch: 43, Mini Batch: 18, Loss= 1257.865479, Training Accuracy= 87.40000
#
# Fold: 2, Epoch: 43, Validation Accuracy= 60.10000
#
# Fold: 2, Epoch: 44, Mini Batch: 10, Loss= 1618.492065, Training Accuracy= 85.40000
# Fold: 2, Epoch: 44, Mini Batch: 18, Loss= 878.627441, Training Accuracy= 90.40000
#
# Fold: 2, Epoch: 44, Validation Accuracy= 60.50000
#
# Fold: 2, Epoch: 45, Mini Batch: 10, Loss= 1582.071289, Training Accuracy= 88.40000
# Fold: 2, Epoch: 45, Mini Batch: 18, Loss= 930.022949, Training Accuracy= 91.00000
#
# Fold: 2, Epoch: 45, Validation Accuracy= 60.30000
#
# Fold: 2, Epoch: 46, Mini Batch: 10, Loss= 1236.311279, Training Accuracy= 88.60000
# Fold: 2, Epoch: 46, Mini Batch: 18, Loss= 1107.511597, Training Accuracy= 88.20000
#
# Fold: 2, Epoch: 46, Validation Accuracy= 59.70000
#
# Fold: 2, Epoch: 47, Mini Batch: 10, Loss= 1603.523926, Training Accuracy= 86.20000
# Fold: 2, Epoch: 47, Mini Batch: 18, Loss= 1339.227295, Training Accuracy= 88.20000
#
# Fold: 2, Epoch: 47, Validation Accuracy= 59.30000
#
# Fold: 2, Epoch: 48, Mini Batch: 10, Loss= 1186.048828, Training Accuracy= 87.80000
# Fold: 2, Epoch: 48, Mini Batch: 18, Loss= 902.757568, Training Accuracy= 88.60000
#
# Fold: 2, Epoch: 48, Validation Accuracy= 59.90000
#
# Fold: 2, Epoch: 49, Mini Batch: 10, Loss= 1239.751953, Training Accuracy= 88.00000
# Fold: 2, Epoch: 49, Mini Batch: 18, Loss= 889.149475, Training Accuracy= 89.80000
#
# Fold: 2, Epoch: 49, Validation Accuracy= 59.30000
#
# Fold: 2, Epoch: 50, Mini Batch: 10, Loss= 1043.727661, Training Accuracy= 88.00000
# Fold: 2, Epoch: 50, Mini Batch: 18, Loss= 1000.461121, Training Accuracy= 87.60000
#
# Fold: 2, Epoch: 50, Validation Accuracy= 60.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          498  393   891
# 1            2  107   109
# All        500  500  1000
#
# Fold: 2, Epoch: 51, Mini Batch: 10, Loss= 1023.434753, Training Accuracy= 89.40000
# Fold: 2, Epoch: 51, Mini Batch: 18, Loss= 905.413208, Training Accuracy= 89.60000
#
# Fold: 2, Epoch: 51, Validation Accuracy= 61.50000
#
# Fold: 2, Epoch: 52, Mini Batch: 10, Loss= 1015.570007, Training Accuracy= 88.80000
# Fold: 2, Epoch: 52, Mini Batch: 18, Loss= 1081.219971, Training Accuracy= 89.20000
#
# Fold: 2, Epoch: 52, Validation Accuracy= 61.40000
#
# Fold: 2, Epoch: 53, Mini Batch: 10, Loss= 1101.731201, Training Accuracy= 88.40000
# Fold: 2, Epoch: 53, Mini Batch: 18, Loss= 966.208618, Training Accuracy= 90.00000
#
# Fold: 2, Epoch: 53, Validation Accuracy= 59.50000
#
# Fold: 2, Epoch: 54, Mini Batch: 10, Loss= 1303.241699, Training Accuracy= 87.80000
# Fold: 2, Epoch: 54, Mini Batch: 18, Loss= 1081.175781, Training Accuracy= 90.20000
#
# Fold: 2, Epoch: 54, Validation Accuracy= 59.20000
#
# Fold: 2, Epoch: 55, Mini Batch: 10, Loss= 813.299255, Training Accuracy= 90.80000
# Fold: 2, Epoch: 55, Mini Batch: 18, Loss= 947.179138, Training Accuracy= 91.00000
#
# Fold: 2, Epoch: 55, Validation Accuracy= 61.60000
#
# Fold: 2, Epoch: 56, Mini Batch: 10, Loss= 1023.275146, Training Accuracy= 90.60000
# Fold: 2, Epoch: 56, Mini Batch: 18, Loss= 713.410400, Training Accuracy= 91.40000
#
# Fold: 2, Epoch: 56, Validation Accuracy= 60.80000
#
# Fold: 2, Epoch: 57, Mini Batch: 10, Loss= 1119.969482, Training Accuracy= 87.40000
# Fold: 2, Epoch: 57, Mini Batch: 18, Loss= 803.019226, Training Accuracy= 91.40000
#
# Fold: 2, Epoch: 57, Validation Accuracy= 61.80000
#
# Fold: 2, Epoch: 58, Mini Batch: 10, Loss= 1296.056030, Training Accuracy= 87.20000
# Fold: 2, Epoch: 58, Mini Batch: 18, Loss= 1127.209473, Training Accuracy= 89.80000
#
# Fold: 2, Epoch: 58, Validation Accuracy= 60.80000
#
# Fold: 2, Epoch: 59, Mini Batch: 10, Loss= 1161.058350, Training Accuracy= 88.40000
# Fold: 2, Epoch: 59, Mini Batch: 18, Loss= 673.975342, Training Accuracy= 90.80000
#
# Fold: 2, Epoch: 59, Validation Accuracy= 61.80000
#
# Fold: 2, Epoch: 60, Mini Batch: 10, Loss= 891.450684, Training Accuracy= 91.00000
# Fold: 2, Epoch: 60, Mini Batch: 18, Loss= 768.179810, Training Accuracy= 89.00000
#
# Fold: 2, Epoch: 60, Validation Accuracy= 62.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          496  375   871
# 1            4  125   129
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1098) (1000, 2)
# Training Data and Labels shape:  (9000, 1098) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 3, Epoch: 1, Mini Batch: 10, Loss= 18106.148438, Training Accuracy= 67.20000
# Fold: 3, Epoch: 1, Mini Batch: 18, Loss= 14470.068359, Training Accuracy= 71.20000
#
# Fold: 3, Epoch: 1, Validation Accuracy= 52.60000
#
# Fold: 3, Epoch: 2, Mini Batch: 10, Loss= 10673.798828, Training Accuracy= 76.00000
# Fold: 3, Epoch: 2, Mini Batch: 18, Loss= 11445.756836, Training Accuracy= 73.20000
#
# Fold: 3, Epoch: 2, Validation Accuracy= 52.40000
#
# Fold: 3, Epoch: 3, Mini Batch: 10, Loss= 9805.785156, Training Accuracy= 75.40000
# Fold: 3, Epoch: 3, Mini Batch: 18, Loss= 9916.185547, Training Accuracy= 76.40000
#
# Fold: 3, Epoch: 3, Validation Accuracy= 50.70000
#
# Fold: 3, Epoch: 4, Mini Batch: 10, Loss= 9008.199219, Training Accuracy= 77.20000
# Fold: 3, Epoch: 4, Mini Batch: 18, Loss= 7841.350586, Training Accuracy= 80.00000
#
# Fold: 3, Epoch: 4, Validation Accuracy= 50.30000
#
# Fold: 3, Epoch: 5, Mini Batch: 10, Loss= 7819.996094, Training Accuracy= 80.00000
# Fold: 3, Epoch: 5, Mini Batch: 18, Loss= 5737.651855, Training Accuracy= 83.40000
#
# Fold: 3, Epoch: 5, Validation Accuracy= 50.50000
#
# Fold: 3, Epoch: 6, Mini Batch: 10, Loss= 6728.192871, Training Accuracy= 81.00000
# Fold: 3, Epoch: 6, Mini Batch: 18, Loss= 5849.328125, Training Accuracy= 82.40000
#
# Fold: 3, Epoch: 6, Validation Accuracy= 50.30000
#
# Fold: 3, Epoch: 7, Mini Batch: 10, Loss= 6159.084473, Training Accuracy= 78.60000
# Fold: 3, Epoch: 7, Mini Batch: 18, Loss= 5756.428223, Training Accuracy= 80.40000
#
# Fold: 3, Epoch: 7, Validation Accuracy= 50.20000
#
# Fold: 3, Epoch: 8, Mini Batch: 10, Loss= 6401.763184, Training Accuracy= 78.40000
# Fold: 3, Epoch: 8, Mini Batch: 18, Loss= 5285.101562, Training Accuracy= 82.40000
#
# Fold: 3, Epoch: 8, Validation Accuracy= 50.40000
#
# Fold: 3, Epoch: 9, Mini Batch: 10, Loss= 4769.836914, Training Accuracy= 82.80000
# Fold: 3, Epoch: 9, Mini Batch: 18, Loss= 4885.568848, Training Accuracy= 83.40000
#
# Fold: 3, Epoch: 9, Validation Accuracy= 51.20000
#
# Fold: 3, Epoch: 10, Mini Batch: 10, Loss= 5091.338867, Training Accuracy= 80.00000
# Fold: 3, Epoch: 10, Mini Batch: 18, Loss= 4776.115723, Training Accuracy= 80.00000
#
# Fold: 3, Epoch: 10, Validation Accuracy= 52.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          500  479   979
# 1            0   21    21
# All        500  500  1000
#
# Fold: 3, Epoch: 11, Mini Batch: 10, Loss= 4317.285156, Training Accuracy= 82.20000
# Fold: 3, Epoch: 11, Mini Batch: 18, Loss= 3595.824463, Training Accuracy= 84.60000
#
# Fold: 3, Epoch: 11, Validation Accuracy= 52.10000
#
# Fold: 3, Epoch: 12, Mini Batch: 10, Loss= 3978.578613, Training Accuracy= 82.20000
# Fold: 3, Epoch: 12, Mini Batch: 18, Loss= 4143.244629, Training Accuracy= 82.40000
#
# Fold: 3, Epoch: 12, Validation Accuracy= 52.10000
#
# Fold: 3, Epoch: 13, Mini Batch: 10, Loss= 4317.430176, Training Accuracy= 82.20000
# Fold: 3, Epoch: 13, Mini Batch: 18, Loss= 3656.107422, Training Accuracy= 81.80000
#
# Fold: 3, Epoch: 13, Validation Accuracy= 52.90000
#
# Fold: 3, Epoch: 14, Mini Batch: 10, Loss= 4159.008789, Training Accuracy= 80.40000
# Fold: 3, Epoch: 14, Mini Batch: 18, Loss= 3636.709717, Training Accuracy= 82.60000
#
# Fold: 3, Epoch: 14, Validation Accuracy= 51.90000
#
# Fold: 3, Epoch: 15, Mini Batch: 10, Loss= 4272.899902, Training Accuracy= 81.00000
# Fold: 3, Epoch: 15, Mini Batch: 18, Loss= 3175.219971, Training Accuracy= 83.20000
#
# Fold: 3, Epoch: 15, Validation Accuracy= 53.40000
#
# Fold: 3, Epoch: 16, Mini Batch: 10, Loss= 3183.608643, Training Accuracy= 83.60000
# Fold: 3, Epoch: 16, Mini Batch: 18, Loss= 3324.079102, Training Accuracy= 83.60000
#
# Fold: 3, Epoch: 16, Validation Accuracy= 54.10000
#
# Fold: 3, Epoch: 17, Mini Batch: 10, Loss= 2907.406006, Training Accuracy= 85.60000
# Fold: 3, Epoch: 17, Mini Batch: 18, Loss= 3253.637695, Training Accuracy= 83.00000
#
# Fold: 3, Epoch: 17, Validation Accuracy= 54.20000
#
# Fold: 3, Epoch: 18, Mini Batch: 10, Loss= 3308.667480, Training Accuracy= 83.60000
# Fold: 3, Epoch: 18, Mini Batch: 18, Loss= 3070.182861, Training Accuracy= 83.40000
#
# Fold: 3, Epoch: 18, Validation Accuracy= 52.90000
#
# Fold: 3, Epoch: 19, Mini Batch: 10, Loss= 3074.202881, Training Accuracy= 83.60000
# Fold: 3, Epoch: 19, Mini Batch: 18, Loss= 2882.258545, Training Accuracy= 83.60000
#
# Fold: 3, Epoch: 19, Validation Accuracy= 55.00000
#
# Fold: 3, Epoch: 20, Mini Batch: 10, Loss= 3153.133057, Training Accuracy= 84.20000
# Fold: 3, Epoch: 20, Mini Batch: 18, Loss= 2422.598145, Training Accuracy= 84.80000
#
# Fold: 3, Epoch: 20, Validation Accuracy= 53.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          500  469   969
# 1            0   31    31
# All        500  500  1000
#
# Fold: 3, Epoch: 21, Mini Batch: 10, Loss= 3049.639404, Training Accuracy= 82.60000
# Fold: 3, Epoch: 21, Mini Batch: 18, Loss= 2768.943359, Training Accuracy= 82.60000
#
# Fold: 3, Epoch: 21, Validation Accuracy= 53.00000
#
# Fold: 3, Epoch: 22, Mini Batch: 10, Loss= 3344.927490, Training Accuracy= 81.20000
# Fold: 3, Epoch: 22, Mini Batch: 18, Loss= 2391.142578, Training Accuracy= 85.60000
#
# Fold: 3, Epoch: 22, Validation Accuracy= 53.10000
#
# Fold: 3, Epoch: 23, Mini Batch: 10, Loss= 3032.402344, Training Accuracy= 82.40000
# Fold: 3, Epoch: 23, Mini Batch: 18, Loss= 2683.756348, Training Accuracy= 85.20000
#
# Fold: 3, Epoch: 23, Validation Accuracy= 52.40000
#
# Fold: 3, Epoch: 24, Mini Batch: 10, Loss= 2634.781494, Training Accuracy= 83.80000
# Fold: 3, Epoch: 24, Mini Batch: 18, Loss= 2323.577881, Training Accuracy= 86.20000
#
# Fold: 3, Epoch: 24, Validation Accuracy= 53.10000
#
# Fold: 3, Epoch: 25, Mini Batch: 10, Loss= 2053.380371, Training Accuracy= 87.40000
# Fold: 3, Epoch: 25, Mini Batch: 18, Loss= 2111.201172, Training Accuracy= 85.60000
#
# Fold: 3, Epoch: 25, Validation Accuracy= 54.50000
#
# Fold: 3, Epoch: 26, Mini Batch: 10, Loss= 2569.162598, Training Accuracy= 82.40000
# Fold: 3, Epoch: 26, Mini Batch: 18, Loss= 2444.818115, Training Accuracy= 84.40000
#
# Fold: 3, Epoch: 26, Validation Accuracy= 54.30000
#
# Fold: 3, Epoch: 27, Mini Batch: 10, Loss= 2114.910645, Training Accuracy= 85.20000
# Fold: 3, Epoch: 27, Mini Batch: 18, Loss= 2073.854492, Training Accuracy= 85.60000
#
# Fold: 3, Epoch: 27, Validation Accuracy= 54.30000
#
# Fold: 3, Epoch: 28, Mini Batch: 10, Loss= 2095.510986, Training Accuracy= 85.40000
# Fold: 3, Epoch: 28, Mini Batch: 18, Loss= 1997.789307, Training Accuracy= 86.20000
#
# Fold: 3, Epoch: 28, Validation Accuracy= 55.60000
#
# Fold: 3, Epoch: 29, Mini Batch: 10, Loss= 1992.306030, Training Accuracy= 86.60000
# Fold: 3, Epoch: 29, Mini Batch: 18, Loss= 2091.965088, Training Accuracy= 85.40000
#
# Fold: 3, Epoch: 29, Validation Accuracy= 55.00000
#
# Fold: 3, Epoch: 30, Mini Batch: 10, Loss= 1976.137451, Training Accuracy= 85.80000
# Fold: 3, Epoch: 30, Mini Batch: 18, Loss= 1852.401855, Training Accuracy= 85.40000
#
# Fold: 3, Epoch: 30, Validation Accuracy= 56.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          497  431   928
# 1            3   69    72
# All        500  500  1000
#
# Fold: 3, Epoch: 31, Mini Batch: 10, Loss= 1970.083496, Training Accuracy= 86.60000
# Fold: 3, Epoch: 31, Mini Batch: 18, Loss= 2011.863770, Training Accuracy= 86.00000
#
# Fold: 3, Epoch: 31, Validation Accuracy= 55.10000
#
# Fold: 3, Epoch: 32, Mini Batch: 10, Loss= 1865.785522, Training Accuracy= 87.20000
# Fold: 3, Epoch: 32, Mini Batch: 18, Loss= 1618.970215, Training Accuracy= 87.20000
#
# Fold: 3, Epoch: 32, Validation Accuracy= 54.20000
#
# Fold: 3, Epoch: 33, Mini Batch: 10, Loss= 1997.984253, Training Accuracy= 85.80000
# Fold: 3, Epoch: 33, Mini Batch: 18, Loss= 1773.061157, Training Accuracy= 86.40000
#
# Fold: 3, Epoch: 33, Validation Accuracy= 58.20000
#
# Fold: 3, Epoch: 34, Mini Batch: 10, Loss= 1802.080444, Training Accuracy= 85.80000
# Fold: 3, Epoch: 34, Mini Batch: 18, Loss= 1634.702515, Training Accuracy= 87.60000
#
# Fold: 3, Epoch: 34, Validation Accuracy= 56.90000
#
# Fold: 3, Epoch: 35, Mini Batch: 10, Loss= 2188.218018, Training Accuracy= 85.80000
# Fold: 3, Epoch: 35, Mini Batch: 18, Loss= 1670.866699, Training Accuracy= 88.00000
#
# Fold: 3, Epoch: 35, Validation Accuracy= 56.90000
#
# Fold: 3, Epoch: 36, Mini Batch: 10, Loss= 2348.944580, Training Accuracy= 86.00000
# Fold: 3, Epoch: 36, Mini Batch: 18, Loss= 1371.503052, Training Accuracy= 89.20000
#
# Fold: 3, Epoch: 36, Validation Accuracy= 57.60000
#
# Fold: 3, Epoch: 37, Mini Batch: 10, Loss= 1431.426025, Training Accuracy= 88.60000
# Fold: 3, Epoch: 37, Mini Batch: 18, Loss= 1534.676025, Training Accuracy= 87.20000
#
# Fold: 3, Epoch: 37, Validation Accuracy= 56.50000
#
# Fold: 3, Epoch: 38, Mini Batch: 10, Loss= 1594.620483, Training Accuracy= 88.40000
# Fold: 3, Epoch: 38, Mini Batch: 18, Loss= 1490.238770, Training Accuracy= 87.80000
#
# Fold: 3, Epoch: 38, Validation Accuracy= 57.60000
#
# Fold: 3, Epoch: 39, Mini Batch: 10, Loss= 1589.874023, Training Accuracy= 86.20000
# Fold: 3, Epoch: 39, Mini Batch: 18, Loss= 1424.551025, Training Accuracy= 87.60000
#
# Fold: 3, Epoch: 39, Validation Accuracy= 57.80000
#
# Fold: 3, Epoch: 40, Mini Batch: 10, Loss= 1319.791260, Training Accuracy= 89.00000
# Fold: 3, Epoch: 40, Mini Batch: 18, Loss= 1290.286255, Training Accuracy= 88.00000
#
# Fold: 3, Epoch: 40, Validation Accuracy= 55.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          497  438   935
# 1            3   62    65
# All        500  500  1000
#
# Fold: 3, Epoch: 41, Mini Batch: 10, Loss= 1260.573120, Training Accuracy= 88.20000
# Fold: 3, Epoch: 41, Mini Batch: 18, Loss= 1332.937744, Training Accuracy= 88.40000
#
# Fold: 3, Epoch: 41, Validation Accuracy= 56.80000
#
# Fold: 3, Epoch: 42, Mini Batch: 10, Loss= 1206.819214, Training Accuracy= 87.80000
# Fold: 3, Epoch: 42, Mini Batch: 18, Loss= 1056.379028, Training Accuracy= 89.20000
#
# Fold: 3, Epoch: 42, Validation Accuracy= 58.50000
#
# Fold: 3, Epoch: 43, Mini Batch: 10, Loss= 1560.711182, Training Accuracy= 87.80000
# Fold: 3, Epoch: 43, Mini Batch: 18, Loss= 1096.575806, Training Accuracy= 89.40000
#
# Fold: 3, Epoch: 43, Validation Accuracy= 60.90000
#
# Fold: 3, Epoch: 44, Mini Batch: 10, Loss= 1542.325684, Training Accuracy= 87.20000
# Fold: 3, Epoch: 44, Mini Batch: 18, Loss= 1055.281494, Training Accuracy= 89.40000
#
# Fold: 3, Epoch: 44, Validation Accuracy= 61.60000
#
# Fold: 3, Epoch: 45, Mini Batch: 10, Loss= 1448.288574, Training Accuracy= 86.60000
# Fold: 3, Epoch: 45, Mini Batch: 18, Loss= 913.214111, Training Accuracy= 90.40000
#
# Fold: 3, Epoch: 45, Validation Accuracy= 60.20000
#
# Fold: 3, Epoch: 46, Mini Batch: 10, Loss= 1376.206299, Training Accuracy= 87.60000
# Fold: 3, Epoch: 46, Mini Batch: 18, Loss= 1165.557495, Training Accuracy= 88.60000
#
# Fold: 3, Epoch: 46, Validation Accuracy= 59.30000
#
# Fold: 3, Epoch: 47, Mini Batch: 10, Loss= 1702.718750, Training Accuracy= 86.00000
# Fold: 3, Epoch: 47, Mini Batch: 18, Loss= 1115.193237, Training Accuracy= 89.80000
#
# Fold: 3, Epoch: 47, Validation Accuracy= 60.10000
#
# Fold: 3, Epoch: 48, Mini Batch: 10, Loss= 1103.628784, Training Accuracy= 88.80000
# Fold: 3, Epoch: 48, Mini Batch: 18, Loss= 1081.357788, Training Accuracy= 87.80000
#
# Fold: 3, Epoch: 48, Validation Accuracy= 60.10000
#
# Fold: 3, Epoch: 49, Mini Batch: 10, Loss= 1313.216797, Training Accuracy= 87.00000
# Fold: 3, Epoch: 49, Mini Batch: 18, Loss= 1036.624023, Training Accuracy= 89.40000
#
# Fold: 3, Epoch: 49, Validation Accuracy= 58.70000
#
# Fold: 3, Epoch: 50, Mini Batch: 10, Loss= 1324.974976, Training Accuracy= 86.40000
# Fold: 3, Epoch: 50, Mini Batch: 18, Loss= 1022.890930, Training Accuracy= 90.20000
#
# Fold: 3, Epoch: 50, Validation Accuracy= 58.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          496  408   904
# 1            4   92    96
# All        500  500  1000
#
# Fold: 3, Epoch: 51, Mini Batch: 10, Loss= 1077.407227, Training Accuracy= 88.80000
# Fold: 3, Epoch: 51, Mini Batch: 18, Loss= 1060.914307, Training Accuracy= 90.20000
#
# Fold: 3, Epoch: 51, Validation Accuracy= 60.80000
#
# Fold: 3, Epoch: 52, Mini Batch: 10, Loss= 1092.608765, Training Accuracy= 89.20000
# Fold: 3, Epoch: 52, Mini Batch: 18, Loss= 1265.059326, Training Accuracy= 88.20000
#
# Fold: 3, Epoch: 52, Validation Accuracy= 63.90000
#
# Fold: 3, Epoch: 53, Mini Batch: 10, Loss= 1222.745361, Training Accuracy= 87.60000
# Fold: 3, Epoch: 53, Mini Batch: 18, Loss= 936.228760, Training Accuracy= 89.00000
#
# Fold: 3, Epoch: 53, Validation Accuracy= 61.80000
#
# Fold: 3, Epoch: 54, Mini Batch: 10, Loss= 1254.886597, Training Accuracy= 88.20000
# Fold: 3, Epoch: 54, Mini Batch: 18, Loss= 1019.657227, Training Accuracy= 89.60000
#
# Fold: 3, Epoch: 54, Validation Accuracy= 61.80000
#
# Fold: 3, Epoch: 55, Mini Batch: 10, Loss= 977.879944, Training Accuracy= 88.80000
# Fold: 3, Epoch: 55, Mini Batch: 18, Loss= 907.161194, Training Accuracy= 89.80000
#
# Fold: 3, Epoch: 55, Validation Accuracy= 60.50000
#
# Fold: 3, Epoch: 56, Mini Batch: 10, Loss= 970.827209, Training Accuracy= 89.60000
# Fold: 3, Epoch: 56, Mini Batch: 18, Loss= 677.580750, Training Accuracy= 90.40000
#
# Fold: 3, Epoch: 56, Validation Accuracy= 59.40000
#
# Fold: 3, Epoch: 57, Mini Batch: 10, Loss= 1051.850830, Training Accuracy= 89.40000
# Fold: 3, Epoch: 57, Mini Batch: 18, Loss= 740.756226, Training Accuracy= 93.00000
#
# Fold: 3, Epoch: 57, Validation Accuracy= 59.00000
#
# Fold: 3, Epoch: 58, Mini Batch: 10, Loss= 1221.040283, Training Accuracy= 89.60000
# Fold: 3, Epoch: 58, Mini Batch: 18, Loss= 1096.397949, Training Accuracy= 90.60000
#
# Fold: 3, Epoch: 58, Validation Accuracy= 57.50000
#
# Fold: 3, Epoch: 59, Mini Batch: 10, Loss= 1387.234741, Training Accuracy= 86.60000
# Fold: 3, Epoch: 59, Mini Batch: 18, Loss= 910.859497, Training Accuracy= 90.80000
#
# Fold: 3, Epoch: 59, Validation Accuracy= 57.60000
#
# Fold: 3, Epoch: 60, Mini Batch: 10, Loss= 818.478638, Training Accuracy= 91.60000
# Fold: 3, Epoch: 60, Mini Batch: 18, Loss= 1001.215515, Training Accuracy= 88.80000
#
# Fold: 3, Epoch: 60, Validation Accuracy= 57.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          494  417   911
# 1            6   83    89
# All        500  500  1000

# %%
# class SessionExec():
    
#     def __init__(self):
#         self.epochs = 30
        
#     def trainModel(self, trainDataIN, trainLabelsIN):
#         with tf.Session() as sess:
#             sess.run(tf.initialize_all_variables())

#             for epoch in range(self.epochs): 
#                 feed_dict = {self.trainGraphDict['trainData']: trainDataIN,
#                              self.trainGraphDict['trainLabels']: trainLabelsIN,
#                              self.trainGraphDict['keep_prob']: 0.7
#                         }

#                 if epoch == self.epochs-1:  # Capture the weights for the last iteration.
#                     print ('ENtering the last iteration.....', epoch)
#                     wLRND, bLRND, _, loss, tpred = sess.run([self.trainGraphDict['weightsLRND'],
#                                                 self.trainGraphDict['biasesLRND'],
#                                                 self.trainGraphDict['optimizer'],
#                                                 self.trainGraphDict['lossCE'],
#                                                 self.trainGraphDict['trainPred']], feed_dict=feed_dict)
#                 else:
#                     _, loss, tpred = sess.run([self.trainGraphDict['optimizer'], 
#                                                 self.trainGraphDict['lossCE'],
#                                                 self.trainGraphDict['trainPred']], feed_dict=feed_dict)

#                 if (epoch+1)%2 == 0 or epoch==self.epochs-1:
#                     # Evaluate training set
#                     tacc = accuracy(tpred, trainLabelsIN)
#                     print ("Fold: " + str(self.foldNUM+1) + ", Iter: " + str(epoch+1) + ", Loss= " + "{:.6f}".format(loss) + ", Training Accuracy= " + "{:.5f}".format(tacc))
    
# #             print (wLRND)
# #             print ('')
# #             print (bLRND)
#             return tpred, tacc, wLRND, bLRND

                
#     # After all epoch are over with, test the model with the cross validation set    
#     def validateModel(self, validDataIN, validLabelsIN):
#         with tf.Session() as sess:
#             sess.run(tf.initialize_all_variables())
            
#             feed_dict = {self.validGraphDict['validData']: validDataIN,
#                      self.validGraphDict['validLabels']: validLabelsIN
#                 }

#             vpred = sess.run(self.validGraphDict['validPred'], feed_dict=feed_dict)
            
#             # Evaluate corss-validation set
#             vacc = accuracy(vpred, validLabelsIN)
#             print ("Fold: " + str(self.foldNUM+1) + ", Cross Validation Accuracy= " + "{:.5f}".format(vacc))

#             print ('')
#             print ('')
            
#             return vpred, vacc 
        
    
    
#     def sumWghtBias(self, cmnDictIN, newDictIN):
#         for param, val_aray in newDictIN.items():
#             cmnDictIN[param] = np.add(val_aray, cmnDictIN[param])    
#         return cmnDictIN
            
        
#     def execute(self, updWghtBias=False):
#         meanValidAcc = 0
#         self.wLRND = {}
#         self.bLRND = {}
#         for foldNUM, (trainDataIN, trainLabelsIN, validDataIN, validLabelsIN, labelDict) in enumerate(genTrainValidFolds(featureDIR, oneHot=True)):
#             print ('')
#             print ('Validation Data and Labels shape: ', validDataIN.shape, validLabelsIN.shape)
#             print ('Training Data and Labels shape: ', trainDataIN.shape, trainLabelsIN.shape)
#             print ('The Label Dictionary is given as: ', labelDict)
#             self.foldNUM = foldNUM
            
#             reset_graph()
            
#             # Build a class Object
#             objNNET = BuildNeuralNet()
            
#             # Build the training Graph
#             self.trainGraphDict = objNNET.trainNet(regularization=False)
#             tpred, tacc, wLRND, bLRND = self.trainModel(trainDataIN, trainLabelsIN)
            
            
#             reset_graph()
            
#             # Add all the weights and biases received from each training fold
#             if updWghtBias:
#                 if not (self.wLRND and self.bLRND):
#                     self.wLRND = wLRND
#                     self.bLRND = bLRND
#                 else:
#                     self.wLRND = self.sumWghtBias(self.wLRND, wLRND)
#                     self.bLRND = self.sumWghtBias(self.bLRND, bLRND)

                    
#             self.validGraphDict = objNNET.crossValid(wLRND, bLRND)
#             vpred, vacc = self.validateModel(validDataIN, validLabelsIN)
            
#             trainCM = confusionMatrix(trainLabelsIN,tpred)
#             validCM = confusionMatrix(validLabelsIN,vpred)

#             meanValidAcc += vacc
#             print ('Confusion Matrix Training Set')
#             print (trainCM)
#             print ('')
#             print ('Confusion Matrix CrossValid Set')
#             print (validCM)
            
# #             if foldNUM ==2:
# #                 break
        
#         # Test the cross validation accuracy for the nth-fold when the weights are averaged 
#         # Find the average of all the weights and biases from the training folds and take their average
#         if updWghtBias:
#             wLRND = {k: v/(foldNUM+1) for k, v in self.wLRND.items()} 
#             bLRND = {k: v/(foldNUM+1) for k, v in self.bLRND.items()} 
#             self.validGraphDict = objNNET.crossValid(wLRND, bLRND)
#             vpred, vacc = self.validateModel(validDataIN, validLabelsIN)
#             print ("Fold: " + str(self.foldNUM+1) + ", Aveaged Weight Cross Validation Accuracy= " + "{:.5f}".format(vacc))
        
#         print ('')
#         print ('The Mean crossValidation Accuracy is: ', meanValidAcc/(foldNUM+1))
            
            
# SessionExec().execute(updWghtBias=False)




# # Running i is : 0
# # Validation Data and Labels shape:  (1000, 162) (1000, 2)
# # Training Data and Labels shape:  (9000, 162) (9000, 2)
# # The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
# # Fold: 1, Iter: 10, Loss= 1.603019, Training Accuracy= 0.79000
# # Fold: 1, Cross Validation Accuracy= 0.79200

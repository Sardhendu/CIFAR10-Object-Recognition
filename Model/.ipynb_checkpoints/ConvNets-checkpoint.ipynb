# %%
## Import Packages:
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import time
import os, sys
from six.moves import cPickle as pickle
from six.moves import range
from collections import defaultdict


# Model Packages import
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import confusion_matrix

# Get the current working directory
cwd = os.getcwd()
mydir = os.path.abspath(os.path.join(cwd, ".."))
sys.path.append(mydir)
from DataGenerator import genTrainValidFolds


# Packages for plot:
import matplotlib
from matplotlib import pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
def reset_graph():  # Reset the graph
    if 'sess' in globals() and sess:
        sess.close()
    tf.reset_default_graph()
    
    
def reshape_data(dataset, labels=None, imageSize=32, numChannels=1, sample_size=None):
    if sample_size:
        dataset = dataset[:sample_size].reshape((-1,imageSize,imageSize,numChannels)) # To reshape the
        # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
        if labels:
            numLabels = len(np.unique(labels))
            labels = (np.arange(numLabels) == labels[:,None]).astype(np.float32)
    else:
        dataset = dataset.reshape((-1,imageSize,imageSize,numChannels)) # To reshape the  
        # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
        if labels:
            numLabels = len(np.unique(labels))
            labels = (np.arange(numLabels) == labels[:,None]).astype(np.float32)
    return dataset, labels

def accuracy(predictions, labels):
    # Both the predictions and the labels should be in One-Hot vector format.
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))/ predictions.shape[0])


def confusionMatrix(predictions, labels):
    # Both the predictions and the labels should be in One-Hot vector format.
    return (pd.crosstab(np.argmax(labels, 1), np.argmax(predictions, 1), rownames=['True'], colnames=['Predicted'], margins=True))

# %% [markdown]
# # Build the Train, CrossValid and Test Graph:
# ---------
#
# The below modules build a simple convolutional neural network graph.

# %%
class BuildConvNet():
    
    def __init__(self, params):
        self.imageSize = params['imageSize']
        
        
        # NETWORK ARCHITECTURE PARAMETERS
        self.numLabels = params['numLabels']
        self.numChannels = params['numChannels']             # numChannels -> For grayscale =1, for RGB =3
        self.numHidden1 = params['numHidden1']               # numHiddenUnits for the fully connected layerr
        self.numHidden2 = params['numHidden2']               # numHiddenUnits for the fully connected layer

        self.conv1Kernel = params['conv1Kernel']             # Size of kernel for the first convolution layer
        self.conv2Kernel = params['conv2Kernel']             # Size of kernel for the second convolution layer
        self.conv1Depth = params['conv1Depth']               # Number of kernels for the first convolution layer
        self.conv2Depth = params['conv2Depth']               # Number of kernels for the second convolution layer
        self.conv1Stride = params['conv1Stride']             # Strides for the first convolution layer filter  
        self.conv2Stride = params['conv2Stride']             # Strides for the second convolution layer filter

        self.pool1Kernel = params['pool1Kernel']             # Size of kernel for the first Pooling layer
        self.pool2Kernel = params['pool2Kernel']             # Size of kernel for the second Pooling layer  
        self.pool1Stride = params['pool1Stride']             # Strides for the first Pooling layer filter
        self.pool2Stride = params['pool2Stride']             # Strides for the second Pooling layer filter
        
        # BATCH PARAMETERS
        self.epochs = params['epochs']
        self.numFolds = params['numFolds']
        self.batchSize = params['batchSize']
        
        # LEARNING PARAMETERS
        self.keepProb = params['keepProb']
        self.optimizerParam = params['optimizerParam']
        
        # WEIGHTS AND BIASES
        self.weights = {
            'cv1_wght': tf.Variable(tf.random_normal([self.conv1Kernel, self.conv1Kernel, self.numChannels, self.conv1Depth], seed=8753)),
            'cv2_wgth': tf.Variable(tf.random_normal([self.conv2Kernel, self.conv2Kernel, self.conv1Depth, self.conv2Depth], seed=3521)),
            'fc2_wght': tf.Variable(tf.random_normal([self.numHidden1, self.numHidden2], seed=9777)),
            'out_wght': tf.Variable(tf.random_normal([self.numHidden2, self.numLabels], seed=6467))
        }

        self.biases = {
            'cv1_bias': tf.Variable(tf.random_normal([self.conv1Depth], seed=8767)),
            'cv2_bias': tf.Variable(tf.random_normal([self.conv2Depth], seed=9887)),
            'fc1_bias': tf.Variable(tf.random_normal([self.numHidden1], seed=4323)),
            'fc2_bias': tf.Variable(tf.random_normal([self.numHidden2], seed=4348)),
            'out_bias': tf.Variable(tf.random_normal([self.numLabels], seed=9878))
        }


    def preprocessImageGraph(self):
        '''
            Normally the inputs have dtype unit8 (0-255), We however take the input as float32 because we perform 
            operations like brightness, contrast and whitening that doest arithmatic operation which many make the 
            pixels value as floating point.
        '''
        imageIN = tf.placeholder(tf.float32, [self.imageSize, self.imageSize, self.numChannels])

        # Crop a portion from the image
    #     distorted_image = tf.random_crop(distorted_image, [32, 32, 3])       # Given an image this operation will make a random crop of the image given the crop size

        # Flip the image
        distorted_image = tf.image.random_flip_left_right(imageIN)   # Given an image this operation may or may not flip the image
        # Add random brightness
        distorted_image = tf.image.random_brightness(distorted_image,max_delta=63)
        # Add random contrast
        distorted_image = tf.image.random_contrast(distorted_image,lower=0.2, upper=1.8)
        # Standarize: # Subtract off the mean and divide by the variance of the pixels.:
        distorted_image = tf.image.per_image_standardization(distorted_image)

        return dict(imageIN=imageIN,
                     distorted_image=distorted_image)
    

    def convLayer(self, x, w, b, s=1, nlModel='RELU'):
        x = tf.nn.conv2d(x, w, [1,s,s,1], padding='SAME') # Same padding
        x = tf.nn.bias_add(x, b)
        if nlModel == 'RELU':
            return tf.nn.relu(x)
        elif nlModel == 'LOGIT':
            return tf.sigmoid(x)


    def poolLayer(self, x, k=2, s=2, poolType='MAX'):
        if poolType=='MAX':
            return tf.nn.max_pool(x, ksize=[1,k,k,1], strides=[1,s,s,1], padding='SAME')
        elif poolType == 'AVG':
            return tf.nn.avg_pool(data, ksize=[1,k,k,1], strides=[1,s,s,1], padding='SAME')

        
    def fcLayer(self, x, w, b, keepProb=None, nModel='RELU'):
        x = tf.matmul(x, w) + b
        if nModel=='RELU':
            x = tf.nn.relu(x)
        if nModel=='LOGIT':
            x = tf.sigmoid(x)
        if keepProb:
            return tf.nn.dropout(x, keepProb, seed=6162)
        else:
            return x
        
        
    def outputLayer(self, x, w, b):
        x = tf.matmul(x, w) + b
        return x, tf.nn.softmax(x)
    
            
    # Convolutional Layer (Includes the convLayer and the max pool layer)
    def convFeatureExtractor(self, x):
        # Convolution and Pooling Layer 1
        conv1 = self.convLayer(x, self.weights['cv1_wght'], self.biases['cv1_bias'], s=self.conv1Stride)
        conv1 = self.poolLayer(conv1, k=self.pool1Kernel)

        # Convolution and Pooling Layer 2
        conv2 = self.convLayer(conv1, self.weights['cv2_wgth'], self.biases['cv2_bias'], self.conv2Stride)
        conv2 = self.poolLayer(conv2, k=self.pool2Kernel)
        
        # Get the features in flattened fashion
        poolShape = conv2.get_shape().as_list()[1]
        numConvFeatures = poolShape*poolShape*self.conv2Depth
        convFeatures = tf.reshape(conv2, [-1, numConvFeatures])
        
        return convFeatures, numConvFeatures
        
        
    # Create the training Graph Lineage
    def trainGraph(self):
        trainData = tf.placeholder(tf.float32, [None, self.imageSize, self.imageSize, self.numChannels])
        trainLabels = tf.placeholder(tf.float32, [None, self.numLabels])

        # Convolutional Layer
        convFeatures, numConvFeatures = self.convFeatureExtractor(trainData)
        
        # Fully connected layer : Reshape conv2 output to fit fully connected layer input
        self.weights['fc1_wght'] =  tf.Variable(tf.random_normal([numConvFeatures, self.numHidden1], seed=6663))
        fc1State = self.fcLayer(convFeatures, self.weights['fc1_wght'], self.biases['fc1_bias'], keepProb=self.keepProb['fc1'], nModel='RELU')  # = 0.5
        
        # Fully connected layer : Layer 2
        fc2State = self.fcLayer(fc1State, self.weights['fc2_wght'], self.biases['fc2_bias'], keepProb=self.keepProb['fc2'], nModel='RELU')  # 0.75

        # Output, or the Softmax layer
        pred, outputState = self.outputLayer(fc2State, self.weights['out_wght'], self.biases['out_bias'])
        
        # Loss function and Optimization
        lossCE = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=pred, labels=trainLabels))
        
        if self.optimizerParam['optimizer'] == 'ADAM':
            optimizer = tf.train.AdamOptimizer(learning_rate=self.optimizerParam['learning_rate']).minimize(lossCE)
        elif self.optimizerParam['optimizer'] == 'RMSPROP':
            optimizer = tf.train.RMSPropOptimizer(learning_rate=self.optimizerParam['learning_rate'], 
                                                  momentum=self.optimizerParam['momentum']).minimize(lossCE)  # 0.0006  # 0.8
        else:
            print ("Your provided optimizers do not match with any of the initialized optimizers: .........")
            return None

        
        return dict(
            trainData=trainData, 
            trainLabels=trainLabels, 
            optimizer=optimizer, 
            lossCE=lossCE,
            trainPred = outputState,
            wghtNew = self.weights
        )
    
    
    # Create the Validation Graph Lineage
    def validGraph(self):

        validData = tf.placeholder(tf.float32, [None, self.imageSize, self.imageSize, self.numChannels])
        validLabels = tf.placeholder(tf.float32, [None, self.numLabels])

        # Convolution and Pooling Layer 1
        vconvFeatures, numConvFeatures = self.convFeatureExtractor(validData)
        
        # Fully connected layer/Hidden Layer 2 : Reshape conv2 output to fit fully connected layer input
        vFc1State = self.fcLayer(vconvFeatures, self.weights['fc1_wght'], self.biases['fc1_bias'], nModel='RELU')
        
        # Fully connected layer/Hidden layer 2
        vFc2State = self.fcLayer(vFc1State, self.weights['fc2_wght'], self.biases['fc2_bias'], nModel='RELU')


        # Output Layer or the softmax layer
        vPred, vOutState = self.outputLayer(vFc2State, self.weights['out_wght'], self.biases['out_bias'])


        return dict(
            validData = validData,
            validLabels = validLabels,
            validPred = vOutState
        )

# %% [markdown]
# # Execute the Train, CrossValid and Test graph and evaluate Models:
# -------
# The below modules executes the graph given the input parameters and provides the training accuracy, validation accuracy and confusion matrix.

# %%
class SessionExec():
    
    def __init__(self, featureDIR, params):
        self.featureDIR = featureDIR
        
        self.numFolds = params['numFolds']
        self.epochs = params['epochs']
        self.batchSize = params['batchSize']
        self.imageSize = params['imageSize']
        self.numChannels = params['numChannels']
        
        self.prevWghtDict = {}
        self.validCMDict = {}
        self.wghtChngDict = defaultdict(list)
        self.meanValidAcc = 0
        self.loss_PerEpoch_PerFold = defaultdict(list)
        self.trainacc_PerEpoch_PerFold = defaultdict(list)
        self.validacc_PerEpoch_PerFold = defaultdict(list)
        
        
        
    def captureWghtChange(self, wghtDict):   
        for layer, wght_arr in wghtDict.items():
#             print (layer)
#             print (np.sum(np.abs(wght_arr-self.prevWghtDict[layer])))
#             print ('********************')
            self.wghtChngDict[layer].append(np.sum(np.abs(wght_arr-self.prevWghtDict[layer])))
    
    
    def preprocessImage(self, dataIN, sess):
        dataOut = np.ndarray(shape=(dataIN.shape[0],dataIN.shape[1],dataIN.shape[2],dataIN.shape[3]), dtype='float32')
        for numImage in np.arange(dataIN.shape[0]):
            feed_dict = {
                self.preprocessGraphDict['imageIN']:dataIN[numImage,:]
            }
            dataOut[numImage,:] = sess.run(self.preprocessGraphDict['distorted_image'],
                                                      feed_dict=feed_dict)
        return dataOut
    
    
    def trainModel(self, trainDataIN, trainLabelsIN, sess):    
        numBatches = int(trainDataIN.shape[0]/self.batchSize)
        for numBatch in np.arange(numBatches):
#                     print ('Batch no: ', numBatch)
#                     print (numBatch*self.batchSize,  (numBatch+1)*self.batchSize)
            batchData = trainDataIN[numBatch*self.batchSize : (numBatch+1)*self.batchSize]
            batchLabels = trainLabelsIN[numBatch*self.batchSize : (numBatch+1)*self.batchSize]

            feed_dict = {self.trainGraphDict['trainData']: batchData,
                         self.trainGraphDict['trainLabels']: batchLabels
#                              self.trainGraphDict['keep_prob']: 0.7
                    }

            _, loss, tpred, wght = sess.run([self.trainGraphDict['optimizer'],
                                        self.trainGraphDict['lossCE'],
                                        self.trainGraphDict['trainPred'],
                                        self.trainGraphDict['wghtNew']], feed_dict=feed_dict)
            
            if any(self.prevWghtDict):
                self.captureWghtChange(wght)
                self.prevWghtDict = wght
            else:
                self.prevWghtDict = wght
                
                
            if ((numBatch+1)%50 == 0) or ((numBatch+1) == numBatches): 
                tacc = accuracy(tpred, batchLabels)
                print ("Fold: " + str(self.foldNUM+1) + 
                       ", Epoch: " + str(self.epoch+1)+ 
                       ", Mini Batch: " + str(numBatch+1) + 
                       ", Loss= " + "{:.6f}".format(loss) + 
                       ", Training Accuracy= " + "{:.5f}".format(tacc))
    
        return loss, tacc
    
    
    def validModel(self, validDataIN, validLabelsIN, sess):
        feed_dict = {self.validGraphDict['validData']: validDataIN,
                     self.validGraphDict['validLabels']: validLabelsIN
#                              self.trainGraphDict['keep_prob']: 0.7
                }

        vpred = sess.run(self.validGraphDict['validPred'], feed_dict=feed_dict)
        
        vacc = accuracy(vpred, validLabelsIN)
        print ("Fold: " + str(self.foldNUM+1) + 
                ", Epoch: " + str(self.epoch+1) + 
                ", Validation Accuracy= " + "{:.5f}".format(vacc))
        
        return vpred, vacc 
        
        
    def execute(self, preprocess=None):
        meanValidAcc = 0
        
        for foldNUM, (trainDataIN, trainLabelsIN, validDataIN, validLabelsIN, labelDict) in enumerate(genTrainValidFolds(self.featureDIR, oneHot=True)):   
            print ('')
            print ('##########################################################################################')
            trainDataIN, _ = reshape_data(trainDataIN, imageSize=self.imageSize, numChannels=self.numChannels)                                       
            validDataIN, _ = reshape_data(validDataIN, imageSize=self.imageSize, numChannels=self.numChannels)
            
            print ('')
            print ('Validation Data and Labels shape: ', validDataIN.shape, validLabelsIN.shape)
            print ('Training Data and Labels shape: ', trainDataIN.shape, trainLabelsIN.shape)
            print ('The Label Dictionary is given as: ', labelDict)
            print ('')
            
            self.foldNUM = foldNUM

            reset_graph()

            # Create a object encapsulating the graph lineage
            objCNN = BuildConvNet(params)
            self.preprocessGraphDict = objCNN.preprocessImageGraph()
            self.trainGraphDict = objCNN.trainGraph()
            self.validGraphDict = objCNN.validGraph()
            
            with tf.Session() as sess:
                sess.run(tf.global_variables_initializer())

                for epoch in range(self.epochs): 
                    self.epoch = epoch
                    
                    # Preprocess The data;
                    if preprocess:
                        trainDataIN = self.preprocessImage(trainDataIN, sess)
                        validDataIN = self.preprocessImage(validDataIN, sess)
                        
#                     print ('The shape of the preprocessed train data is: ', trainDataIN.shape)
#                     print ('The shape of the preprocessed valid data is: ', trainDataIN.shape)
                    # Train The model for Epochs
                    loss, tacc = self.trainModel(trainDataIN, trainLabelsIN, sess)
                    print ('')
                    
                    # Validate the model for Epochs
                    vpred, vacc = self.validModel(validDataIN, validLabelsIN, sess)
                    print ('')
                    
                    self.loss_PerEpoch_PerFold[foldNUM+1].append(loss)
                    self.trainacc_PerEpoch_PerFold[foldNUM+1].append(tacc)
                    self.validacc_PerEpoch_PerFold[foldNUM+1].append(vacc)
                    
                    if (epoch+1)%10 ==0 or ((epoch+1) == self.epochs):
                        validCM = confusionMatrix(validLabelsIN,vpred)
                        print ('Confusion Matrix CrossValid Set')
                        print (validCM)
                        print ('')
            
            self.meanValidAcc += vacc
            self.validCMDict[foldNUM] = validCM
            
            if foldNUM == self.numFolds-1:
                break
                
        return (self.wghtChngDict, 
                self.meanValidAcc/self.numFolds, 
                self.loss_PerEpoch_PerFold, 
                self.trainacc_PerEpoch_PerFold, 
                self.validacc_PerEpoch_PerFold,
                self.validCMDict)

# %% [markdown]
# # Evaluate:
# -----

# %%
RGBbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/RGB/batchData/"
ZCAbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/ZCA/batchData/"
STDbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/STD/batchData/"
EDGbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/EDG/batchData/"
HOGp1batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/HOGp1/batchData/"   # dim =162
HOGp2batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/HOGp2/batchData/"   # dim =576
HOGp3batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/HOGp3/batchData/"
HOGp4batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/HOGp4/batchData/"

ZCAbatchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/augmented/ZCA/batchData/"
STDbatchAug_dir= "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/augmented/STD/batchData/"
EDGbatchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/augmented/EDG/batchData/"
HOGp1batchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/augmented/HOGp1/batchData/"
HOGp2batchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/augmented/HOGp2/batchData/"
HOGp3batchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/augmented/HOGp3/batchData/"
HOGp4batchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/featureModels/augmented/HOGp4/batchData/"

# %% [markdown]
# # RBG Image Feature and Preprocessing
# ------

# %%
def vizualize(validacc_dict, trainacc_dict, meanValidAcc, epochMeanValidAcc, rows, columns, figsize=(40,20), xlabels=None, ylabels=None, titles=None):
    fig1, axs = plt.subplots(rows, columns, figsize=figsize, facecolor='w', edgecolor='k')   # 
    axs = axs.ravel()
    numFolds = len(validacc_dict.keys())
    for foldNum in np.arange(numFolds):
        axs[foldNum].plot(validacc_dict[foldNum+1])
        axs[foldNum].plot(trainacc_dict[foldNum+1])
        axs[foldNum].axhline(y=meanValidAcc, color = 'k')
        axs[foldNum].axhline(y=epochMeanValidAcc, color = 'b')
        axs[foldNum].set_title('Validation/Training accuracy Fold:%s '%str(foldNum+1))
        axs[foldNum].legend(['validation acc', 'training acc', ['n-fold avg valid acc'], ['avg mean Epoch valid acc']], loc=4)
#         axs[foldNum].legend(['validation acc', 'training acc', ], loc=4)

# %% [markdown]
# ## CONV: | RBG | Preprocessed | Adam Optimizer | [5x5x64, 5x5x64], [1024x1024]
# -------

# %%
featureDIR = RGBbatch_dir

params = dict(imageSize = 32,
              seed = 2316,                 # Set the seeds for the random weights generator
              numFolds = 1,
              
              # Network Parameters
              numLabels = 2,
              numChannels = 3,             # numChannels -> For grayscale =1, for RGB =3
              numHidden1 = 1024,           # numHiddenUnits for the fully connected layerr
              numHidden2 = 1024,            # numHiddenUnits for the fully connected layer
              
              conv1Kernel = 5,             # Size of kernel for the first convolution layer
              conv2Kernel = 5,             # Size of kernel for the second convolution layer
              conv1Depth = 64,             # Number of kernels for the first convolution layer
              conv2Depth = 64,             # Number of kernels for the second convolution layer
              conv1Stride = 1,             # Strides for the first convolution layer filter  
              conv2Stride = 1,             # Strides for the second convolution layer filter
              
              pool1Kernel = 2,             # Size of kernel for the first Pooling layer
              pool2Kernel = 2,             # Size of kernel for the second Pooling layer  
              pool1Stride = 2,             # Strides for the first Pooling layer filter
              pool2Stride = 2,             # Strides for the second Pooling layer filter
              
              # Learning Variables     
              epochs = 20,
              batchSize = 128,
        
              keepProb = dict(fc1=0.5, fc2=0.5),
#               optimizerParam = dict(optimizer='RMSPROP', learning_rate=0.0008, momentum=0.8)
              optimizerParam = dict(optimizer='ADAM', learning_rate=0.0008)  # at 0.003 descents slowely, 
        )

# print (params)

(out, meanValidAcc, lossPerEpochPerFold, 
 taccPerEpochPerFold, vaccPerEpochPerFold, validCMDict) = SessionExec(featureDIR, params).execute(preprocess=True) 

print ('The mean Valid Accuracy per fold is : ', meanValidAcc)
for nfold in np.arange(params['numFolds']):
    print ('The mean Valid Accuracy based on epochs for the fold number (%s) is : '%str(nfold+1), np.mean(vaccPerEpochPerFold[nfold + 1]))
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 1, Mini Batch: 10, Loss= 5471080.000000, Training Accuracy= 63.28125
# Fold: 1, Epoch: 1, Mini Batch: 20, Loss= 4036292.750000, Training Accuracy= 67.96875
# Fold: 1, Epoch: 1, Mini Batch: 30, Loss= 3866766.750000, Training Accuracy= 67.18750
# Fold: 1, Epoch: 1, Mini Batch: 40, Loss= 3786496.000000, Training Accuracy= 71.09375
# Fold: 1, Epoch: 1, Mini Batch: 50, Loss= 2552095.000000, Training Accuracy= 76.56250
# Fold: 1, Epoch: 1, Mini Batch: 60, Loss= 1736281.250000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 1, Mini Batch: 70, Loss= 1563338.000000, Training Accuracy= 81.25000
#
# Fold: 1, Epoch: 1, Validation Accuracy= 84.90000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 2, Mini Batch: 10, Loss= 2157596.500000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 2, Mini Batch: 20, Loss= 2102666.750000, Training Accuracy= 75.78125
# Fold: 1, Epoch: 2, Mini Batch: 30, Loss= 1964973.250000, Training Accuracy= 75.00000
# Fold: 1, Epoch: 2, Mini Batch: 40, Loss= 1692778.500000, Training Accuracy= 74.21875
# Fold: 1, Epoch: 2, Mini Batch: 50, Loss= 1199429.250000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 2, Mini Batch: 60, Loss= 1461237.625000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 2, Mini Batch: 70, Loss= 921215.125000, Training Accuracy= 78.90625
#
# Fold: 1, Epoch: 2, Validation Accuracy= 86.90000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 3, Mini Batch: 10, Loss= 1295796.625000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 3, Mini Batch: 20, Loss= 1381105.500000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 3, Mini Batch: 30, Loss= 1057515.750000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 3, Mini Batch: 40, Loss= 935253.750000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 3, Mini Batch: 50, Loss= 879365.625000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 3, Mini Batch: 60, Loss= 1179566.750000, Training Accuracy= 75.78125
# Fold: 1, Epoch: 3, Mini Batch: 70, Loss= 390448.000000, Training Accuracy= 85.15625
#
# Fold: 1, Epoch: 3, Validation Accuracy= 86.90000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 4, Mini Batch: 10, Loss= 782204.375000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 4, Mini Batch: 20, Loss= 780099.500000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 4, Mini Batch: 30, Loss= 630266.125000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 4, Mini Batch: 40, Loss= 772643.250000, Training Accuracy= 78.12500
# Fold: 1, Epoch: 4, Mini Batch: 50, Loss= 678999.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 4, Mini Batch: 60, Loss= 836212.375000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 4, Mini Batch: 70, Loss= 585417.375000, Training Accuracy= 82.81250
#
# Fold: 1, Epoch: 4, Validation Accuracy= 87.30000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 5, Mini Batch: 10, Loss= 614771.625000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 5, Mini Batch: 20, Loss= 712416.500000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 5, Mini Batch: 30, Loss= 701322.000000, Training Accuracy= 76.56250
# Fold: 1, Epoch: 5, Mini Batch: 40, Loss= 1115738.750000, Training Accuracy= 75.00000
# Fold: 1, Epoch: 5, Mini Batch: 50, Loss= 697407.250000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 5, Mini Batch: 60, Loss= 410689.937500, Training Accuracy= 85.15625
# Fold: 1, Epoch: 5, Mini Batch: 70, Loss= 535245.625000, Training Accuracy= 81.25000
#
# Fold: 1, Epoch: 5, Validation Accuracy= 87.00000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 6, Mini Batch: 10, Loss= 654556.437500, Training Accuracy= 80.46875
# Fold: 1, Epoch: 6, Mini Batch: 20, Loss= 939046.250000, Training Accuracy= 75.00000
# Fold: 1, Epoch: 6, Mini Batch: 30, Loss= 630271.437500, Training Accuracy= 82.81250
# Fold: 1, Epoch: 6, Mini Batch: 40, Loss= 514448.250000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 6, Mini Batch: 50, Loss= 527234.500000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 6, Mini Batch: 60, Loss= 529587.125000, Training Accuracy= 74.21875
# Fold: 1, Epoch: 6, Mini Batch: 70, Loss= 437469.062500, Training Accuracy= 82.03125
#
# Fold: 1, Epoch: 6, Validation Accuracy= 88.10000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 7, Mini Batch: 10, Loss= 292130.843750, Training Accuracy= 84.37500
# Fold: 1, Epoch: 7, Mini Batch: 20, Loss= 434770.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 7, Mini Batch: 30, Loss= 356195.750000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 7, Mini Batch: 40, Loss= 452209.687500, Training Accuracy= 79.68750
# Fold: 1, Epoch: 7, Mini Batch: 50, Loss= 518990.687500, Training Accuracy= 73.43750
# Fold: 1, Epoch: 7, Mini Batch: 60, Loss= 491503.687500, Training Accuracy= 80.46875
# Fold: 1, Epoch: 7, Mini Batch: 70, Loss= 351555.031250, Training Accuracy= 82.03125
#
# Fold: 1, Epoch: 7, Validation Accuracy= 87.40000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 8, Mini Batch: 10, Loss= 339690.500000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 8, Mini Batch: 20, Loss= 372294.218750, Training Accuracy= 83.59375
# Fold: 1, Epoch: 8, Mini Batch: 30, Loss= 458631.375000, Training Accuracy= 76.56250
# Fold: 1, Epoch: 8, Mini Batch: 40, Loss= 477654.156250, Training Accuracy= 77.34375
# Fold: 1, Epoch: 8, Mini Batch: 50, Loss= 248650.765625, Training Accuracy= 86.71875
# Fold: 1, Epoch: 8, Mini Batch: 60, Loss= 336293.250000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 8, Mini Batch: 70, Loss= 405497.250000, Training Accuracy= 78.12500
#
# Fold: 1, Epoch: 8, Validation Accuracy= 87.60000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 9, Mini Batch: 10, Loss= 429197.093750, Training Accuracy= 83.59375
# Fold: 1, Epoch: 9, Mini Batch: 20, Loss= 275053.687500, Training Accuracy= 86.71875
# Fold: 1, Epoch: 9, Mini Batch: 30, Loss= 228970.906250, Training Accuracy= 87.50000
# Fold: 1, Epoch: 9, Mini Batch: 40, Loss= 313125.281250, Training Accuracy= 84.37500
# Fold: 1, Epoch: 9, Mini Batch: 50, Loss= 410920.062500, Training Accuracy= 76.56250
# Fold: 1, Epoch: 9, Mini Batch: 60, Loss= 322319.937500, Training Accuracy= 77.34375
# Fold: 1, Epoch: 9, Mini Batch: 70, Loss= 238805.531250, Training Accuracy= 79.68750
#
# Fold: 1, Epoch: 9, Validation Accuracy= 88.60000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 10, Mini Batch: 10, Loss= 221482.406250, Training Accuracy= 84.37500
# Fold: 1, Epoch: 10, Mini Batch: 20, Loss= 262382.468750, Training Accuracy= 81.25000
# Fold: 1, Epoch: 10, Mini Batch: 30, Loss= 307099.250000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 10, Mini Batch: 40, Loss= 358620.968750, Training Accuracy= 73.43750
# Fold: 1, Epoch: 10, Mini Batch: 50, Loss= 292190.625000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 10, Mini Batch: 60, Loss= 327408.625000, Training Accuracy= 76.56250
# Fold: 1, Epoch: 10, Mini Batch: 70, Loss= 185031.781250, Training Accuracy= 85.15625
#
# Fold: 1, Epoch: 10, Validation Accuracy= 88.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          415   32   447
# 1           85  468   553
# All        500  500  1000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 11, Mini Batch: 10, Loss= 221094.468750, Training Accuracy= 83.59375
# Fold: 1, Epoch: 11, Mini Batch: 20, Loss= 353482.062500, Training Accuracy= 78.90625
# Fold: 1, Epoch: 11, Mini Batch: 30, Loss= 284319.968750, Training Accuracy= 80.46875
# Fold: 1, Epoch: 11, Mini Batch: 40, Loss= 365773.062500, Training Accuracy= 73.43750
# Fold: 1, Epoch: 11, Mini Batch: 50, Loss= 201334.437500, Training Accuracy= 79.68750
# Fold: 1, Epoch: 11, Mini Batch: 60, Loss= 382660.687500, Training Accuracy= 72.65625
# Fold: 1, Epoch: 11, Mini Batch: 70, Loss= 257860.656250, Training Accuracy= 82.81250
#
# Fold: 1, Epoch: 11, Validation Accuracy= 87.30000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 12, Mini Batch: 10, Loss= 222321.281250, Training Accuracy= 82.81250
# Fold: 1, Epoch: 12, Mini Batch: 20, Loss= 309803.562500, Training Accuracy= 77.34375
# Fold: 1, Epoch: 12, Mini Batch: 30, Loss= 193030.406250, Training Accuracy= 82.81250
# Fold: 1, Epoch: 12, Mini Batch: 40, Loss= 239999.359375, Training Accuracy= 77.34375
# Fold: 1, Epoch: 12, Mini Batch: 50, Loss= 213406.328125, Training Accuracy= 77.34375
# Fold: 1, Epoch: 12, Mini Batch: 60, Loss= 285035.625000, Training Accuracy= 72.65625
# Fold: 1, Epoch: 12, Mini Batch: 70, Loss= 167942.046875, Training Accuracy= 78.12500
#
# Fold: 1, Epoch: 12, Validation Accuracy= 88.10000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 13, Mini Batch: 10, Loss= 109712.601562, Training Accuracy= 85.15625
# Fold: 1, Epoch: 13, Mini Batch: 20, Loss= 176344.203125, Training Accuracy= 80.46875
# Fold: 1, Epoch: 13, Mini Batch: 30, Loss= 296784.375000, Training Accuracy= 76.56250
# Fold: 1, Epoch: 13, Mini Batch: 40, Loss= 199278.500000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 13, Mini Batch: 50, Loss= 228248.750000, Training Accuracy= 73.43750
# Fold: 1, Epoch: 13, Mini Batch: 60, Loss= 222238.750000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 13, Mini Batch: 70, Loss= 179685.484375, Training Accuracy= 77.34375
#
# Fold: 1, Epoch: 13, Validation Accuracy= 87.50000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 14, Mini Batch: 10, Loss= 128466.734375, Training Accuracy= 82.81250
# Fold: 1, Epoch: 14, Mini Batch: 20, Loss= 209871.484375, Training Accuracy= 78.12500
# Fold: 1, Epoch: 14, Mini Batch: 30, Loss= 225665.625000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 14, Mini Batch: 40, Loss= 188925.062500, Training Accuracy= 79.68750
# Fold: 1, Epoch: 14, Mini Batch: 50, Loss= 193927.312500, Training Accuracy= 76.56250
# Fold: 1, Epoch: 14, Mini Batch: 60, Loss= 204450.828125, Training Accuracy= 80.46875
# Fold: 1, Epoch: 14, Mini Batch: 70, Loss= 134182.468750, Training Accuracy= 81.25000
#
# Fold: 1, Epoch: 14, Validation Accuracy= 87.50000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 15, Mini Batch: 10, Loss= 131477.156250, Training Accuracy= 83.59375
# Fold: 1, Epoch: 15, Mini Batch: 20, Loss= 198975.906250, Training Accuracy= 78.90625
# Fold: 1, Epoch: 15, Mini Batch: 30, Loss= 157011.046875, Training Accuracy= 80.46875
# Fold: 1, Epoch: 15, Mini Batch: 40, Loss= 144017.687500, Training Accuracy= 80.46875
# Fold: 1, Epoch: 15, Mini Batch: 50, Loss= 247848.593750, Training Accuracy= 72.65625
# Fold: 1, Epoch: 15, Mini Batch: 60, Loss= 116241.296875, Training Accuracy= 86.71875
# Fold: 1, Epoch: 15, Mini Batch: 70, Loss= 98349.187500, Training Accuracy= 84.37500
#
# Fold: 1, Epoch: 15, Validation Accuracy= 87.30000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 16, Mini Batch: 10, Loss= 144010.968750, Training Accuracy= 76.56250
# Fold: 1, Epoch: 16, Mini Batch: 20, Loss= 118942.382812, Training Accuracy= 82.03125
# Fold: 1, Epoch: 16, Mini Batch: 30, Loss= 142968.375000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 16, Mini Batch: 40, Loss= 119351.156250, Training Accuracy= 78.12500
# Fold: 1, Epoch: 16, Mini Batch: 50, Loss= 202193.250000, Training Accuracy= 75.78125
# Fold: 1, Epoch: 16, Mini Batch: 60, Loss= 139261.437500, Training Accuracy= 75.78125
# Fold: 1, Epoch: 16, Mini Batch: 70, Loss= 116229.250000, Training Accuracy= 85.15625
#
# Fold: 1, Epoch: 16, Validation Accuracy= 86.40000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 17, Mini Batch: 10, Loss= 142803.468750, Training Accuracy= 80.46875
# Fold: 1, Epoch: 17, Mini Batch: 20, Loss= 128513.671875, Training Accuracy= 80.46875
# Fold: 1, Epoch: 17, Mini Batch: 30, Loss= 142425.593750, Training Accuracy= 76.56250
# Fold: 1, Epoch: 17, Mini Batch: 40, Loss= 212386.500000, Training Accuracy= 71.09375
# Fold: 1, Epoch: 17, Mini Batch: 50, Loss= 116152.664062, Training Accuracy= 74.21875
# Fold: 1, Epoch: 17, Mini Batch: 60, Loss= 172173.843750, Training Accuracy= 78.12500
# Fold: 1, Epoch: 17, Mini Batch: 70, Loss= 135087.625000, Training Accuracy= 82.03125
#
# Fold: 1, Epoch: 17, Validation Accuracy= 86.80000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 18, Mini Batch: 10, Loss= 110836.796875, Training Accuracy= 82.81250
# Fold: 1, Epoch: 18, Mini Batch: 20, Loss= 146916.718750, Training Accuracy= 74.21875
# Fold: 1, Epoch: 18, Mini Batch: 30, Loss= 97218.875000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 18, Mini Batch: 40, Loss= 136270.687500, Training Accuracy= 74.21875
# Fold: 1, Epoch: 18, Mini Batch: 50, Loss= 100508.828125, Training Accuracy= 72.65625
# Fold: 1, Epoch: 18, Mini Batch: 60, Loss= 125403.734375, Training Accuracy= 76.56250
# Fold: 1, Epoch: 18, Mini Batch: 70, Loss= 118577.843750, Training Accuracy= 78.12500
#
# Fold: 1, Epoch: 18, Validation Accuracy= 86.80000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 19, Mini Batch: 10, Loss= 77515.718750, Training Accuracy= 81.25000
# Fold: 1, Epoch: 19, Mini Batch: 20, Loss= 123545.570312, Training Accuracy= 77.34375
# Fold: 1, Epoch: 19, Mini Batch: 30, Loss= 83691.765625, Training Accuracy= 78.12500
# Fold: 1, Epoch: 19, Mini Batch: 40, Loss= 150754.781250, Training Accuracy= 74.21875
# Fold: 1, Epoch: 19, Mini Batch: 50, Loss= 110823.789062, Training Accuracy= 75.00000
# Fold: 1, Epoch: 19, Mini Batch: 60, Loss= 117943.609375, Training Accuracy= 78.12500
# Fold: 1, Epoch: 19, Mini Batch: 70, Loss= 93885.546875, Training Accuracy= 75.78125
#
# Fold: 1, Epoch: 19, Validation Accuracy= 86.70000
#
# Thw shape of the preprocessed train data is:  (9000, 32, 32, 3)
# Thw shape of the preprocessed valid data is:  (9000, 32, 32, 3)
# Fold: 1, Epoch: 20, Mini Batch: 10, Loss= 48259.003906, Training Accuracy= 85.15625
# Fold: 1, Epoch: 20, Mini Batch: 20, Loss= 82554.968750, Training Accuracy= 77.34375
# Fold: 1, Epoch: 20, Mini Batch: 30, Loss= 88440.859375, Training Accuracy= 76.56250
# Fold: 1, Epoch: 20, Mini Batch: 40, Loss= 118125.187500, Training Accuracy= 77.34375
# Fold: 1, Epoch: 20, Mini Batch: 50, Loss= 88561.226562, Training Accuracy= 72.65625
# Fold: 1, Epoch: 20, Mini Batch: 60, Loss= 82004.140625, Training Accuracy= 78.90625
# Fold: 1, Epoch: 20, Mini Batch: 70, Loss= 102995.789062, Training Accuracy= 80.46875
#
# Fold: 1, Epoch: 20, Validation Accuracy= 86.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          408   44   452
# 1           92  456   548
# All        500  500  1000
#
# The mean Valid Accuracy is :  86.4

# %%
rows = 1
columns = 2
vizualize(vaccPerEpochPerFold, taccPerEpochPerFold, meanValidAcc=meanValidAcc, rows=rows, columns=columns, figsize=(5*columns, 5*rows))

# %% [markdown]
# ## CONV: | RGB | Preprocessed | Augmented | RMSPROP Optimizer | [5x5x64, 5x5x64], [1024x1024]
# -------

# %%
featureDIR = RGBbatch_dir

params = dict(imageSize = 32,
              seed = 2316,                 # Set the seeds for the random weights generator
              numFolds = 10,
              
              # Network Parameters
              numLabels = 2,
              numChannels = 3,             # numChannels -> For grayscale =1, for RGB =3
              numHidden1 = 1024,           # numHiddenUnits for the fully connected layerr
              numHidden2 = 1024,            # numHiddenUnits for the fully connected layer
              
              conv1Kernel = 5,             # Size of kernel for the first convolution layer
              conv2Kernel = 5,             # Size of kernel for the second convolution layer
              conv1Depth = 64,             # Number of kernels for the first convolution layer
              conv2Depth = 64,             # Number of kernels for the second convolution layer
              conv1Stride = 1,             # Strides for the first convolution layer filter  
              conv2Stride = 1,             # Strides for the second convolution layer filter
              
              pool1Kernel = 2,             # Size of kernel for the first Pooling layer
              pool2Kernel = 2,             # Size of kernel for the second Pooling layer  
              pool1Stride = 2,             # Strides for the first Pooling layer filter
              pool2Stride = 2,             # Strides for the second Pooling layer filter
              
              # Learning Variables     
              epochs = 20,
              batchSize = 128,
        
              keepProb = dict(fc1=0.5, fc2=0.5),
              optimizerParam = dict(optimizer='RMSPROP', learning_rate=0.0001, momentum=0.9)
#               optimizerParam = dict(optimizer='ADAM', learning_rate=0.003)  # at 0.003 descents slowely, 
        )

start_time = time.time()
(out, meanValidAcc, lossPerEpochPerFold, 
 taccPerEpochPerFold, vaccPerEpochPerFold, validCMDict) = SessionExec(featureDIR, params).execute() 

print("--- %s seconds " % (time.time() - start_time) + 
      '--- %s minutes' %str((time.time() - start_time)/60) + 
      '--- %s hours' %str((time.time() - start_time)/3600))

print ('The mean Valid Accuracy per fold is : ', meanValidAcc)
for nfold in np.arange(params['numFolds']):
    print ('The mean Valid Accuracy based on epochs for the fold number (%s) is : '%str(nfold+1), np.mean(vaccPerEpochPerFold[nfold + 1]))
    epochMeanValidAcc = np.mean(vaccPerEpochPerFold[nfold + 1])
    
## Total time taken : 2.572072856624921 hours
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 1, Epoch: 1, Mini Batch: 30, Loss= 398688736.000000, Training Accuracy= 68.75000
# Fold: 1, Epoch: 1, Mini Batch: 60, Loss= 188019968.000000, Training Accuracy= 75.78125
# Fold: 1, Epoch: 1, Mini Batch: 70, Loss= 165904480.000000, Training Accuracy= 72.65625
#
# Fold: 1, Epoch: 1, Validation Accuracy= 81.40000
#
# Fold: 1, Epoch: 2, Mini Batch: 30, Loss= 82510840.000000, Training Accuracy= 78.12500
# Fold: 1, Epoch: 2, Mini Batch: 60, Loss= 74756144.000000, Training Accuracy= 78.12500
# Fold: 1, Epoch: 2, Mini Batch: 70, Loss= 61374944.000000, Training Accuracy= 74.21875
#
# Fold: 1, Epoch: 2, Validation Accuracy= 85.70000
#
# Fold: 1, Epoch: 3, Mini Batch: 30, Loss= 69853720.000000, Training Accuracy= 78.12500
# Fold: 1, Epoch: 3, Mini Batch: 60, Loss= 33567136.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 3, Mini Batch: 70, Loss= 29779148.000000, Training Accuracy= 84.37500
#
# Fold: 1, Epoch: 3, Validation Accuracy= 87.30000
#
# Fold: 1, Epoch: 4, Mini Batch: 30, Loss= 42321828.000000, Training Accuracy= 78.12500
# Fold: 1, Epoch: 4, Mini Batch: 60, Loss= 44794992.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 4, Mini Batch: 70, Loss= 33567848.000000, Training Accuracy= 78.12500
#
# Fold: 1, Epoch: 4, Validation Accuracy= 88.40000
#
# Fold: 1, Epoch: 5, Mini Batch: 30, Loss= 24245432.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 5, Mini Batch: 60, Loss= 29702780.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 5, Mini Batch: 70, Loss= 27138856.000000, Training Accuracy= 77.34375
#
# Fold: 1, Epoch: 5, Validation Accuracy= 86.70000
#
# Fold: 1, Epoch: 6, Mini Batch: 30, Loss= 19980768.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 6, Mini Batch: 60, Loss= 17859278.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 6, Mini Batch: 70, Loss= 17234864.000000, Training Accuracy= 83.59375
#
# Fold: 1, Epoch: 6, Validation Accuracy= 89.10000
#
# Fold: 1, Epoch: 7, Mini Batch: 30, Loss= 8392032.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 7, Mini Batch: 60, Loss= 13150596.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 7, Mini Batch: 70, Loss= 8393642.000000, Training Accuracy= 86.71875
#
# Fold: 1, Epoch: 7, Validation Accuracy= 88.10000
#
# Fold: 1, Epoch: 8, Mini Batch: 30, Loss= 14349450.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 8, Mini Batch: 60, Loss= 14541633.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 8, Mini Batch: 70, Loss= 9854474.000000, Training Accuracy= 85.15625
#
# Fold: 1, Epoch: 8, Validation Accuracy= 89.80000
#
# Fold: 1, Epoch: 9, Mini Batch: 30, Loss= 11876539.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 9, Mini Batch: 60, Loss= 10348688.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 9, Mini Batch: 70, Loss= 10338765.000000, Training Accuracy= 82.81250
#
# Fold: 1, Epoch: 9, Validation Accuracy= 88.00000
#
# Fold: 1, Epoch: 10, Mini Batch: 30, Loss= 12357519.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 10, Mini Batch: 60, Loss= 8491266.000000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 10, Mini Batch: 70, Loss= 11122842.000000, Training Accuracy= 79.68750
#
# Fold: 1, Epoch: 10, Validation Accuracy= 88.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          415   26   441
# 1           85  474   559
# All        500  500  1000
#
# Fold: 1, Epoch: 11, Mini Batch: 30, Loss= 5371145.000000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 11, Mini Batch: 60, Loss= 12176815.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 11, Mini Batch: 70, Loss= 7434509.000000, Training Accuracy= 81.25000
#
# Fold: 1, Epoch: 11, Validation Accuracy= 88.80000
#
# Fold: 1, Epoch: 12, Mini Batch: 30, Loss= 6400836.500000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 12, Mini Batch: 60, Loss= 6651932.000000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 12, Mini Batch: 70, Loss= 6051674.500000, Training Accuracy= 86.71875
#
# Fold: 1, Epoch: 12, Validation Accuracy= 88.40000
#
# Fold: 1, Epoch: 13, Mini Batch: 30, Loss= 7112221.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 13, Mini Batch: 60, Loss= 7842425.000000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 13, Mini Batch: 70, Loss= 5629570.000000, Training Accuracy= 83.59375
#
# Fold: 1, Epoch: 13, Validation Accuracy= 89.20000
#
# Fold: 1, Epoch: 14, Mini Batch: 30, Loss= 5874072.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 14, Mini Batch: 60, Loss= 5421396.500000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 14, Mini Batch: 70, Loss= 6041016.000000, Training Accuracy= 88.28125
#
# Fold: 1, Epoch: 14, Validation Accuracy= 90.50000
#
# Fold: 1, Epoch: 15, Mini Batch: 30, Loss= 5438706.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 15, Mini Batch: 60, Loss= 5589606.500000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 15, Mini Batch: 70, Loss= 6148412.000000, Training Accuracy= 84.37500
#
# Fold: 1, Epoch: 15, Validation Accuracy= 90.20000
#
# Fold: 1, Epoch: 16, Mini Batch: 30, Loss= 4193835.250000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 16, Mini Batch: 60, Loss= 7286875.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 16, Mini Batch: 70, Loss= 8104485.000000, Training Accuracy= 82.81250
#
# Fold: 1, Epoch: 16, Validation Accuracy= 89.80000
#
# Fold: 1, Epoch: 17, Mini Batch: 30, Loss= 2817024.500000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 17, Mini Batch: 60, Loss= 5788571.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 17, Mini Batch: 70, Loss= 4224423.000000, Training Accuracy= 86.71875
#
# Fold: 1, Epoch: 17, Validation Accuracy= 89.70000
#
# Fold: 1, Epoch: 18, Mini Batch: 30, Loss= 4414302.000000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 18, Mini Batch: 60, Loss= 6434843.000000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 18, Mini Batch: 70, Loss= 5508493.000000, Training Accuracy= 88.28125
#
# Fold: 1, Epoch: 18, Validation Accuracy= 89.70000
#
# Fold: 1, Epoch: 19, Mini Batch: 30, Loss= 3670813.500000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 19, Mini Batch: 60, Loss= 5266908.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 19, Mini Batch: 70, Loss= 2570144.000000, Training Accuracy= 87.50000
#
# Fold: 1, Epoch: 19, Validation Accuracy= 90.50000
#
# Fold: 1, Epoch: 20, Mini Batch: 30, Loss= 1845886.750000, Training Accuracy= 90.62500
# Fold: 1, Epoch: 20, Mini Batch: 60, Loss= 6044000.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 20, Mini Batch: 70, Loss= 4836751.000000, Training Accuracy= 86.71875
#
# Fold: 1, Epoch: 20, Validation Accuracy= 90.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          454   45   499
# 1           46  455   501
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 2, Epoch: 1, Mini Batch: 30, Loss= 364371648.000000, Training Accuracy= 65.62500
# Fold: 2, Epoch: 1, Mini Batch: 60, Loss= 183720896.000000, Training Accuracy= 75.00000
# Fold: 2, Epoch: 1, Mini Batch: 70, Loss= 156276448.000000, Training Accuracy= 74.21875
#
# Fold: 2, Epoch: 1, Validation Accuracy= 81.00000
#
# Fold: 2, Epoch: 2, Mini Batch: 30, Loss= 91335056.000000, Training Accuracy= 74.21875
# Fold: 2, Epoch: 2, Mini Batch: 60, Loss= 65535252.000000, Training Accuracy= 78.90625
# Fold: 2, Epoch: 2, Mini Batch: 70, Loss= 54732092.000000, Training Accuracy= 80.46875
#
# Fold: 2, Epoch: 2, Validation Accuracy= 85.10000
#
# Fold: 2, Epoch: 3, Mini Batch: 30, Loss= 65187880.000000, Training Accuracy= 76.56250
# Fold: 2, Epoch: 3, Mini Batch: 60, Loss= 37111280.000000, Training Accuracy= 79.68750
# Fold: 2, Epoch: 3, Mini Batch: 70, Loss= 30352160.000000, Training Accuracy= 82.03125
#
# Fold: 2, Epoch: 3, Validation Accuracy= 86.70000
#
# Fold: 2, Epoch: 4, Mini Batch: 30, Loss= 31977826.000000, Training Accuracy= 78.12500
# Fold: 2, Epoch: 4, Mini Batch: 60, Loss= 43412996.000000, Training Accuracy= 81.25000
# Fold: 2, Epoch: 4, Mini Batch: 70, Loss= 30865086.000000, Training Accuracy= 80.46875
#
# Fold: 2, Epoch: 4, Validation Accuracy= 87.00000
#
# Fold: 2, Epoch: 5, Mini Batch: 30, Loss= 24269828.000000, Training Accuracy= 78.12500
# Fold: 2, Epoch: 5, Mini Batch: 60, Loss= 31681844.000000, Training Accuracy= 79.68750
# Fold: 2, Epoch: 5, Mini Batch: 70, Loss= 25927842.000000, Training Accuracy= 79.68750
#
# Fold: 2, Epoch: 5, Validation Accuracy= 87.50000
#
# Fold: 2, Epoch: 6, Mini Batch: 30, Loss= 19832186.000000, Training Accuracy= 80.46875
# Fold: 2, Epoch: 6, Mini Batch: 60, Loss= 16075414.000000, Training Accuracy= 80.46875
# Fold: 2, Epoch: 6, Mini Batch: 70, Loss= 14009248.000000, Training Accuracy= 83.59375
#
# Fold: 2, Epoch: 6, Validation Accuracy= 87.80000
#
# Fold: 2, Epoch: 7, Mini Batch: 30, Loss= 7928965.500000, Training Accuracy= 85.93750
# Fold: 2, Epoch: 7, Mini Batch: 60, Loss= 14374081.000000, Training Accuracy= 83.59375
# Fold: 2, Epoch: 7, Mini Batch: 70, Loss= 6930323.500000, Training Accuracy= 88.28125
#
# Fold: 2, Epoch: 7, Validation Accuracy= 88.00000
#
# Fold: 2, Epoch: 8, Mini Batch: 30, Loss= 13456350.000000, Training Accuracy= 78.90625
# Fold: 2, Epoch: 8, Mini Batch: 60, Loss= 13031515.000000, Training Accuracy= 82.81250
# Fold: 2, Epoch: 8, Mini Batch: 70, Loss= 6053077.000000, Training Accuracy= 85.15625
#
# Fold: 2, Epoch: 8, Validation Accuracy= 88.00000
#
# Fold: 2, Epoch: 9, Mini Batch: 30, Loss= 11602524.000000, Training Accuracy= 80.46875
# Fold: 2, Epoch: 9, Mini Batch: 60, Loss= 10944664.000000, Training Accuracy= 82.03125
# Fold: 2, Epoch: 9, Mini Batch: 70, Loss= 11279034.000000, Training Accuracy= 78.90625
#
# Fold: 2, Epoch: 9, Validation Accuracy= 88.50000
#
# Fold: 2, Epoch: 10, Mini Batch: 30, Loss= 5198478.000000, Training Accuracy= 86.71875
# Fold: 2, Epoch: 10, Mini Batch: 60, Loss= 8672339.000000, Training Accuracy= 85.93750
# Fold: 2, Epoch: 10, Mini Batch: 70, Loss= 8583460.000000, Training Accuracy= 83.59375
#
# Fold: 2, Epoch: 10, Validation Accuracy= 89.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          453   60   513
# 1           47  440   487
# All        500  500  1000
#
# Fold: 2, Epoch: 11, Mini Batch: 30, Loss= 6759923.500000, Training Accuracy= 85.93750
# Fold: 2, Epoch: 11, Mini Batch: 60, Loss= 8079343.500000, Training Accuracy= 79.68750
# Fold: 2, Epoch: 11, Mini Batch: 70, Loss= 6339594.500000, Training Accuracy= 88.28125
#
# Fold: 2, Epoch: 11, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 12, Mini Batch: 30, Loss= 4875783.000000, Training Accuracy= 82.03125
# Fold: 2, Epoch: 12, Mini Batch: 60, Loss= 5196473.000000, Training Accuracy= 85.15625
# Fold: 2, Epoch: 12, Mini Batch: 70, Loss= 4991943.000000, Training Accuracy= 86.71875
#
# Fold: 2, Epoch: 12, Validation Accuracy= 86.90000
#
# Fold: 2, Epoch: 13, Mini Batch: 30, Loss= 5679665.000000, Training Accuracy= 85.15625
# Fold: 2, Epoch: 13, Mini Batch: 60, Loss= 8638396.000000, Training Accuracy= 82.03125
# Fold: 2, Epoch: 13, Mini Batch: 70, Loss= 5683638.000000, Training Accuracy= 83.59375
#
# Fold: 2, Epoch: 13, Validation Accuracy= 88.20000
#
# Fold: 2, Epoch: 14, Mini Batch: 30, Loss= 4871166.000000, Training Accuracy= 85.15625
# Fold: 2, Epoch: 14, Mini Batch: 60, Loss= 5116389.500000, Training Accuracy= 87.50000
# Fold: 2, Epoch: 14, Mini Batch: 70, Loss= 4544852.000000, Training Accuracy= 83.59375
#
# Fold: 2, Epoch: 14, Validation Accuracy= 89.20000
#
# Fold: 2, Epoch: 15, Mini Batch: 30, Loss= 4467012.500000, Training Accuracy= 83.59375
# Fold: 2, Epoch: 15, Mini Batch: 60, Loss= 5984023.500000, Training Accuracy= 84.37500
# Fold: 2, Epoch: 15, Mini Batch: 70, Loss= 3729604.250000, Training Accuracy= 85.93750
#
# Fold: 2, Epoch: 15, Validation Accuracy= 88.80000
#
# Fold: 2, Epoch: 16, Mini Batch: 30, Loss= 4378670.000000, Training Accuracy= 87.50000
# Fold: 2, Epoch: 16, Mini Batch: 60, Loss= 6789004.000000, Training Accuracy= 83.59375
# Fold: 2, Epoch: 16, Mini Batch: 70, Loss= 5050475.000000, Training Accuracy= 82.81250
#
# Fold: 2, Epoch: 16, Validation Accuracy= 89.30000
#
# Fold: 2, Epoch: 17, Mini Batch: 30, Loss= 4941243.500000, Training Accuracy= 84.37500
# Fold: 2, Epoch: 17, Mini Batch: 60, Loss= 6177154.500000, Training Accuracy= 83.59375
# Fold: 2, Epoch: 17, Mini Batch: 70, Loss= 2975186.500000, Training Accuracy= 88.28125
#
# Fold: 2, Epoch: 17, Validation Accuracy= 88.60000
#
# Fold: 2, Epoch: 18, Mini Batch: 30, Loss= 3276436.000000, Training Accuracy= 87.50000
# Fold: 2, Epoch: 18, Mini Batch: 60, Loss= 5590274.500000, Training Accuracy= 82.03125
# Fold: 2, Epoch: 18, Mini Batch: 70, Loss= 4339173.000000, Training Accuracy= 83.59375
#
# Fold: 2, Epoch: 18, Validation Accuracy= 89.30000
#
# Fold: 2, Epoch: 19, Mini Batch: 30, Loss= 3088852.000000, Training Accuracy= 85.93750
# Fold: 2, Epoch: 19, Mini Batch: 60, Loss= 4226793.500000, Training Accuracy= 82.03125
# Fold: 2, Epoch: 19, Mini Batch: 70, Loss= 2313009.500000, Training Accuracy= 86.71875
#
# Fold: 2, Epoch: 19, Validation Accuracy= 88.90000
#
# Fold: 2, Epoch: 20, Mini Batch: 30, Loss= 1677312.000000, Training Accuracy= 88.28125
# Fold: 2, Epoch: 20, Mini Batch: 60, Loss= 6225754.500000, Training Accuracy= 85.15625
# Fold: 2, Epoch: 20, Mini Batch: 70, Loss= 2791074.000000, Training Accuracy= 89.06250
#
# Fold: 2, Epoch: 20, Validation Accuracy= 89.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          456   66   522
# 1           44  434   478
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 3, Epoch: 1, Mini Batch: 30, Loss= 372814336.000000, Training Accuracy= 64.06250
# Fold: 3, Epoch: 1, Mini Batch: 60, Loss= 173858848.000000, Training Accuracy= 75.00000
# Fold: 3, Epoch: 1, Mini Batch: 70, Loss= 152140464.000000, Training Accuracy= 71.87500
#
# Fold: 3, Epoch: 1, Validation Accuracy= 80.50000
#
# Fold: 3, Epoch: 2, Mini Batch: 30, Loss= 91426944.000000, Training Accuracy= 71.87500
# Fold: 3, Epoch: 2, Mini Batch: 60, Loss= 66404508.000000, Training Accuracy= 77.34375
# Fold: 3, Epoch: 2, Mini Batch: 70, Loss= 56693864.000000, Training Accuracy= 73.43750
#
# Fold: 3, Epoch: 2, Validation Accuracy= 87.00000
#
# Fold: 3, Epoch: 3, Mini Batch: 30, Loss= 71531384.000000, Training Accuracy= 76.56250
# Fold: 3, Epoch: 3, Mini Batch: 60, Loss= 39152528.000000, Training Accuracy= 80.46875
# Fold: 3, Epoch: 3, Mini Batch: 70, Loss= 33719668.000000, Training Accuracy= 80.46875
#
# Fold: 3, Epoch: 3, Validation Accuracy= 86.20000
#
# Fold: 3, Epoch: 4, Mini Batch: 30, Loss= 30916336.000000, Training Accuracy= 78.12500
# Fold: 3, Epoch: 4, Mini Batch: 60, Loss= 43297696.000000, Training Accuracy= 76.56250
# Fold: 3, Epoch: 4, Mini Batch: 70, Loss= 32105276.000000, Training Accuracy= 78.90625
#
# Fold: 3, Epoch: 4, Validation Accuracy= 88.10000
#
# Fold: 3, Epoch: 5, Mini Batch: 30, Loss= 23894232.000000, Training Accuracy= 76.56250
# Fold: 3, Epoch: 5, Mini Batch: 60, Loss= 30853210.000000, Training Accuracy= 78.12500
# Fold: 3, Epoch: 5, Mini Batch: 70, Loss= 31273644.000000, Training Accuracy= 77.34375
#
# Fold: 3, Epoch: 5, Validation Accuracy= 87.40000
#
# Fold: 3, Epoch: 6, Mini Batch: 30, Loss= 20942540.000000, Training Accuracy= 78.90625
# Fold: 3, Epoch: 6, Mini Batch: 60, Loss= 15964700.000000, Training Accuracy= 78.12500
# Fold: 3, Epoch: 6, Mini Batch: 70, Loss= 15194576.000000, Training Accuracy= 82.03125
#
# Fold: 3, Epoch: 6, Validation Accuracy= 88.00000
#
# Fold: 3, Epoch: 7, Mini Batch: 30, Loss= 9711533.000000, Training Accuracy= 87.50000
# Fold: 3, Epoch: 7, Mini Batch: 60, Loss= 14044028.000000, Training Accuracy= 84.37500
# Fold: 3, Epoch: 7, Mini Batch: 70, Loss= 8184712.000000, Training Accuracy= 88.28125
#
# Fold: 3, Epoch: 7, Validation Accuracy= 88.20000
#
# Fold: 3, Epoch: 8, Mini Batch: 30, Loss= 13618266.000000, Training Accuracy= 79.68750
# Fold: 3, Epoch: 8, Mini Batch: 60, Loss= 14175123.000000, Training Accuracy= 82.03125
# Fold: 3, Epoch: 8, Mini Batch: 70, Loss= 9249642.000000, Training Accuracy= 83.59375
#
# Fold: 3, Epoch: 8, Validation Accuracy= 87.20000
#
# Fold: 3, Epoch: 9, Mini Batch: 30, Loss= 9292749.000000, Training Accuracy= 83.59375
# Fold: 3, Epoch: 9, Mini Batch: 60, Loss= 11164752.000000, Training Accuracy= 80.46875
# Fold: 3, Epoch: 9, Mini Batch: 70, Loss= 8163414.000000, Training Accuracy= 83.59375
#
# Fold: 3, Epoch: 9, Validation Accuracy= 88.50000
#
# Fold: 3, Epoch: 10, Mini Batch: 30, Loss= 5969119.000000, Training Accuracy= 86.71875
# Fold: 3, Epoch: 10, Mini Batch: 60, Loss= 10156605.000000, Training Accuracy= 85.15625
# Fold: 3, Epoch: 10, Mini Batch: 70, Loss= 8779841.000000, Training Accuracy= 83.59375
#
# Fold: 3, Epoch: 10, Validation Accuracy= 88.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          412   30   442
# 1           88  470   558
# All        500  500  1000
#
# Fold: 3, Epoch: 11, Mini Batch: 30, Loss= 5652330.000000, Training Accuracy= 86.71875
# Fold: 3, Epoch: 11, Mini Batch: 60, Loss= 9734050.000000, Training Accuracy= 82.81250
# Fold: 3, Epoch: 11, Mini Batch: 70, Loss= 6458947.000000, Training Accuracy= 88.28125
#
# Fold: 3, Epoch: 11, Validation Accuracy= 88.60000
#
# Fold: 3, Epoch: 12, Mini Batch: 30, Loss= 5151836.000000, Training Accuracy= 85.93750
# Fold: 3, Epoch: 12, Mini Batch: 60, Loss= 6364646.000000, Training Accuracy= 85.93750
# Fold: 3, Epoch: 12, Mini Batch: 70, Loss= 5137680.000000, Training Accuracy= 86.71875
#
# Fold: 3, Epoch: 12, Validation Accuracy= 89.10000
#
# Fold: 3, Epoch: 13, Mini Batch: 30, Loss= 5079492.500000, Training Accuracy= 86.71875
# Fold: 3, Epoch: 13, Mini Batch: 60, Loss= 8731726.000000, Training Accuracy= 81.25000
# Fold: 3, Epoch: 13, Mini Batch: 70, Loss= 6462889.500000, Training Accuracy= 85.15625
#
# Fold: 3, Epoch: 13, Validation Accuracy= 90.00000
#
# Fold: 3, Epoch: 14, Mini Batch: 30, Loss= 6656245.000000, Training Accuracy= 85.93750
# Fold: 3, Epoch: 14, Mini Batch: 60, Loss= 4555419.500000, Training Accuracy= 85.93750
# Fold: 3, Epoch: 14, Mini Batch: 70, Loss= 7224046.000000, Training Accuracy= 82.03125
#
# Fold: 3, Epoch: 14, Validation Accuracy= 88.50000
#
# Fold: 3, Epoch: 15, Mini Batch: 30, Loss= 3978131.500000, Training Accuracy= 84.37500
# Fold: 3, Epoch: 15, Mini Batch: 60, Loss= 6126903.000000, Training Accuracy= 82.81250
# Fold: 3, Epoch: 15, Mini Batch: 70, Loss= 4174938.500000, Training Accuracy= 85.15625
#
# Fold: 3, Epoch: 15, Validation Accuracy= 89.40000
#
# Fold: 3, Epoch: 16, Mini Batch: 30, Loss= 5176035.500000, Training Accuracy= 85.15625
# Fold: 3, Epoch: 16, Mini Batch: 60, Loss= 4990890.000000, Training Accuracy= 85.93750
# Fold: 3, Epoch: 16, Mini Batch: 70, Loss= 5168039.500000, Training Accuracy= 81.25000
#
# Fold: 3, Epoch: 16, Validation Accuracy= 89.80000
#
# Fold: 3, Epoch: 17, Mini Batch: 30, Loss= 4708505.500000, Training Accuracy= 82.81250
# Fold: 3, Epoch: 17, Mini Batch: 60, Loss= 6622405.500000, Training Accuracy= 82.03125
# Fold: 3, Epoch: 17, Mini Batch: 70, Loss= 2583248.250000, Training Accuracy= 89.84375
#
# Fold: 3, Epoch: 17, Validation Accuracy= 90.20000
#
# Fold: 3, Epoch: 18, Mini Batch: 30, Loss= 3891827.500000, Training Accuracy= 85.15625
# Fold: 3, Epoch: 18, Mini Batch: 60, Loss= 5403006.000000, Training Accuracy= 83.59375
# Fold: 3, Epoch: 18, Mini Batch: 70, Loss= 4162147.250000, Training Accuracy= 84.37500
#
# Fold: 3, Epoch: 18, Validation Accuracy= 88.90000
#
# Fold: 3, Epoch: 19, Mini Batch: 30, Loss= 2263264.500000, Training Accuracy= 88.28125
# Fold: 3, Epoch: 19, Mini Batch: 60, Loss= 4124584.000000, Training Accuracy= 83.59375
# Fold: 3, Epoch: 19, Mini Batch: 70, Loss= 2525057.500000, Training Accuracy= 86.71875
#
# Fold: 3, Epoch: 19, Validation Accuracy= 89.50000
#
# Fold: 3, Epoch: 20, Mini Batch: 30, Loss= 1910331.250000, Training Accuracy= 91.40625
# Fold: 3, Epoch: 20, Mini Batch: 60, Loss= 5099409.500000, Training Accuracy= 83.59375
# Fold: 3, Epoch: 20, Mini Batch: 70, Loss= 3687238.000000, Training Accuracy= 85.93750
#
# Fold: 3, Epoch: 20, Validation Accuracy= 89.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          452   54   506
# 1           48  446   494
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 4, Epoch: 1, Mini Batch: 30, Loss= 351317312.000000, Training Accuracy= 65.62500
# Fold: 4, Epoch: 1, Mini Batch: 60, Loss= 179368288.000000, Training Accuracy= 75.78125
# Fold: 4, Epoch: 1, Mini Batch: 70, Loss= 161208512.000000, Training Accuracy= 73.43750
#
# Fold: 4, Epoch: 1, Validation Accuracy= 78.40000
#
# Fold: 4, Epoch: 2, Mini Batch: 30, Loss= 87895712.000000, Training Accuracy= 75.00000
# Fold: 4, Epoch: 2, Mini Batch: 60, Loss= 65710668.000000, Training Accuracy= 78.90625
# Fold: 4, Epoch: 2, Mini Batch: 70, Loss= 61808896.000000, Training Accuracy= 76.56250
#
# Fold: 4, Epoch: 2, Validation Accuracy= 84.50000
#
# Fold: 4, Epoch: 3, Mini Batch: 30, Loss= 66087624.000000, Training Accuracy= 77.34375
# Fold: 4, Epoch: 3, Mini Batch: 60, Loss= 38155584.000000, Training Accuracy= 76.56250
# Fold: 4, Epoch: 3, Mini Batch: 70, Loss= 27776730.000000, Training Accuracy= 84.37500
#
# Fold: 4, Epoch: 3, Validation Accuracy= 84.50000
#
# Fold: 4, Epoch: 4, Mini Batch: 30, Loss= 36893120.000000, Training Accuracy= 78.90625
# Fold: 4, Epoch: 4, Mini Batch: 60, Loss= 37438128.000000, Training Accuracy= 79.68750
# Fold: 4, Epoch: 4, Mini Batch: 70, Loss= 32963732.000000, Training Accuracy= 78.12500
#
# Fold: 4, Epoch: 4, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 5, Mini Batch: 30, Loss= 22073336.000000, Training Accuracy= 79.68750
# Fold: 4, Epoch: 5, Mini Batch: 60, Loss= 29350020.000000, Training Accuracy= 76.56250
# Fold: 4, Epoch: 5, Mini Batch: 70, Loss= 29685048.000000, Training Accuracy= 78.90625
#
# Fold: 4, Epoch: 5, Validation Accuracy= 85.00000
#
# Fold: 4, Epoch: 6, Mini Batch: 30, Loss= 21661358.000000, Training Accuracy= 80.46875
# Fold: 4, Epoch: 6, Mini Batch: 60, Loss= 13182926.000000, Training Accuracy= 82.81250
# Fold: 4, Epoch: 6, Mini Batch: 70, Loss= 16347654.000000, Training Accuracy= 80.46875
#
# Fold: 4, Epoch: 6, Validation Accuracy= 84.70000
#
# Fold: 4, Epoch: 7, Mini Batch: 30, Loss= 8640648.000000, Training Accuracy= 85.93750
# Fold: 4, Epoch: 7, Mini Batch: 60, Loss= 14212291.000000, Training Accuracy= 84.37500
# Fold: 4, Epoch: 7, Mini Batch: 70, Loss= 12481336.000000, Training Accuracy= 82.81250
#
# Fold: 4, Epoch: 7, Validation Accuracy= 86.50000
#
# Fold: 4, Epoch: 8, Mini Batch: 30, Loss= 15013292.000000, Training Accuracy= 81.25000
# Fold: 4, Epoch: 8, Mini Batch: 60, Loss= 14198280.000000, Training Accuracy= 82.81250
# Fold: 4, Epoch: 8, Mini Batch: 70, Loss= 9844162.000000, Training Accuracy= 82.81250
#
# Fold: 4, Epoch: 8, Validation Accuracy= 86.40000
#
# Fold: 4, Epoch: 9, Mini Batch: 30, Loss= 8253364.500000, Training Accuracy= 83.59375
# Fold: 4, Epoch: 9, Mini Batch: 60, Loss= 9656544.000000, Training Accuracy= 82.03125
# Fold: 4, Epoch: 9, Mini Batch: 70, Loss= 10916370.000000, Training Accuracy= 83.59375
#
# Fold: 4, Epoch: 9, Validation Accuracy= 86.70000
#
# Fold: 4, Epoch: 10, Mini Batch: 30, Loss= 8491331.000000, Training Accuracy= 82.03125
# Fold: 4, Epoch: 10, Mini Batch: 60, Loss= 7751790.500000, Training Accuracy= 89.06250
# Fold: 4, Epoch: 10, Mini Batch: 70, Loss= 7485122.500000, Training Accuracy= 79.68750
#
# Fold: 4, Epoch: 10, Validation Accuracy= 87.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          411   35   446
# 1           89  465   554
# All        500  500  1000
#
# Fold: 4, Epoch: 11, Mini Batch: 30, Loss= 5972347.500000, Training Accuracy= 87.50000
# Fold: 4, Epoch: 11, Mini Batch: 60, Loss= 10271930.000000, Training Accuracy= 81.25000
# Fold: 4, Epoch: 11, Mini Batch: 70, Loss= 8570421.000000, Training Accuracy= 84.37500
#
# Fold: 4, Epoch: 11, Validation Accuracy= 86.30000
#
# Fold: 4, Epoch: 12, Mini Batch: 30, Loss= 4921090.000000, Training Accuracy= 85.15625
# Fold: 4, Epoch: 12, Mini Batch: 60, Loss= 5094205.000000, Training Accuracy= 86.71875
# Fold: 4, Epoch: 12, Mini Batch: 70, Loss= 4990072.500000, Training Accuracy= 83.59375
#
# Fold: 4, Epoch: 12, Validation Accuracy= 87.10000
#
# Fold: 4, Epoch: 13, Mini Batch: 30, Loss= 5830455.000000, Training Accuracy= 90.62500
# Fold: 4, Epoch: 13, Mini Batch: 60, Loss= 5907256.000000, Training Accuracy= 85.15625
# Fold: 4, Epoch: 13, Mini Batch: 70, Loss= 3892097.000000, Training Accuracy= 86.71875
#
# Fold: 4, Epoch: 13, Validation Accuracy= 86.90000
#
# Fold: 4, Epoch: 14, Mini Batch: 30, Loss= 5841088.000000, Training Accuracy= 85.93750
# Fold: 4, Epoch: 14, Mini Batch: 60, Loss= 5148873.000000, Training Accuracy= 86.71875
# Fold: 4, Epoch: 14, Mini Batch: 70, Loss= 5867676.000000, Training Accuracy= 82.81250
#
# Fold: 4, Epoch: 14, Validation Accuracy= 88.30000
#
# Fold: 4, Epoch: 15, Mini Batch: 30, Loss= 3628809.000000, Training Accuracy= 85.15625
# Fold: 4, Epoch: 15, Mini Batch: 60, Loss= 5473241.000000, Training Accuracy= 85.15625
# Fold: 4, Epoch: 15, Mini Batch: 70, Loss= 4829641.000000, Training Accuracy= 84.37500
#
# Fold: 4, Epoch: 15, Validation Accuracy= 87.80000
#
# Fold: 4, Epoch: 16, Mini Batch: 30, Loss= 3575304.750000, Training Accuracy= 86.71875
# Fold: 4, Epoch: 16, Mini Batch: 60, Loss= 6651641.000000, Training Accuracy= 85.93750
# Fold: 4, Epoch: 16, Mini Batch: 70, Loss= 6862422.500000, Training Accuracy= 82.03125
#
# Fold: 4, Epoch: 16, Validation Accuracy= 88.00000
#
# Fold: 4, Epoch: 17, Mini Batch: 30, Loss= 3103707.500000, Training Accuracy= 88.28125
# Fold: 4, Epoch: 17, Mini Batch: 60, Loss= 6975002.500000, Training Accuracy= 79.68750
# Fold: 4, Epoch: 17, Mini Batch: 70, Loss= 3868420.750000, Training Accuracy= 86.71875
#
# Fold: 4, Epoch: 17, Validation Accuracy= 88.80000
#
# Fold: 4, Epoch: 18, Mini Batch: 30, Loss= 3937855.000000, Training Accuracy= 85.93750
# Fold: 4, Epoch: 18, Mini Batch: 60, Loss= 5741352.000000, Training Accuracy= 82.03125
# Fold: 4, Epoch: 18, Mini Batch: 70, Loss= 3257621.500000, Training Accuracy= 83.59375
#
# Fold: 4, Epoch: 18, Validation Accuracy= 87.70000
#
# Fold: 4, Epoch: 19, Mini Batch: 30, Loss= 2512057.500000, Training Accuracy= 89.06250
# Fold: 4, Epoch: 19, Mini Batch: 60, Loss= 4271666.000000, Training Accuracy= 85.93750
# Fold: 4, Epoch: 19, Mini Batch: 70, Loss= 2622146.500000, Training Accuracy= 86.71875
#
# Fold: 4, Epoch: 19, Validation Accuracy= 88.40000
#
# Fold: 4, Epoch: 20, Mini Batch: 30, Loss= 2787302.250000, Training Accuracy= 87.50000
# Fold: 4, Epoch: 20, Mini Batch: 60, Loss= 5673949.500000, Training Accuracy= 83.59375
# Fold: 4, Epoch: 20, Mini Batch: 70, Loss= 3099120.500000, Training Accuracy= 86.71875
#
# Fold: 4, Epoch: 20, Validation Accuracy= 89.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          434   38   472
# 1           66  462   528
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 5, Epoch: 1, Mini Batch: 30, Loss= 269204288.000000, Training Accuracy= 68.75000
# Fold: 5, Epoch: 1, Mini Batch: 60, Loss= 173346560.000000, Training Accuracy= 75.78125
# Fold: 5, Epoch: 1, Mini Batch: 70, Loss= 159437360.000000, Training Accuracy= 71.09375
#
# Fold: 5, Epoch: 1, Validation Accuracy= 82.20000
#
# Fold: 5, Epoch: 2, Mini Batch: 30, Loss= 89293616.000000, Training Accuracy= 75.78125
# Fold: 5, Epoch: 2, Mini Batch: 60, Loss= 67478256.000000, Training Accuracy= 78.90625
# Fold: 5, Epoch: 2, Mini Batch: 70, Loss= 66317376.000000, Training Accuracy= 75.00000
#
# Fold: 5, Epoch: 2, Validation Accuracy= 86.60000
#
# Fold: 5, Epoch: 3, Mini Batch: 30, Loss= 30611348.000000, Training Accuracy= 80.46875
# Fold: 5, Epoch: 3, Mini Batch: 60, Loss= 41009432.000000, Training Accuracy= 81.25000
# Fold: 5, Epoch: 3, Mini Batch: 70, Loss= 34200388.000000, Training Accuracy= 80.46875
#
# Fold: 5, Epoch: 3, Validation Accuracy= 87.70000
#
# Fold: 5, Epoch: 4, Mini Batch: 30, Loss= 30562680.000000, Training Accuracy= 76.56250
# Fold: 5, Epoch: 4, Mini Batch: 60, Loss= 40085296.000000, Training Accuracy= 75.78125
# Fold: 5, Epoch: 4, Mini Batch: 70, Loss= 29341082.000000, Training Accuracy= 81.25000
#
# Fold: 5, Epoch: 4, Validation Accuracy= 88.40000
#
# Fold: 5, Epoch: 5, Mini Batch: 30, Loss= 20188264.000000, Training Accuracy= 79.68750
# Fold: 5, Epoch: 5, Mini Batch: 60, Loss= 31080312.000000, Training Accuracy= 80.46875
# Fold: 5, Epoch: 5, Mini Batch: 70, Loss= 27778168.000000, Training Accuracy= 78.90625
#
# Fold: 5, Epoch: 5, Validation Accuracy= 88.00000
#
# Fold: 5, Epoch: 6, Mini Batch: 30, Loss= 13766684.000000, Training Accuracy= 81.25000
# Fold: 5, Epoch: 6, Mini Batch: 60, Loss= 14497030.000000, Training Accuracy= 82.03125
# Fold: 5, Epoch: 6, Mini Batch: 70, Loss= 17548416.000000, Training Accuracy= 83.59375
#
# Fold: 5, Epoch: 6, Validation Accuracy= 88.90000
#
# Fold: 5, Epoch: 7, Mini Batch: 30, Loss= 18139972.000000, Training Accuracy= 80.46875
# Fold: 5, Epoch: 7, Mini Batch: 60, Loss= 12714402.000000, Training Accuracy= 85.15625
# Fold: 5, Epoch: 7, Mini Batch: 70, Loss= 8621768.000000, Training Accuracy= 84.37500
#
# Fold: 5, Epoch: 7, Validation Accuracy= 88.40000
#
# Fold: 5, Epoch: 8, Mini Batch: 30, Loss= 6748378.000000, Training Accuracy= 86.71875
# Fold: 5, Epoch: 8, Mini Batch: 60, Loss= 12576014.000000, Training Accuracy= 83.59375
# Fold: 5, Epoch: 8, Mini Batch: 70, Loss= 9399546.000000, Training Accuracy= 80.46875
#
# Fold: 5, Epoch: 8, Validation Accuracy= 88.50000
#
# Fold: 5, Epoch: 9, Mini Batch: 30, Loss= 7832433.000000, Training Accuracy= 85.15625
# Fold: 5, Epoch: 9, Mini Batch: 60, Loss= 8106467.000000, Training Accuracy= 85.15625
# Fold: 5, Epoch: 9, Mini Batch: 70, Loss= 10602016.000000, Training Accuracy= 79.68750
#
# Fold: 5, Epoch: 9, Validation Accuracy= 90.10000
#
# Fold: 5, Epoch: 10, Mini Batch: 30, Loss= 9982003.000000, Training Accuracy= 84.37500
# Fold: 5, Epoch: 10, Mini Batch: 60, Loss= 10041946.000000, Training Accuracy= 84.37500
# Fold: 5, Epoch: 10, Mini Batch: 70, Loss= 7901277.500000, Training Accuracy= 80.46875
#
# Fold: 5, Epoch: 10, Validation Accuracy= 89.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          430   39   469
# 1           70  461   531
# All        500  500  1000
#
# Fold: 5, Epoch: 11, Mini Batch: 30, Loss= 5671729.500000, Training Accuracy= 82.03125
# Fold: 5, Epoch: 11, Mini Batch: 60, Loss= 7486442.000000, Training Accuracy= 84.37500
# Fold: 5, Epoch: 11, Mini Batch: 70, Loss= 6537669.000000, Training Accuracy= 84.37500
#
# Fold: 5, Epoch: 11, Validation Accuracy= 88.80000
#
# Fold: 5, Epoch: 12, Mini Batch: 30, Loss= 5711337.000000, Training Accuracy= 85.93750
# Fold: 5, Epoch: 12, Mini Batch: 60, Loss= 6284823.000000, Training Accuracy= 85.15625
# Fold: 5, Epoch: 12, Mini Batch: 70, Loss= 4683918.000000, Training Accuracy= 84.37500
#
# Fold: 5, Epoch: 12, Validation Accuracy= 90.20000
#
# Fold: 5, Epoch: 13, Mini Batch: 30, Loss= 4348849.000000, Training Accuracy= 83.59375
# Fold: 5, Epoch: 13, Mini Batch: 60, Loss= 4715906.500000, Training Accuracy= 81.25000
# Fold: 5, Epoch: 13, Mini Batch: 70, Loss= 5293015.000000, Training Accuracy= 83.59375
#
# Fold: 5, Epoch: 13, Validation Accuracy= 90.20000
#
# Fold: 5, Epoch: 14, Mini Batch: 30, Loss= 4590935.500000, Training Accuracy= 85.15625
# Fold: 5, Epoch: 14, Mini Batch: 60, Loss= 4459787.000000, Training Accuracy= 85.15625
# Fold: 5, Epoch: 14, Mini Batch: 70, Loss= 5973490.000000, Training Accuracy= 80.46875
#
# Fold: 5, Epoch: 14, Validation Accuracy= 89.80000
#
# Fold: 5, Epoch: 15, Mini Batch: 30, Loss= 2632087.250000, Training Accuracy= 86.71875
# Fold: 5, Epoch: 15, Mini Batch: 60, Loss= 8075164.000000, Training Accuracy= 78.12500
# Fold: 5, Epoch: 15, Mini Batch: 70, Loss= 3422404.500000, Training Accuracy= 86.71875
#
# Fold: 5, Epoch: 15, Validation Accuracy= 89.90000
#
# Fold: 5, Epoch: 16, Mini Batch: 30, Loss= 2528328.000000, Training Accuracy= 85.93750
# Fold: 5, Epoch: 16, Mini Batch: 60, Loss= 4439181.500000, Training Accuracy= 88.28125
# Fold: 5, Epoch: 16, Mini Batch: 70, Loss= 5221694.500000, Training Accuracy= 82.81250
#
# Fold: 5, Epoch: 16, Validation Accuracy= 90.40000
#
# Fold: 5, Epoch: 17, Mini Batch: 30, Loss= 3278158.250000, Training Accuracy= 85.93750
# Fold: 5, Epoch: 17, Mini Batch: 60, Loss= 5154340.500000, Training Accuracy= 82.03125
# Fold: 5, Epoch: 17, Mini Batch: 70, Loss= 3553293.000000, Training Accuracy= 88.28125
#
# Fold: 5, Epoch: 17, Validation Accuracy= 90.70000
#
# Fold: 5, Epoch: 18, Mini Batch: 30, Loss= 3629289.250000, Training Accuracy= 82.81250
# Fold: 5, Epoch: 18, Mini Batch: 60, Loss= 4625762.000000, Training Accuracy= 82.03125
# Fold: 5, Epoch: 18, Mini Batch: 70, Loss= 3050563.000000, Training Accuracy= 84.37500
#
# Fold: 5, Epoch: 18, Validation Accuracy= 90.40000
#
# Fold: 5, Epoch: 19, Mini Batch: 30, Loss= 5016124.500000, Training Accuracy= 79.68750
# Fold: 5, Epoch: 19, Mini Batch: 60, Loss= 5311807.000000, Training Accuracy= 82.81250
# Fold: 5, Epoch: 19, Mini Batch: 70, Loss= 3019382.500000, Training Accuracy= 84.37500
#
# Fold: 5, Epoch: 19, Validation Accuracy= 90.70000
#
# Fold: 5, Epoch: 20, Mini Batch: 30, Loss= 1639131.250000, Training Accuracy= 85.15625
# Fold: 5, Epoch: 20, Mini Batch: 60, Loss= 4169982.000000, Training Accuracy= 87.50000
# Fold: 5, Epoch: 20, Mini Batch: 70, Loss= 2221842.000000, Training Accuracy= 86.71875
#
# Fold: 5, Epoch: 20, Validation Accuracy= 90.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          462   58   520
# 1           38  442   480
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 6, Epoch: 1, Mini Batch: 30, Loss= 269204288.000000, Training Accuracy= 68.75000
# Fold: 6, Epoch: 1, Mini Batch: 60, Loss= 172426912.000000, Training Accuracy= 75.78125
# Fold: 6, Epoch: 1, Mini Batch: 70, Loss= 162742624.000000, Training Accuracy= 71.87500
#
# Fold: 6, Epoch: 1, Validation Accuracy= 82.70000
#
# Fold: 6, Epoch: 2, Mini Batch: 30, Loss= 98633688.000000, Training Accuracy= 72.65625
# Fold: 6, Epoch: 2, Mini Batch: 60, Loss= 74917504.000000, Training Accuracy= 75.78125
# Fold: 6, Epoch: 2, Mini Batch: 70, Loss= 75787120.000000, Training Accuracy= 71.09375
#
# Fold: 6, Epoch: 2, Validation Accuracy= 86.70000
#
# Fold: 6, Epoch: 3, Mini Batch: 30, Loss= 37505836.000000, Training Accuracy= 81.25000
# Fold: 6, Epoch: 3, Mini Batch: 60, Loss= 50119668.000000, Training Accuracy= 76.56250
# Fold: 6, Epoch: 3, Mini Batch: 70, Loss= 35458072.000000, Training Accuracy= 82.03125
#
# Fold: 6, Epoch: 3, Validation Accuracy= 87.60000
#
# Fold: 6, Epoch: 4, Mini Batch: 30, Loss= 26130536.000000, Training Accuracy= 81.25000
# Fold: 6, Epoch: 4, Mini Batch: 60, Loss= 40894900.000000, Training Accuracy= 79.68750
# Fold: 6, Epoch: 4, Mini Batch: 70, Loss= 40352680.000000, Training Accuracy= 75.78125
#
# Fold: 6, Epoch: 4, Validation Accuracy= 86.70000
#
# Fold: 6, Epoch: 5, Mini Batch: 30, Loss= 19912184.000000, Training Accuracy= 78.12500
# Fold: 6, Epoch: 5, Mini Batch: 60, Loss= 32511258.000000, Training Accuracy= 81.25000
# Fold: 6, Epoch: 5, Mini Batch: 70, Loss= 28354192.000000, Training Accuracy= 77.34375
#
# Fold: 6, Epoch: 5, Validation Accuracy= 88.10000
#
# Fold: 6, Epoch: 6, Mini Batch: 30, Loss= 14358961.000000, Training Accuracy= 78.90625
# Fold: 6, Epoch: 6, Mini Batch: 60, Loss= 18519480.000000, Training Accuracy= 82.81250
# Fold: 6, Epoch: 6, Mini Batch: 70, Loss= 19474880.000000, Training Accuracy= 81.25000
#
# Fold: 6, Epoch: 6, Validation Accuracy= 87.70000
#
# Fold: 6, Epoch: 7, Mini Batch: 30, Loss= 19693712.000000, Training Accuracy= 77.34375
# Fold: 6, Epoch: 7, Mini Batch: 60, Loss= 17206690.000000, Training Accuracy= 82.81250
# Fold: 6, Epoch: 7, Mini Batch: 70, Loss= 10677952.000000, Training Accuracy= 85.15625
#
# Fold: 6, Epoch: 7, Validation Accuracy= 87.90000
#
# Fold: 6, Epoch: 8, Mini Batch: 30, Loss= 9163748.000000, Training Accuracy= 85.15625
# Fold: 6, Epoch: 8, Mini Batch: 60, Loss= 14823462.000000, Training Accuracy= 83.59375
# Fold: 6, Epoch: 8, Mini Batch: 70, Loss= 9374741.000000, Training Accuracy= 83.59375
#
# Fold: 6, Epoch: 8, Validation Accuracy= 89.40000
#
# Fold: 6, Epoch: 9, Mini Batch: 30, Loss= 8488047.000000, Training Accuracy= 84.37500
# Fold: 6, Epoch: 9, Mini Batch: 60, Loss= 13472608.000000, Training Accuracy= 82.81250
# Fold: 6, Epoch: 9, Mini Batch: 70, Loss= 9311648.000000, Training Accuracy= 82.03125
#
# Fold: 6, Epoch: 9, Validation Accuracy= 88.00000
#
# Fold: 6, Epoch: 10, Mini Batch: 30, Loss= 8950852.000000, Training Accuracy= 84.37500
# Fold: 6, Epoch: 10, Mini Batch: 60, Loss= 9812990.000000, Training Accuracy= 85.15625
# Fold: 6, Epoch: 10, Mini Batch: 70, Loss= 10968050.000000, Training Accuracy= 82.81250
#
# Fold: 6, Epoch: 10, Validation Accuracy= 89.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          440   47   487
# 1           60  453   513
# All        500  500  1000
#
# Fold: 6, Epoch: 11, Mini Batch: 30, Loss= 8448408.000000, Training Accuracy= 81.25000
# Fold: 6, Epoch: 11, Mini Batch: 60, Loss= 8688708.000000, Training Accuracy= 86.71875
# Fold: 6, Epoch: 11, Mini Batch: 70, Loss= 9331045.000000, Training Accuracy= 85.15625
#
# Fold: 6, Epoch: 11, Validation Accuracy= 88.10000
#
# Fold: 6, Epoch: 12, Mini Batch: 30, Loss= 5133721.500000, Training Accuracy= 85.15625
# Fold: 6, Epoch: 12, Mini Batch: 60, Loss= 6548880.000000, Training Accuracy= 83.59375
# Fold: 6, Epoch: 12, Mini Batch: 70, Loss= 6010132.500000, Training Accuracy= 85.15625
#
# Fold: 6, Epoch: 12, Validation Accuracy= 88.90000
#
# Fold: 6, Epoch: 13, Mini Batch: 30, Loss= 5417696.500000, Training Accuracy= 88.28125
# Fold: 6, Epoch: 13, Mini Batch: 60, Loss= 6281113.500000, Training Accuracy= 82.03125
# Fold: 6, Epoch: 13, Mini Batch: 70, Loss= 6435107.500000, Training Accuracy= 81.25000
#
# Fold: 6, Epoch: 13, Validation Accuracy= 88.90000
#
# Fold: 6, Epoch: 14, Mini Batch: 30, Loss= 4461195.000000, Training Accuracy= 85.93750
# Fold: 6, Epoch: 14, Mini Batch: 60, Loss= 5107888.000000, Training Accuracy= 85.15625
# Fold: 6, Epoch: 14, Mini Batch: 70, Loss= 7842308.000000, Training Accuracy= 81.25000
#
# Fold: 6, Epoch: 14, Validation Accuracy= 89.50000
#
# Fold: 6, Epoch: 15, Mini Batch: 30, Loss= 4296346.000000, Training Accuracy= 87.50000
# Fold: 6, Epoch: 15, Mini Batch: 60, Loss= 5567104.500000, Training Accuracy= 89.06250
# Fold: 6, Epoch: 15, Mini Batch: 70, Loss= 5043867.000000, Training Accuracy= 85.15625
#
# Fold: 6, Epoch: 15, Validation Accuracy= 90.10000
#
# Fold: 6, Epoch: 16, Mini Batch: 30, Loss= 3320693.000000, Training Accuracy= 87.50000
# Fold: 6, Epoch: 16, Mini Batch: 60, Loss= 4400889.000000, Training Accuracy= 87.50000
# Fold: 6, Epoch: 16, Mini Batch: 70, Loss= 6767486.000000, Training Accuracy= 85.93750
#
# Fold: 6, Epoch: 16, Validation Accuracy= 90.30000
#
# Fold: 6, Epoch: 17, Mini Batch: 30, Loss= 3924056.000000, Training Accuracy= 85.15625
# Fold: 6, Epoch: 17, Mini Batch: 60, Loss= 5543909.500000, Training Accuracy= 84.37500
# Fold: 6, Epoch: 17, Mini Batch: 70, Loss= 4278975.000000, Training Accuracy= 84.37500
#
# Fold: 6, Epoch: 17, Validation Accuracy= 89.10000
#
# Fold: 6, Epoch: 18, Mini Batch: 30, Loss= 4308811.000000, Training Accuracy= 86.71875
# Fold: 6, Epoch: 18, Mini Batch: 60, Loss= 6554062.000000, Training Accuracy= 83.59375
# Fold: 6, Epoch: 18, Mini Batch: 70, Loss= 6406682.000000, Training Accuracy= 85.15625
#
# Fold: 6, Epoch: 18, Validation Accuracy= 89.80000
#
# Fold: 6, Epoch: 19, Mini Batch: 30, Loss= 3458794.500000, Training Accuracy= 88.28125
# Fold: 6, Epoch: 19, Mini Batch: 60, Loss= 5336673.000000, Training Accuracy= 85.93750
# Fold: 6, Epoch: 19, Mini Batch: 70, Loss= 2592453.500000, Training Accuracy= 88.28125
#
# Fold: 6, Epoch: 19, Validation Accuracy= 89.70000
#
# Fold: 6, Epoch: 20, Mini Batch: 30, Loss= 2012188.500000, Training Accuracy= 89.06250
# Fold: 6, Epoch: 20, Mini Batch: 60, Loss= 4368744.000000, Training Accuracy= 83.59375
# Fold: 6, Epoch: 20, Mini Batch: 70, Loss= 4919117.500000, Training Accuracy= 83.59375
#
# Fold: 6, Epoch: 20, Validation Accuracy= 89.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          429   33   462
# 1           71  467   538
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 7, Epoch: 1, Mini Batch: 30, Loss= 269204288.000000, Training Accuracy= 68.75000
# Fold: 7, Epoch: 1, Mini Batch: 60, Loss= 165682272.000000, Training Accuracy= 78.90625
# Fold: 7, Epoch: 1, Mini Batch: 70, Loss= 153368416.000000, Training Accuracy= 73.43750
#
# Fold: 7, Epoch: 1, Validation Accuracy= 82.10000
#
# Fold: 7, Epoch: 2, Mini Batch: 30, Loss= 96515200.000000, Training Accuracy= 73.43750
# Fold: 7, Epoch: 2, Mini Batch: 60, Loss= 63879688.000000, Training Accuracy= 77.34375
# Fold: 7, Epoch: 2, Mini Batch: 70, Loss= 66580004.000000, Training Accuracy= 73.43750
#
# Fold: 7, Epoch: 2, Validation Accuracy= 86.20000
#
# Fold: 7, Epoch: 3, Mini Batch: 30, Loss= 34210656.000000, Training Accuracy= 78.12500
# Fold: 7, Epoch: 3, Mini Batch: 60, Loss= 46399840.000000, Training Accuracy= 78.12500
# Fold: 7, Epoch: 3, Mini Batch: 70, Loss= 36504240.000000, Training Accuracy= 80.46875
#
# Fold: 7, Epoch: 3, Validation Accuracy= 86.00000
#
# Fold: 7, Epoch: 4, Mini Batch: 30, Loss= 23897724.000000, Training Accuracy= 80.46875
# Fold: 7, Epoch: 4, Mini Batch: 60, Loss= 39338988.000000, Training Accuracy= 80.46875
# Fold: 7, Epoch: 4, Mini Batch: 70, Loss= 31486682.000000, Training Accuracy= 79.68750
#
# Fold: 7, Epoch: 4, Validation Accuracy= 86.40000
#
# Fold: 7, Epoch: 5, Mini Batch: 30, Loss= 26904858.000000, Training Accuracy= 75.00000
# Fold: 7, Epoch: 5, Mini Batch: 60, Loss= 31353364.000000, Training Accuracy= 81.25000
# Fold: 7, Epoch: 5, Mini Batch: 70, Loss= 21363400.000000, Training Accuracy= 77.34375
#
# Fold: 7, Epoch: 5, Validation Accuracy= 87.40000
#
# Fold: 7, Epoch: 6, Mini Batch: 30, Loss= 11260409.000000, Training Accuracy= 78.90625
# Fold: 7, Epoch: 6, Mini Batch: 60, Loss= 19658856.000000, Training Accuracy= 79.68750
# Fold: 7, Epoch: 6, Mini Batch: 70, Loss= 17047572.000000, Training Accuracy= 78.90625
#
# Fold: 7, Epoch: 6, Validation Accuracy= 87.40000
#
# Fold: 7, Epoch: 7, Mini Batch: 30, Loss= 14269368.000000, Training Accuracy= 77.34375
# Fold: 7, Epoch: 7, Mini Batch: 60, Loss= 16346250.000000, Training Accuracy= 83.59375
# Fold: 7, Epoch: 7, Mini Batch: 70, Loss= 9978322.000000, Training Accuracy= 85.93750
#
# Fold: 7, Epoch: 7, Validation Accuracy= 87.70000
#
# Fold: 7, Epoch: 8, Mini Batch: 30, Loss= 8132644.000000, Training Accuracy= 85.15625
# Fold: 7, Epoch: 8, Mini Batch: 60, Loss= 13784236.000000, Training Accuracy= 82.81250
# Fold: 7, Epoch: 8, Mini Batch: 70, Loss= 7910332.000000, Training Accuracy= 86.71875
#
# Fold: 7, Epoch: 8, Validation Accuracy= 87.70000
#
# Fold: 7, Epoch: 9, Mini Batch: 30, Loss= 12241093.000000, Training Accuracy= 79.68750
# Fold: 7, Epoch: 9, Mini Batch: 60, Loss= 10404914.000000, Training Accuracy= 83.59375
# Fold: 7, Epoch: 9, Mini Batch: 70, Loss= 8610704.000000, Training Accuracy= 86.71875
#
# Fold: 7, Epoch: 9, Validation Accuracy= 87.20000
#
# Fold: 7, Epoch: 10, Mini Batch: 30, Loss= 10409959.000000, Training Accuracy= 84.37500
# Fold: 7, Epoch: 10, Mini Batch: 60, Loss= 7608796.500000, Training Accuracy= 85.93750
# Fold: 7, Epoch: 10, Mini Batch: 70, Loss= 10173527.000000, Training Accuracy= 82.81250
#
# Fold: 7, Epoch: 10, Validation Accuracy= 87.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          408   38   446
# 1           92  462   554
# All        500  500  1000
#
# Fold: 7, Epoch: 11, Mini Batch: 30, Loss= 7465681.500000, Training Accuracy= 82.03125
# Fold: 7, Epoch: 11, Mini Batch: 60, Loss= 10551240.000000, Training Accuracy= 85.15625
# Fold: 7, Epoch: 11, Mini Batch: 70, Loss= 8075284.000000, Training Accuracy= 82.03125
#
# Fold: 7, Epoch: 11, Validation Accuracy= 87.80000
#
# Fold: 7, Epoch: 12, Mini Batch: 30, Loss= 6031428.500000, Training Accuracy= 88.28125
# Fold: 7, Epoch: 12, Mini Batch: 60, Loss= 6683441.000000, Training Accuracy= 86.71875
# Fold: 7, Epoch: 12, Mini Batch: 70, Loss= 5415520.500000, Training Accuracy= 88.28125
#
# Fold: 7, Epoch: 12, Validation Accuracy= 88.30000
#
# Fold: 7, Epoch: 13, Mini Batch: 30, Loss= 5640412.000000, Training Accuracy= 86.71875
# Fold: 7, Epoch: 13, Mini Batch: 60, Loss= 5585284.500000, Training Accuracy= 81.25000
# Fold: 7, Epoch: 13, Mini Batch: 70, Loss= 3951116.500000, Training Accuracy= 88.28125
#
# Fold: 7, Epoch: 13, Validation Accuracy= 89.10000
#
# Fold: 7, Epoch: 14, Mini Batch: 30, Loss= 2631015.500000, Training Accuracy= 89.84375
# Fold: 7, Epoch: 14, Mini Batch: 60, Loss= 3076468.000000, Training Accuracy= 88.28125
# Fold: 7, Epoch: 14, Mini Batch: 70, Loss= 6078180.000000, Training Accuracy= 85.15625
#
# Fold: 7, Epoch: 14, Validation Accuracy= 90.50000
#
# Fold: 7, Epoch: 15, Mini Batch: 30, Loss= 2936416.000000, Training Accuracy= 87.50000
# Fold: 7, Epoch: 15, Mini Batch: 60, Loss= 5975191.000000, Training Accuracy= 88.28125
# Fold: 7, Epoch: 15, Mini Batch: 70, Loss= 3971551.250000, Training Accuracy= 88.28125
#
# Fold: 7, Epoch: 15, Validation Accuracy= 88.50000
#
# Fold: 7, Epoch: 16, Mini Batch: 30, Loss= 2364209.000000, Training Accuracy= 89.06250
# Fold: 7, Epoch: 16, Mini Batch: 60, Loss= 4756842.000000, Training Accuracy= 89.06250
# Fold: 7, Epoch: 16, Mini Batch: 70, Loss= 7910863.000000, Training Accuracy= 85.15625
#
# Fold: 7, Epoch: 16, Validation Accuracy= 88.80000
#
# Fold: 7, Epoch: 17, Mini Batch: 30, Loss= 4615548.000000, Training Accuracy= 85.15625
# Fold: 7, Epoch: 17, Mini Batch: 60, Loss= 6660118.000000, Training Accuracy= 87.50000
# Fold: 7, Epoch: 17, Mini Batch: 70, Loss= 3607295.000000, Training Accuracy= 89.84375
#
# Fold: 7, Epoch: 17, Validation Accuracy= 89.60000
#
# Fold: 7, Epoch: 18, Mini Batch: 30, Loss= 3996717.500000, Training Accuracy= 83.59375
# Fold: 7, Epoch: 18, Mini Batch: 60, Loss= 7010190.000000, Training Accuracy= 81.25000
# Fold: 7, Epoch: 18, Mini Batch: 70, Loss= 4951846.000000, Training Accuracy= 86.71875
#
# Fold: 7, Epoch: 18, Validation Accuracy= 89.60000
#
# Fold: 7, Epoch: 19, Mini Batch: 30, Loss= 3604731.500000, Training Accuracy= 82.81250
# Fold: 7, Epoch: 19, Mini Batch: 60, Loss= 6164559.500000, Training Accuracy= 85.15625
# Fold: 7, Epoch: 19, Mini Batch: 70, Loss= 2685939.500000, Training Accuracy= 87.50000
#
# Fold: 7, Epoch: 19, Validation Accuracy= 89.70000
#
# Fold: 7, Epoch: 20, Mini Batch: 30, Loss= 2283033.500000, Training Accuracy= 87.50000
# Fold: 7, Epoch: 20, Mini Batch: 60, Loss= 4580295.500000, Training Accuracy= 86.71875
# Fold: 7, Epoch: 20, Mini Batch: 70, Loss= 4014852.750000, Training Accuracy= 88.28125
#
# Fold: 7, Epoch: 20, Validation Accuracy= 88.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          420   35   455
# 1           80  465   545
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# ...
# Fold: 8, Epoch: 17, Mini Batch: 60, Loss= 8670156.000000, Training Accuracy= 80.46875
# Fold: 8, Epoch: 17, Mini Batch: 70, Loss= 4430207.000000, Training Accuracy= 84.37500
#
# Fold: 8, Epoch: 17, Validation Accuracy= 88.60000
#
# Fold: 8, Epoch: 18, Mini Batch: 30, Loss= 4551378.000000, Training Accuracy= 83.59375
# Fold: 8, Epoch: 18, Mini Batch: 60, Loss= 5741433.000000, Training Accuracy= 79.68750
# Fold: 8, Epoch: 18, Mini Batch: 70, Loss= 4586012.000000, Training Accuracy= 83.59375
#
# Fold: 8, Epoch: 18, Validation Accuracy= 88.10000
#
# Fold: 8, Epoch: 19, Mini Batch: 30, Loss= 3736025.250000, Training Accuracy= 86.71875
# Fold: 8, Epoch: 19, Mini Batch: 60, Loss= 4962918.000000, Training Accuracy= 88.28125
# Fold: 8, Epoch: 19, Mini Batch: 70, Loss= 3119682.000000, Training Accuracy= 86.71875
#
# Fold: 8, Epoch: 19, Validation Accuracy= 88.70000
#
# Fold: 8, Epoch: 20, Mini Batch: 30, Loss= 1912879.500000, Training Accuracy= 88.28125
# Fold: 8, Epoch: 20, Mini Batch: 60, Loss= 5474199.000000, Training Accuracy= 83.59375
# Fold: 8, Epoch: 20, Mini Batch: 70, Loss= 2564367.500000, Training Accuracy= 84.37500
#
# Fold: 8, Epoch: 20, Validation Accuracy= 88.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          417   34   451
# 1           83  466   549
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 9, Epoch: 1, Mini Batch: 30, Loss= 269204288.000000, Training Accuracy= 68.75000
# Fold: 9, Epoch: 1, Mini Batch: 60, Loss= 230255840.000000, Training Accuracy= 64.84375
# Fold: 9, Epoch: 1, Mini Batch: 70, Loss= 136573040.000000, Training Accuracy= 72.65625
#
# Fold: 9, Epoch: 1, Validation Accuracy= 82.30000
#
# Fold: 9, Epoch: 2, Mini Batch: 30, Loss= 104891024.000000, Training Accuracy= 77.34375
# Fold: 9, Epoch: 2, Mini Batch: 60, Loss= 71074328.000000, Training Accuracy= 76.56250
# Fold: 9, Epoch: 2, Mini Batch: 70, Loss= 64536008.000000, Training Accuracy= 73.43750
#
# Fold: 9, Epoch: 2, Validation Accuracy= 86.00000
#
# Fold: 9, Epoch: 3, Mini Batch: 30, Loss= 39879880.000000, Training Accuracy= 75.78125
# Fold: 9, Epoch: 3, Mini Batch: 60, Loss= 31176180.000000, Training Accuracy= 82.03125
# Fold: 9, Epoch: 3, Mini Batch: 70, Loss= 32503432.000000, Training Accuracy= 84.37500
#
# Fold: 9, Epoch: 3, Validation Accuracy= 86.20000
#
# Fold: 9, Epoch: 4, Mini Batch: 30, Loss= 33029706.000000, Training Accuracy= 80.46875
# Fold: 9, Epoch: 4, Mini Batch: 60, Loss= 19558638.000000, Training Accuracy= 79.68750
# Fold: 9, Epoch: 4, Mini Batch: 70, Loss= 36523888.000000, Training Accuracy= 78.12500
#
# Fold: 9, Epoch: 4, Validation Accuracy= 87.50000
#
# Fold: 9, Epoch: 5, Mini Batch: 30, Loss= 29787000.000000, Training Accuracy= 78.90625
# Fold: 9, Epoch: 5, Mini Batch: 60, Loss= 19866458.000000, Training Accuracy= 79.68750
# Fold: 9, Epoch: 5, Mini Batch: 70, Loss= 21491418.000000, Training Accuracy= 82.03125
#
# Fold: 9, Epoch: 5, Validation Accuracy= 88.00000
#
# Fold: 9, Epoch: 6, Mini Batch: 30, Loss= 13049128.000000, Training Accuracy= 82.81250
# Fold: 9, Epoch: 6, Mini Batch: 60, Loss= 15985792.000000, Training Accuracy= 80.46875
# Fold: 9, Epoch: 6, Mini Batch: 70, Loss= 14293670.000000, Training Accuracy= 85.15625
#
# Fold: 9, Epoch: 6, Validation Accuracy= 87.90000
#
# Fold: 9, Epoch: 7, Mini Batch: 30, Loss= 16103147.000000, Training Accuracy= 77.34375
# Fold: 9, Epoch: 7, Mini Batch: 60, Loss= 9549497.000000, Training Accuracy= 83.59375
# Fold: 9, Epoch: 7, Mini Batch: 70, Loss= 12046171.000000, Training Accuracy= 82.03125
#
# Fold: 9, Epoch: 7, Validation Accuracy= 88.50000
#
# Fold: 9, Epoch: 8, Mini Batch: 30, Loss= 9450117.000000, Training Accuracy= 84.37500
# Fold: 9, Epoch: 8, Mini Batch: 60, Loss= 6816786.000000, Training Accuracy= 82.81250
# Fold: 9, Epoch: 8, Mini Batch: 70, Loss= 10650682.000000, Training Accuracy= 83.59375
#
# Fold: 9, Epoch: 8, Validation Accuracy= 87.60000
#
# Fold: 9, Epoch: 9, Mini Batch: 30, Loss= 10973723.000000, Training Accuracy= 83.59375
# Fold: 9, Epoch: 9, Mini Batch: 60, Loss= 10372761.000000, Training Accuracy= 83.59375
# Fold: 9, Epoch: 9, Mini Batch: 70, Loss= 8393934.000000, Training Accuracy= 85.93750
#
# Fold: 9, Epoch: 9, Validation Accuracy= 87.70000
#
# Fold: 9, Epoch: 10, Mini Batch: 30, Loss= 6842411.500000, Training Accuracy= 88.28125
# Fold: 9, Epoch: 10, Mini Batch: 60, Loss= 6904503.500000, Training Accuracy= 80.46875
# Fold: 9, Epoch: 10, Mini Batch: 70, Loss= 10410146.000000, Training Accuracy= 76.56250
#
# Fold: 9, Epoch: 10, Validation Accuracy= 87.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          434   58   492
# 1           66  442   508
# All        500  500  1000
#
# Fold: 9, Epoch: 11, Mini Batch: 30, Loss= 7911580.000000, Training Accuracy= 79.68750
# Fold: 9, Epoch: 11, Mini Batch: 60, Loss= 4507600.000000, Training Accuracy= 83.59375
# Fold: 9, Epoch: 11, Mini Batch: 70, Loss= 6443940.500000, Training Accuracy= 88.28125
#
# Fold: 9, Epoch: 11, Validation Accuracy= 87.00000
#
# Fold: 9, Epoch: 12, Mini Batch: 30, Loss= 7101781.000000, Training Accuracy= 84.37500
# Fold: 9, Epoch: 12, Mini Batch: 60, Loss= 5029003.500000, Training Accuracy= 80.46875
# Fold: 9, Epoch: 12, Mini Batch: 70, Loss= 4868638.000000, Training Accuracy= 85.93750
#
# Fold: 9, Epoch: 12, Validation Accuracy= 87.90000
#
# Fold: 9, Epoch: 13, Mini Batch: 30, Loss= 5197625.000000, Training Accuracy= 85.93750
# Fold: 9, Epoch: 13, Mini Batch: 60, Loss= 6422446.000000, Training Accuracy= 83.59375
# Fold: 9, Epoch: 13, Mini Batch: 70, Loss= 3800507.250000, Training Accuracy= 85.93750
#
# Fold: 9, Epoch: 13, Validation Accuracy= 88.10000
#
# Fold: 9, Epoch: 14, Mini Batch: 30, Loss= 3528373.750000, Training Accuracy= 87.50000
# Fold: 9, Epoch: 14, Mini Batch: 60, Loss= 4495339.000000, Training Accuracy= 86.71875
# Fold: 9, Epoch: 14, Mini Batch: 70, Loss= 7796429.500000, Training Accuracy= 81.25000
#
# Fold: 9, Epoch: 14, Validation Accuracy= 88.90000
#
# Fold: 9, Epoch: 15, Mini Batch: 30, Loss= 4631835.500000, Training Accuracy= 83.59375
# Fold: 9, Epoch: 15, Mini Batch: 60, Loss= 4111380.000000, Training Accuracy= 85.93750
# Fold: 9, Epoch: 15, Mini Batch: 70, Loss= 3732090.000000, Training Accuracy= 85.15625
#
# Fold: 9, Epoch: 15, Validation Accuracy= 89.00000
#
# Fold: 9, Epoch: 16, Mini Batch: 30, Loss= 2124029.000000, Training Accuracy= 92.18750
# Fold: 9, Epoch: 16, Mini Batch: 60, Loss= 3681461.000000, Training Accuracy= 87.50000
# Fold: 9, Epoch: 16, Mini Batch: 70, Loss= 8847586.000000, Training Accuracy= 80.46875
#
# Fold: 9, Epoch: 16, Validation Accuracy= 88.90000
#
# Fold: 9, Epoch: 17, Mini Batch: 30, Loss= 4623866.000000, Training Accuracy= 84.37500
# Fold: 9, Epoch: 17, Mini Batch: 60, Loss= 2019434.500000, Training Accuracy= 89.84375
# Fold: 9, Epoch: 17, Mini Batch: 70, Loss= 4357272.000000, Training Accuracy= 82.03125
#
# Fold: 9, Epoch: 17, Validation Accuracy= 88.90000
#
# Fold: 9, Epoch: 18, Mini Batch: 30, Loss= 4875339.000000, Training Accuracy= 84.37500
# Fold: 9, Epoch: 18, Mini Batch: 60, Loss= 3703472.500000, Training Accuracy= 87.50000
# Fold: 9, Epoch: 18, Mini Batch: 70, Loss= 4810819.000000, Training Accuracy= 85.93750
#
# Fold: 9, Epoch: 18, Validation Accuracy= 89.00000
#
# Fold: 9, Epoch: 19, Mini Batch: 30, Loss= 3723688.250000, Training Accuracy= 82.81250
# Fold: 9, Epoch: 19, Mini Batch: 60, Loss= 1546436.750000, Training Accuracy= 89.06250
# Fold: 9, Epoch: 19, Mini Batch: 70, Loss= 3861291.750000, Training Accuracy= 83.59375
#
# Fold: 9, Epoch: 19, Validation Accuracy= 88.40000
#
# Fold: 9, Epoch: 20, Mini Batch: 30, Loss= 1326289.000000, Training Accuracy= 92.96875
# Fold: 9, Epoch: 20, Mini Batch: 60, Loss= 2171819.000000, Training Accuracy= 89.06250
# Fold: 9, Epoch: 20, Mini Batch: 70, Loss= 3244132.000000, Training Accuracy= 86.71875
#
# Fold: 9, Epoch: 20, Validation Accuracy= 89.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          439   48   487
# 1           61  452   513
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 10, Epoch: 1, Mini Batch: 30, Loss= 269204288.000000, Training Accuracy= 68.75000
# Fold: 10, Epoch: 1, Mini Batch: 60, Loss= 230255840.000000, Training Accuracy= 64.84375
# Fold: 10, Epoch: 1, Mini Batch: 70, Loss= 106996640.000000, Training Accuracy= 74.21875
#
# Fold: 10, Epoch: 1, Validation Accuracy= 83.20000
#
# Fold: 10, Epoch: 2, Mini Batch: 30, Loss= 105943184.000000, Training Accuracy= 75.78125
# Fold: 10, Epoch: 2, Mini Batch: 60, Loss= 73656352.000000, Training Accuracy= 74.21875
# Fold: 10, Epoch: 2, Mini Batch: 70, Loss= 41849584.000000, Training Accuracy= 77.34375
#
# Fold: 10, Epoch: 2, Validation Accuracy= 85.30000
#
# Fold: 10, Epoch: 3, Mini Batch: 30, Loss= 35635400.000000, Training Accuracy= 78.90625
# Fold: 10, Epoch: 3, Mini Batch: 60, Loss= 30180552.000000, Training Accuracy= 79.68750
# Fold: 10, Epoch: 3, Mini Batch: 70, Loss= 31692494.000000, Training Accuracy= 77.34375
#
# Fold: 10, Epoch: 3, Validation Accuracy= 84.40000
#
# Fold: 10, Epoch: 4, Mini Batch: 30, Loss= 31487530.000000, Training Accuracy= 75.78125
# Fold: 10, Epoch: 4, Mini Batch: 60, Loss= 18802070.000000, Training Accuracy= 82.81250
# Fold: 10, Epoch: 4, Mini Batch: 70, Loss= 19713788.000000, Training Accuracy= 78.12500
#
# Fold: 10, Epoch: 4, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 5, Mini Batch: 30, Loss= 28080660.000000, Training Accuracy= 78.12500
# Fold: 10, Epoch: 5, Mini Batch: 60, Loss= 15700347.000000, Training Accuracy= 81.25000
# Fold: 10, Epoch: 5, Mini Batch: 70, Loss= 19441278.000000, Training Accuracy= 81.25000
#
# Fold: 10, Epoch: 5, Validation Accuracy= 88.30000
#
# Fold: 10, Epoch: 6, Mini Batch: 30, Loss= 11865743.000000, Training Accuracy= 85.15625
# Fold: 10, Epoch: 6, Mini Batch: 60, Loss= 13360485.000000, Training Accuracy= 81.25000
# Fold: 10, Epoch: 6, Mini Batch: 70, Loss= 10986918.000000, Training Accuracy= 87.50000
#
# Fold: 10, Epoch: 6, Validation Accuracy= 88.10000
#
# Fold: 10, Epoch: 7, Mini Batch: 30, Loss= 17859224.000000, Training Accuracy= 80.46875
# Fold: 10, Epoch: 7, Mini Batch: 60, Loss= 11062098.000000, Training Accuracy= 81.25000
# Fold: 10, Epoch: 7, Mini Batch: 70, Loss= 11608352.000000, Training Accuracy= 83.59375
#
# Fold: 10, Epoch: 7, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 8, Mini Batch: 30, Loss= 7281694.500000, Training Accuracy= 84.37500
# Fold: 10, Epoch: 8, Mini Batch: 60, Loss= 9335030.000000, Training Accuracy= 80.46875
# Fold: 10, Epoch: 8, Mini Batch: 70, Loss= 12740328.000000, Training Accuracy= 85.15625
#
# Fold: 10, Epoch: 8, Validation Accuracy= 87.00000
#
# Fold: 10, Epoch: 9, Mini Batch: 30, Loss= 10707197.000000, Training Accuracy= 82.03125
# Fold: 10, Epoch: 9, Mini Batch: 60, Loss= 8436745.000000, Training Accuracy= 84.37500
# Fold: 10, Epoch: 9, Mini Batch: 70, Loss= 9177432.000000, Training Accuracy= 80.46875
#
# Fold: 10, Epoch: 9, Validation Accuracy= 85.90000
#
# Fold: 10, Epoch: 10, Mini Batch: 30, Loss= 9268378.000000, Training Accuracy= 81.25000
# Fold: 10, Epoch: 10, Mini Batch: 60, Loss= 6123200.000000, Training Accuracy= 83.59375
# Fold: 10, Epoch: 10, Mini Batch: 70, Loss= 6712925.000000, Training Accuracy= 85.15625
#
# Fold: 10, Epoch: 10, Validation Accuracy= 88.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          440   58   498
# 1           60  442   502
# All        500  500  1000
#
# Fold: 10, Epoch: 11, Mini Batch: 30, Loss= 6862722.000000, Training Accuracy= 83.59375
# Fold: 10, Epoch: 11, Mini Batch: 60, Loss= 4966796.000000, Training Accuracy= 84.37500
# Fold: 10, Epoch: 11, Mini Batch: 70, Loss= 5370475.500000, Training Accuracy= 82.81250
#
# Fold: 10, Epoch: 11, Validation Accuracy= 87.90000
#
# Fold: 10, Epoch: 12, Mini Batch: 30, Loss= 5870640.000000, Training Accuracy= 85.93750
# Fold: 10, Epoch: 12, Mini Batch: 60, Loss= 5909245.000000, Training Accuracy= 82.03125
# Fold: 10, Epoch: 12, Mini Batch: 70, Loss= 5359577.500000, Training Accuracy= 81.25000
#
# Fold: 10, Epoch: 12, Validation Accuracy= 88.40000
#
# Fold: 10, Epoch: 13, Mini Batch: 30, Loss= 5078530.000000, Training Accuracy= 84.37500
# Fold: 10, Epoch: 13, Mini Batch: 60, Loss= 3918744.250000, Training Accuracy= 86.71875
# Fold: 10, Epoch: 13, Mini Batch: 70, Loss= 4553261.000000, Training Accuracy= 86.71875
#
# Fold: 10, Epoch: 13, Validation Accuracy= 88.10000
#
# Fold: 10, Epoch: 14, Mini Batch: 30, Loss= 4239114.000000, Training Accuracy= 85.15625
# Fold: 10, Epoch: 14, Mini Batch: 60, Loss= 2897425.000000, Training Accuracy= 87.50000
# Fold: 10, Epoch: 14, Mini Batch: 70, Loss= 2453699.250000, Training Accuracy= 85.15625
#
# Fold: 10, Epoch: 14, Validation Accuracy= 88.40000
#
# Fold: 10, Epoch: 15, Mini Batch: 30, Loss= 3578705.250000, Training Accuracy= 85.15625
# Fold: 10, Epoch: 15, Mini Batch: 60, Loss= 3717602.000000, Training Accuracy= 85.93750
# Fold: 10, Epoch: 15, Mini Batch: 70, Loss= 5347910.000000, Training Accuracy= 82.03125
#
# Fold: 10, Epoch: 15, Validation Accuracy= 88.80000
#
# Fold: 10, Epoch: 16, Mini Batch: 30, Loss= 1893952.000000, Training Accuracy= 90.62500
# Fold: 10, Epoch: 16, Mini Batch: 60, Loss= 3320211.000000, Training Accuracy= 84.37500
# Fold: 10, Epoch: 16, Mini Batch: 70, Loss= 5335565.500000, Training Accuracy= 85.15625
#
# Fold: 10, Epoch: 16, Validation Accuracy= 88.10000
#
# Fold: 10, Epoch: 17, Mini Batch: 30, Loss= 4563518.000000, Training Accuracy= 84.37500
# Fold: 10, Epoch: 17, Mini Batch: 60, Loss= 2144313.500000, Training Accuracy= 87.50000
# Fold: 10, Epoch: 17, Mini Batch: 70, Loss= 2380013.750000, Training Accuracy= 84.37500
#
# Fold: 10, Epoch: 17, Validation Accuracy= 88.40000
#
# Fold: 10, Epoch: 18, Mini Batch: 30, Loss= 3890229.500000, Training Accuracy= 81.25000
# Fold: 10, Epoch: 18, Mini Batch: 60, Loss= 2633785.250000, Training Accuracy= 85.15625
# Fold: 10, Epoch: 18, Mini Batch: 70, Loss= 3426030.750000, Training Accuracy= 82.81250
#
# Fold: 10, Epoch: 18, Validation Accuracy= 87.60000
#
# Fold: 10, Epoch: 19, Mini Batch: 30, Loss= 4328436.000000, Training Accuracy= 85.15625
# Fold: 10, Epoch: 19, Mini Batch: 60, Loss= 1033651.000000, Training Accuracy= 93.75000
# Fold: 10, Epoch: 19, Mini Batch: 70, Loss= 1848226.625000, Training Accuracy= 85.93750
#
# Fold: 10, Epoch: 19, Validation Accuracy= 88.30000
#
# Fold: 10, Epoch: 20, Mini Batch: 30, Loss= 1763521.250000, Training Accuracy= 87.50000
# Fold: 10, Epoch: 20, Mini Batch: 60, Loss= 2201938.000000, Training Accuracy= 88.28125
# Fold: 10, Epoch: 20, Mini Batch: 70, Loss= 2440160.500000, Training Accuracy= 86.71875
#
# Fold: 10, Epoch: 20, Validation Accuracy= 89.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          438   41   479
# 1           62  459   521
# All        500  500  1000
#
# --- 9259.462271928787 seconds --- 154.32437131404876 minutes--- 2.572072856624921 hours
# The mean Valid Accuracy per fold is :  89.49
# The mean Valid Accuracy based on epochs for the fold number (1) is :  88.555
# The mean Valid Accuracy based on epochs for the fold number (2) is :  87.715
# The mean Valid Accuracy based on epochs for the fold number (3) is :  88.155
# The mean Valid Accuracy based on epochs for the fold number (4) is :  86.45
# The mean Valid Accuracy based on epochs for the fold number (5) is :  88.97
# The mean Valid Accuracy based on epochs for the fold number (6) is :  88.405
# The mean Valid Accuracy based on epochs for the fold number (7) is :  87.775
# The mean Valid Accuracy based on epochs for the fold number (8) is :  87.565
# The mean Valid Accuracy based on epochs for the fold number (9) is :  87.725
# The mean Valid Accuracy based on epochs for the fold number (10) is :  87.385

# %%
rows = 2
columns = 5
vizualize(vaccPerEpochPerFold, 
          taccPerEpochPerFold, 
          meanValidAcc=meanValidAcc, 
          epochMeanValidAcc=epochMeanValidAcc,
          rows=rows, 
          columns=columns, 
          figsize=(5*columns, 5*rows))


# validacc_dict, trainacc_dict, meanValidAcc, epochMeanValidAcc,

# %% [markdown]
# ## CONV: | RGB | Preprocessed | Augmented | RMSPROP Optimizer | [3x3x64, 5x5x64], [1024x1024]
# -------

# %%
featureDIR = RGBbatch_dir

params = dict(imageSize = 32,
              seed = 2316,                 # Set the seeds for the random weights generator
              numFolds = 1,
              
              # Network Parameters
              numLabels = 2,
              numChannels = 3,             # numChannels -> For grayscale =1, for RGB =3
              numHidden1 = 1024,           # numHiddenUnits for the fully connected layerr
              numHidden2 = 1024,            # numHiddenUnits for the fully connected layer
              
              conv1Kernel = 3,             # Size of kernel for the first convolution layer
              conv2Kernel = 5,             # Size of kernel for the second convolution layer
              conv1Depth = 64,             # Number of kernels for the first convolution layer
              conv2Depth = 64,             # Number of kernels for the second convolution layer
              conv1Stride = 1,             # Strides for the first convolution layer filter  
              conv2Stride = 1,             # Strides for the second convolution layer filter
              
              pool1Kernel = 2,             # Size of kernel for the first Pooling layer
              pool2Kernel = 2,             # Size of kernel for the second Pooling layer  
              pool1Stride = 2,             # Strides for the first Pooling layer filter
              pool2Stride = 2,             # Strides for the second Pooling layer filter
              
              # Learning Variables     
              epochs = 20,
              batchSize = 128,
        
              keepProb = dict(fc1=0.5, fc2=0.5),
              optimizerParam = dict(optimizer='RMSPROP', learning_rate=0.0001, momentum=0.9)
#               optimizerParam = dict(optimizer='ADAM', learning_rate=0.003)  # at 0.003 descents slowely, 
        )
(out, meanValidAcc, lossPerEpochPerFold, 
 taccPerEpochPerFold, vaccPerEpochPerFold, validCMDict) = SessionExec(featureDIR, params).execute() 

print ('The mean Valid Accuracy per fold is : ', meanValidAcc)
for nfold in np.arange(params['numFolds']):
    print ('The mean Valid Accuracy based on epochs for the fold number (%s) is : '%str(nfold+1), np.mean(vaccPerEpochPerFold[nfold + 1]))
    epochMeanValidAcc = np.mean(vaccPerEpochPerFold[nfold + 1])
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# WARNING:tensorflow:From <ipython-input-10-da0aab849e95>:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Fold: 1, Epoch: 1, Mini Batch: 10, Loss= 400220416.000000, Training Accuracy= 59.37500
# Fold: 1, Epoch: 1, Mini Batch: 20, Loss= 272674912.000000, Training Accuracy= 58.59375
# Fold: 1, Epoch: 1, Mini Batch: 30, Loss= 261731328.000000, Training Accuracy= 57.81250
# Fold: 1, Epoch: 1, Mini Batch: 40, Loss= 169993696.000000, Training Accuracy= 67.18750
# Fold: 1, Epoch: 1, Mini Batch: 50, Loss= 91929320.000000, Training Accuracy= 70.31250
# Fold: 1, Epoch: 1, Mini Batch: 60, Loss= 79881832.000000, Training Accuracy= 70.31250
# Fold: 1, Epoch: 1, Mini Batch: 70, Loss= 80197888.000000, Training Accuracy= 72.65625
#
# Fold: 1, Epoch: 1, Validation Accuracy= 84.60000
#
# Fold: 1, Epoch: 2, Mini Batch: 10, Loss= 72246096.000000, Training Accuracy= 78.12500
# Fold: 1, Epoch: 2, Mini Batch: 20, Loss= 101729032.000000, Training Accuracy= 75.00000
# Fold: 1, Epoch: 2, Mini Batch: 30, Loss= 70415392.000000, Training Accuracy= 70.31250
# Fold: 1, Epoch: 2, Mini Batch: 40, Loss= 56434076.000000, Training Accuracy= 72.65625
# Fold: 1, Epoch: 2, Mini Batch: 50, Loss= 46026872.000000, Training Accuracy= 73.43750
# Fold: 1, Epoch: 2, Mini Batch: 60, Loss= 46794480.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 2, Mini Batch: 70, Loss= 37266384.000000, Training Accuracy= 73.43750
#
# Fold: 1, Epoch: 2, Validation Accuracy= 88.30000
#
# Fold: 1, Epoch: 3, Mini Batch: 10, Loss= 35705612.000000, Training Accuracy= 75.00000
# Fold: 1, Epoch: 3, Mini Batch: 20, Loss= 33253754.000000, Training Accuracy= 78.12500
# Fold: 1, Epoch: 3, Mini Batch: 30, Loss= 23934948.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 3, Mini Batch: 40, Loss= 30789590.000000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 3, Mini Batch: 50, Loss= 30537968.000000, Training Accuracy= 75.78125
# Fold: 1, Epoch: 3, Mini Batch: 60, Loss= 24863242.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 3, Mini Batch: 70, Loss= 26217522.000000, Training Accuracy= 75.78125
#
# Fold: 1, Epoch: 3, Validation Accuracy= 88.40000
#
# Fold: 1, Epoch: 4, Mini Batch: 10, Loss= 23314190.000000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 4, Mini Batch: 20, Loss= 30215160.000000, Training Accuracy= 75.78125
# Fold: 1, Epoch: 4, Mini Batch: 30, Loss= 24050084.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 4, Mini Batch: 40, Loss= 18003504.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 4, Mini Batch: 50, Loss= 19716430.000000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 4, Mini Batch: 60, Loss= 23814196.000000, Training Accuracy= 75.78125
# Fold: 1, Epoch: 4, Mini Batch: 70, Loss= 14825818.000000, Training Accuracy= 82.81250
#
# Fold: 1, Epoch: 4, Validation Accuracy= 89.10000
#
# Fold: 1, Epoch: 5, Mini Batch: 10, Loss= 13880202.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 5, Mini Batch: 20, Loss= 20256680.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 5, Mini Batch: 30, Loss= 19236538.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 5, Mini Batch: 40, Loss= 14431842.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 5, Mini Batch: 50, Loss= 12507496.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 5, Mini Batch: 60, Loss= 15986263.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 5, Mini Batch: 70, Loss= 11012755.000000, Training Accuracy= 78.12500
#
# Fold: 1, Epoch: 5, Validation Accuracy= 88.90000
#
# Fold: 1, Epoch: 6, Mini Batch: 10, Loss= 7919191.500000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 6, Mini Batch: 20, Loss= 15818237.000000, Training Accuracy= 75.00000
# Fold: 1, Epoch: 6, Mini Batch: 30, Loss= 9797525.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 6, Mini Batch: 40, Loss= 9918490.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 6, Mini Batch: 50, Loss= 15111754.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 6, Mini Batch: 60, Loss= 8670021.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 6, Mini Batch: 70, Loss= 13600446.000000, Training Accuracy= 81.25000
#
# Fold: 1, Epoch: 6, Validation Accuracy= 88.90000
#
# Fold: 1, Epoch: 7, Mini Batch: 10, Loss= 6018126.500000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 7, Mini Batch: 20, Loss= 13005072.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 7, Mini Batch: 30, Loss= 10972180.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 7, Mini Batch: 40, Loss= 7099965.500000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 7, Mini Batch: 50, Loss= 10121954.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 7, Mini Batch: 60, Loss= 6405173.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 7, Mini Batch: 70, Loss= 4017031.500000, Training Accuracy= 85.15625
#
# Fold: 1, Epoch: 7, Validation Accuracy= 88.50000
#
# Fold: 1, Epoch: 8, Mini Batch: 10, Loss= 5804134.500000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 8, Mini Batch: 20, Loss= 7778521.500000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 8, Mini Batch: 30, Loss= 9983376.000000, Training Accuracy= 78.12500
# Fold: 1, Epoch: 8, Mini Batch: 40, Loss= 6841777.000000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 8, Mini Batch: 50, Loss= 6398881.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 8, Mini Batch: 60, Loss= 5293104.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 8, Mini Batch: 70, Loss= 9275116.000000, Training Accuracy= 82.81250
#
# Fold: 1, Epoch: 8, Validation Accuracy= 88.60000
#
# Fold: 1, Epoch: 9, Mini Batch: 10, Loss= 9618028.000000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 9, Mini Batch: 20, Loss= 7455240.500000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 9, Mini Batch: 30, Loss= 7461986.000000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 9, Mini Batch: 40, Loss= 8277169.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 9, Mini Batch: 50, Loss= 7830238.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 9, Mini Batch: 60, Loss= 7290748.500000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 9, Mini Batch: 70, Loss= 6227008.000000, Training Accuracy= 85.15625
#
# Fold: 1, Epoch: 9, Validation Accuracy= 90.00000
#
# Fold: 1, Epoch: 10, Mini Batch: 10, Loss= 3662492.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 10, Mini Batch: 20, Loss= 8048516.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 10, Mini Batch: 30, Loss= 8418260.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 10, Mini Batch: 40, Loss= 2380756.000000, Training Accuracy= 90.62500
# Fold: 1, Epoch: 10, Mini Batch: 50, Loss= 4773088.000000, Training Accuracy= 91.40625
# Fold: 1, Epoch: 10, Mini Batch: 60, Loss= 6693538.500000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 10, Mini Batch: 70, Loss= 3883272.750000, Training Accuracy= 86.71875
#
# Fold: 1, Epoch: 10, Validation Accuracy= 90.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          451   48   499
# 1           49  452   501
# All        500  500  1000
#
# Fold: 1, Epoch: 11, Mini Batch: 10, Loss= 3313508.750000, Training Accuracy= 89.84375
# Fold: 1, Epoch: 11, Mini Batch: 20, Loss= 7777551.000000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 11, Mini Batch: 30, Loss= 6442629.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 11, Mini Batch: 40, Loss= 4045889.250000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 11, Mini Batch: 50, Loss= 3881568.000000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 11, Mini Batch: 60, Loss= 8099382.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 11, Mini Batch: 70, Loss= 5706419.000000, Training Accuracy= 83.59375
#
# Fold: 1, Epoch: 11, Validation Accuracy= 90.00000
#
# Fold: 1, Epoch: 12, Mini Batch: 10, Loss= 3578616.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 12, Mini Batch: 20, Loss= 5100441.500000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 12, Mini Batch: 30, Loss= 7705222.500000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 12, Mini Batch: 40, Loss= 5477021.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 12, Mini Batch: 50, Loss= 7378679.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 12, Mini Batch: 60, Loss= 6531939.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 12, Mini Batch: 70, Loss= 4737543.000000, Training Accuracy= 85.93750
#
# Fold: 1, Epoch: 12, Validation Accuracy= 89.30000
#
# Fold: 1, Epoch: 13, Mini Batch: 10, Loss= 4491630.500000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 13, Mini Batch: 20, Loss= 3580485.750000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 13, Mini Batch: 30, Loss= 4252660.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 13, Mini Batch: 40, Loss= 4174797.500000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 13, Mini Batch: 50, Loss= 4268574.500000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 13, Mini Batch: 60, Loss= 3272117.500000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 13, Mini Batch: 70, Loss= 4765133.000000, Training Accuracy= 85.93750
#
# Fold: 1, Epoch: 13, Validation Accuracy= 89.20000
#
# Fold: 1, Epoch: 14, Mini Batch: 10, Loss= 3844225.500000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 14, Mini Batch: 20, Loss= 4521184.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 14, Mini Batch: 30, Loss= 3343094.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 14, Mini Batch: 40, Loss= 4136772.750000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 14, Mini Batch: 50, Loss= 5305770.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 14, Mini Batch: 60, Loss= 3376752.000000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 14, Mini Batch: 70, Loss= 3687447.750000, Training Accuracy= 81.25000
#
# Fold: 1, Epoch: 14, Validation Accuracy= 89.80000
#
# Fold: 1, Epoch: 15, Mini Batch: 10, Loss= 2352112.000000, Training Accuracy= 92.18750
# Fold: 1, Epoch: 15, Mini Batch: 20, Loss= 4058523.000000, Training Accuracy= 89.84375
# Fold: 1, Epoch: 15, Mini Batch: 30, Loss= 3173428.500000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 15, Mini Batch: 40, Loss= 3305319.500000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 15, Mini Batch: 50, Loss= 2964750.500000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 15, Mini Batch: 60, Loss= 5019208.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 15, Mini Batch: 70, Loss= 1756257.250000, Training Accuracy= 89.84375
#
# Fold: 1, Epoch: 15, Validation Accuracy= 90.00000
#
# Fold: 1, Epoch: 16, Mini Batch: 10, Loss= 2242284.500000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 16, Mini Batch: 20, Loss= 2998261.000000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 16, Mini Batch: 30, Loss= 4931233.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 16, Mini Batch: 40, Loss= 1907222.625000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 16, Mini Batch: 50, Loss= 2441707.750000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 16, Mini Batch: 60, Loss= 3013954.500000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 16, Mini Batch: 70, Loss= 3182436.000000, Training Accuracy= 87.50000
#
# Fold: 1, Epoch: 16, Validation Accuracy= 90.30000
#
# Fold: 1, Epoch: 17, Mini Batch: 10, Loss= 1169286.750000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 17, Mini Batch: 20, Loss= 2392547.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 17, Mini Batch: 30, Loss= 2544023.000000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 17, Mini Batch: 40, Loss= 3696672.500000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 17, Mini Batch: 50, Loss= 1824692.750000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 17, Mini Batch: 60, Loss= 2440372.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 17, Mini Batch: 70, Loss= 1947537.625000, Training Accuracy= 88.28125
#
# Fold: 1, Epoch: 17, Validation Accuracy= 89.90000
#
# Fold: 1, Epoch: 18, Mini Batch: 10, Loss= 1170906.500000, Training Accuracy= 90.62500
# Fold: 1, Epoch: 18, Mini Batch: 20, Loss= 2413443.500000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 18, Mini Batch: 30, Loss= 3094823.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 18, Mini Batch: 40, Loss= 1674477.250000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 18, Mini Batch: 50, Loss= 2652755.250000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 18, Mini Batch: 60, Loss= 2528187.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 18, Mini Batch: 70, Loss= 1358166.875000, Training Accuracy= 92.96875
#
# Fold: 1, Epoch: 18, Validation Accuracy= 90.40000
#
# Fold: 1, Epoch: 19, Mini Batch: 10, Loss= 1004538.812500, Training Accuracy= 92.18750
# Fold: 1, Epoch: 19, Mini Batch: 20, Loss= 2797177.250000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 19, Mini Batch: 30, Loss= 2077640.750000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 19, Mini Batch: 40, Loss= 3132198.500000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 19, Mini Batch: 50, Loss= 3463411.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 19, Mini Batch: 60, Loss= 2200500.000000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 19, Mini Batch: 70, Loss= 1296503.500000, Training Accuracy= 89.84375
#
# Fold: 1, Epoch: 19, Validation Accuracy= 90.70000
#
# Fold: 1, Epoch: 20, Mini Batch: 10, Loss= 1017000.625000, Training Accuracy= 92.96875
# Fold: 1, Epoch: 20, Mini Batch: 20, Loss= 2795702.000000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 20, Mini Batch: 30, Loss= 2263943.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 20, Mini Batch: 40, Loss= 1739268.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 20, Mini Batch: 50, Loss= 1552848.875000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 20, Mini Batch: 60, Loss= 2280300.750000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 20, Mini Batch: 70, Loss= 1696066.375000, Training Accuracy= 87.50000
#
# Fold: 1, Epoch: 20, Validation Accuracy= 89.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          423   25   448
# 1           77  475   552
# All        500  500  1000
#
# The mean Valid Accuracy per fold is :  89.8
# The mean Valid Accuracy based on epochs for the fold number (1) is :  89.25

# %%
rows = 1
columns = 2
vizualize(vaccPerEpochPerFold, taccPerEpochPerFold, 
          meanValidAcc=meanValidAcc, epochMeanValidAcc=epochMeanValidAcc, rows=rows, columns=columns, figsize=(5*columns, 5*rows))

# %%
ax = plt.figure(figsize=(40,10), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
featureDIR = RGBbatch_dir

params = dict(imageSize = 32,
              seed = 2316,                 # Set the seeds for the random weights generator
              numFolds = 1,
              
              # Network Parameters
              numLabels = 2,
              numChannels = 3,             # numChannels -> For grayscale =1, for RGB =3
              numHidden1 = 1280,           # numHiddenUnits for the fully connected layerr
              numHidden2 = 1024,            # numHiddenUnits for the fully connected layer
              
              conv1Kernel = 3,             # Size of kernel for the first convolution layer
              conv2Kernel = 5,             # Size of kernel for the second convolution layer
              conv1Depth = 64,             # Number of kernels for the first convolution layer
              conv2Depth = 64,             # Number of kernels for the second convolution layer
              conv1Stride = 1,             # Strides for the first convolution layer filter  
              conv2Stride = 1,             # Strides for the second convolution layer filter
              
              pool1Kernel = 2,             # Size of kernel for the first Pooling layer
              pool2Kernel = 2,             # Size of kernel for the second Pooling layer  
              pool1Stride = 2,             # Strides for the first Pooling layer filter
              pool2Stride = 2,             # Strides for the second Pooling layer filter
              
              # Learning Variables     
              epochs = 20,
              batchSize = 128,
        
              keepProb = dict(fc1=0.5, fc2=0.5),
              optimizerParam = dict(optimizer='RMSPROP', learning_rate=0.00008, momentum=0.9)
#               optimizerParam = dict(optimizer='ADAM', learning_rate=0.003)  # at 0.003 descents slowely, 
        )
(out, meanValidAcc, lossPerEpochPerFold, 
 taccPerEpochPerFold, vaccPerEpochPerFold, validCMDict) = SessionExec(featureDIR, params).execute() 

print ('The mean Valid Accuracy per fold is : ', meanValidAcc)
for nfold in np.arange(params['numFolds']):
    print ('The mean Valid Accuracy based on epochs for the fold number (%s) is : '%str(nfold+1), np.mean(vaccPerEpochPerFold[nfold + 1]))
    epochMeanValidAcc = np.mean(vaccPerEpochPerFold[nfold + 1])
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 1, Epoch: 1, Mini Batch: 10, Loss= 608151104.000000, Training Accuracy= 46.09375
# Fold: 1, Epoch: 1, Mini Batch: 20, Loss= 406857984.000000, Training Accuracy= 55.46875
# Fold: 1, Epoch: 1, Mini Batch: 30, Loss= 299970080.000000, Training Accuracy= 58.59375
# Fold: 1, Epoch: 1, Mini Batch: 40, Loss= 298549856.000000, Training Accuracy= 61.71875
# Fold: 1, Epoch: 1, Mini Batch: 50, Loss= 185782272.000000, Training Accuracy= 69.53125
# Fold: 1, Epoch: 1, Mini Batch: 60, Loss= 157627808.000000, Training Accuracy= 70.31250
# Fold: 1, Epoch: 1, Mini Batch: 70, Loss= 97632352.000000, Training Accuracy= 76.56250
#
# Fold: 1, Epoch: 1, Validation Accuracy= 85.50000
#
# Fold: 1, Epoch: 2, Mini Batch: 10, Loss= 100800880.000000, Training Accuracy= 73.43750
# Fold: 1, Epoch: 2, Mini Batch: 20, Loss= 85642736.000000, Training Accuracy= 74.21875
# Fold: 1, Epoch: 2, Mini Batch: 30, Loss= 117198768.000000, Training Accuracy= 67.96875
# Fold: 1, Epoch: 2, Mini Batch: 40, Loss= 97444712.000000, Training Accuracy= 69.53125
# Fold: 1, Epoch: 2, Mini Batch: 50, Loss= 82311632.000000, Training Accuracy= 75.78125
# Fold: 1, Epoch: 2, Mini Batch: 60, Loss= 63190156.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 2, Mini Batch: 70, Loss= 47273000.000000, Training Accuracy= 74.21875
#
# Fold: 1, Epoch: 2, Validation Accuracy= 86.90000
#
# Fold: 1, Epoch: 3, Mini Batch: 10, Loss= 32525414.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 3, Mini Batch: 20, Loss= 46313392.000000, Training Accuracy= 74.21875
# Fold: 1, Epoch: 3, Mini Batch: 30, Loss= 57232236.000000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 3, Mini Batch: 40, Loss= 45357732.000000, Training Accuracy= 74.21875
# Fold: 1, Epoch: 3, Mini Batch: 50, Loss= 41605968.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 3, Mini Batch: 60, Loss= 37277408.000000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 3, Mini Batch: 70, Loss= 18932904.000000, Training Accuracy= 83.59375
#
# Fold: 1, Epoch: 3, Validation Accuracy= 88.20000
#
# Fold: 1, Epoch: 4, Mini Batch: 10, Loss= 32821062.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 4, Mini Batch: 20, Loss= 55857896.000000, Training Accuracy= 76.56250
# Fold: 1, Epoch: 4, Mini Batch: 30, Loss= 32877544.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 4, Mini Batch: 40, Loss= 19087764.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 4, Mini Batch: 50, Loss= 28245716.000000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 4, Mini Batch: 60, Loss= 28533736.000000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 4, Mini Batch: 70, Loss= 26733296.000000, Training Accuracy= 77.34375
#
# Fold: 1, Epoch: 4, Validation Accuracy= 88.60000
#
# Fold: 1, Epoch: 5, Mini Batch: 10, Loss= 17221888.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 5, Mini Batch: 20, Loss= 12260434.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 5, Mini Batch: 30, Loss= 25713832.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 5, Mini Batch: 40, Loss= 13573626.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 5, Mini Batch: 50, Loss= 23458908.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 5, Mini Batch: 60, Loss= 17564608.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 5, Mini Batch: 70, Loss= 21004230.000000, Training Accuracy= 82.03125
#
# Fold: 1, Epoch: 5, Validation Accuracy= 89.00000
#
# Fold: 1, Epoch: 6, Mini Batch: 10, Loss= 16652422.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 6, Mini Batch: 20, Loss= 12373886.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 6, Mini Batch: 30, Loss= 25805942.000000, Training Accuracy= 78.12500
# Fold: 1, Epoch: 6, Mini Batch: 40, Loss= 12522101.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 6, Mini Batch: 50, Loss= 16107506.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 6, Mini Batch: 60, Loss= 18657610.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 6, Mini Batch: 70, Loss= 16203880.000000, Training Accuracy= 79.68750
#
# Fold: 1, Epoch: 6, Validation Accuracy= 89.10000
#
# Fold: 1, Epoch: 7, Mini Batch: 10, Loss= 7400658.000000, Training Accuracy= 89.84375
# Fold: 1, Epoch: 7, Mini Batch: 20, Loss= 17792992.000000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 7, Mini Batch: 30, Loss= 10614446.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 7, Mini Batch: 40, Loss= 13572418.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 7, Mini Batch: 50, Loss= 11885247.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 7, Mini Batch: 60, Loss= 14563478.000000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 7, Mini Batch: 70, Loss= 9583363.000000, Training Accuracy= 85.93750
#
# Fold: 1, Epoch: 7, Validation Accuracy= 89.60000
#
# Fold: 1, Epoch: 8, Mini Batch: 10, Loss= 9936386.000000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 8, Mini Batch: 20, Loss= 9399840.000000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 8, Mini Batch: 30, Loss= 13831924.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 8, Mini Batch: 40, Loss= 13355517.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 8, Mini Batch: 50, Loss= 11279166.000000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 8, Mini Batch: 60, Loss= 13915980.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 8, Mini Batch: 70, Loss= 13505270.000000, Training Accuracy= 80.46875
#
# Fold: 1, Epoch: 8, Validation Accuracy= 89.30000
#
# Fold: 1, Epoch: 9, Mini Batch: 10, Loss= 9032721.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 9, Mini Batch: 20, Loss= 9841120.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 9, Mini Batch: 30, Loss= 12374878.000000, Training Accuracy= 79.68750
# Fold: 1, Epoch: 9, Mini Batch: 40, Loss= 10931330.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 9, Mini Batch: 50, Loss= 11996477.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 9, Mini Batch: 60, Loss= 9283034.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 9, Mini Batch: 70, Loss= 8319505.000000, Training Accuracy= 85.15625
#
# Fold: 1, Epoch: 9, Validation Accuracy= 89.00000
#
# Fold: 1, Epoch: 10, Mini Batch: 10, Loss= 8233572.000000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 10, Mini Batch: 20, Loss= 6054298.500000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 10, Mini Batch: 30, Loss= 10325989.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 10, Mini Batch: 40, Loss= 7514787.500000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 10, Mini Batch: 50, Loss= 8751436.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 10, Mini Batch: 60, Loss= 7799781.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 10, Mini Batch: 70, Loss= 8034599.000000, Training Accuracy= 83.59375
#
# Fold: 1, Epoch: 10, Validation Accuracy= 88.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   29   447
# 1           82  471   553
# All        500  500  1000
#
# Fold: 1, Epoch: 11, Mini Batch: 10, Loss= 10877172.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 11, Mini Batch: 20, Loss= 6583884.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 11, Mini Batch: 30, Loss= 7622756.500000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 11, Mini Batch: 40, Loss= 8511443.000000, Training Accuracy= 84.37500
# Fold: 1, Epoch: 11, Mini Batch: 50, Loss= 4810044.500000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 11, Mini Batch: 60, Loss= 10829253.000000, Training Accuracy= 77.34375
# Fold: 1, Epoch: 11, Mini Batch: 70, Loss= 8836360.000000, Training Accuracy= 84.37500
#
# Fold: 1, Epoch: 11, Validation Accuracy= 89.60000
#
# Fold: 1, Epoch: 12, Mini Batch: 10, Loss= 5650133.000000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 12, Mini Batch: 20, Loss= 7674620.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 12, Mini Batch: 30, Loss= 11053354.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 12, Mini Batch: 40, Loss= 9311946.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 12, Mini Batch: 50, Loss= 6745765.000000, Training Accuracy= 81.25000
# Fold: 1, Epoch: 12, Mini Batch: 60, Loss= 8948953.000000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 12, Mini Batch: 70, Loss= 6011229.000000, Training Accuracy= 85.15625
#
# Fold: 1, Epoch: 12, Validation Accuracy= 89.40000
#
# Fold: 1, Epoch: 13, Mini Batch: 10, Loss= 4145851.750000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 13, Mini Batch: 20, Loss= 4179898.000000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 13, Mini Batch: 30, Loss= 5375731.500000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 13, Mini Batch: 40, Loss= 5183638.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 13, Mini Batch: 50, Loss= 5751928.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 13, Mini Batch: 60, Loss= 6363994.500000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 13, Mini Batch: 70, Loss= 3472132.000000, Training Accuracy= 90.62500
#
# Fold: 1, Epoch: 13, Validation Accuracy= 89.10000
#
# Fold: 1, Epoch: 14, Mini Batch: 10, Loss= 6692083.500000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 14, Mini Batch: 20, Loss= 5972042.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 14, Mini Batch: 30, Loss= 3898321.000000, Training Accuracy= 90.62500
# Fold: 1, Epoch: 14, Mini Batch: 40, Loss= 8271831.500000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 14, Mini Batch: 50, Loss= 4017015.000000, Training Accuracy= 89.84375
# Fold: 1, Epoch: 14, Mini Batch: 60, Loss= 5013672.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 14, Mini Batch: 70, Loss= 6540108.000000, Training Accuracy= 84.37500
#
# Fold: 1, Epoch: 14, Validation Accuracy= 90.50000
#
# Fold: 1, Epoch: 15, Mini Batch: 10, Loss= 2167727.500000, Training Accuracy= 94.53125
# Fold: 1, Epoch: 15, Mini Batch: 20, Loss= 4392148.500000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 15, Mini Batch: 30, Loss= 5026556.500000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 15, Mini Batch: 40, Loss= 3640946.000000, Training Accuracy= 91.40625
# Fold: 1, Epoch: 15, Mini Batch: 50, Loss= 3581327.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 15, Mini Batch: 60, Loss= 4366584.500000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 15, Mini Batch: 70, Loss= 6547818.000000, Training Accuracy= 82.03125
#
# Fold: 1, Epoch: 15, Validation Accuracy= 90.50000
#
# Fold: 1, Epoch: 16, Mini Batch: 10, Loss= 4343514.000000, Training Accuracy= 89.84375
# Fold: 1, Epoch: 16, Mini Batch: 20, Loss= 5231059.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 16, Mini Batch: 30, Loss= 5595077.500000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 16, Mini Batch: 40, Loss= 5680829.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 16, Mini Batch: 50, Loss= 3590047.250000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 16, Mini Batch: 60, Loss= 4365805.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 16, Mini Batch: 70, Loss= 2541556.000000, Training Accuracy= 89.84375
#
# Fold: 1, Epoch: 16, Validation Accuracy= 89.90000
#
# Fold: 1, Epoch: 17, Mini Batch: 10, Loss= 3370752.250000, Training Accuracy= 90.62500
# Fold: 1, Epoch: 17, Mini Batch: 20, Loss= 5069904.500000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 17, Mini Batch: 30, Loss= 5403725.500000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 17, Mini Batch: 40, Loss= 2700973.500000, Training Accuracy= 92.18750
# Fold: 1, Epoch: 17, Mini Batch: 50, Loss= 1544169.250000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 17, Mini Batch: 60, Loss= 6446745.500000, Training Accuracy= 82.03125
# Fold: 1, Epoch: 17, Mini Batch: 70, Loss= 4580764.500000, Training Accuracy= 86.71875
#
# Fold: 1, Epoch: 17, Validation Accuracy= 89.70000
#
# Fold: 1, Epoch: 18, Mini Batch: 10, Loss= 1897983.875000, Training Accuracy= 89.84375
# Fold: 1, Epoch: 18, Mini Batch: 20, Loss= 5925365.500000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 18, Mini Batch: 30, Loss= 5784102.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 18, Mini Batch: 40, Loss= 3365367.000000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 18, Mini Batch: 50, Loss= 2345962.000000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 18, Mini Batch: 60, Loss= 2827460.000000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 18, Mini Batch: 70, Loss= 4461840.000000, Training Accuracy= 86.71875
#
# Fold: 1, Epoch: 18, Validation Accuracy= 90.40000
#
# Fold: 1, Epoch: 19, Mini Batch: 10, Loss= 762109.375000, Training Accuracy= 94.53125
# Fold: 1, Epoch: 19, Mini Batch: 20, Loss= 2438366.000000, Training Accuracy= 91.40625
# Fold: 1, Epoch: 19, Mini Batch: 30, Loss= 2952539.000000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 19, Mini Batch: 40, Loss= 4984418.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 19, Mini Batch: 50, Loss= 6329813.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 19, Mini Batch: 60, Loss= 2570017.000000, Training Accuracy= 87.50000
# Fold: 1, Epoch: 19, Mini Batch: 70, Loss= 3430020.750000, Training Accuracy= 82.03125
#
# Fold: 1, Epoch: 19, Validation Accuracy= 90.50000
#
# Fold: 1, Epoch: 20, Mini Batch: 10, Loss= 2749654.500000, Training Accuracy= 88.28125
# Fold: 1, Epoch: 20, Mini Batch: 20, Loss= 3836795.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 20, Mini Batch: 30, Loss= 2734948.750000, Training Accuracy= 90.62500
# Fold: 1, Epoch: 20, Mini Batch: 40, Loss= 4198881.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 20, Mini Batch: 50, Loss= 1982947.625000, Training Accuracy= 89.84375
# Fold: 1, Epoch: 20, Mini Batch: 60, Loss= 1630710.750000, Training Accuracy= 89.84375
# Fold: 1, Epoch: 20, Mini Batch: 70, Loss= 2980036.500000, Training Accuracy= 89.06250
#
# Fold: 1, Epoch: 20, Validation Accuracy= 91.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          455   42   497
# 1           45  458   503
# All        500  500  1000
#
# The mean Valid Accuracy per fold is :  91.3
# The mean Valid Accuracy based on epochs for the fold number (1) is :  89.25

# %%
rows = 1
columns = 2
vizualize(vaccPerEpochPerFold, 
          taccPerEpochPerFold, 
          meanValidAcc=meanValidAcc, 
          epochMeanValidAcc=epochMeanValidAcc, 
          rows=rows, columns=columns, figsize=(5*columns, 5*rows))

# %%
featureDIR = RGBbatch_dir

params = dict(imageSize = 32,
              seed = 2316,                 # Set the seeds for the random weights generator
              numFolds = 10,
              
              # Network Parameters
              numLabels = 2,
              numChannels = 3,             # numChannels -> For grayscale =1, for RGB =3
              numHidden1 = 1280,           # numHiddenUnits for the fully connected layerr
              numHidden2 = 1024,            # numHiddenUnits for the fully connected layer
              
              conv1Kernel = 3,             # Size of kernel for the first convolution layer
              conv2Kernel = 5,             # Size of kernel for the second convolution layer
              conv1Depth = 64,             # Number of kernels for the first convolution layer
              conv2Depth = 64,             # Number of kernels for the second convolution layer
              conv1Stride = 1,             # Strides for the first convolution layer filter  
              conv2Stride = 1,             # Strides for the second convolution layer filter
              
              pool1Kernel = 2,             # Size of kernel for the first Pooling layer
              pool2Kernel = 2,             # Size of kernel for the second Pooling layer  
              pool1Stride = 2,             # Strides for the first Pooling layer filter
              pool2Stride = 2,             # Strides for the second Pooling layer filter
              
              # Learning Variables     
              epochs = 20,
              batchSize = 128,
        
              keepProb = dict(fc1=0.5, fc2=0.5),
              optimizerParam = dict(optimizer='RMSPROP', learning_rate=0.00008, momentum=0.9)
#               optimizerParam = dict(optimizer='ADAM', learning_rate=0.003)  # at 0.003 descents slowely, 
        )

start_time = time.time()

(out, meanValidAcc, lossPerEpochPerFold, 
 taccPerEpochPerFold, vaccPerEpochPerFold, validCMDict) = SessionExec(featureDIR, params).execute() 

print("--- %s seconds " % (time.time() - start_time) + 
      '--- %s minutes' %str((time.time() - start_time)/60) + 
      '--- %s hours' %str((time.time() - start_time)/3600))


print ('The mean Valid Accuracy per fold is : ', meanValidAcc)
for nfold in np.arange(params['numFolds']):
    print ('The mean Valid Accuracy based on epochs for the fold number (%s) is : '%str(nfold+1), np.mean(vaccPerEpochPerFold[nfold + 1]))
    epochMeanValidAcc = np.mean(vaccPerEpochPerFold[nfold + 1])
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 1, Epoch: 1, Mini Batch: 50, Loss= 161555632.000000, Training Accuracy= 67.18750
# Fold: 1, Epoch: 1, Mini Batch: 70, Loss= 103628048.000000, Training Accuracy= 73.43750
#
# Fold: 1, Epoch: 1, Validation Accuracy= 83.50000
#
# Fold: 1, Epoch: 2, Mini Batch: 50, Loss= 83419120.000000, Training Accuracy= 75.78125
# Fold: 1, Epoch: 2, Mini Batch: 70, Loss= 57385928.000000, Training Accuracy= 76.56250
#
# Fold: 1, Epoch: 2, Validation Accuracy= 87.20000
#
# Fold: 1, Epoch: 3, Mini Batch: 50, Loss= 31350286.000000, Training Accuracy= 78.90625
# Fold: 1, Epoch: 3, Mini Batch: 70, Loss= 45461064.000000, Training Accuracy= 74.21875
#
# Fold: 1, Epoch: 3, Validation Accuracy= 87.60000
#
# Fold: 1, Epoch: 4, Mini Batch: 50, Loss= 25083008.000000, Training Accuracy= 80.46875
# Fold: 1, Epoch: 4, Mini Batch: 70, Loss= 20145822.000000, Training Accuracy= 78.12500
#
# Fold: 1, Epoch: 4, Validation Accuracy= 89.70000
#
# Fold: 1, Epoch: 5, Mini Batch: 50, Loss= 13859922.000000, Training Accuracy= 85.93750
# Fold: 1, Epoch: 5, Mini Batch: 70, Loss= 28965604.000000, Training Accuracy= 76.56250
#
# Fold: 1, Epoch: 5, Validation Accuracy= 89.40000
#
# Fold: 1, Epoch: 6, Mini Batch: 50, Loss= 12798014.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 6, Mini Batch: 70, Loss= 21864028.000000, Training Accuracy= 78.90625
#
# Fold: 1, Epoch: 6, Validation Accuracy= 89.30000
#
# Fold: 1, Epoch: 7, Mini Batch: 50, Loss= 10633948.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 7, Mini Batch: 70, Loss= 17539564.000000, Training Accuracy= 82.03125
#
# Fold: 1, Epoch: 7, Validation Accuracy= 90.00000
#
# Fold: 1, Epoch: 8, Mini Batch: 50, Loss= 15011817.000000, Training Accuracy= 82.81250
# Fold: 1, Epoch: 8, Mini Batch: 70, Loss= 8210924.500000, Training Accuracy= 87.50000
#
# Fold: 1, Epoch: 8, Validation Accuracy= 89.60000
#
# Fold: 1, Epoch: 9, Mini Batch: 50, Loss= 7764506.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 9, Mini Batch: 70, Loss= 8804316.000000, Training Accuracy= 85.15625
#
# Fold: 1, Epoch: 9, Validation Accuracy= 89.90000
#
# Fold: 1, Epoch: 10, Mini Batch: 50, Loss= 7146137.500000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 10, Mini Batch: 70, Loss= 7543486.500000, Training Accuracy= 80.46875
#
# Fold: 1, Epoch: 10, Validation Accuracy= 90.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          453   52   505
# 1           47  448   495
# All        500  500  1000
#
# Fold: 1, Epoch: 11, Mini Batch: 50, Loss= 5001488.000000, Training Accuracy= 92.18750
# Fold: 1, Epoch: 11, Mini Batch: 70, Loss= 8766063.000000, Training Accuracy= 84.37500
#
# Fold: 1, Epoch: 11, Validation Accuracy= 91.00000
#
# Fold: 1, Epoch: 12, Mini Batch: 50, Loss= 6208367.000000, Training Accuracy= 83.59375
# Fold: 1, Epoch: 12, Mini Batch: 70, Loss= 6574494.000000, Training Accuracy= 87.50000
#
# Fold: 1, Epoch: 12, Validation Accuracy= 90.80000
#
# Fold: 1, Epoch: 13, Mini Batch: 50, Loss= 3815253.500000, Training Accuracy= 90.62500
# Fold: 1, Epoch: 13, Mini Batch: 70, Loss= 5628964.000000, Training Accuracy= 89.84375
#
# Fold: 1, Epoch: 13, Validation Accuracy= 90.40000
#
# Fold: 1, Epoch: 14, Mini Batch: 50, Loss= 5540568.000000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 14, Mini Batch: 70, Loss= 7252756.500000, Training Accuracy= 89.84375
#
# Fold: 1, Epoch: 14, Validation Accuracy= 91.20000
#
# Fold: 1, Epoch: 15, Mini Batch: 50, Loss= 4998441.000000, Training Accuracy= 86.71875
# Fold: 1, Epoch: 15, Mini Batch: 70, Loss= 6083411.000000, Training Accuracy= 85.93750
#
# Fold: 1, Epoch: 15, Validation Accuracy= 90.50000
#
# Fold: 1, Epoch: 16, Mini Batch: 50, Loss= 4425681.000000, Training Accuracy= 85.15625
# Fold: 1, Epoch: 16, Mini Batch: 70, Loss= 3875689.750000, Training Accuracy= 86.71875
#
# Fold: 1, Epoch: 16, Validation Accuracy= 90.50000
#
# Fold: 1, Epoch: 17, Mini Batch: 50, Loss= 2622750.000000, Training Accuracy= 90.62500
# Fold: 1, Epoch: 17, Mini Batch: 70, Loss= 3653455.000000, Training Accuracy= 89.84375
#
# Fold: 1, Epoch: 17, Validation Accuracy= 91.20000
#
# Fold: 1, Epoch: 18, Mini Batch: 50, Loss= 3936821.500000, Training Accuracy= 92.18750
# Fold: 1, Epoch: 18, Mini Batch: 70, Loss= 4691231.500000, Training Accuracy= 87.50000
#
# Fold: 1, Epoch: 18, Validation Accuracy= 91.00000
#
# Fold: 1, Epoch: 19, Mini Batch: 50, Loss= 3142244.000000, Training Accuracy= 90.62500
# Fold: 1, Epoch: 19, Mini Batch: 70, Loss= 1470661.875000, Training Accuracy= 92.18750
#
# Fold: 1, Epoch: 19, Validation Accuracy= 90.70000
#
# Fold: 1, Epoch: 20, Mini Batch: 50, Loss= 2886730.000000, Training Accuracy= 89.06250
# Fold: 1, Epoch: 20, Mini Batch: 70, Loss= 3585556.250000, Training Accuracy= 88.28125
#
# Fold: 1, Epoch: 20, Validation Accuracy= 91.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          448   36   484
# 1           52  464   516
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 2, Epoch: 1, Mini Batch: 50, Loss= 144612096.000000, Training Accuracy= 67.18750
# Fold: 2, Epoch: 1, Mini Batch: 70, Loss= 113807144.000000, Training Accuracy= 73.43750
#
# Fold: 2, Epoch: 1, Validation Accuracy= 80.80000
#
# Fold: 2, Epoch: 2, Mini Batch: 50, Loss= 91249960.000000, Training Accuracy= 74.21875
# Fold: 2, Epoch: 2, Mini Batch: 70, Loss= 52323024.000000, Training Accuracy= 75.78125
#
# Fold: 2, Epoch: 2, Validation Accuracy= 85.90000
#
# Fold: 2, Epoch: 3, Mini Batch: 50, Loss= 27202296.000000, Training Accuracy= 79.68750
# Fold: 2, Epoch: 3, Mini Batch: 70, Loss= 48570472.000000, Training Accuracy= 71.87500
#
# Fold: 2, Epoch: 3, Validation Accuracy= 86.40000
#
# Fold: 2, Epoch: 4, Mini Batch: 50, Loss= 24407378.000000, Training Accuracy= 81.25000
# Fold: 2, Epoch: 4, Mini Batch: 70, Loss= 18301016.000000, Training Accuracy= 78.90625
#
# Fold: 2, Epoch: 4, Validation Accuracy= 87.60000
#
# Fold: 2, Epoch: 5, Mini Batch: 50, Loss= 13729036.000000, Training Accuracy= 86.71875
# Fold: 2, Epoch: 5, Mini Batch: 70, Loss= 27569688.000000, Training Accuracy= 78.90625
#
# Fold: 2, Epoch: 5, Validation Accuracy= 87.60000
#
# Fold: 2, Epoch: 6, Mini Batch: 50, Loss= 15686849.000000, Training Accuracy= 85.93750
# Fold: 2, Epoch: 6, Mini Batch: 70, Loss= 20928972.000000, Training Accuracy= 81.25000
#
# Fold: 2, Epoch: 6, Validation Accuracy= 87.40000
#
# Fold: 2, Epoch: 7, Mini Batch: 50, Loss= 12023975.000000, Training Accuracy= 83.59375
# Fold: 2, Epoch: 7, Mini Batch: 70, Loss= 17192140.000000, Training Accuracy= 80.46875
#
# Fold: 2, Epoch: 7, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 8, Mini Batch: 50, Loss= 13766635.000000, Training Accuracy= 83.59375
# Fold: 2, Epoch: 8, Mini Batch: 70, Loss= 9070708.000000, Training Accuracy= 87.50000
#
# Fold: 2, Epoch: 8, Validation Accuracy= 87.90000
#
# Fold: 2, Epoch: 9, Mini Batch: 50, Loss= 5783052.000000, Training Accuracy= 89.06250
# Fold: 2, Epoch: 9, Mini Batch: 70, Loss= 11611386.000000, Training Accuracy= 82.81250
#
# Fold: 2, Epoch: 9, Validation Accuracy= 87.80000
#
# Fold: 2, Epoch: 10, Mini Batch: 50, Loss= 5702327.000000, Training Accuracy= 89.06250
# Fold: 2, Epoch: 10, Mini Batch: 70, Loss= 9503044.000000, Training Accuracy= 79.68750
#
# Fold: 2, Epoch: 10, Validation Accuracy= 88.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          439   58   497
# 1           61  442   503
# All        500  500  1000
#
# Fold: 2, Epoch: 11, Mini Batch: 50, Loss= 3387002.500000, Training Accuracy= 87.50000
# Fold: 2, Epoch: 11, Mini Batch: 70, Loss= 5642150.000000, Training Accuracy= 85.93750
#
# Fold: 2, Epoch: 11, Validation Accuracy= 89.20000
#
# Fold: 2, Epoch: 12, Mini Batch: 50, Loss= 5320704.000000, Training Accuracy= 87.50000
# Fold: 2, Epoch: 12, Mini Batch: 70, Loss= 6840841.000000, Training Accuracy= 84.37500
#
# Fold: 2, Epoch: 12, Validation Accuracy= 88.40000
#
# Fold: 2, Epoch: 13, Mini Batch: 50, Loss= 6165095.000000, Training Accuracy= 87.50000
# Fold: 2, Epoch: 13, Mini Batch: 70, Loss= 6042196.000000, Training Accuracy= 85.15625
#
# Fold: 2, Epoch: 13, Validation Accuracy= 88.50000
#
# Fold: 2, Epoch: 14, Mini Batch: 50, Loss= 4451914.000000, Training Accuracy= 92.18750
# Fold: 2, Epoch: 14, Mini Batch: 70, Loss= 6609060.000000, Training Accuracy= 85.15625
#
# Fold: 2, Epoch: 14, Validation Accuracy= 90.10000
#
# Fold: 2, Epoch: 15, Mini Batch: 50, Loss= 3849918.500000, Training Accuracy= 89.84375
# Fold: 2, Epoch: 15, Mini Batch: 70, Loss= 6645355.000000, Training Accuracy= 82.03125
#
# Fold: 2, Epoch: 15, Validation Accuracy= 89.50000
#
# Fold: 2, Epoch: 16, Mini Batch: 50, Loss= 3474003.500000, Training Accuracy= 85.93750
# Fold: 2, Epoch: 16, Mini Batch: 70, Loss= 5226533.000000, Training Accuracy= 82.03125
#
# Fold: 2, Epoch: 16, Validation Accuracy= 88.70000
#
# Fold: 2, Epoch: 17, Mini Batch: 50, Loss= 2955815.500000, Training Accuracy= 91.40625
# Fold: 2, Epoch: 17, Mini Batch: 70, Loss= 3963253.750000, Training Accuracy= 87.50000
#
# Fold: 2, Epoch: 17, Validation Accuracy= 89.80000
#
# Fold: 2, Epoch: 18, Mini Batch: 50, Loss= 3610352.750000, Training Accuracy= 90.62500
# Fold: 2, Epoch: 18, Mini Batch: 70, Loss= 3753182.000000, Training Accuracy= 86.71875
#
# Fold: 2, Epoch: 18, Validation Accuracy= 89.00000
#
# Fold: 2, Epoch: 19, Mini Batch: 50, Loss= 1501212.250000, Training Accuracy= 94.53125
# Fold: 2, Epoch: 19, Mini Batch: 70, Loss= 2824240.250000, Training Accuracy= 87.50000
#
# Fold: 2, Epoch: 19, Validation Accuracy= 89.80000
#
# Fold: 2, Epoch: 20, Mini Batch: 50, Loss= 3861394.750000, Training Accuracy= 87.50000
# Fold: 2, Epoch: 20, Mini Batch: 70, Loss= 2657142.250000, Training Accuracy= 88.28125
#
# Fold: 2, Epoch: 20, Validation Accuracy= 89.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          426   30   456
# 1           74  470   544
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 3, Epoch: 1, Mini Batch: 50, Loss= 145909376.000000, Training Accuracy= 66.40625
# Fold: 3, Epoch: 1, Mini Batch: 70, Loss= 101916192.000000, Training Accuracy= 71.09375
#
# Fold: 3, Epoch: 1, Validation Accuracy= 83.20000
#
# Fold: 3, Epoch: 2, Mini Batch: 50, Loss= 84801592.000000, Training Accuracy= 74.21875
# Fold: 3, Epoch: 2, Mini Batch: 70, Loss= 49312700.000000, Training Accuracy= 75.78125
#
# Fold: 3, Epoch: 2, Validation Accuracy= 85.80000
#
# Fold: 3, Epoch: 3, Mini Batch: 50, Loss= 30967788.000000, Training Accuracy= 75.78125
# Fold: 3, Epoch: 3, Mini Batch: 70, Loss= 51655288.000000, Training Accuracy= 72.65625
#
# Fold: 3, Epoch: 3, Validation Accuracy= 87.80000
#
# Fold: 3, Epoch: 4, Mini Batch: 50, Loss= 20389050.000000, Training Accuracy= 82.03125
# Fold: 3, Epoch: 4, Mini Batch: 70, Loss= 26307720.000000, Training Accuracy= 76.56250
#
# Fold: 3, Epoch: 4, Validation Accuracy= 88.80000
#
# Fold: 3, Epoch: 5, Mini Batch: 50, Loss= 13007470.000000, Training Accuracy= 86.71875
# Fold: 3, Epoch: 5, Mini Batch: 70, Loss= 27518848.000000, Training Accuracy= 78.12500
#
# Fold: 3, Epoch: 5, Validation Accuracy= 89.40000
#
# Fold: 3, Epoch: 6, Mini Batch: 50, Loss= 16669029.000000, Training Accuracy= 81.25000
# Fold: 3, Epoch: 6, Mini Batch: 70, Loss= 17551908.000000, Training Accuracy= 82.03125
#
# Fold: 3, Epoch: 6, Validation Accuracy= 89.50000
#
# Fold: 3, Epoch: 7, Mini Batch: 50, Loss= 8484310.000000, Training Accuracy= 83.59375
# Fold: 3, Epoch: 7, Mini Batch: 70, Loss= 13096469.000000, Training Accuracy= 80.46875
#
# Fold: 3, Epoch: 7, Validation Accuracy= 89.50000
#
# Fold: 3, Epoch: 8, Mini Batch: 50, Loss= 11362220.000000, Training Accuracy= 83.59375
# Fold: 3, Epoch: 8, Mini Batch: 70, Loss= 10672029.000000, Training Accuracy= 86.71875
#
# Fold: 3, Epoch: 8, Validation Accuracy= 90.90000
#
# Fold: 3, Epoch: 9, Mini Batch: 50, Loss= 5408092.000000, Training Accuracy= 88.28125
# Fold: 3, Epoch: 9, Mini Batch: 70, Loss= 10054348.000000, Training Accuracy= 80.46875
#
# Fold: 3, Epoch: 9, Validation Accuracy= 90.70000
#
# Fold: 3, Epoch: 10, Mini Batch: 50, Loss= 7588689.000000, Training Accuracy= 85.15625
# Fold: 3, Epoch: 10, Mini Batch: 70, Loss= 9563821.000000, Training Accuracy= 81.25000
#
# Fold: 3, Epoch: 10, Validation Accuracy= 90.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          449   40   489
# 1           51  460   511
# All        500  500  1000
#
# Fold: 3, Epoch: 11, Mini Batch: 50, Loss= 3928795.500000, Training Accuracy= 89.84375
# Fold: 3, Epoch: 11, Mini Batch: 70, Loss= 6767158.500000, Training Accuracy= 86.71875
#
# Fold: 3, Epoch: 11, Validation Accuracy= 91.60000
#
# Fold: 3, Epoch: 12, Mini Batch: 50, Loss= 4370096.500000, Training Accuracy= 84.37500
# Fold: 3, Epoch: 12, Mini Batch: 70, Loss= 7851702.500000, Training Accuracy= 84.37500
#
# Fold: 3, Epoch: 12, Validation Accuracy= 91.50000
#
# Fold: 3, Epoch: 13, Mini Batch: 50, Loss= 5350842.000000, Training Accuracy= 84.37500
# Fold: 3, Epoch: 13, Mini Batch: 70, Loss= 4572050.500000, Training Accuracy= 88.28125
#
# Fold: 3, Epoch: 13, Validation Accuracy= 90.00000
#
# Fold: 3, Epoch: 14, Mini Batch: 50, Loss= 3830313.000000, Training Accuracy= 88.28125
# Fold: 3, Epoch: 14, Mini Batch: 70, Loss= 6514804.500000, Training Accuracy= 89.06250
#
# Fold: 3, Epoch: 14, Validation Accuracy= 90.70000
#
# Fold: 3, Epoch: 15, Mini Batch: 50, Loss= 4055668.500000, Training Accuracy= 86.71875
# Fold: 3, Epoch: 15, Mini Batch: 70, Loss= 6815214.000000, Training Accuracy= 80.46875
#
# Fold: 3, Epoch: 15, Validation Accuracy= 91.20000
#
# Fold: 3, Epoch: 16, Mini Batch: 50, Loss= 3821114.500000, Training Accuracy= 86.71875
# Fold: 3, Epoch: 16, Mini Batch: 70, Loss= 5084536.000000, Training Accuracy= 86.71875
#
# Fold: 3, Epoch: 16, Validation Accuracy= 92.00000
#
# Fold: 3, Epoch: 17, Mini Batch: 50, Loss= 1385852.500000, Training Accuracy= 91.40625
# Fold: 3, Epoch: 17, Mini Batch: 70, Loss= 4825324.500000, Training Accuracy= 86.71875
#
# Fold: 3, Epoch: 17, Validation Accuracy= 91.30000
#
# Fold: 3, Epoch: 18, Mini Batch: 50, Loss= 3272850.500000, Training Accuracy= 90.62500
# Fold: 3, Epoch: 18, Mini Batch: 70, Loss= 4178563.000000, Training Accuracy= 86.71875
#
# Fold: 3, Epoch: 18, Validation Accuracy= 91.50000
#
# Fold: 3, Epoch: 19, Mini Batch: 50, Loss= 2584785.250000, Training Accuracy= 93.75000
# Fold: 3, Epoch: 19, Mini Batch: 70, Loss= 2444850.000000, Training Accuracy= 91.40625
#
# Fold: 3, Epoch: 19, Validation Accuracy= 92.30000
#
# Fold: 3, Epoch: 20, Mini Batch: 50, Loss= 4394876.000000, Training Accuracy= 86.71875
# Fold: 3, Epoch: 20, Mini Batch: 70, Loss= 2219894.500000, Training Accuracy= 89.06250
#
# Fold: 3, Epoch: 20, Validation Accuracy= 90.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          423   18   441
# 1           77  482   559
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 4, Epoch: 1, Mini Batch: 50, Loss= 146523680.000000, Training Accuracy= 70.31250
# Fold: 4, Epoch: 1, Mini Batch: 70, Loss= 101307304.000000, Training Accuracy= 71.87500
#
# Fold: 4, Epoch: 1, Validation Accuracy= 81.20000
#
# Fold: 4, Epoch: 2, Mini Batch: 50, Loss= 88716944.000000, Training Accuracy= 75.78125
# Fold: 4, Epoch: 2, Mini Batch: 70, Loss= 50391024.000000, Training Accuracy= 76.56250
#
# Fold: 4, Epoch: 2, Validation Accuracy= 83.70000
#
# Fold: 4, Epoch: 3, Mini Batch: 50, Loss= 27156638.000000, Training Accuracy= 79.68750
# Fold: 4, Epoch: 3, Mini Batch: 70, Loss= 48455768.000000, Training Accuracy= 78.12500
#
# Fold: 4, Epoch: 3, Validation Accuracy= 85.60000
#
# Fold: 4, Epoch: 4, Mini Batch: 50, Loss= 22674170.000000, Training Accuracy= 84.37500
# Fold: 4, Epoch: 4, Mini Batch: 70, Loss= 20472378.000000, Training Accuracy= 76.56250
#
# Fold: 4, Epoch: 4, Validation Accuracy= 86.40000
#
# Fold: 4, Epoch: 5, Mini Batch: 50, Loss= 13557837.000000, Training Accuracy= 86.71875
# Fold: 4, Epoch: 5, Mini Batch: 70, Loss= 30077760.000000, Training Accuracy= 77.34375
#
# Fold: 4, Epoch: 5, Validation Accuracy= 87.10000
#
# Fold: 4, Epoch: 6, Mini Batch: 50, Loss= 16800220.000000, Training Accuracy= 85.15625
# Fold: 4, Epoch: 6, Mini Batch: 70, Loss= 18033712.000000, Training Accuracy= 81.25000
#
# Fold: 4, Epoch: 6, Validation Accuracy= 87.20000
#
# Fold: 4, Epoch: 7, Mini Batch: 50, Loss= 12172353.000000, Training Accuracy= 83.59375
# Fold: 4, Epoch: 7, Mini Batch: 70, Loss= 10761452.000000, Training Accuracy= 85.93750
#
# Fold: 4, Epoch: 7, Validation Accuracy= 87.40000
#
# Fold: 4, Epoch: 8, Mini Batch: 50, Loss= 11795221.000000, Training Accuracy= 82.81250
# Fold: 4, Epoch: 8, Mini Batch: 70, Loss= 10716224.000000, Training Accuracy= 87.50000
#
# Fold: 4, Epoch: 8, Validation Accuracy= 87.50000
#
# Fold: 4, Epoch: 9, Mini Batch: 50, Loss= 3375495.500000, Training Accuracy= 89.06250
# Fold: 4, Epoch: 9, Mini Batch: 70, Loss= 10043860.000000, Training Accuracy= 82.81250
#
# Fold: 4, Epoch: 9, Validation Accuracy= 88.10000
#
# Fold: 4, Epoch: 10, Mini Batch: 50, Loss= 8137812.000000, Training Accuracy= 87.50000
# Fold: 4, Epoch: 10, Mini Batch: 70, Loss= 10102908.000000, Training Accuracy= 79.68750
#
# Fold: 4, Epoch: 10, Validation Accuracy= 88.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          427   44   471
# 1           73  456   529
# All        500  500  1000
#
# Fold: 4, Epoch: 11, Mini Batch: 50, Loss= 3428737.250000, Training Accuracy= 89.06250
# Fold: 4, Epoch: 11, Mini Batch: 70, Loss= 7382446.000000, Training Accuracy= 87.50000
#
# Fold: 4, Epoch: 11, Validation Accuracy= 88.30000
#
# Fold: 4, Epoch: 12, Mini Batch: 50, Loss= 4591935.000000, Training Accuracy= 87.50000
# Fold: 4, Epoch: 12, Mini Batch: 70, Loss= 6569443.500000, Training Accuracy= 85.15625
#
# Fold: 4, Epoch: 12, Validation Accuracy= 89.10000
#
# Fold: 4, Epoch: 13, Mini Batch: 50, Loss= 5376055.500000, Training Accuracy= 85.93750
# Fold: 4, Epoch: 13, Mini Batch: 70, Loss= 6666663.500000, Training Accuracy= 88.28125
#
# Fold: 4, Epoch: 13, Validation Accuracy= 88.30000
#
# Fold: 4, Epoch: 14, Mini Batch: 50, Loss= 4756135.500000, Training Accuracy= 89.06250
# Fold: 4, Epoch: 14, Mini Batch: 70, Loss= 6140108.500000, Training Accuracy= 87.50000
#
# Fold: 4, Epoch: 14, Validation Accuracy= 88.50000
#
# Fold: 4, Epoch: 15, Mini Batch: 50, Loss= 3128539.500000, Training Accuracy= 87.50000
# Fold: 4, Epoch: 15, Mini Batch: 70, Loss= 5657488.000000, Training Accuracy= 87.50000
#
# Fold: 4, Epoch: 15, Validation Accuracy= 89.30000
#
# Fold: 4, Epoch: 16, Mini Batch: 50, Loss= 2845416.250000, Training Accuracy= 90.62500
# Fold: 4, Epoch: 16, Mini Batch: 70, Loss= 4878601.000000, Training Accuracy= 82.81250
#
# Fold: 4, Epoch: 16, Validation Accuracy= 87.80000
#
# Fold: 4, Epoch: 17, Mini Batch: 50, Loss= 1835197.250000, Training Accuracy= 91.40625
# Fold: 4, Epoch: 17, Mini Batch: 70, Loss= 4146904.000000, Training Accuracy= 87.50000
#
# Fold: 4, Epoch: 17, Validation Accuracy= 88.60000
#
# Fold: 4, Epoch: 18, Mini Batch: 50, Loss= 3818117.000000, Training Accuracy= 91.40625
# Fold: 4, Epoch: 18, Mini Batch: 70, Loss= 3267660.250000, Training Accuracy= 87.50000
#
# Fold: 4, Epoch: 18, Validation Accuracy= 88.10000
#
# Fold: 4, Epoch: 19, Mini Batch: 50, Loss= 2444761.000000, Training Accuracy= 92.18750
# Fold: 4, Epoch: 19, Mini Batch: 70, Loss= 3467611.000000, Training Accuracy= 85.93750
#
# Fold: 4, Epoch: 19, Validation Accuracy= 89.50000
#
# Fold: 4, Epoch: 20, Mini Batch: 50, Loss= 2244231.750000, Training Accuracy= 87.50000
# Fold: 4, Epoch: 20, Mini Batch: 70, Loss= 2807047.500000, Training Accuracy= 86.71875
#
# Fold: 4, Epoch: 20, Validation Accuracy= 88.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          414   27   441
# 1           86  473   559
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 5, Epoch: 1, Mini Batch: 50, Loss= 147117120.000000, Training Accuracy= 69.53125
# Fold: 5, Epoch: 1, Mini Batch: 70, Loss= 100514136.000000, Training Accuracy= 71.87500
#
# Fold: 5, Epoch: 1, Validation Accuracy= 85.50000
#
# Fold: 5, Epoch: 2, Mini Batch: 50, Loss= 84063456.000000, Training Accuracy= 75.00000
# Fold: 5, Epoch: 2, Mini Batch: 70, Loss= 52325872.000000, Training Accuracy= 78.90625
#
# Fold: 5, Epoch: 2, Validation Accuracy= 86.70000
#
# Fold: 5, Epoch: 3, Mini Batch: 50, Loss= 31285152.000000, Training Accuracy= 78.90625
# Fold: 5, Epoch: 3, Mini Batch: 70, Loss= 44985772.000000, Training Accuracy= 76.56250
#
# Fold: 5, Epoch: 3, Validation Accuracy= 87.80000
#
# Fold: 5, Epoch: 4, Mini Batch: 50, Loss= 21234756.000000, Training Accuracy= 82.81250
# Fold: 5, Epoch: 4, Mini Batch: 70, Loss= 18027868.000000, Training Accuracy= 80.46875
#
# Fold: 5, Epoch: 4, Validation Accuracy= 88.30000
#
# Fold: 5, Epoch: 5, Mini Batch: 50, Loss= 18195724.000000, Training Accuracy= 83.59375
# Fold: 5, Epoch: 5, Mini Batch: 70, Loss= 29999098.000000, Training Accuracy= 78.90625
#
# Fold: 5, Epoch: 5, Validation Accuracy= 88.40000
#
# Fold: 5, Epoch: 6, Mini Batch: 50, Loss= 18348994.000000, Training Accuracy= 86.71875
# Fold: 5, Epoch: 6, Mini Batch: 70, Loss= 20813448.000000, Training Accuracy= 81.25000
#
# Fold: 5, Epoch: 6, Validation Accuracy= 90.00000
#
# Fold: 5, Epoch: 7, Mini Batch: 50, Loss= 11796734.000000, Training Accuracy= 82.03125
# Fold: 5, Epoch: 7, Mini Batch: 70, Loss= 14812096.000000, Training Accuracy= 82.03125
#
# Fold: 5, Epoch: 7, Validation Accuracy= 90.50000
#
# Fold: 5, Epoch: 8, Mini Batch: 50, Loss= 12908310.000000, Training Accuracy= 79.68750
# Fold: 5, Epoch: 8, Mini Batch: 70, Loss= 9630139.000000, Training Accuracy= 83.59375
#
# Fold: 5, Epoch: 8, Validation Accuracy= 90.80000
#
# Fold: 5, Epoch: 9, Mini Batch: 50, Loss= 5778492.000000, Training Accuracy= 89.06250
# Fold: 5, Epoch: 9, Mini Batch: 70, Loss= 12313132.000000, Training Accuracy= 82.03125
#
# Fold: 5, Epoch: 9, Validation Accuracy= 91.30000
#
# Fold: 5, Epoch: 10, Mini Batch: 50, Loss= 6638129.000000, Training Accuracy= 90.62500
# Fold: 5, Epoch: 10, Mini Batch: 70, Loss= 9925448.000000, Training Accuracy= 78.90625
#
# Fold: 5, Epoch: 10, Validation Accuracy= 91.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          452   41   493
# 1           48  459   507
# All        500  500  1000
#
# Fold: 5, Epoch: 11, Mini Batch: 50, Loss= 5140270.500000, Training Accuracy= 86.71875
# Fold: 5, Epoch: 11, Mini Batch: 70, Loss= 7454203.000000, Training Accuracy= 88.28125
#
# Fold: 5, Epoch: 11, Validation Accuracy= 91.60000
#
# Fold: 5, Epoch: 12, Mini Batch: 50, Loss= 6062038.000000, Training Accuracy= 86.71875
# Fold: 5, Epoch: 12, Mini Batch: 70, Loss= 7168378.500000, Training Accuracy= 85.15625
#
# Fold: 5, Epoch: 12, Validation Accuracy= 91.40000
#
# Fold: 5, Epoch: 13, Mini Batch: 50, Loss= 5839366.500000, Training Accuracy= 88.28125
# Fold: 5, Epoch: 13, Mini Batch: 70, Loss= 6050956.000000, Training Accuracy= 84.37500
#
# Fold: 5, Epoch: 13, Validation Accuracy= 91.70000
#
# Fold: 5, Epoch: 14, Mini Batch: 50, Loss= 6538973.500000, Training Accuracy= 87.50000
# Fold: 5, Epoch: 14, Mini Batch: 70, Loss= 6258079.000000, Training Accuracy= 88.28125
#
# Fold: 5, Epoch: 14, Validation Accuracy= 91.20000
#
# Fold: 5, Epoch: 15, Mini Batch: 50, Loss= 4629679.000000, Training Accuracy= 89.06250
# Fold: 5, Epoch: 15, Mini Batch: 70, Loss= 5349044.000000, Training Accuracy= 88.28125
#
# Fold: 5, Epoch: 15, Validation Accuracy= 91.80000
#
# Fold: 5, Epoch: 16, Mini Batch: 50, Loss= 5120921.000000, Training Accuracy= 90.62500
# Fold: 5, Epoch: 16, Mini Batch: 70, Loss= 5377693.000000, Training Accuracy= 82.81250
#
# Fold: 5, Epoch: 16, Validation Accuracy= 91.70000
#
# Fold: 5, Epoch: 17, Mini Batch: 50, Loss= 3319629.250000, Training Accuracy= 87.50000
# Fold: 5, Epoch: 17, Mini Batch: 70, Loss= 3999262.000000, Training Accuracy= 86.71875
#
# Fold: 5, Epoch: 17, Validation Accuracy= 91.70000
#
# Fold: 5, Epoch: 18, Mini Batch: 50, Loss= 2739429.500000, Training Accuracy= 92.18750
# Fold: 5, Epoch: 18, Mini Batch: 70, Loss= 4369488.500000, Training Accuracy= 89.06250
#
# Fold: 5, Epoch: 18, Validation Accuracy= 91.90000
#
# Fold: 5, Epoch: 19, Mini Batch: 50, Loss= 2840583.000000, Training Accuracy= 92.96875
# Fold: 5, Epoch: 19, Mini Batch: 70, Loss= 1200847.000000, Training Accuracy= 89.84375
#
# Fold: 5, Epoch: 19, Validation Accuracy= 92.60000
#
# Fold: 5, Epoch: 20, Mini Batch: 50, Loss= 3916787.500000, Training Accuracy= 88.28125
# Fold: 5, Epoch: 20, Mini Batch: 70, Loss= 2301203.250000, Training Accuracy= 89.84375
#
# Fold: 5, Epoch: 20, Validation Accuracy= 92.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          438   18   456
# 1           62  482   544
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 6, Epoch: 1, Mini Batch: 50, Loss= 146092480.000000, Training Accuracy= 67.96875
# Fold: 6, Epoch: 1, Mini Batch: 70, Loss= 94468624.000000, Training Accuracy= 72.65625
#
# Fold: 6, Epoch: 1, Validation Accuracy= 83.70000
#
# Fold: 6, Epoch: 2, Mini Batch: 50, Loss= 86193528.000000, Training Accuracy= 73.43750
# Fold: 6, Epoch: 2, Mini Batch: 70, Loss= 51697104.000000, Training Accuracy= 75.78125
#
# Fold: 6, Epoch: 2, Validation Accuracy= 86.20000
#
# Fold: 6, Epoch: 3, Mini Batch: 50, Loss= 34257248.000000, Training Accuracy= 79.68750
# Fold: 6, Epoch: 3, Mini Batch: 70, Loss= 42727368.000000, Training Accuracy= 75.78125
#
# Fold: 6, Epoch: 3, Validation Accuracy= 86.60000
#
# Fold: 6, Epoch: 4, Mini Batch: 50, Loss= 24705412.000000, Training Accuracy= 81.25000
# Fold: 6, Epoch: 4, Mini Batch: 70, Loss= 23279936.000000, Training Accuracy= 75.78125
#
# Fold: 6, Epoch: 4, Validation Accuracy= 87.30000
#
# Fold: 6, Epoch: 5, Mini Batch: 50, Loss= 16334166.000000, Training Accuracy= 85.93750
# Fold: 6, Epoch: 5, Mini Batch: 70, Loss= 26244234.000000, Training Accuracy= 78.90625
#
# Fold: 6, Epoch: 5, Validation Accuracy= 88.00000
#
# Fold: 6, Epoch: 6, Mini Batch: 50, Loss= 17718832.000000, Training Accuracy= 82.03125
# Fold: 6, Epoch: 6, Mini Batch: 70, Loss= 15957117.000000, Training Accuracy= 82.81250
#
# Fold: 6, Epoch: 6, Validation Accuracy= 88.40000
#
# Fold: 6, Epoch: 7, Mini Batch: 50, Loss= 9287010.000000, Training Accuracy= 85.93750
# Fold: 6, Epoch: 7, Mini Batch: 70, Loss= 9968219.000000, Training Accuracy= 82.81250
#
# Fold: 6, Epoch: 7, Validation Accuracy= 89.00000
#
# Fold: 6, Epoch: 8, Mini Batch: 50, Loss= 13498728.000000, Training Accuracy= 84.37500
# Fold: 6, Epoch: 8, Mini Batch: 70, Loss= 9589237.000000, Training Accuracy= 84.37500
#
# Fold: 6, Epoch: 8, Validation Accuracy= 88.90000
#
# Fold: 6, Epoch: 9, Mini Batch: 50, Loss= 5755483.000000, Training Accuracy= 87.50000
# Fold: 6, Epoch: 9, Mini Batch: 70, Loss= 8625418.000000, Training Accuracy= 84.37500
#
# Fold: 6, Epoch: 9, Validation Accuracy= 89.10000
#
# Fold: 6, Epoch: 10, Mini Batch: 50, Loss= 5187151.000000, Training Accuracy= 86.71875
# Fold: 6, Epoch: 10, Mini Batch: 70, Loss= 12319459.000000, Training Accuracy= 76.56250
#
# Fold: 6, Epoch: 10, Validation Accuracy= 89.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          424   33   457
# 1           76  467   543
# All        500  500  1000
#
# Fold: 6, Epoch: 11, Mini Batch: 50, Loss= 3894796.500000, Training Accuracy= 89.84375
# Fold: 6, Epoch: 11, Mini Batch: 70, Loss= 5589075.000000, Training Accuracy= 91.40625
#
# Fold: 6, Epoch: 11, Validation Accuracy= 89.90000
#
# Fold: 6, Epoch: 12, Mini Batch: 50, Loss= 5508057.000000, Training Accuracy= 86.71875
# Fold: 6, Epoch: 12, Mini Batch: 70, Loss= 8409122.000000, Training Accuracy= 82.81250
#
# Fold: 6, Epoch: 12, Validation Accuracy= 89.80000
#
# Fold: 6, Epoch: 13, Mini Batch: 50, Loss= 7001807.000000, Training Accuracy= 89.06250
# Fold: 6, Epoch: 13, Mini Batch: 70, Loss= 5800616.000000, Training Accuracy= 86.71875
#
# Fold: 6, Epoch: 13, Validation Accuracy= 89.20000
#
# Fold: 6, Epoch: 14, Mini Batch: 50, Loss= 5463628.500000, Training Accuracy= 86.71875
# Fold: 6, Epoch: 14, Mini Batch: 70, Loss= 5902577.000000, Training Accuracy= 87.50000
#
# Fold: 6, Epoch: 14, Validation Accuracy= 90.00000
#
# Fold: 6, Epoch: 15, Mini Batch: 50, Loss= 2703810.500000, Training Accuracy= 89.06250
# Fold: 6, Epoch: 15, Mini Batch: 70, Loss= 6027579.000000, Training Accuracy= 85.15625
#
# Fold: 6, Epoch: 15, Validation Accuracy= 89.30000
#
# Fold: 6, Epoch: 16, Mini Batch: 50, Loss= 2978743.000000, Training Accuracy= 87.50000
# Fold: 6, Epoch: 16, Mini Batch: 70, Loss= 4397019.500000, Training Accuracy= 84.37500
#
# Fold: 6, Epoch: 16, Validation Accuracy= 90.00000
#
# Fold: 6, Epoch: 17, Mini Batch: 50, Loss= 2340979.750000, Training Accuracy= 90.62500
# Fold: 6, Epoch: 17, Mini Batch: 70, Loss= 4168130.000000, Training Accuracy= 85.15625
#
# Fold: 6, Epoch: 17, Validation Accuracy= 90.20000
#
# Fold: 6, Epoch: 18, Mini Batch: 50, Loss= 3679872.000000, Training Accuracy= 91.40625
# Fold: 6, Epoch: 18, Mini Batch: 70, Loss= 4067782.250000, Training Accuracy= 85.93750
#
# Fold: 6, Epoch: 18, Validation Accuracy= 90.70000
#
# Fold: 6, Epoch: 19, Mini Batch: 50, Loss= 2785038.000000, Training Accuracy= 92.18750
# Fold: 6, Epoch: 19, Mini Batch: 70, Loss= 2504527.500000, Training Accuracy= 86.71875
#
# Fold: 6, Epoch: 19, Validation Accuracy= 90.80000
#
# Fold: 6, Epoch: 20, Mini Batch: 50, Loss= 2712883.000000, Training Accuracy= 88.28125
# Fold: 6, Epoch: 20, Mini Batch: 70, Loss= 2335771.500000, Training Accuracy= 86.71875
#
# Fold: 6, Epoch: 20, Validation Accuracy= 90.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          438   33   471
# 1           62  467   529
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 7, Epoch: 1, Mini Batch: 50, Loss= 156929232.000000, Training Accuracy= 67.18750
# Fold: 7, Epoch: 1, Mini Batch: 70, Loss= 103038840.000000, Training Accuracy= 75.00000
#
# Fold: 7, Epoch: 1, Validation Accuracy= 83.50000
#
# Fold: 7, Epoch: 2, Mini Batch: 50, Loss= 88526072.000000, Training Accuracy= 73.43750
# Fold: 7, Epoch: 2, Mini Batch: 70, Loss= 48184992.000000, Training Accuracy= 78.12500
#
# Fold: 7, Epoch: 2, Validation Accuracy= 85.70000
#
# Fold: 7, Epoch: 3, Mini Batch: 50, Loss= 33528068.000000, Training Accuracy= 78.90625
# Fold: 7, Epoch: 3, Mini Batch: 70, Loss= 45276256.000000, Training Accuracy= 75.00000
#
# Fold: 7, Epoch: 3, Validation Accuracy= 87.00000
#
# Fold: 7, Epoch: 4, Mini Batch: 50, Loss= 21556652.000000, Training Accuracy= 82.81250
# Fold: 7, Epoch: 4, Mini Batch: 70, Loss= 24965780.000000, Training Accuracy= 75.00000
#
# Fold: 7, Epoch: 4, Validation Accuracy= 87.10000
#
# Fold: 7, Epoch: 5, Mini Batch: 50, Loss= 17221100.000000, Training Accuracy= 85.15625
# Fold: 7, Epoch: 5, Mini Batch: 70, Loss= 27223734.000000, Training Accuracy= 80.46875
#
# Fold: 7, Epoch: 5, Validation Accuracy= 87.30000
#
# Fold: 7, Epoch: 6, Mini Batch: 50, Loss= 18350436.000000, Training Accuracy= 83.59375
# Fold: 7, Epoch: 6, Mini Batch: 70, Loss= 18062076.000000, Training Accuracy= 82.81250
#
# Fold: 7, Epoch: 6, Validation Accuracy= 87.00000
#
# Fold: 7, Epoch: 7, Mini Batch: 50, Loss= 11305881.000000, Training Accuracy= 82.03125
# Fold: 7, Epoch: 7, Mini Batch: 70, Loss= 11712632.000000, Training Accuracy= 83.59375
#
# Fold: 7, Epoch: 7, Validation Accuracy= 87.80000
#
# Fold: 7, Epoch: 8, Mini Batch: 50, Loss= 11411309.000000, Training Accuracy= 85.15625
# Fold: 7, Epoch: 8, Mini Batch: 70, Loss= 9934296.000000, Training Accuracy= 85.93750
#
# Fold: 7, Epoch: 8, Validation Accuracy= 88.20000
#
# Fold: 7, Epoch: 9, Mini Batch: 50, Loss= 4157873.250000, Training Accuracy= 90.62500
# Fold: 7, Epoch: 9, Mini Batch: 70, Loss= 9583186.000000, Training Accuracy= 85.93750
#
# Fold: 7, Epoch: 9, Validation Accuracy= 88.20000
#
# Fold: 7, Epoch: 10, Mini Batch: 50, Loss= 7505254.000000, Training Accuracy= 83.59375
# Fold: 7, Epoch: 10, Mini Batch: 70, Loss= 10458988.000000, Training Accuracy= 78.12500
#
# Fold: 7, Epoch: 10, Validation Accuracy= 88.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          438   56   494
# 1           62  444   506
# All        500  500  1000
#
# Fold: 7, Epoch: 11, Mini Batch: 50, Loss= 3681828.500000, Training Accuracy= 89.06250
# Fold: 7, Epoch: 11, Mini Batch: 70, Loss= 6085492.000000, Training Accuracy= 88.28125
#
# Fold: 7, Epoch: 11, Validation Accuracy= 87.70000
#
# Fold: 7, Epoch: 12, Mini Batch: 50, Loss= 3950115.000000, Training Accuracy= 84.37500
# Fold: 7, Epoch: 12, Mini Batch: 70, Loss= 6599289.000000, Training Accuracy= 85.93750
#
# Fold: 7, Epoch: 12, Validation Accuracy= 88.70000
#
# Fold: 7, Epoch: 13, Mini Batch: 50, Loss= 6126938.000000, Training Accuracy= 90.62500
# Fold: 7, Epoch: 13, Mini Batch: 70, Loss= 6004920.000000, Training Accuracy= 87.50000
#
# Fold: 7, Epoch: 13, Validation Accuracy= 88.80000
#
# Fold: 7, Epoch: 14, Mini Batch: 50, Loss= 5625154.000000, Training Accuracy= 88.28125
# Fold: 7, Epoch: 14, Mini Batch: 70, Loss= 5892670.000000, Training Accuracy= 85.93750
#
# Fold: 7, Epoch: 14, Validation Accuracy= 89.30000
#
# Fold: 7, Epoch: 15, Mini Batch: 50, Loss= 3985992.250000, Training Accuracy= 86.71875
# Fold: 7, Epoch: 15, Mini Batch: 70, Loss= 7531892.500000, Training Accuracy= 84.37500
#
# Fold: 7, Epoch: 15, Validation Accuracy= 89.50000
#
# Fold: 7, Epoch: 16, Mini Batch: 50, Loss= 3657988.000000, Training Accuracy= 88.28125
# Fold: 7, Epoch: 16, Mini Batch: 70, Loss= 5254673.000000, Training Accuracy= 85.15625
#
# Fold: 7, Epoch: 16, Validation Accuracy= 88.60000
#
# Fold: 7, Epoch: 17, Mini Batch: 50, Loss= 1515757.000000, Training Accuracy= 91.40625
# Fold: 7, Epoch: 17, Mini Batch: 70, Loss= 5763194.500000, Training Accuracy= 83.59375
#
# Fold: 7, Epoch: 17, Validation Accuracy= 87.70000
#
# Fold: 7, Epoch: 18, Mini Batch: 50, Loss= 3417223.000000, Training Accuracy= 89.84375
# Fold: 7, Epoch: 18, Mini Batch: 70, Loss= 3766334.500000, Training Accuracy= 88.28125
#
# Fold: 7, Epoch: 18, Validation Accuracy= 89.40000
#
# Fold: 7, Epoch: 19, Mini Batch: 50, Loss= 2169926.250000, Training Accuracy= 92.96875
# Fold: 7, Epoch: 19, Mini Batch: 70, Loss= 2078538.625000, Training Accuracy= 89.84375
#
# Fold: 7, Epoch: 19, Validation Accuracy= 89.00000
#
# Fold: 7, Epoch: 20, Mini Batch: 50, Loss= 3497493.000000, Training Accuracy= 87.50000
# Fold: 7, Epoch: 20, Mini Batch: 70, Loss= 3707506.000000, Training Accuracy= 88.28125
#
# Fold: 7, Epoch: 20, Validation Accuracy= 89.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          438   42   480
# 1           62  458   520
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 8, Epoch: 1, Mini Batch: 50, Loss= 171072736.000000, Training Accuracy= 70.31250
# Fold: 8, Epoch: 1, Mini Batch: 70, Loss= 112025528.000000, Training Accuracy= 72.65625
#
# Fold: 8, Epoch: 1, Validation Accuracy= 84.10000
#
# Fold: 8, Epoch: 2, Mini Batch: 50, Loss= 68894816.000000, Training Accuracy= 74.21875
# Fold: 8, Epoch: 2, Mini Batch: 70, Loss= 45921148.000000, Training Accuracy= 77.34375
#
# Fold: 8, Epoch: 2, Validation Accuracy= 86.30000
#
# Fold: 8, Epoch: 3, Mini Batch: 50, Loss= 45697976.000000, Training Accuracy= 75.00000
# Fold: 8, Epoch: 3, Mini Batch: 70, Loss= 44477096.000000, Training Accuracy= 77.34375
#
# Fold: 8, Epoch: 3, Validation Accuracy= 88.10000
#
# Fold: 8, Epoch: 4, Mini Batch: 50, Loss= 30834832.000000, Training Accuracy= 75.00000
# Fold: 8, Epoch: 4, Mini Batch: 70, Loss= 25921152.000000, Training Accuracy= 77.34375
#
# Fold: 8, Epoch: 4, Validation Accuracy= 88.30000
#
# Fold: 8, Epoch: 5, Mini Batch: 50, Loss= 25254374.000000, Training Accuracy= 78.90625
# Fold: 8, Epoch: 5, Mini Batch: 70, Loss= 31371692.000000, Training Accuracy= 75.00000
#
# Fold: 8, Epoch: 5, Validation Accuracy= 88.50000
#
# Fold: 8, Epoch: 6, Mini Batch: 50, Loss= 15428572.000000, Training Accuracy= 81.25000
# Fold: 8, Epoch: 6, Mini Batch: 70, Loss= 18280912.000000, Training Accuracy= 84.37500
#
# Fold: 8, Epoch: 6, Validation Accuracy= 87.60000
#
# Fold: 8, Epoch: 7, Mini Batch: 50, Loss= 13740766.000000, Training Accuracy= 81.25000
# Fold: 8, Epoch: 7, Mini Batch: 70, Loss= 10073166.000000, Training Accuracy= 83.59375
#
# Fold: 8, Epoch: 7, Validation Accuracy= 88.10000
#
# Fold: 8, Epoch: 8, Mini Batch: 50, Loss= 13729056.000000, Training Accuracy= 82.81250
# Fold: 8, Epoch: 8, Mini Batch: 70, Loss= 10826866.000000, Training Accuracy= 82.81250
#
# Fold: 8, Epoch: 8, Validation Accuracy= 89.00000
#
# Fold: 8, Epoch: 9, Mini Batch: 50, Loss= 14078370.000000, Training Accuracy= 78.12500
# Fold: 8, Epoch: 9, Mini Batch: 70, Loss= 11570684.000000, Training Accuracy= 82.81250
#
# Fold: 8, Epoch: 9, Validation Accuracy= 89.60000
#
# Fold: 8, Epoch: 10, Mini Batch: 50, Loss= 8925203.000000, Training Accuracy= 85.15625
# Fold: 8, Epoch: 10, Mini Batch: 70, Loss= 9197112.000000, Training Accuracy= 81.25000
#
# Fold: 8, Epoch: 10, Validation Accuracy= 89.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          429   37   466
# 1           71  463   534
# All        500  500  1000
#
# Fold: 8, Epoch: 11, Mini Batch: 50, Loss= 8987347.000000, Training Accuracy= 83.59375
# Fold: 8, Epoch: 11, Mini Batch: 70, Loss= 7312427.500000, Training Accuracy= 85.15625
#
# Fold: 8, Epoch: 11, Validation Accuracy= 89.80000
#
# Fold: 8, Epoch: 12, Mini Batch: 50, Loss= 6858918.000000, Training Accuracy= 89.06250
# Fold: 8, Epoch: 12, Mini Batch: 70, Loss= 7275538.500000, Training Accuracy= 86.71875
#
# Fold: 8, Epoch: 12, Validation Accuracy= 88.20000
#
# Fold: 8, Epoch: 13, Mini Batch: 50, Loss= 7767654.500000, Training Accuracy= 82.03125
# Fold: 8, Epoch: 13, Mini Batch: 70, Loss= 5604219.000000, Training Accuracy= 82.81250
#
# Fold: 8, Epoch: 13, Validation Accuracy= 89.30000
#
# Fold: 8, Epoch: 14, Mini Batch: 50, Loss= 3288288.500000, Training Accuracy= 85.93750
# Fold: 8, Epoch: 14, Mini Batch: 70, Loss= 4408766.000000, Training Accuracy= 88.28125
#
# Fold: 8, Epoch: 14, Validation Accuracy= 88.70000
#
# Fold: 8, Epoch: 15, Mini Batch: 50, Loss= 8370073.500000, Training Accuracy= 75.00000
# Fold: 8, Epoch: 15, Mini Batch: 70, Loss= 6823264.500000, Training Accuracy= 85.15625
#
# Fold: 8, Epoch: 15, Validation Accuracy= 88.70000
#
# Fold: 8, Epoch: 16, Mini Batch: 50, Loss= 4981603.000000, Training Accuracy= 84.37500
# Fold: 8, Epoch: 16, Mini Batch: 70, Loss= 3333416.500000, Training Accuracy= 89.06250
#
# Fold: 8, Epoch: 16, Validation Accuracy= 89.60000
#
# Fold: 8, Epoch: 17, Mini Batch: 50, Loss= 5495526.500000, Training Accuracy= 82.81250
# Fold: 8, Epoch: 17, Mini Batch: 70, Loss= 4485950.000000, Training Accuracy= 84.37500
#
# Fold: 8, Epoch: 17, Validation Accuracy= 89.20000
#
# Fold: 8, Epoch: 18, Mini Batch: 50, Loss= 5628856.500000, Training Accuracy= 79.68750
# Fold: 8, Epoch: 18, Mini Batch: 70, Loss= 3843083.250000, Training Accuracy= 89.06250
#
# Fold: 8, Epoch: 18, Validation Accuracy= 89.80000
#
# Fold: 8, Epoch: 19, Mini Batch: 50, Loss= 2061923.500000, Training Accuracy= 92.96875
# Fold: 8, Epoch: 19, Mini Batch: 70, Loss= 2644301.000000, Training Accuracy= 87.50000
#
# Fold: 8, Epoch: 19, Validation Accuracy= 90.60000
#
# Fold: 8, Epoch: 20, Mini Batch: 50, Loss= 2971420.750000, Training Accuracy= 89.84375
# Fold: 8, Epoch: 20, Mini Batch: 70, Loss= 3716349.500000, Training Accuracy= 89.06250
#
# Fold: 8, Epoch: 20, Validation Accuracy= 89.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          448   53   501
# 1           52  447   499
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 9, Epoch: 1, Mini Batch: 50, Loss= 171072736.000000, Training Accuracy= 70.31250
# Fold: 9, Epoch: 1, Mini Batch: 70, Loss= 112006192.000000, Training Accuracy= 71.87500
#
# Fold: 9, Epoch: 1, Validation Accuracy= 85.10000
#
# Fold: 9, Epoch: 2, Mini Batch: 50, Loss= 69051240.000000, Training Accuracy= 72.65625
# Fold: 9, Epoch: 2, Mini Batch: 70, Loss= 50060268.000000, Training Accuracy= 76.56250
#
# Fold: 9, Epoch: 2, Validation Accuracy= 85.70000
#
# Fold: 9, Epoch: 3, Mini Batch: 50, Loss= 47023664.000000, Training Accuracy= 72.65625
# Fold: 9, Epoch: 3, Mini Batch: 70, Loss= 42748220.000000, Training Accuracy= 77.34375
#
# Fold: 9, Epoch: 3, Validation Accuracy= 88.00000
#
# Fold: 9, Epoch: 4, Mini Batch: 50, Loss= 30989740.000000, Training Accuracy= 76.56250
# Fold: 9, Epoch: 4, Mini Batch: 70, Loss= 25858752.000000, Training Accuracy= 76.56250
#
# Fold: 9, Epoch: 4, Validation Accuracy= 88.00000
#
# Fold: 9, Epoch: 5, Mini Batch: 50, Loss= 25846800.000000, Training Accuracy= 77.34375
# Fold: 9, Epoch: 5, Mini Batch: 70, Loss= 26680268.000000, Training Accuracy= 77.34375
#
# Fold: 9, Epoch: 5, Validation Accuracy= 88.80000
#
# Fold: 9, Epoch: 6, Mini Batch: 50, Loss= 12014147.000000, Training Accuracy= 82.03125
# Fold: 9, Epoch: 6, Mini Batch: 70, Loss= 18400898.000000, Training Accuracy= 81.25000
#
# Fold: 9, Epoch: 6, Validation Accuracy= 88.30000
#
# Fold: 9, Epoch: 7, Mini Batch: 50, Loss= 15534286.000000, Training Accuracy= 80.46875
# Fold: 9, Epoch: 7, Mini Batch: 70, Loss= 9798540.000000, Training Accuracy= 85.15625
#
# Fold: 9, Epoch: 7, Validation Accuracy= 88.80000
#
# Fold: 9, Epoch: 8, Mini Batch: 50, Loss= 11323803.000000, Training Accuracy= 81.25000
# Fold: 9, Epoch: 8, Mini Batch: 70, Loss= 9309746.000000, Training Accuracy= 82.03125
#
# Fold: 9, Epoch: 8, Validation Accuracy= 87.50000
#
# Fold: 9, Epoch: 9, Mini Batch: 50, Loss= 11741870.000000, Training Accuracy= 78.90625
# Fold: 9, Epoch: 9, Mini Batch: 70, Loss= 7826792.000000, Training Accuracy= 87.50000
#
# Fold: 9, Epoch: 9, Validation Accuracy= 89.40000
#
# Fold: 9, Epoch: 10, Mini Batch: 50, Loss= 11510215.000000, Training Accuracy= 81.25000
# Fold: 9, Epoch: 10, Mini Batch: 70, Loss= 7784230.500000, Training Accuracy= 82.03125
#
# Fold: 9, Epoch: 10, Validation Accuracy= 88.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          446   57   503
# 1           54  443   497
# All        500  500  1000
#
# Fold: 9, Epoch: 11, Mini Batch: 50, Loss= 8349780.500000, Training Accuracy= 79.68750
# Fold: 9, Epoch: 11, Mini Batch: 70, Loss= 6641518.000000, Training Accuracy= 84.37500
#
# Fold: 9, Epoch: 11, Validation Accuracy= 89.50000
#
# Fold: 9, Epoch: 12, Mini Batch: 50, Loss= 6325178.000000, Training Accuracy= 87.50000
# Fold: 9, Epoch: 12, Mini Batch: 70, Loss= 8330543.000000, Training Accuracy= 83.59375
#
# Fold: 9, Epoch: 12, Validation Accuracy= 90.00000
#
# Fold: 9, Epoch: 13, Mini Batch: 50, Loss= 6890864.000000, Training Accuracy= 82.03125
# Fold: 9, Epoch: 13, Mini Batch: 70, Loss= 6355575.000000, Training Accuracy= 82.81250
#
# Fold: 9, Epoch: 13, Validation Accuracy= 89.10000
#
# Fold: 9, Epoch: 14, Mini Batch: 50, Loss= 5221874.000000, Training Accuracy= 83.59375
# Fold: 9, Epoch: 14, Mini Batch: 70, Loss= 5289533.000000, Training Accuracy= 89.06250
#
# Fold: 9, Epoch: 14, Validation Accuracy= 89.30000
#
# Fold: 9, Epoch: 15, Mini Batch: 50, Loss= 6781738.500000, Training Accuracy= 79.68750
# Fold: 9, Epoch: 15, Mini Batch: 70, Loss= 7022194.000000, Training Accuracy= 85.15625
#
# Fold: 9, Epoch: 15, Validation Accuracy= 89.20000
#
# Fold: 9, Epoch: 16, Mini Batch: 50, Loss= 3226931.750000, Training Accuracy= 87.50000
# Fold: 9, Epoch: 16, Mini Batch: 70, Loss= 5557967.500000, Training Accuracy= 83.59375
#
# Fold: 9, Epoch: 16, Validation Accuracy= 89.30000
#
# Fold: 9, Epoch: 17, Mini Batch: 50, Loss= 4342436.500000, Training Accuracy= 81.25000
# Fold: 9, Epoch: 17, Mini Batch: 70, Loss= 3607490.000000, Training Accuracy= 82.81250
#
# Fold: 9, Epoch: 17, Validation Accuracy= 89.50000
#
# Fold: 9, Epoch: 18, Mini Batch: 50, Loss= 4827672.500000, Training Accuracy= 83.59375
# Fold: 9, Epoch: 18, Mini Batch: 70, Loss= 3951281.250000, Training Accuracy= 84.37500
#
# Fold: 9, Epoch: 18, Validation Accuracy= 90.30000
#
# Fold: 9, Epoch: 19, Mini Batch: 50, Loss= 2987868.750000, Training Accuracy= 89.84375
# Fold: 9, Epoch: 19, Mini Batch: 70, Loss= 2451421.500000, Training Accuracy= 89.06250
#
# Fold: 9, Epoch: 19, Validation Accuracy= 90.20000
#
# Fold: 9, Epoch: 20, Mini Batch: 50, Loss= 2899721.500000, Training Accuracy= 86.71875
# Fold: 9, Epoch: 20, Mini Batch: 70, Loss= 2705811.250000, Training Accuracy= 89.06250
#
# Fold: 9, Epoch: 20, Validation Accuracy= 90.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          448   48   496
# 1           52  452   504
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 32, 32, 3) (1000, 2)
# Training Data and Labels shape:  (9000, 32, 32, 3) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# Fold: 10, Epoch: 1, Mini Batch: 50, Loss= 171072736.000000, Training Accuracy= 70.31250
# Fold: 10, Epoch: 1, Mini Batch: 70, Loss= 125891392.000000, Training Accuracy= 67.18750
#
# Fold: 10, Epoch: 1, Validation Accuracy= 82.30000
#
# Fold: 10, Epoch: 2, Mini Batch: 50, Loss= 71773184.000000, Training Accuracy= 74.21875
# Fold: 10, Epoch: 2, Mini Batch: 70, Loss= 34669148.000000, Training Accuracy= 79.68750
#
# Fold: 10, Epoch: 2, Validation Accuracy= 84.80000
#
# Fold: 10, Epoch: 3, Mini Batch: 50, Loss= 46207016.000000, Training Accuracy= 75.00000
# Fold: 10, Epoch: 3, Mini Batch: 70, Loss= 19055432.000000, Training Accuracy= 81.25000
#
# Fold: 10, Epoch: 3, Validation Accuracy= 87.30000
#
# Fold: 10, Epoch: 4, Mini Batch: 50, Loss= 31870948.000000, Training Accuracy= 72.65625
# Fold: 10, Epoch: 4, Mini Batch: 70, Loss= 24669564.000000, Training Accuracy= 80.46875
#
# Fold: 10, Epoch: 4, Validation Accuracy= 88.70000
#
# Fold: 10, Epoch: 5, Mini Batch: 50, Loss= 24630964.000000, Training Accuracy= 78.12500
# Fold: 10, Epoch: 5, Mini Batch: 70, Loss= 16668521.000000, Training Accuracy= 81.25000
#
# Fold: 10, Epoch: 5, Validation Accuracy= 88.50000
#
# Fold: 10, Epoch: 6, Mini Batch: 50, Loss= 14309486.000000, Training Accuracy= 82.81250
# Fold: 10, Epoch: 6, Mini Batch: 70, Loss= 10542250.000000, Training Accuracy= 79.68750
#
# Fold: 10, Epoch: 6, Validation Accuracy= 88.50000
#
# Fold: 10, Epoch: 7, Mini Batch: 50, Loss= 15315925.000000, Training Accuracy= 77.34375
# Fold: 10, Epoch: 7, Mini Batch: 70, Loss= 8575321.000000, Training Accuracy= 85.15625
#
# Fold: 10, Epoch: 7, Validation Accuracy= 88.50000
#
# Fold: 10, Epoch: 8, Mini Batch: 50, Loss= 9857269.000000, Training Accuracy= 82.81250
# Fold: 10, Epoch: 8, Mini Batch: 70, Loss= 14540390.000000, Training Accuracy= 78.90625
#
# Fold: 10, Epoch: 8, Validation Accuracy= 89.50000
#
# Fold: 10, Epoch: 9, Mini Batch: 50, Loss= 13085285.000000, Training Accuracy= 78.12500
# Fold: 10, Epoch: 9, Mini Batch: 70, Loss= 6745921.000000, Training Accuracy= 85.93750
#
# Fold: 10, Epoch: 9, Validation Accuracy= 89.30000
#
# Fold: 10, Epoch: 10, Mini Batch: 50, Loss= 9572712.000000, Training Accuracy= 84.37500
# Fold: 10, Epoch: 10, Mini Batch: 70, Loss= 7526106.500000, Training Accuracy= 84.37500
#
# Fold: 10, Epoch: 10, Validation Accuracy= 89.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          423   32   455
# 1           77  468   545
# All        500  500  1000
#
# Fold: 10, Epoch: 11, Mini Batch: 50, Loss= 8219950.000000, Training Accuracy= 83.59375
# Fold: 10, Epoch: 11, Mini Batch: 70, Loss= 7466114.500000, Training Accuracy= 89.84375
#
# Fold: 10, Epoch: 11, Validation Accuracy= 90.20000
#
# Fold: 10, Epoch: 12, Mini Batch: 50, Loss= 6494246.000000, Training Accuracy= 86.71875
# Fold: 10, Epoch: 12, Mini Batch: 70, Loss= 6412713.000000, Training Accuracy= 86.71875
#
# Fold: 10, Epoch: 12, Validation Accuracy= 89.40000
#
# Fold: 10, Epoch: 13, Mini Batch: 50, Loss= 5466015.500000, Training Accuracy= 82.03125
# Fold: 10, Epoch: 13, Mini Batch: 70, Loss= 6377827.000000, Training Accuracy= 83.59375
#
# Fold: 10, Epoch: 13, Validation Accuracy= 90.20000
#
# Fold: 10, Epoch: 14, Mini Batch: 50, Loss= 5519398.000000, Training Accuracy= 82.81250
# Fold: 10, Epoch: 14, Mini Batch: 70, Loss= 4671164.500000, Training Accuracy= 85.93750
#
# Fold: 10, Epoch: 14, Validation Accuracy= 90.20000
#
# Fold: 10, Epoch: 15, Mini Batch: 50, Loss= 6669595.000000, Training Accuracy= 76.56250
# Fold: 10, Epoch: 15, Mini Batch: 70, Loss= 5173991.000000, Training Accuracy= 85.15625
#
# Fold: 10, Epoch: 15, Validation Accuracy= 90.30000
#
# Fold: 10, Epoch: 16, Mini Batch: 50, Loss= 3848154.750000, Training Accuracy= 85.15625
# Fold: 10, Epoch: 16, Mini Batch: 70, Loss= 4357703.000000, Training Accuracy= 85.15625
#
# Fold: 10, Epoch: 16, Validation Accuracy= 90.20000
#
# Fold: 10, Epoch: 17, Mini Batch: 50, Loss= 4138863.500000, Training Accuracy= 85.93750
# Fold: 10, Epoch: 17, Mini Batch: 70, Loss= 3513417.000000, Training Accuracy= 89.06250
#
# Fold: 10, Epoch: 17, Validation Accuracy= 89.90000
#
# Fold: 10, Epoch: 18, Mini Batch: 50, Loss= 6249636.000000, Training Accuracy= 79.68750
# Fold: 10, Epoch: 18, Mini Batch: 70, Loss= 3913555.500000, Training Accuracy= 85.15625
#
# Fold: 10, Epoch: 18, Validation Accuracy= 90.20000
#
# Fold: 10, Epoch: 19, Mini Batch: 50, Loss= 3870177.000000, Training Accuracy= 86.71875
# Fold: 10, Epoch: 19, Mini Batch: 70, Loss= 4246309.500000, Training Accuracy= 86.71875
#
# Fold: 10, Epoch: 19, Validation Accuracy= 90.40000
#
# Fold: 10, Epoch: 20, Mini Batch: 50, Loss= 4023211.000000, Training Accuracy= 88.28125
# Fold: 10, Epoch: 20, Mini Batch: 70, Loss= 3397249.000000, Training Accuracy= 90.62500
#
# Fold: 10, Epoch: 20, Validation Accuracy= 90.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          432   32   464
# 1           68  468   536
# All        500  500  1000
#
# --- 36717.52900791168 seconds --- 611.9588169296583 minutes--- 10.199313617216216 hours
# The mean Valid Accuracy per fold is :  90.16
# The mean Valid Accuracy based on epochs for the fold number (1) is :  89.74
# The mean Valid Accuracy based on epochs for the fold number (2) is :  87.965
# The mean Valid Accuracy based on epochs for the fold number (3) is :  89.955
# The mean Valid Accuracy based on epochs for the fold number (4) is :  87.435
# The mean Valid Accuracy based on epochs for the fold number (5) is :  90.4
# The mean Valid Accuracy based on epochs for the fold number (6) is :  88.835
# The mean Valid Accuracy based on epochs for the fold number (7) is :  87.915
# The mean Valid Accuracy based on epochs for the fold number (8) is :  88.61
# The mean Valid Accuracy based on epochs for the fold number (9) is :  88.745
# The mean Valid Accuracy based on epochs for the fold number (10) is :  88.875

# %%
# validCMDict[0].ix[0,0]
# Out:
# 448

# %%
# Confusion Matrix
evalDF = pd.DataFrame(index=[i+1 for i in np.arange(10)], columns=['airplaneAccuracy', 'catAccuracy', 'overallAccuracy'])
for numFold in validCMDict.keys():
    evalDF.ix[numFold+1, 'airplaneAccuracy'] = validCMDict[numFold].ix[0,0]/500
    evalDF.ix[numFold+1, 'catAccuracy'] = validCMDict[numFold].ix[1,1]/500
    evalDF.ix[numFold+1, 'overallAccuracy'] = (validCMDict[numFold].ix[0,0]+validCMDict[numFold].ix[1,1])/1000




# Vizualize the evaluation results
rows = 2
columns = 5
vizualize(vaccPerEpochPerFold, 
          taccPerEpochPerFold, 
          meanValidAcc=meanValidAcc, 
          epochMeanValidAcc=epochMeanValidAcc, 
          rows=rows, columns=columns, figsize=(5*columns, 5*rows))
evalDF
# Out:
#    airplaneAccuracy catAccuracy overallAccuracy
# 1             0.896       0.928           0.912
# 2             0.852        0.94           0.896
# 3             0.846       0.964           0.905
# 4             0.828       0.946           0.887
# 5             0.876       0.964            0.92
# 6             0.876       0.934           0.905
# 7             0.876       0.916           0.896
# 8             0.896       0.894           0.895
# 9             0.896       0.904             0.9
# 10            0.864       0.936             0.9

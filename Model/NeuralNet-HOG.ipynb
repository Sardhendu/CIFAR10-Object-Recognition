# %%
# Import Packages:
from __future__ import print_function

import os, sys
from six.moves import cPickle as pickle
from six.moves import range
from collections import defaultdict

# Model Packeges import
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.metrics import confusion_matrix

# Get the current working directory
cwd = os.getcwd()
mydir = os.path.abspath(os.path.join(cwd, ".."))
sys.path.append(mydir)
from DataGenerator import genTrainValidFolds

# Packages for plot:
import matplotlib
from matplotlib import pyplot as plt
matplotlib.style.use('ggplot')
# %matplotlib inline

# %%
# def toOneHotVector():
def reset_graph():  # Reset the graph
    if 'sess' in globals() and sess:
        sess.close()
    tf.reset_default_graph()
    
    
def reshape_data(dataset, labels, featureSize, numLabels, sample_size=None):
    if sample_size:
        dataset = dataset[:sample_size].reshape(sample_size, featureSize) # To reshape the  
        # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
        labels = (np.arange(numLabels) == labels[:,None]).astype(np.float32)
    else:
        dataset = dataset.reshape(len(dataset), featureSize) # To reshape the  
        # Map 0 to [1.0, 0.0, 0.0 ...], 1 to [0.0, 1.0, 0.0 ...]
        labels = (np.arange(numLabels) == labels[:,None]).astype(np.float32)
    return dataset, labels


def accuracy(predictions, labels):
    # Both the predictions and the labels should be in One-Hot vector format.
    return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))/ predictions.shape[0])


def confusionMatrix(predictions, labels):
    # Both the predictions and the labels should be in One-Hot vector format.
    return (pd.crosstab(np.argmax(labels, 1), np.argmax(predictions, 1), rownames=['True'], colnames=['Predicted'], margins=True))

def vizualize(validacc_dict, trainacc_dict, meanValidAcc, rows, columns, figsize=(40,20), xlabels=None, ylabels=None, titles=None):
    fig1, axs = plt.subplots(rows, columns, figsize=figsize, facecolor='w', edgecolor='k')   # 
    axs = axs.ravel()
    numFolds = len(validacc_dict.keys())
    for foldNum in np.arange(numFolds):
        axs[foldNum].plot(validacc_dict[foldNum+1])
        axs[foldNum].plot(trainacc_dict[foldNum+1])
        axs[foldNum].axhline(y=meanValidAcc, color = 'k')
        axs[foldNum].set_title('Validation/Training accuracy Fold:%s '%str(foldNum+1))
        axs[foldNum].legend(['validation acc', 'training acc', ['n-fold avg valid acc']], loc=4)

# %%
class BuildNeuralNet():
    
    def __init__(self, params, featureSize):
        print (params)
        self.imageSize = params['imageSize']
        self.numLabels = params['numLabels']
        
        # Network params
        self.numHidden1 = params['numHidden1']
        self.numHidden2 = params['numHidden2']
        self.numHidden3 = params['numHidden3'] 
        
        # Batch Variables
        self.numFolds = params['numFolds']
        self.epochs = params['epochs']
        self.batchSize = params['batchSize']
        
        # Optimization Params
        self.keepProb = params['keepProb']
        self.optimizerParam = params['optimizerParam']
        
        self.featureSize = featureSize
#         print (self.featureSize)
#         print (self.numHidden1)
        
        self.weights = {
            "hid1_wght": tf.Variable(tf.random_normal([self.featureSize, self.numHidden1], seed=1877)),
            "hid2_wght" : tf.Variable(tf.random_normal([self.numHidden1, self.numHidden2], seed=74698)),
            "hid3_wght": tf.Variable(tf.random_normal([self.numHidden2, self.numHidden3], seed=9036)),
#             "hid4_wght": tf.Variable(tf.random_normal([self.numHidden3, self.numHidden4], seed=9476)),
            "out_wght": tf.Variable(tf.random_normal([self.numHidden3, self.numLabels], seed=5664))
        }
        
        self.biases = {
            "hid1_bias": tf.Variable(tf.random_normal([self.numHidden1], seed=6353)),
            "hid2_bias": tf.Variable(tf.random_normal([self.numHidden2], seed=7476)),
            "hid3_bias": tf.Variable(tf.random_normal([self.numHidden3], seed=1322)),
#             "hid4_bias": tf.Variable(tf.random_normal([self.numHidden4], seed=8722)),
            "out_bias": tf.Variable(tf.random_normal([self.numLabels], seed=2228))
        }
        
    def hiddenLayer(self, x, w, b, keepProb=None, nlModel='RELU'):
        x = tf.matmul(x, w) + b
        if nlModel == 'RELU':
            x = tf.nn.relu(x)
        elif nlModel == 'LOGIT':
            x = tf.sigmoid(x)
            
        if keepProb:
            return tf.nn.dropout(x, keepProb)
        else: return x
        
        
    def outputLayer(self, x, w, b):
        x = tf.matmul(x, w) + b
        return x, tf.nn.softmax(x)
        
        
    def trainGraph(self, regularization=False):
        trainData = tf.placeholder(tf.float32, [None, self.featureSize])
        trainLabels = tf.placeholder(tf.float32, [None, self.numLabels])

        # 1st Hidden Layer State
        hid1State = self.hiddenLayer(x=trainData, w=self.weights['hid1_wght'], b=self.biases['hid1_bias'], keepProb=self.keepProb['hid1'], nlModel='RELU') 
        
        # 2nd Hidden Layer State
        hid2State = self.hiddenLayer(x=hid1State, w=self.weights['hid2_wght'], b=self.biases['hid2_bias'], keepProb=self.keepProb['hid2'], nlModel='RELU') 
        
        # 3nd Hidden Layer State
        hid3State = self.hiddenLayer(x=hid2State, w=self.weights['hid3_wght'], b=self.biases['hid3_bias'], keepProb=self.keepProb['hid3'], nlModel='RELU') 
        
        # 4rth Hidden Layer State
        # hid4State = self.hiddenLayer(x=hid2State, w=self.weights['hid4_wght'], b=self.biases['hid4_bias'], dropoutProb=0.75, nlModel='RELU') 
        
        # Output Layer State
        hidToOut, outState = self.outputLayer(x=hid3State, w=self.weights['out_wght'], b=self.biases['out_bias'])
        
        # Loss Function
        lossCE = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=hidToOut, labels=trainLabels))
        
        # Loss function using L2 Regularization
        if regularization:
            print ('Doing L2 Regularization')
            regularizers = (tf.nn.l2_loss(self.weights['hid1_wght']) 
                            + tf.nn.l2_loss(self.weights['hid2_wght']) 
                            + tf.nn.l2_loss(self.weights['hid3_wght']) 
                            + tf.nn.l2_loss(self.weights['out_wght'])
                        )
            lossCE = tf.reduce_mean(lossCE + (0.005 * regularizers))
        
        
        # Optimizer
        if self.optimizerParam['optimizer'] == 'ADAM': 
            optimizer = tf.train.AdamOptimizer(learning_rate=self.optimizerParam['learning_rate']).minimize(lossCE)   # 0.008
        elif self.optimizerParam['optimizer'] == 'MOMENTUM':
             optimizer = tf.train.MomentumOptimizer(learning_rate=self.optimizerParam['learning_rate'],               # l=0.004, m=0.5
                                                    momentum=self.optimizerParam['momentum'], 
                                                    use_locking=False, name='Momentum', use_nesterov=False).minimize(lossCE)
        elif self.optimizerParam['optimizer'] == 'SGD':                                                              # 0.001
            optimizer = tf.train.GradientDescentOptimizer(self.optimizerParam['learning_rate']).minimize(lossCE)
        elif self.optimizerParam['optimizer'] == 'ADAGRAD':
            optimizer = tf.train.AdagradOptimizer(learning_rate=self.optimizerParam['learning_rate']).minimize(lossCE)  # 0.04
        elif self.optimizerParam['optimizer'] == 'RMSPROP':
            optimizer = tf.train.RMSPropOptimizer(learning_rate=self.optimizerParam['learning_rate'],                # 0.001
                                                  momentum=self.optimizerParam['momentum']).minimize(lossCE)
        else:
            print ("Your provided optimizers do not match with any of the initialized optimizers: .........")
            return None
        
        # Evaluate model
#         trainPred = tf.equal(tf.argmax(outState, 1), tf.argmax(trainLabels, 1))
#         trainAccuracy = tf.reduce_mean(tf.cast(trainPred, tf.float32))
        
        return dict(
            trainData = trainData, 
            trainLabels = trainLabels,
            trainPred = outState,
            optimizer = optimizer,
            lossCE = lossCE,
            wghtNew = self.weights
        )
    
    
    def validGraph(self):

        validData = tf.placeholder(tf.float32, [None, self.featureSize])
        validLabels = tf.placeholder(tf.float32, [None, self.numLabels])

        # 1st Hidden Layer State
        vhid1State = self.hiddenLayer(x=validData, w=self.weights['hid1_wght'], b=self.biases['hid1_bias'], nlModel='RELU')

        # 2nd Hidden Layer State
        vhid2State = self.hiddenLayer(x=vhid1State, w=self.weights['hid2_wght'], b=self.biases['hid2_bias'], nlModel='RELU')

        # 3nd Hidden Layer State
        vhid3State = self.hiddenLayer(x=vhid2State, w=self.weights['hid3_wght'], b=self.biases['hid3_bias'], nlModel='RELU')
        
        # 4th Hidden Layer State
        # vhid4State = self.hiddenLayer(x=vhid3State, w=self.weights['hid4_wght'], b=self.biases['hid4_bias'], nlModel='RELU')

        # Output Layer State
        _, validOutState = self.outputLayer(x=vhid3State, w=self.weights['out_wght'], b=self.biases['out_bias'])

        return dict(
            validData = validData,
            validLabels = validLabels,
            validPred = validOutState
        )

# %%
class SessionExec():
    
    def __init__(self, featureDIR, params):
        self.featureDIR = featureDIR
        
        self.numFolds = params['numFolds']
        self.epochs = params['epochs']
        self.batchSize = params['batchSize']
        self.imageSize = params['imageSize']
        
        self.prevWghtDict = {}
        self.wghtChngDict = defaultdict(list)
        self.meanValidAcc = 0
        self.loss_PerEpoch_PerFold = defaultdict(list)
        self.trainacc_PerEpoch_PerFold = defaultdict(list)
        self.validacc_PerEpoch_PerFold = defaultdict(list)
        
        
        
    def captureWghtChange(self, wghtDict):   
        for layer, wght_arr in wghtDict.items():
#             print (layer)
#             print (np.sum(np.abs(wght_arr-self.prevWghtDict[layer])))
#             print ('********************')
            self.wghtChngDict[layer].append(np.sum(np.abs(wght_arr-self.prevWghtDict[layer])))
    
    
    
    def trainModel(self, trainDataIN, trainLabelsIN, sess):    
        numBatches = int(trainDataIN.shape[0]/self.batchSize)
        for numBatch in np.arange(numBatches):
#                     print ('Batch no: ', numBatch)
#                     print (numBatch*self.batchSize,  (numBatch+1)*self.batchSize)
            batchData = trainDataIN[numBatch*self.batchSize : (numBatch+1)*self.batchSize]
            batchLabels = trainLabelsIN[numBatch*self.batchSize : (numBatch+1)*self.batchSize]

            feed_dict = {self.trainGraphDict['trainData']: batchData,
                         self.trainGraphDict['trainLabels']: batchLabels
#                              self.trainGraphDict['keep_prob']: 0.7
                    }

            _, loss, tpred, wght = sess.run([self.trainGraphDict['optimizer'],
                                        self.trainGraphDict['lossCE'],
                                        self.trainGraphDict['trainPred'],
                                        self.trainGraphDict['wghtNew']], feed_dict=feed_dict)
            
            if any(self.prevWghtDict):
                self.captureWghtChange(wght)
                self.prevWghtDict = wght
            else:
                self.prevWghtDict = wght
                
                
            if ((numBatch+1)%20 == 0) or ((numBatch+1) == numBatches): 
                tacc = accuracy(tpred, batchLabels)
                print ("Fold: " + str(self.foldNUM+1) + 
                       ", Epoch: " + str(self.epoch+1)+ 
                       ", Mini Batch: " + str(numBatch+1) + 
                       ", Loss= " + "{:.6f}".format(loss) + 
                       ", Training Accuracy= " + "{:.5f}".format(tacc))
    
        return loss, tacc
    
    
    def validModel(self, validDataIN, validLabelsIN, sess):
        feed_dict = {self.validGraphDict['validData']: validDataIN,
                     self.validGraphDict['validLabels']: validLabelsIN
#                              self.trainGraphDict['keep_prob']: 0.7
                }

        vpred = sess.run(self.validGraphDict['validPred'], feed_dict=feed_dict)
        
        vacc = accuracy(vpred, validLabelsIN)
        print ("Fold: " + str(self.foldNUM+1) + 
                ", Epoch: " + str(self.epoch+1)+ 
                ", Validation Accuracy= " + "{:.5f}".format(vacc))
        
        return vpred, vacc 
        
        
    def execute(self):
        meanValidAcc = 0
        
        for foldNUM, (trainDataIN, trainLabelsIN, validDataIN, validLabelsIN, labelDict) in enumerate(genTrainValidFolds(featureDIR, oneHot=True)):   
            print ('')
            print ('##########################################################################################')

            print ('')
            print ('Validation Data and Labels shape: ', validDataIN.shape, validLabelsIN.shape)
            print ('Training Data and Labels shape: ', trainDataIN.shape, trainLabelsIN.shape)
            print ('The Label Dictionary is given as: ', labelDict)
            print ('')
            
            self.foldNUM = foldNUM

            reset_graph()

            # Create a object encapsulating the graph lineage
            objNN = BuildNeuralNet(params, trainDataIN.shape[1])
            self.trainGraphDict = objNN.trainGraph()
            self.validGraphDict = objNN.validGraph()
            
            with tf.Session() as sess:
                sess.run(tf.initialize_all_variables())

                for epoch in range(self.epochs): 
                    self.epoch = epoch
                    
                    # Train The model for Epochs
                    loss, tacc = self.trainModel(trainDataIN, trainLabelsIN, sess)
                    print ('')
                    
                    # Validate the model for Epochs
                    vpred, vacc = self.validModel(validDataIN, validLabelsIN, sess)
                    print ('')
                    
                    self.loss_PerEpoch_PerFold[foldNUM+1].append(loss)
                    self.trainacc_PerEpoch_PerFold[foldNUM+1].append(tacc)
                    self.validacc_PerEpoch_PerFold[foldNUM+1].append(vacc)
                    
                    if (epoch+1)%10 ==0 or ((epoch+1) == self.epochs):
                        validCM = confusionMatrix(validLabelsIN,vpred)
                        print ('Confusion Matrix CrossValid Set')
                        print (validCM)
                        print ('')
            
            self.meanValidAcc += vacc
            
            if foldNUM == self.numFolds-1:
                break
                
        return (self.wghtChngDict, 
                self.meanValidAcc/self.numFolds, 
                self.loss_PerEpoch_PerFold, 
                self.trainacc_PerEpoch_PerFold, 
                self.validacc_PerEpoch_PerFold)

# %% [markdown]
# # MODEL 1: HOG multi-filter with ADAM Optimizer

# %%
ZCAbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/ZCA/batchData/"
STDbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/STD/batchData/"
EDGbatch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/EDG/batchData/"
HOGp1batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp1/batchData/"   # dim =162
HOGp2batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp2/batchData/"   # dim =576
HOGp3batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp3/batchData/"
HOGp4batch_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/HOGp4/batchData/"

ZCAbatchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/augmented/ZCA/batchData/"
STDbatchAug_dir= "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/augmented/STD/batchData/"
EDGbatchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/augmented/EDG/batchData/"
HOGp1batchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/augmented/HOGp1/batchData/"
HOGp2batchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/augmented/HOGp2/batchData/"
HOGp3batchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/augmented/HOGp3/batchData/"
HOGp4batchAug_dir = "/Users/sam/All-Program/App-DataSet/Kaggle-Challenges/CIFAR-10/Model-Sardhendu/augmented/HOGp4/batchData/"

# %% [markdown]
# ## 4-kernels : HOG - Adam Optimizer / Non-Augmented / Hidden Units : 1024x1280x1280
# -------

# %%
featureDIR = HOGp4batch_dir
params = dict(imageSize = 32,
              numLabels = 2,
              
              # Network params
              numHidden1 = 1024,
              numHidden2 = 1280,
              numHidden3 = 1280, 

              # Batch Variables
              numFolds = 10,
              epochs = 30,
              batchSize = 1000,
             
              # Optimization Params
              keepProb = dict(hid1=0.75, hid2=0.5, hid3=0.5),
              optimizerParam = dict(optimizer='ADAM', learning_rate=0.006)
             )

# optimizer = tf.train.AdamOptimizer(learning_rate=0.008).minimize(lossCE)

(out, meanValidAcc, lossPerEpochPerFold, taccPerEpochPerFold, vaccPerEpochPerFold) = SessionExec(featureDIR, params).execute() 

print ('The mean Valid Accuracy is : ', meanValidAcc)
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 1, Epoch: 1, Mini Batch: 9, Loss= 21865.863281, Training Accuracy= 74.60000
#
# Fold: 1, Epoch: 1, Validation Accuracy= 79.50000
#
# Fold: 1, Epoch: 2, Mini Batch: 9, Loss= 14991.425781, Training Accuracy= 77.60000
#
# Fold: 1, Epoch: 2, Validation Accuracy= 78.70000
#
# Fold: 1, Epoch: 3, Mini Batch: 9, Loss= 9870.385742, Training Accuracy= 80.40000
#
# Fold: 1, Epoch: 3, Validation Accuracy= 84.30000
#
# Fold: 1, Epoch: 4, Mini Batch: 9, Loss= 8673.492188, Training Accuracy= 80.10000
#
# Fold: 1, Epoch: 4, Validation Accuracy= 87.30000
#
# Fold: 1, Epoch: 5, Mini Batch: 9, Loss= 6752.040527, Training Accuracy= 80.60000
#
# Fold: 1, Epoch: 5, Validation Accuracy= 84.80000
#
# Fold: 1, Epoch: 6, Mini Batch: 9, Loss= 6462.100098, Training Accuracy= 79.90000
#
# Fold: 1, Epoch: 6, Validation Accuracy= 86.20000
#
# Fold: 1, Epoch: 7, Mini Batch: 9, Loss= 5109.916992, Training Accuracy= 83.30000
#
# Fold: 1, Epoch: 7, Validation Accuracy= 86.70000
#
# Fold: 1, Epoch: 8, Mini Batch: 9, Loss= 4855.499023, Training Accuracy= 84.20000
#
# Fold: 1, Epoch: 8, Validation Accuracy= 86.60000
#
# Fold: 1, Epoch: 9, Mini Batch: 9, Loss= 3969.071777, Training Accuracy= 83.60000
#
# Fold: 1, Epoch: 9, Validation Accuracy= 87.20000
#
# Fold: 1, Epoch: 10, Mini Batch: 9, Loss= 3974.262451, Training Accuracy= 83.30000
#
# Fold: 1, Epoch: 10, Validation Accuracy= 87.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          423   46   469
# 1           77  454   531
# All        500  500  1000
#
# Fold: 1, Epoch: 11, Mini Batch: 9, Loss= 3971.787598, Training Accuracy= 84.40000
#
# Fold: 1, Epoch: 11, Validation Accuracy= 87.40000
#
# Fold: 1, Epoch: 12, Mini Batch: 9, Loss= 3614.028564, Training Accuracy= 82.50000
#
# Fold: 1, Epoch: 12, Validation Accuracy= 87.60000
#
# Fold: 1, Epoch: 13, Mini Batch: 9, Loss= 3097.270996, Training Accuracy= 85.20000
#
# Fold: 1, Epoch: 13, Validation Accuracy= 88.10000
#
# Fold: 1, Epoch: 14, Mini Batch: 9, Loss= 2817.977295, Training Accuracy= 85.50000
#
# Fold: 1, Epoch: 14, Validation Accuracy= 87.60000
#
# Fold: 1, Epoch: 15, Mini Batch: 9, Loss= 3054.854248, Training Accuracy= 85.20000
#
# Fold: 1, Epoch: 15, Validation Accuracy= 87.70000
#
# Fold: 1, Epoch: 16, Mini Batch: 9, Loss= 2547.167480, Training Accuracy= 84.10000
#
# Fold: 1, Epoch: 16, Validation Accuracy= 87.40000
#
# Fold: 1, Epoch: 17, Mini Batch: 9, Loss= 2397.705566, Training Accuracy= 84.50000
#
# Fold: 1, Epoch: 17, Validation Accuracy= 87.80000
#
# Fold: 1, Epoch: 18, Mini Batch: 9, Loss= 2283.179443, Training Accuracy= 84.50000
#
# Fold: 1, Epoch: 18, Validation Accuracy= 87.80000
#
# Fold: 1, Epoch: 19, Mini Batch: 9, Loss= 2236.467773, Training Accuracy= 84.80000
#
# Fold: 1, Epoch: 19, Validation Accuracy= 88.30000
#
# Fold: 1, Epoch: 20, Mini Batch: 9, Loss= 1996.328003, Training Accuracy= 86.10000
#
# Fold: 1, Epoch: 20, Validation Accuracy= 88.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          431   50   481
# 1           69  450   519
# All        500  500  1000
#
# Fold: 1, Epoch: 21, Mini Batch: 9, Loss= 1632.854248, Training Accuracy= 86.60000
#
# Fold: 1, Epoch: 21, Validation Accuracy= 88.10000
#
# Fold: 1, Epoch: 22, Mini Batch: 9, Loss= 1984.076172, Training Accuracy= 86.40000
#
# Fold: 1, Epoch: 22, Validation Accuracy= 88.10000
#
# Fold: 1, Epoch: 23, Mini Batch: 9, Loss= 1689.824463, Training Accuracy= 86.50000
#
# Fold: 1, Epoch: 23, Validation Accuracy= 88.10000
#
# Fold: 1, Epoch: 24, Mini Batch: 9, Loss= 1437.922729, Training Accuracy= 87.40000
#
# Fold: 1, Epoch: 24, Validation Accuracy= 88.20000
#
# Fold: 1, Epoch: 25, Mini Batch: 9, Loss= 1434.802979, Training Accuracy= 88.80000
#
# Fold: 1, Epoch: 25, Validation Accuracy= 88.60000
#
# Fold: 1, Epoch: 26, Mini Batch: 9, Loss= 1473.005005, Training Accuracy= 87.90000
#
# Fold: 1, Epoch: 26, Validation Accuracy= 88.70000
#
# Fold: 1, Epoch: 27, Mini Batch: 9, Loss= 1225.589478, Training Accuracy= 87.80000
#
# Fold: 1, Epoch: 27, Validation Accuracy= 88.70000
#
# Fold: 1, Epoch: 28, Mini Batch: 9, Loss= 1031.471313, Training Accuracy= 88.00000
#
# Fold: 1, Epoch: 28, Validation Accuracy= 88.00000
#
# Fold: 1, Epoch: 29, Mini Batch: 9, Loss= 1206.001465, Training Accuracy= 87.30000
#
# Fold: 1, Epoch: 29, Validation Accuracy= 88.20000
#
# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 1152.337280, Training Accuracy= 88.10000
#
# Fold: 1, Epoch: 30, Validation Accuracy= 88.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          430   50   480
# 1           70  450   520
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 2, Epoch: 1, Mini Batch: 9, Loss= 21559.759766, Training Accuracy= 73.50000
#
# Fold: 2, Epoch: 1, Validation Accuracy= 83.90000
#
# Fold: 2, Epoch: 2, Mini Batch: 9, Loss= 14060.625000, Training Accuracy= 81.90000
#
# Fold: 2, Epoch: 2, Validation Accuracy= 86.10000
#
# Fold: 2, Epoch: 3, Mini Batch: 9, Loss= 9773.316406, Training Accuracy= 80.70000
#
# Fold: 2, Epoch: 3, Validation Accuracy= 85.40000
#
# Fold: 2, Epoch: 4, Mini Batch: 9, Loss= 8862.575195, Training Accuracy= 80.00000
#
# Fold: 2, Epoch: 4, Validation Accuracy= 85.00000
#
# Fold: 2, Epoch: 5, Mini Batch: 9, Loss= 7656.913086, Training Accuracy= 80.60000
#
# Fold: 2, Epoch: 5, Validation Accuracy= 86.20000
#
# Fold: 2, Epoch: 6, Mini Batch: 9, Loss= 6049.726562, Training Accuracy= 82.80000
#
# Fold: 2, Epoch: 6, Validation Accuracy= 86.30000
#
# Fold: 2, Epoch: 7, Mini Batch: 9, Loss= 4757.723633, Training Accuracy= 84.20000
#
# Fold: 2, Epoch: 7, Validation Accuracy= 86.50000
#
# Fold: 2, Epoch: 8, Mini Batch: 9, Loss= 4931.134766, Training Accuracy= 83.20000
#
# Fold: 2, Epoch: 8, Validation Accuracy= 86.80000
#
# Fold: 2, Epoch: 9, Mini Batch: 9, Loss= 4137.223145, Training Accuracy= 82.90000
#
# Fold: 2, Epoch: 9, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 10, Mini Batch: 9, Loss= 4163.380859, Training Accuracy= 84.70000
#
# Fold: 2, Epoch: 10, Validation Accuracy= 87.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   46   464
# 1           82  454   536
# All        500  500  1000
#
# Fold: 2, Epoch: 11, Mini Batch: 9, Loss= 3835.242188, Training Accuracy= 83.30000
#
# Fold: 2, Epoch: 11, Validation Accuracy= 86.80000
#
# Fold: 2, Epoch: 12, Mini Batch: 9, Loss= 3327.000488, Training Accuracy= 85.00000
#
# Fold: 2, Epoch: 12, Validation Accuracy= 86.70000
#
# Fold: 2, Epoch: 13, Mini Batch: 9, Loss= 2989.804932, Training Accuracy= 84.20000
#
# Fold: 2, Epoch: 13, Validation Accuracy= 86.50000
#
# Fold: 2, Epoch: 14, Mini Batch: 9, Loss= 2534.879395, Training Accuracy= 84.00000
#
# Fold: 2, Epoch: 14, Validation Accuracy= 87.70000
#
# Fold: 2, Epoch: 15, Mini Batch: 9, Loss= 2705.941895, Training Accuracy= 83.50000
#
# Fold: 2, Epoch: 15, Validation Accuracy= 87.40000
#
# Fold: 2, Epoch: 16, Mini Batch: 9, Loss= 2608.958984, Training Accuracy= 84.40000
#
# Fold: 2, Epoch: 16, Validation Accuracy= 87.50000
#
# Fold: 2, Epoch: 17, Mini Batch: 9, Loss= 2165.439697, Training Accuracy= 86.80000
#
# Fold: 2, Epoch: 17, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 18, Mini Batch: 9, Loss= 1986.230591, Training Accuracy= 86.20000
#
# Fold: 2, Epoch: 18, Validation Accuracy= 86.80000
#
# Fold: 2, Epoch: 19, Mini Batch: 9, Loss= 1649.471802, Training Accuracy= 86.20000
#
# Fold: 2, Epoch: 19, Validation Accuracy= 86.60000
#
# Fold: 2, Epoch: 20, Mini Batch: 9, Loss= 1671.942993, Training Accuracy= 87.30000
#
# Fold: 2, Epoch: 20, Validation Accuracy= 86.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   54   472
# 1           82  446   528
# All        500  500  1000
#
# Fold: 2, Epoch: 21, Mini Batch: 9, Loss= 1285.989868, Training Accuracy= 88.90000
#
# Fold: 2, Epoch: 21, Validation Accuracy= 86.80000
#
# Fold: 2, Epoch: 22, Mini Batch: 9, Loss= 1410.900757, Training Accuracy= 85.50000
#
# Fold: 2, Epoch: 22, Validation Accuracy= 86.70000
#
# Fold: 2, Epoch: 23, Mini Batch: 9, Loss= 1421.334595, Training Accuracy= 86.50000
#
# Fold: 2, Epoch: 23, Validation Accuracy= 86.60000
#
# Fold: 2, Epoch: 24, Mini Batch: 9, Loss= 1188.862061, Training Accuracy= 87.90000
#
# Fold: 2, Epoch: 24, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 25, Mini Batch: 9, Loss= 1255.785156, Training Accuracy= 87.20000
#
# Fold: 2, Epoch: 25, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 26, Mini Batch: 9, Loss= 986.653137, Training Accuracy= 88.90000
#
# Fold: 2, Epoch: 26, Validation Accuracy= 87.00000
#
# Fold: 2, Epoch: 27, Mini Batch: 9, Loss= 1130.881592, Training Accuracy= 88.30000
#
# Fold: 2, Epoch: 27, Validation Accuracy= 87.00000
#
# Fold: 2, Epoch: 28, Mini Batch: 9, Loss= 1039.950928, Training Accuracy= 90.00000
#
# Fold: 2, Epoch: 28, Validation Accuracy= 86.50000
#
# Fold: 2, Epoch: 29, Mini Batch: 9, Loss= 882.361023, Training Accuracy= 89.80000
#
# Fold: 2, Epoch: 29, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 30, Mini Batch: 9, Loss= 898.601990, Training Accuracy= 90.50000
#
# Fold: 2, Epoch: 30, Validation Accuracy= 87.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          422   50   472
# 1           78  450   528
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 3, Epoch: 1, Mini Batch: 9, Loss= 23392.214844, Training Accuracy= 75.40000
#
# Fold: 3, Epoch: 1, Validation Accuracy= 80.30000
#
# Fold: 3, Epoch: 2, Mini Batch: 9, Loss= 15753.776367, Training Accuracy= 78.20000
#
# Fold: 3, Epoch: 2, Validation Accuracy= 80.30000
#
# Fold: 3, Epoch: 3, Mini Batch: 9, Loss= 9785.423828, Training Accuracy= 79.20000
#
# Fold: 3, Epoch: 3, Validation Accuracy= 81.00000
#
# Fold: 3, Epoch: 4, Mini Batch: 9, Loss= 7717.551758, Training Accuracy= 82.00000
#
# Fold: 3, Epoch: 4, Validation Accuracy= 84.60000
#
# Fold: 3, Epoch: 5, Mini Batch: 9, Loss= 7187.485352, Training Accuracy= 80.10000
#
# Fold: 3, Epoch: 5, Validation Accuracy= 84.50000
#
# Fold: 3, Epoch: 6, Mini Batch: 9, Loss= 6186.743652, Training Accuracy= 82.80000
#
# Fold: 3, Epoch: 6, Validation Accuracy= 83.60000
#
# Fold: 3, Epoch: 7, Mini Batch: 9, Loss= 5511.213867, Training Accuracy= 83.60000
#
# Fold: 3, Epoch: 7, Validation Accuracy= 82.80000
#
# Fold: 3, Epoch: 8, Mini Batch: 9, Loss= 4345.390625, Training Accuracy= 84.80000
#
# Fold: 3, Epoch: 8, Validation Accuracy= 84.60000
#
# Fold: 3, Epoch: 9, Mini Batch: 9, Loss= 3894.219971, Training Accuracy= 83.90000
#
# Fold: 3, Epoch: 9, Validation Accuracy= 83.50000
#
# Fold: 3, Epoch: 10, Mini Batch: 9, Loss= 3772.674072, Training Accuracy= 83.20000
#
# Fold: 3, Epoch: 10, Validation Accuracy= 84.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          395   49   444
# 1          105  451   556
# All        500  500  1000
#
# Fold: 3, Epoch: 11, Mini Batch: 9, Loss= 3812.549561, Training Accuracy= 84.10000
#
# Fold: 3, Epoch: 11, Validation Accuracy= 84.70000
#
# Fold: 3, Epoch: 12, Mini Batch: 9, Loss= 2964.328369, Training Accuracy= 84.60000
#
# Fold: 3, Epoch: 12, Validation Accuracy= 84.40000
#
# Fold: 3, Epoch: 13, Mini Batch: 9, Loss= 2852.717285, Training Accuracy= 84.70000
#
# Fold: 3, Epoch: 13, Validation Accuracy= 84.90000
#
# Fold: 3, Epoch: 14, Mini Batch: 9, Loss= 3094.987549, Training Accuracy= 84.10000
#
# Fold: 3, Epoch: 14, Validation Accuracy= 84.70000
#
# Fold: 3, Epoch: 15, Mini Batch: 9, Loss= 2722.277100, Training Accuracy= 85.10000
#
# Fold: 3, Epoch: 15, Validation Accuracy= 84.80000
#
# Fold: 3, Epoch: 16, Mini Batch: 9, Loss= 2388.086914, Training Accuracy= 85.00000
#
# Fold: 3, Epoch: 16, Validation Accuracy= 84.50000
#
# Fold: 3, Epoch: 17, Mini Batch: 9, Loss= 2223.360352, Training Accuracy= 86.00000
#
# Fold: 3, Epoch: 17, Validation Accuracy= 84.10000
#
# Fold: 3, Epoch: 18, Mini Batch: 9, Loss= 2182.738525, Training Accuracy= 85.30000
#
# Fold: 3, Epoch: 18, Validation Accuracy= 84.30000
#
# Fold: 3, Epoch: 19, Mini Batch: 9, Loss= 1988.079346, Training Accuracy= 86.70000
#
# Fold: 3, Epoch: 19, Validation Accuracy= 84.80000
#
# Fold: 3, Epoch: 20, Mini Batch: 9, Loss= 1995.228027, Training Accuracy= 84.40000
#
# Fold: 3, Epoch: 20, Validation Accuracy= 85.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          411   60   471
# 1           89  440   529
# All        500  500  1000
#
# Fold: 3, Epoch: 21, Mini Batch: 9, Loss= 1817.350708, Training Accuracy= 86.60000
#
# Fold: 3, Epoch: 21, Validation Accuracy= 85.70000
#
# Fold: 3, Epoch: 22, Mini Batch: 9, Loss= 1637.712769, Training Accuracy= 86.50000
#
# Fold: 3, Epoch: 22, Validation Accuracy= 85.10000
#
# Fold: 3, Epoch: 23, Mini Batch: 9, Loss= 1647.959717, Training Accuracy= 86.30000
#
# Fold: 3, Epoch: 23, Validation Accuracy= 84.70000
#
# Fold: 3, Epoch: 24, Mini Batch: 9, Loss= 1432.897217, Training Accuracy= 88.10000
#
# Fold: 3, Epoch: 24, Validation Accuracy= 84.70000
#
# Fold: 3, Epoch: 25, Mini Batch: 9, Loss= 1234.144043, Training Accuracy= 87.50000
#
# Fold: 3, Epoch: 25, Validation Accuracy= 84.80000
#
# Fold: 3, Epoch: 26, Mini Batch: 9, Loss= 1338.553467, Training Accuracy= 87.90000
#
# Fold: 3, Epoch: 26, Validation Accuracy= 85.00000
#
# Fold: 3, Epoch: 27, Mini Batch: 9, Loss= 1282.703979, Training Accuracy= 88.40000
#
# Fold: 3, Epoch: 27, Validation Accuracy= 84.60000
#
# Fold: 3, Epoch: 28, Mini Batch: 9, Loss= 1084.134277, Training Accuracy= 89.50000
#
# Fold: 3, Epoch: 28, Validation Accuracy= 84.90000
#
# Fold: 3, Epoch: 29, Mini Batch: 9, Loss= 1160.784790, Training Accuracy= 86.20000
#
# Fold: 3, Epoch: 29, Validation Accuracy= 84.90000
#
# Fold: 3, Epoch: 30, Mini Batch: 9, Loss= 933.461121, Training Accuracy= 89.40000
#
# Fold: 3, Epoch: 30, Validation Accuracy= 84.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          413   66   479
# 1           87  434   521
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 4, Epoch: 1, Mini Batch: 9, Loss= 22911.523438, Training Accuracy= 75.80000
#
# Fold: 4, Epoch: 1, Validation Accuracy= 81.90000
#
# Fold: 4, Epoch: 2, Mini Batch: 9, Loss= 15060.706055, Training Accuracy= 78.80000
#
# Fold: 4, Epoch: 2, Validation Accuracy= 80.30000
#
# Fold: 4, Epoch: 3, Mini Batch: 9, Loss= 9244.314453, Training Accuracy= 79.80000
#
# Fold: 4, Epoch: 3, Validation Accuracy= 84.30000
#
# Fold: 4, Epoch: 4, Mini Batch: 9, Loss= 9276.864258, Training Accuracy= 79.30000
#
# Fold: 4, Epoch: 4, Validation Accuracy= 85.70000
#
# Fold: 4, Epoch: 5, Mini Batch: 9, Loss= 7448.692383, Training Accuracy= 80.40000
#
# Fold: 4, Epoch: 5, Validation Accuracy= 84.90000
#
# Fold: 4, Epoch: 6, Mini Batch: 9, Loss= 6164.053711, Training Accuracy= 82.80000
#
# Fold: 4, Epoch: 6, Validation Accuracy= 85.00000
#
# Fold: 4, Epoch: 7, Mini Batch: 9, Loss= 6657.048828, Training Accuracy= 79.80000
#
# Fold: 4, Epoch: 7, Validation Accuracy= 85.60000
#
# Fold: 4, Epoch: 8, Mini Batch: 9, Loss= 4472.392090, Training Accuracy= 83.20000
#
# Fold: 4, Epoch: 8, Validation Accuracy= 85.30000
#
# Fold: 4, Epoch: 9, Mini Batch: 9, Loss= 3993.408936, Training Accuracy= 83.70000
#
# Fold: 4, Epoch: 9, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 10, Mini Batch: 9, Loss= 4135.391602, Training Accuracy= 82.50000
#
# Fold: 4, Epoch: 10, Validation Accuracy= 85.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          416   58   474
# 1           84  442   526
# All        500  500  1000
#
# Fold: 4, Epoch: 11, Mini Batch: 9, Loss= 4267.650879, Training Accuracy= 82.90000
#
# Fold: 4, Epoch: 11, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 12, Mini Batch: 9, Loss= 3169.306641, Training Accuracy= 84.50000
#
# Fold: 4, Epoch: 12, Validation Accuracy= 86.20000
#
# Fold: 4, Epoch: 13, Mini Batch: 9, Loss= 3004.253906, Training Accuracy= 85.30000
#
# Fold: 4, Epoch: 13, Validation Accuracy= 86.90000
#
# Fold: 4, Epoch: 14, Mini Batch: 9, Loss= 3068.092529, Training Accuracy= 83.00000
#
# Fold: 4, Epoch: 14, Validation Accuracy= 86.50000
#
# Fold: 4, Epoch: 15, Mini Batch: 9, Loss= 2601.451904, Training Accuracy= 83.40000
#
# Fold: 4, Epoch: 15, Validation Accuracy= 86.20000
#
# Fold: 4, Epoch: 16, Mini Batch: 9, Loss= 2356.805420, Training Accuracy= 85.70000
#
# Fold: 4, Epoch: 16, Validation Accuracy= 86.70000
#
# Fold: 4, Epoch: 17, Mini Batch: 9, Loss= 2274.378906, Training Accuracy= 85.90000
#
# Fold: 4, Epoch: 17, Validation Accuracy= 86.30000
#
# Fold: 4, Epoch: 18, Mini Batch: 9, Loss= 1827.544556, Training Accuracy= 87.70000
#
# Fold: 4, Epoch: 18, Validation Accuracy= 86.30000
#
# Fold: 4, Epoch: 19, Mini Batch: 9, Loss= 2149.754150, Training Accuracy= 85.10000
#
# Fold: 4, Epoch: 19, Validation Accuracy= 87.00000
#
# Fold: 4, Epoch: 20, Mini Batch: 9, Loss= 1779.972900, Training Accuracy= 87.10000
#
# Fold: 4, Epoch: 20, Validation Accuracy= 86.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          414   48   462
# 1           86  452   538
# All        500  500  1000
#
# Fold: 4, Epoch: 21, Mini Batch: 9, Loss= 1838.345337, Training Accuracy= 86.10000
#
# Fold: 4, Epoch: 21, Validation Accuracy= 86.80000
#
# Fold: 4, Epoch: 22, Mini Batch: 9, Loss= 1667.450684, Training Accuracy= 86.80000
#
# Fold: 4, Epoch: 22, Validation Accuracy= 86.30000
#
# Fold: 4, Epoch: 23, Mini Batch: 9, Loss= 1604.516357, Training Accuracy= 87.40000
#
# Fold: 4, Epoch: 23, Validation Accuracy= 86.80000
#
# Fold: 4, Epoch: 24, Mini Batch: 9, Loss= 1444.825439, Training Accuracy= 86.50000
#
# Fold: 4, Epoch: 24, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 25, Mini Batch: 9, Loss= 1254.433960, Training Accuracy= 88.20000
#
# Fold: 4, Epoch: 25, Validation Accuracy= 86.00000
#
# Fold: 4, Epoch: 26, Mini Batch: 9, Loss= 1292.392944, Training Accuracy= 88.20000
#
# Fold: 4, Epoch: 26, Validation Accuracy= 86.20000
#
# Fold: 4, Epoch: 27, Mini Batch: 9, Loss= 976.850769, Training Accuracy= 90.20000
#
# Fold: 4, Epoch: 27, Validation Accuracy= 85.10000
#
# Fold: 4, Epoch: 28, Mini Batch: 9, Loss= 1244.203735, Training Accuracy= 86.70000
#
# Fold: 4, Epoch: 28, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 29, Mini Batch: 9, Loss= 1174.780640, Training Accuracy= 87.20000
#
# Fold: 4, Epoch: 29, Validation Accuracy= 85.60000
#
# Fold: 4, Epoch: 30, Mini Batch: 9, Loss= 1117.985474, Training Accuracy= 88.80000
#
# Fold: 4, Epoch: 30, Validation Accuracy= 85.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          429   70   499
# 1           71  430   501
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 5, Epoch: 1, Mini Batch: 9, Loss= 20434.363281, Training Accuracy= 75.40000
#
# Fold: 5, Epoch: 1, Validation Accuracy= 82.50000
#
# Fold: 5, Epoch: 2, Mini Batch: 9, Loss= 16229.743164, Training Accuracy= 77.50000
#
# Fold: 5, Epoch: 2, Validation Accuracy= 82.30000
#
# Fold: 5, Epoch: 3, Mini Batch: 9, Loss= 10856.727539, Training Accuracy= 80.00000
#
# Fold: 5, Epoch: 3, Validation Accuracy= 82.90000
#
# Fold: 5, Epoch: 4, Mini Batch: 9, Loss= 7818.059082, Training Accuracy= 81.30000
#
# Fold: 5, Epoch: 4, Validation Accuracy= 85.00000
#
# Fold: 5, Epoch: 5, Mini Batch: 9, Loss= 6458.219238, Training Accuracy= 82.40000
#
# Fold: 5, Epoch: 5, Validation Accuracy= 85.70000
#
# Fold: 5, Epoch: 6, Mini Batch: 9, Loss= 5701.739258, Training Accuracy= 82.50000
#
# Fold: 5, Epoch: 6, Validation Accuracy= 85.30000
#
# Fold: 5, Epoch: 7, Mini Batch: 9, Loss= 6150.483887, Training Accuracy= 81.00000
#
# Fold: 5, Epoch: 7, Validation Accuracy= 84.70000
#
# Fold: 5, Epoch: 8, Mini Batch: 9, Loss= 5352.033691, Training Accuracy= 81.70000
#
# Fold: 5, Epoch: 8, Validation Accuracy= 84.50000
#
# Fold: 5, Epoch: 9, Mini Batch: 9, Loss= 4345.005371, Training Accuracy= 83.10000
#
# Fold: 5, Epoch: 9, Validation Accuracy= 84.90000
#
# Fold: 5, Epoch: 10, Mini Batch: 9, Loss= 4263.572266, Training Accuracy= 83.10000
#
# Fold: 5, Epoch: 10, Validation Accuracy= 85.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          402   46   448
# 1           98  454   552
# All        500  500  1000
#
# Fold: 5, Epoch: 11, Mini Batch: 9, Loss= 3842.273193, Training Accuracy= 82.70000
#
# Fold: 5, Epoch: 11, Validation Accuracy= 85.40000
#
# Fold: 5, Epoch: 12, Mini Batch: 9, Loss= 3417.810303, Training Accuracy= 84.90000
#
# Fold: 5, Epoch: 12, Validation Accuracy= 85.90000
#
# Fold: 5, Epoch: 13, Mini Batch: 9, Loss= 2912.035889, Training Accuracy= 85.90000
#
# Fold: 5, Epoch: 13, Validation Accuracy= 84.70000
#
# Fold: 5, Epoch: 14, Mini Batch: 9, Loss= 2727.844727, Training Accuracy= 86.10000
#
# Fold: 5, Epoch: 14, Validation Accuracy= 86.40000
#
# Fold: 5, Epoch: 15, Mini Batch: 9, Loss= 2610.433838, Training Accuracy= 86.00000
#
# Fold: 5, Epoch: 15, Validation Accuracy= 86.30000
#
# Fold: 5, Epoch: 16, Mini Batch: 9, Loss= 2228.394531, Training Accuracy= 84.10000
#
# Fold: 5, Epoch: 16, Validation Accuracy= 86.70000
#
# Fold: 5, Epoch: 17, Mini Batch: 9, Loss= 2418.565918, Training Accuracy= 85.50000
#
# Fold: 5, Epoch: 17, Validation Accuracy= 86.20000
#
# Fold: 5, Epoch: 18, Mini Batch: 9, Loss= 2088.510254, Training Accuracy= 85.40000
#
# Fold: 5, Epoch: 18, Validation Accuracy= 86.60000
#
# Fold: 5, Epoch: 19, Mini Batch: 9, Loss= 1917.423950, Training Accuracy= 86.40000
#
# Fold: 5, Epoch: 19, Validation Accuracy= 86.40000
#
# Fold: 5, Epoch: 20, Mini Batch: 9, Loss= 1773.161499, Training Accuracy= 86.80000
#
# Fold: 5, Epoch: 20, Validation Accuracy= 86.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          406   46   452
# 1           94  454   548
# All        500  500  1000
#
# Fold: 5, Epoch: 21, Mini Batch: 9, Loss= 1883.727295, Training Accuracy= 86.70000
#
# Fold: 5, Epoch: 21, Validation Accuracy= 86.50000
#
# Fold: 5, Epoch: 22, Mini Batch: 9, Loss= 1484.405762, Training Accuracy= 87.60000
#
# Fold: 5, Epoch: 22, Validation Accuracy= 86.50000
#
# Fold: 5, Epoch: 23, Mini Batch: 9, Loss= 1245.447510, Training Accuracy= 88.10000
#
# Fold: 5, Epoch: 23, Validation Accuracy= 87.10000
#
# Fold: 5, Epoch: 24, Mini Batch: 9, Loss= 1405.349243, Training Accuracy= 89.00000
#
# Fold: 5, Epoch: 24, Validation Accuracy= 86.60000
#
# Fold: 5, Epoch: 25, Mini Batch: 9, Loss= 1283.097900, Training Accuracy= 87.50000
#
# Fold: 5, Epoch: 25, Validation Accuracy= 87.20000
#
# Fold: 5, Epoch: 26, Mini Batch: 9, Loss= 894.755859, Training Accuracy= 89.20000
#
# Fold: 5, Epoch: 26, Validation Accuracy= 87.10000
#
# Fold: 5, Epoch: 27, Mini Batch: 9, Loss= 957.220764, Training Accuracy= 90.30000
#
# Fold: 5, Epoch: 27, Validation Accuracy= 87.00000
#
# Fold: 5, Epoch: 28, Mini Batch: 9, Loss= 1012.478577, Training Accuracy= 89.70000
#
# Fold: 5, Epoch: 28, Validation Accuracy= 87.10000
#
# Fold: 5, Epoch: 29, Mini Batch: 9, Loss= 1082.444458, Training Accuracy= 88.20000
#
# Fold: 5, Epoch: 29, Validation Accuracy= 86.60000
#
# Fold: 5, Epoch: 30, Mini Batch: 9, Loss= 965.552063, Training Accuracy= 88.20000
#
# Fold: 5, Epoch: 30, Validation Accuracy= 86.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          414   51   465
# 1           86  449   535
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 6, Epoch: 1, Mini Batch: 9, Loss= 21339.058594, Training Accuracy= 76.00000
#
# Fold: 6, Epoch: 1, Validation Accuracy= 84.40000
#
# Fold: 6, Epoch: 2, Mini Batch: 9, Loss= 13411.751953, Training Accuracy= 80.40000
#
# Fold: 6, Epoch: 2, Validation Accuracy= 84.70000
#
# Fold: 6, Epoch: 3, Mini Batch: 9, Loss= 9019.835938, Training Accuracy= 79.60000
#
# Fold: 6, Epoch: 3, Validation Accuracy= 84.30000
#
# Fold: 6, Epoch: 4, Mini Batch: 9, Loss= 8901.593750, Training Accuracy= 79.50000
#
# Fold: 6, Epoch: 4, Validation Accuracy= 86.10000
#
# Fold: 6, Epoch: 5, Mini Batch: 9, Loss= 6238.853027, Training Accuracy= 82.20000
#
# Fold: 6, Epoch: 5, Validation Accuracy= 86.70000
#
# Fold: 6, Epoch: 6, Mini Batch: 9, Loss= 6106.222656, Training Accuracy= 82.90000
#
# Fold: 6, Epoch: 6, Validation Accuracy= 86.60000
#
# Fold: 6, Epoch: 7, Mini Batch: 9, Loss= 4672.426270, Training Accuracy= 83.70000
#
# Fold: 6, Epoch: 7, Validation Accuracy= 86.70000
#
# Fold: 6, Epoch: 8, Mini Batch: 9, Loss= 4701.335449, Training Accuracy= 81.80000
#
# Fold: 6, Epoch: 8, Validation Accuracy= 87.10000
#
# Fold: 6, Epoch: 9, Mini Batch: 9, Loss= 4248.671387, Training Accuracy= 82.50000
#
# Fold: 6, Epoch: 9, Validation Accuracy= 87.20000
#
# Fold: 6, Epoch: 10, Mini Batch: 9, Loss= 3783.425049, Training Accuracy= 85.40000
#
# Fold: 6, Epoch: 10, Validation Accuracy= 86.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          407   39   446
# 1           93  461   554
# All        500  500  1000
#
# Fold: 6, Epoch: 11, Mini Batch: 9, Loss= 3137.409912, Training Accuracy= 84.00000
#
# Fold: 6, Epoch: 11, Validation Accuracy= 87.10000
#
# Fold: 6, Epoch: 12, Mini Batch: 9, Loss= 2893.812012, Training Accuracy= 84.80000
#
# Fold: 6, Epoch: 12, Validation Accuracy= 86.40000
#
# Fold: 6, Epoch: 13, Mini Batch: 9, Loss= 2560.606934, Training Accuracy= 85.20000
#
# Fold: 6, Epoch: 13, Validation Accuracy= 86.60000
#
# Fold: 6, Epoch: 14, Mini Batch: 9, Loss= 2400.339844, Training Accuracy= 84.70000
#
# Fold: 6, Epoch: 14, Validation Accuracy= 86.80000
#
# Fold: 6, Epoch: 15, Mini Batch: 9, Loss= 2643.435059, Training Accuracy= 83.50000
#
# Fold: 6, Epoch: 15, Validation Accuracy= 87.30000
#
# Fold: 6, Epoch: 16, Mini Batch: 9, Loss= 2345.955322, Training Accuracy= 86.40000
#
# Fold: 6, Epoch: 16, Validation Accuracy= 86.80000
#
# Fold: 6, Epoch: 17, Mini Batch: 9, Loss= 2338.539307, Training Accuracy= 85.60000
#
# Fold: 6, Epoch: 17, Validation Accuracy= 86.40000
#
# Fold: 6, Epoch: 18, Mini Batch: 9, Loss= 1621.383057, Training Accuracy= 87.30000
#
# Fold: 6, Epoch: 18, Validation Accuracy= 87.20000
#
# Fold: 6, Epoch: 19, Mini Batch: 9, Loss= 2289.143555, Training Accuracy= 85.40000
#
# Fold: 6, Epoch: 19, Validation Accuracy= 87.00000
#
# Fold: 6, Epoch: 20, Mini Batch: 9, Loss= 1754.641968, Training Accuracy= 86.60000
#
# Fold: 6, Epoch: 20, Validation Accuracy= 86.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          414   45   459
# 1           86  455   541
# All        500  500  1000
#
# Fold: 6, Epoch: 21, Mini Batch: 9, Loss= 1679.359009, Training Accuracy= 86.20000
#
# Fold: 6, Epoch: 21, Validation Accuracy= 87.60000
#
# Fold: 6, Epoch: 22, Mini Batch: 9, Loss= 1712.731934, Training Accuracy= 86.20000
#
# Fold: 6, Epoch: 22, Validation Accuracy= 87.00000
#
# Fold: 6, Epoch: 23, Mini Batch: 9, Loss= 1296.524536, Training Accuracy= 87.10000
#
# Fold: 6, Epoch: 23, Validation Accuracy= 87.40000
#
# Fold: 6, Epoch: 24, Mini Batch: 9, Loss= 1326.782593, Training Accuracy= 87.90000
#
# Fold: 6, Epoch: 24, Validation Accuracy= 87.10000
#
# Fold: 6, Epoch: 25, Mini Batch: 9, Loss= 1261.000244, Training Accuracy= 88.30000
#
# Fold: 6, Epoch: 25, Validation Accuracy= 87.70000
#
# Fold: 6, Epoch: 26, Mini Batch: 9, Loss= 1249.904175, Training Accuracy= 89.00000
#
# Fold: 6, Epoch: 26, Validation Accuracy= 88.20000
#
# Fold: 6, Epoch: 27, Mini Batch: 9, Loss= 891.453064, Training Accuracy= 90.80000
#
# Fold: 6, Epoch: 27, Validation Accuracy= 87.60000
#
# Fold: 6, Epoch: 28, Mini Batch: 9, Loss= 1213.371948, Training Accuracy= 87.90000
#
# Fold: 6, Epoch: 28, Validation Accuracy= 87.60000
#
# Fold: 6, Epoch: 29, Mini Batch: 9, Loss= 740.295837, Training Accuracy= 89.30000
#
# Fold: 6, Epoch: 29, Validation Accuracy= 87.40000
#
# Fold: 6, Epoch: 30, Mini Batch: 9, Loss= 1050.930664, Training Accuracy= 88.00000
#
# Fold: 6, Epoch: 30, Validation Accuracy= 87.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          425   53   478
# 1           75  447   522
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 7, Epoch: 1, Mini Batch: 9, Loss= 22910.847656, Training Accuracy= 72.70000
#
# Fold: 7, Epoch: 1, Validation Accuracy= 81.80000
#
# Fold: 7, Epoch: 2, Mini Batch: 9, Loss= 14175.099609, Training Accuracy= 79.90000
#
# Fold: 7, Epoch: 2, Validation Accuracy= 85.40000
#
# Fold: 7, Epoch: 3, Mini Batch: 9, Loss= 9677.349609, Training Accuracy= 82.50000
#
# Fold: 7, Epoch: 3, Validation Accuracy= 85.50000
#
# Fold: 7, Epoch: 4, Mini Batch: 9, Loss= 8262.081055, Training Accuracy= 81.20000
#
# Fold: 7, Epoch: 4, Validation Accuracy= 85.60000
#
# Fold: 7, Epoch: 5, Mini Batch: 9, Loss= 6488.160645, Training Accuracy= 82.60000
#
# Fold: 7, Epoch: 5, Validation Accuracy= 85.50000
#
# Fold: 7, Epoch: 6, Mini Batch: 9, Loss= 6313.799805, Training Accuracy= 81.20000
#
# Fold: 7, Epoch: 6, Validation Accuracy= 86.20000
#
# Fold: 7, Epoch: 7, Mini Batch: 9, Loss= 5374.242188, Training Accuracy= 82.30000
#
# Fold: 7, Epoch: 7, Validation Accuracy= 86.20000
#
# Fold: 7, Epoch: 8, Mini Batch: 9, Loss= 4305.357910, Training Accuracy= 83.00000
#
# Fold: 7, Epoch: 8, Validation Accuracy= 85.60000
#
# Fold: 7, Epoch: 9, Mini Batch: 9, Loss= 4363.118164, Training Accuracy= 83.00000
#
# Fold: 7, Epoch: 9, Validation Accuracy= 86.00000
#
# Fold: 7, Epoch: 10, Mini Batch: 9, Loss= 3952.952148, Training Accuracy= 82.70000
#
# Fold: 7, Epoch: 10, Validation Accuracy= 86.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          421   59   480
# 1           79  441   520
# All        500  500  1000
#
# Fold: 7, Epoch: 11, Mini Batch: 9, Loss= 3307.346191, Training Accuracy= 84.10000
#
# Fold: 7, Epoch: 11, Validation Accuracy= 85.70000
#
# Fold: 7, Epoch: 12, Mini Batch: 9, Loss= 3448.783203, Training Accuracy= 83.20000
#
# Fold: 7, Epoch: 12, Validation Accuracy= 85.80000
#
# Fold: 7, Epoch: 13, Mini Batch: 9, Loss= 2718.252686, Training Accuracy= 85.40000
#
# Fold: 7, Epoch: 13, Validation Accuracy= 86.10000
#
# Fold: 7, Epoch: 14, Mini Batch: 9, Loss= 2134.879150, Training Accuracy= 85.50000
#
# Fold: 7, Epoch: 14, Validation Accuracy= 86.60000
#
# Fold: 7, Epoch: 15, Mini Batch: 9, Loss= 2046.437622, Training Accuracy= 86.20000
#
# Fold: 7, Epoch: 15, Validation Accuracy= 87.20000
#
# Fold: 7, Epoch: 16, Mini Batch: 9, Loss= 1881.516846, Training Accuracy= 88.20000
#
# Fold: 7, Epoch: 16, Validation Accuracy= 86.50000
#
# Fold: 7, Epoch: 17, Mini Batch: 9, Loss= 2103.395996, Training Accuracy= 86.10000
#
# Fold: 7, Epoch: 17, Validation Accuracy= 86.90000
#
# Fold: 7, Epoch: 18, Mini Batch: 9, Loss= 1694.872925, Training Accuracy= 86.40000
#
# Fold: 7, Epoch: 18, Validation Accuracy= 86.70000
#
# Fold: 7, Epoch: 19, Mini Batch: 9, Loss= 1776.639526, Training Accuracy= 86.50000
#
# Fold: 7, Epoch: 19, Validation Accuracy= 86.50000
#
# Fold: 7, Epoch: 20, Mini Batch: 9, Loss= 1691.078735, Training Accuracy= 86.70000
#
# Fold: 7, Epoch: 20, Validation Accuracy= 86.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   50   468
# 1           82  450   532
# All        500  500  1000
#
# Fold: 7, Epoch: 21, Mini Batch: 9, Loss= 1568.514282, Training Accuracy= 87.30000
#
# Fold: 7, Epoch: 21, Validation Accuracy= 87.60000
#
# Fold: 7, Epoch: 22, Mini Batch: 9, Loss= 1333.840942, Training Accuracy= 88.90000
#
# Fold: 7, Epoch: 22, Validation Accuracy= 86.90000
#
# Fold: 7, Epoch: 23, Mini Batch: 9, Loss= 1400.684692, Training Accuracy= 87.10000
#
# Fold: 7, Epoch: 23, Validation Accuracy= 87.30000
#
# Fold: 7, Epoch: 24, Mini Batch: 9, Loss= 1091.937012, Training Accuracy= 89.10000
#
# Fold: 7, Epoch: 24, Validation Accuracy= 87.50000
#
# Fold: 7, Epoch: 25, Mini Batch: 9, Loss= 984.516235, Training Accuracy= 88.90000
#
# Fold: 7, Epoch: 25, Validation Accuracy= 87.20000
#
# Fold: 7, Epoch: 26, Mini Batch: 9, Loss= 1109.260132, Training Accuracy= 87.40000
#
# Fold: 7, Epoch: 26, Validation Accuracy= 87.40000
#
# Fold: 7, Epoch: 27, Mini Batch: 9, Loss= 1212.150879, Training Accuracy= 88.20000
#
# Fold: 7, Epoch: 27, Validation Accuracy= 86.90000
#
# Fold: 7, Epoch: 28, Mini Batch: 9, Loss= 950.482300, Training Accuracy= 87.80000
#
# Fold: 7, Epoch: 28, Validation Accuracy= 87.10000
#
# Fold: 7, Epoch: 29, Mini Batch: 9, Loss= 832.256226, Training Accuracy= 89.20000
#
# Fold: 7, Epoch: 29, Validation Accuracy= 86.80000
#
# Fold: 7, Epoch: 30, Mini Batch: 9, Loss= 800.463867, Training Accuracy= 90.60000
#
# Fold: 7, Epoch: 30, Validation Accuracy= 87.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          433   59   492
# 1           67  441   508
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 8, Epoch: 1, Mini Batch: 9, Loss= 22174.910156, Training Accuracy= 73.60000
#
# Fold: 8, Epoch: 1, Validation Accuracy= 81.90000
#
# Fold: 8, Epoch: 2, Mini Batch: 9, Loss= 15147.085938, Training Accuracy= 78.20000
#
# Fold: 8, Epoch: 2, Validation Accuracy= 85.00000
#
# Fold: 8, Epoch: 3, Mini Batch: 9, Loss= 10061.929688, Training Accuracy= 79.10000
#
# Fold: 8, Epoch: 3, Validation Accuracy= 85.30000
#
# Fold: 8, Epoch: 4, Mini Batch: 9, Loss= 7822.883789, Training Accuracy= 82.90000
#
# Fold: 8, Epoch: 4, Validation Accuracy= 84.30000
#
# Fold: 8, Epoch: 5, Mini Batch: 9, Loss= 6689.995117, Training Accuracy= 81.50000
#
# Fold: 8, Epoch: 5, Validation Accuracy= 84.90000
#
# Fold: 8, Epoch: 6, Mini Batch: 9, Loss= 5774.992188, Training Accuracy= 82.40000
#
# Fold: 8, Epoch: 6, Validation Accuracy= 85.80000
#
# Fold: 8, Epoch: 7, Mini Batch: 9, Loss= 4477.525879, Training Accuracy= 84.00000
#
# Fold: 8, Epoch: 7, Validation Accuracy= 86.10000
#
# Fold: 8, Epoch: 8, Mini Batch: 9, Loss= 4887.345703, Training Accuracy= 82.20000
#
# Fold: 8, Epoch: 8, Validation Accuracy= 86.40000
#
# Fold: 8, Epoch: 9, Mini Batch: 9, Loss= 3853.185547, Training Accuracy= 83.90000
#
# Fold: 8, Epoch: 9, Validation Accuracy= 85.90000
#
# Fold: 8, Epoch: 10, Mini Batch: 9, Loss= 3557.524414, Training Accuracy= 85.00000
#
# Fold: 8, Epoch: 10, Validation Accuracy= 85.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          414   57   471
# 1           86  443   529
# All        500  500  1000
#
# Fold: 8, Epoch: 11, Mini Batch: 9, Loss= 3204.002930, Training Accuracy= 83.80000
#
# Fold: 8, Epoch: 11, Validation Accuracy= 85.60000
#
# Fold: 8, Epoch: 12, Mini Batch: 9, Loss= 3525.044434, Training Accuracy= 82.70000
#
# Fold: 8, Epoch: 12, Validation Accuracy= 85.60000
#
# Fold: 8, Epoch: 13, Mini Batch: 9, Loss= 2612.579102, Training Accuracy= 85.60000
#
# Fold: 8, Epoch: 13, Validation Accuracy= 85.90000
#
# Fold: 8, Epoch: 14, Mini Batch: 9, Loss= 2739.010010, Training Accuracy= 84.80000
#
# Fold: 8, Epoch: 14, Validation Accuracy= 86.00000
#
# Fold: 8, Epoch: 15, Mini Batch: 9, Loss= 2200.927979, Training Accuracy= 85.60000
#
# Fold: 8, Epoch: 15, Validation Accuracy= 86.20000
#
# Fold: 8, Epoch: 16, Mini Batch: 9, Loss= 2323.320557, Training Accuracy= 85.60000
#
# Fold: 8, Epoch: 16, Validation Accuracy= 86.50000
#
# Fold: 8, Epoch: 17, Mini Batch: 9, Loss= 1932.291870, Training Accuracy= 87.30000
#
# Fold: 8, Epoch: 17, Validation Accuracy= 86.40000
#
# Fold: 8, Epoch: 18, Mini Batch: 9, Loss= 1675.291748, Training Accuracy= 87.70000
#
# Fold: 8, Epoch: 18, Validation Accuracy= 87.00000
#
# Fold: 8, Epoch: 19, Mini Batch: 9, Loss= 1755.480835, Training Accuracy= 86.30000
#
# Fold: 8, Epoch: 19, Validation Accuracy= 86.50000
#
# Fold: 8, Epoch: 20, Mini Batch: 9, Loss= 1711.011108, Training Accuracy= 86.90000
#
# Fold: 8, Epoch: 20, Validation Accuracy= 86.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          430   64   494
# 1           70  436   506
# All        500  500  1000
#
# Fold: 8, Epoch: 21, Mini Batch: 9, Loss= 1763.663940, Training Accuracy= 87.50000
#
# Fold: 8, Epoch: 21, Validation Accuracy= 86.00000
#
# Fold: 8, Epoch: 22, Mini Batch: 9, Loss= 1372.757202, Training Accuracy= 86.60000
#
# Fold: 8, Epoch: 22, Validation Accuracy= 86.10000
#
# Fold: 8, Epoch: 23, Mini Batch: 9, Loss= 1337.766602, Training Accuracy= 88.00000
#
# Fold: 8, Epoch: 23, Validation Accuracy= 86.50000
#
# Fold: 8, Epoch: 24, Mini Batch: 9, Loss= 1675.882446, Training Accuracy= 85.70000
#
# Fold: 8, Epoch: 24, Validation Accuracy= 86.00000
#
# Fold: 8, Epoch: 25, Mini Batch: 9, Loss= 1168.611206, Training Accuracy= 88.60000
#
# Fold: 8, Epoch: 25, Validation Accuracy= 85.50000
#
# Fold: 8, Epoch: 26, Mini Batch: 9, Loss= 1048.608032, Training Accuracy= 89.00000
#
# Fold: 8, Epoch: 26, Validation Accuracy= 86.10000
#
# Fold: 8, Epoch: 27, Mini Batch: 9, Loss= 934.539429, Training Accuracy= 91.50000
#
# Fold: 8, Epoch: 27, Validation Accuracy= 86.50000
#
# Fold: 8, Epoch: 28, Mini Batch: 9, Loss= 1243.292480, Training Accuracy= 88.70000
#
# Fold: 8, Epoch: 28, Validation Accuracy= 86.60000
#
# Fold: 8, Epoch: 29, Mini Batch: 9, Loss= 1035.953613, Training Accuracy= 87.10000
#
# Fold: 8, Epoch: 29, Validation Accuracy= 86.40000
#
# Fold: 8, Epoch: 30, Mini Batch: 9, Loss= 870.266479, Training Accuracy= 91.20000
#
# Fold: 8, Epoch: 30, Validation Accuracy= 86.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          425   64   489
# 1           75  436   511
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 9, Epoch: 1, Mini Batch: 9, Loss= 22522.927734, Training Accuracy= 74.40000
#
# Fold: 9, Epoch: 1, Validation Accuracy= 85.40000
#
# Fold: 9, Epoch: 2, Mini Batch: 9, Loss= 14813.125000, Training Accuracy= 78.60000
#
# Fold: 9, Epoch: 2, Validation Accuracy= 86.20000
#
# Fold: 9, Epoch: 3, Mini Batch: 9, Loss= 9490.990234, Training Accuracy= 79.60000
#
# Fold: 9, Epoch: 3, Validation Accuracy= 86.10000
#
# Fold: 9, Epoch: 4, Mini Batch: 9, Loss= 8315.932617, Training Accuracy= 80.50000
#
# Fold: 9, Epoch: 4, Validation Accuracy= 86.70000
#
# Fold: 9, Epoch: 5, Mini Batch: 9, Loss= 6538.491211, Training Accuracy= 82.20000
#
# Fold: 9, Epoch: 5, Validation Accuracy= 86.70000
#
# Fold: 9, Epoch: 6, Mini Batch: 9, Loss= 5316.153809, Training Accuracy= 81.80000
#
# Fold: 9, Epoch: 6, Validation Accuracy= 87.30000
#
# Fold: 9, Epoch: 7, Mini Batch: 9, Loss= 5128.129395, Training Accuracy= 84.10000
#
# Fold: 9, Epoch: 7, Validation Accuracy= 88.10000
#
# Fold: 9, Epoch: 8, Mini Batch: 9, Loss= 4386.005859, Training Accuracy= 83.90000
#
# Fold: 9, Epoch: 8, Validation Accuracy= 87.40000
#
# Fold: 9, Epoch: 9, Mini Batch: 9, Loss= 3386.597412, Training Accuracy= 84.80000
#
# Fold: 9, Epoch: 9, Validation Accuracy= 87.50000
#
# Fold: 9, Epoch: 10, Mini Batch: 9, Loss= 3716.591064, Training Accuracy= 82.20000
#
# Fold: 9, Epoch: 10, Validation Accuracy= 87.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          419   49   468
# 1           81  451   532
# All        500  500  1000
#
# Fold: 9, Epoch: 11, Mini Batch: 9, Loss= 2722.108398, Training Accuracy= 84.00000
#
# Fold: 9, Epoch: 11, Validation Accuracy= 86.30000
#
# Fold: 9, Epoch: 12, Mini Batch: 9, Loss= 2523.280029, Training Accuracy= 86.20000
#
# Fold: 9, Epoch: 12, Validation Accuracy= 87.00000
#
# Fold: 9, Epoch: 13, Mini Batch: 9, Loss= 2716.578857, Training Accuracy= 85.60000
#
# Fold: 9, Epoch: 13, Validation Accuracy= 87.30000
#
# Fold: 9, Epoch: 14, Mini Batch: 9, Loss= 2797.232422, Training Accuracy= 84.30000
#
# Fold: 9, Epoch: 14, Validation Accuracy= 87.30000
#
# Fold: 9, Epoch: 15, Mini Batch: 9, Loss= 2263.220459, Training Accuracy= 85.70000
#
# Fold: 9, Epoch: 15, Validation Accuracy= 87.90000
#
# Fold: 9, Epoch: 16, Mini Batch: 9, Loss= 1794.636353, Training Accuracy= 87.10000
#
# Fold: 9, Epoch: 16, Validation Accuracy= 87.60000
#
# Fold: 9, Epoch: 17, Mini Batch: 9, Loss= 1742.218140, Training Accuracy= 87.40000
#
# Fold: 9, Epoch: 17, Validation Accuracy= 87.70000
#
# Fold: 9, Epoch: 18, Mini Batch: 9, Loss= 2045.203369, Training Accuracy= 84.50000
#
# Fold: 9, Epoch: 18, Validation Accuracy= 87.20000
#
# Fold: 9, Epoch: 19, Mini Batch: 9, Loss= 1642.073242, Training Accuracy= 86.80000
#
# Fold: 9, Epoch: 19, Validation Accuracy= 87.00000
#
# Fold: 9, Epoch: 20, Mini Batch: 9, Loss= 1696.852661, Training Accuracy= 85.80000
#
# Fold: 9, Epoch: 20, Validation Accuracy= 86.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          423   57   480
# 1           77  443   520
# All        500  500  1000
#
# Fold: 9, Epoch: 21, Mini Batch: 9, Loss= 1760.906738, Training Accuracy= 86.20000
#
# Fold: 9, Epoch: 21, Validation Accuracy= 86.80000
#
# Fold: 9, Epoch: 22, Mini Batch: 9, Loss= 1495.473022, Training Accuracy= 87.90000
#
# Fold: 9, Epoch: 22, Validation Accuracy= 87.30000
#
# Fold: 9, Epoch: 23, Mini Batch: 9, Loss= 1263.700195, Training Accuracy= 87.00000
#
# Fold: 9, Epoch: 23, Validation Accuracy= 86.70000
#
# Fold: 9, Epoch: 24, Mini Batch: 9, Loss= 1292.226318, Training Accuracy= 88.20000
#
# Fold: 9, Epoch: 24, Validation Accuracy= 87.00000
#
# Fold: 9, Epoch: 25, Mini Batch: 9, Loss= 1239.754272, Training Accuracy= 87.20000
#
# Fold: 9, Epoch: 25, Validation Accuracy= 87.00000
#
# Fold: 9, Epoch: 26, Mini Batch: 9, Loss= 1267.265869, Training Accuracy= 88.50000
#
# Fold: 9, Epoch: 26, Validation Accuracy= 86.80000
#
# Fold: 9, Epoch: 27, Mini Batch: 9, Loss= 893.190063, Training Accuracy= 89.00000
#
# Fold: 9, Epoch: 27, Validation Accuracy= 87.20000
#
# Fold: 9, Epoch: 28, Mini Batch: 9, Loss= 1050.094238, Training Accuracy= 88.20000
#
# Fold: 9, Epoch: 28, Validation Accuracy= 87.00000
#
# Fold: 9, Epoch: 29, Mini Batch: 9, Loss= 757.030884, Training Accuracy= 89.40000
#
# Fold: 9, Epoch: 29, Validation Accuracy= 87.80000
#
# Fold: 9, Epoch: 30, Mini Batch: 9, Loss= 780.116150, Training Accuracy= 90.40000
#
# Fold: 9, Epoch: 30, Validation Accuracy= 87.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          429   51   480
# 1           71  449   520
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.006, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1280}
# Fold: 10, Epoch: 1, Mini Batch: 9, Loss= 17950.619141, Training Accuracy= 76.10000
#
# Fold: 10, Epoch: 1, Validation Accuracy= 83.40000
#
# Fold: 10, Epoch: 2, Mini Batch: 9, Loss= 12781.958008, Training Accuracy= 80.10000
#
# Fold: 10, Epoch: 2, Validation Accuracy= 84.40000
#
# Fold: 10, Epoch: 3, Mini Batch: 9, Loss= 10859.064453, Training Accuracy= 79.90000
#
# Fold: 10, Epoch: 3, Validation Accuracy= 84.00000
#
# Fold: 10, Epoch: 4, Mini Batch: 9, Loss= 7525.245605, Training Accuracy= 79.60000
#
# Fold: 10, Epoch: 4, Validation Accuracy= 87.90000
#
# Fold: 10, Epoch: 5, Mini Batch: 9, Loss= 6443.395996, Training Accuracy= 81.70000
#
# Fold: 10, Epoch: 5, Validation Accuracy= 88.90000
#
# Fold: 10, Epoch: 6, Mini Batch: 9, Loss= 5231.228027, Training Accuracy= 81.90000
#
# Fold: 10, Epoch: 6, Validation Accuracy= 88.60000
#
# Fold: 10, Epoch: 7, Mini Batch: 9, Loss= 5060.272949, Training Accuracy= 81.90000
#
# Fold: 10, Epoch: 7, Validation Accuracy= 88.80000
#
# Fold: 10, Epoch: 8, Mini Batch: 9, Loss= 4423.485840, Training Accuracy= 81.60000
#
# Fold: 10, Epoch: 8, Validation Accuracy= 88.90000
#
# Fold: 10, Epoch: 9, Mini Batch: 9, Loss= 3447.139404, Training Accuracy= 83.20000
#
# Fold: 10, Epoch: 9, Validation Accuracy= 88.90000
#
# Fold: 10, Epoch: 10, Mini Batch: 9, Loss= 3550.664551, Training Accuracy= 83.40000
#
# Fold: 10, Epoch: 10, Validation Accuracy= 89.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          443   45   488
# 1           57  455   512
# All        500  500  1000
#
# Fold: 10, Epoch: 11, Mini Batch: 9, Loss= 3464.674561, Training Accuracy= 82.90000
#
# Fold: 10, Epoch: 11, Validation Accuracy= 89.50000
#
# Fold: 10, Epoch: 12, Mini Batch: 9, Loss= 3141.582520, Training Accuracy= 83.90000
#
# Fold: 10, Epoch: 12, Validation Accuracy= 88.90000
#
# Fold: 10, Epoch: 13, Mini Batch: 9, Loss= 2741.531494, Training Accuracy= 84.60000
#
# Fold: 10, Epoch: 13, Validation Accuracy= 89.10000
#
# Fold: 10, Epoch: 14, Mini Batch: 9, Loss= 2431.855957, Training Accuracy= 84.10000
#
# Fold: 10, Epoch: 14, Validation Accuracy= 89.10000
#
# Fold: 10, Epoch: 15, Mini Batch: 9, Loss= 2698.496338, Training Accuracy= 83.70000
#
# Fold: 10, Epoch: 15, Validation Accuracy= 89.00000
#
# Fold: 10, Epoch: 16, Mini Batch: 9, Loss= 2366.326904, Training Accuracy= 84.70000
#
# Fold: 10, Epoch: 16, Validation Accuracy= 88.60000
#
# Fold: 10, Epoch: 17, Mini Batch: 9, Loss= 2295.180908, Training Accuracy= 85.20000
#
# Fold: 10, Epoch: 17, Validation Accuracy= 88.90000
#
# Fold: 10, Epoch: 18, Mini Batch: 9, Loss= 2111.354004, Training Accuracy= 85.50000
#
# Fold: 10, Epoch: 18, Validation Accuracy= 88.20000
#
# Fold: 10, Epoch: 19, Mini Batch: 9, Loss= 1907.140259, Training Accuracy= 84.50000
#
# Fold: 10, Epoch: 19, Validation Accuracy= 88.10000
#
# Fold: 10, Epoch: 20, Mini Batch: 9, Loss= 1771.205933, Training Accuracy= 85.40000
#
# Fold: 10, Epoch: 20, Validation Accuracy= 88.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          439   51   490
# 1           61  449   510
# All        500  500  1000
#
# Fold: 10, Epoch: 21, Mini Batch: 9, Loss= 1810.265991, Training Accuracy= 86.30000
#
# Fold: 10, Epoch: 21, Validation Accuracy= 88.60000
#
# Fold: 10, Epoch: 22, Mini Batch: 9, Loss= 1131.646118, Training Accuracy= 87.20000
#
# Fold: 10, Epoch: 22, Validation Accuracy= 88.50000
#
# Fold: 10, Epoch: 23, Mini Batch: 9, Loss= 1321.448120, Training Accuracy= 86.30000
#
# Fold: 10, Epoch: 23, Validation Accuracy= 88.90000
#
# Fold: 10, Epoch: 24, Mini Batch: 9, Loss= 1343.234863, Training Accuracy= 86.70000
#
# Fold: 10, Epoch: 24, Validation Accuracy= 88.50000
#
# Fold: 10, Epoch: 25, Mini Batch: 9, Loss= 1352.507324, Training Accuracy= 85.50000
#
# Fold: 10, Epoch: 25, Validation Accuracy= 89.10000
#
# Fold: 10, Epoch: 26, Mini Batch: 9, Loss= 1353.976807, Training Accuracy= 86.50000
#
# Fold: 10, Epoch: 26, Validation Accuracy= 88.70000
#
# Fold: 10, Epoch: 27, Mini Batch: 9, Loss= 1160.320557, Training Accuracy= 87.70000
#
# Fold: 10, Epoch: 27, Validation Accuracy= 89.00000
#
# Fold: 10, Epoch: 28, Mini Batch: 9, Loss= 1206.464478, Training Accuracy= 87.00000
#
# Fold: 10, Epoch: 28, Validation Accuracy= 88.50000
#
# Fold: 10, Epoch: 29, Mini Batch: 9, Loss= 1065.629028, Training Accuracy= 89.50000
#
# Fold: 10, Epoch: 29, Validation Accuracy= 88.80000
#
# Fold: 10, Epoch: 30, Mini Batch: 9, Loss= 1008.157227, Training Accuracy= 88.60000
#
# Fold: 10, Epoch: 30, Validation Accuracy= 89.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          451   60   511
# 1           49  440   489
# All        500  500  1000
#
# The mean Valid Accuracy is :  86.97

# %%
rows = 2
columns = 5
vizualize(vaccPerEpochPerFold, taccPerEpochPerFold, meanValidAcc=meanValidAcc, rows=rows, columns=columns, figsize=(5*columns, 5*rows))

# %% [markdown]
# ## 4-kernels : HOG - Adam Optimizer / Augmented / Hidden Units : 1024x1280x1280
# ------

# %%
featureDIR = HOGp4batchAug_dir
params = dict(imageSize = 32,
              numLabels = 2,
              
              # Network params
              numHidden1 = 1024,
              numHidden2 = 1280,
              numHidden3 = 1280, 

              # Batch Variables
              numFolds = 10,
              epochs = 30,
              batchSize = 1000,
             
              # Optimization Params
              keepProb = dict(hid1=0.75, hid2=0.5, hid3=0.5),
              optimizerParam = dict(optimizer='ADAM', learning_rate=0.006)
             )

# optimizer = tf.train.AdamOptimizer(learning_rate=0.008).minimize(lossCE)

(out, meanValidAcc, lossPerEpochPerFold, taccPerEpochPerFold, vaccPerEpochPerFold) = SessionExec(featureDIR, params).execute() 

print ('The mean Valid Accuracy is : ', meanValidAcc)


# To'dos:
# 1. Have to lower the weight 
# 2. Have to use L1 norm with dropout
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.006}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 1, Epoch: 1, Mini Batch: 10, Loss= 20542.400391, Training Accuracy= 75.00000
# Fold: 1, Epoch: 1, Mini Batch: 18, Loss= 17575.667969, Training Accuracy= 77.70000
#
# Fold: 1, Epoch: 1, Validation Accuracy= 84.55000
#
# Fold: 1, Epoch: 2, Mini Batch: 10, Loss= 12911.800781, Training Accuracy= 76.20000
# Fold: 1, Epoch: 2, Mini Batch: 18, Loss= 8842.321289, Training Accuracy= 78.20000
#
# Fold: 1, Epoch: 2, Validation Accuracy= 86.20000
#
# Fold: 1, Epoch: 3, Mini Batch: 10, Loss= 7292.386230, Training Accuracy= 78.00000
# Fold: 1, Epoch: 3, Mini Batch: 18, Loss= 7026.482910, Training Accuracy= 78.60000
#
# Fold: 1, Epoch: 3, Validation Accuracy= 86.90000
#
# Fold: 1, Epoch: 4, Mini Batch: 10, Loss= 5746.290039, Training Accuracy= 80.90000
# Fold: 1, Epoch: 4, Mini Batch: 18, Loss= 5235.058594, Training Accuracy= 78.80000
#
# Fold: 1, Epoch: 4, Validation Accuracy= 87.65000
#
# Fold: 1, Epoch: 5, Mini Batch: 10, Loss= 4559.893555, Training Accuracy= 80.40000
# Fold: 1, Epoch: 5, Mini Batch: 18, Loss= 4725.537109, Training Accuracy= 80.90000
#
# Fold: 1, Epoch: 5, Validation Accuracy= 87.70000
#
# Fold: 1, Epoch: 6, Mini Batch: 10, Loss= 4432.171875, Training Accuracy= 79.30000
# Fold: 1, Epoch: 6, Mini Batch: 18, Loss= 3413.411621, Training Accuracy= 81.20000
#
# Fold: 1, Epoch: 6, Validation Accuracy= 87.05000
#
# Fold: 1, Epoch: 7, Mini Batch: 10, Loss= 3520.748047, Training Accuracy= 80.30000
# Fold: 1, Epoch: 7, Mini Batch: 18, Loss= 3568.923096, Training Accuracy= 80.50000
#
# Fold: 1, Epoch: 7, Validation Accuracy= 87.65000
#
# Fold: 1, Epoch: 8, Mini Batch: 10, Loss= 3032.621338, Training Accuracy= 80.70000
# Fold: 1, Epoch: 8, Mini Batch: 18, Loss= 3230.159912, Training Accuracy= 79.80000
#
# Fold: 1, Epoch: 8, Validation Accuracy= 87.70000
#
# Fold: 1, Epoch: 9, Mini Batch: 10, Loss= 3252.895264, Training Accuracy= 78.10000
# Fold: 1, Epoch: 9, Mini Batch: 18, Loss= 2753.377930, Training Accuracy= 80.60000
#
# Fold: 1, Epoch: 9, Validation Accuracy= 87.85000
#
# Fold: 1, Epoch: 10, Mini Batch: 10, Loss= 2500.166992, Training Accuracy= 78.80000
# Fold: 1, Epoch: 10, Mini Batch: 18, Loss= 2131.628418, Training Accuracy= 80.70000
#
# Fold: 1, Epoch: 10, Validation Accuracy= 87.50000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           839    89   928
# 1           161   911  1072
# All        1000  1000  2000
#
# Fold: 1, Epoch: 11, Mini Batch: 10, Loss= 1907.286743, Training Accuracy= 83.00000
# Fold: 1, Epoch: 11, Mini Batch: 18, Loss= 2257.773438, Training Accuracy= 82.00000
#
# Fold: 1, Epoch: 11, Validation Accuracy= 87.55000
#
# Fold: 1, Epoch: 12, Mini Batch: 10, Loss= 2097.438965, Training Accuracy= 81.20000
# Fold: 1, Epoch: 12, Mini Batch: 18, Loss= 1887.344727, Training Accuracy= 83.50000
#
# Fold: 1, Epoch: 12, Validation Accuracy= 87.30000
#
# Fold: 1, Epoch: 13, Mini Batch: 10, Loss= 1843.400269, Training Accuracy= 81.70000
# Fold: 1, Epoch: 13, Mini Batch: 18, Loss= 1857.758545, Training Accuracy= 81.60000
#
# Fold: 1, Epoch: 13, Validation Accuracy= 87.50000
#
# Fold: 1, Epoch: 14, Mini Batch: 10, Loss= 1485.956787, Training Accuracy= 83.20000
# Fold: 1, Epoch: 14, Mini Batch: 18, Loss= 1761.682983, Training Accuracy= 81.80000
#
# Fold: 1, Epoch: 14, Validation Accuracy= 87.20000
#
# Fold: 1, Epoch: 15, Mini Batch: 10, Loss= 1382.742554, Training Accuracy= 83.10000
# Fold: 1, Epoch: 15, Mini Batch: 18, Loss= 1378.862549, Training Accuracy= 83.00000
#
# Fold: 1, Epoch: 15, Validation Accuracy= 87.45000
#
# Fold: 1, Epoch: 16, Mini Batch: 10, Loss= 1278.270752, Training Accuracy= 82.70000
# Fold: 1, Epoch: 16, Mini Batch: 18, Loss= 1452.788696, Training Accuracy= 82.90000
#
# Fold: 1, Epoch: 16, Validation Accuracy= 87.60000
#
# Fold: 1, Epoch: 17, Mini Batch: 10, Loss= 1162.223999, Training Accuracy= 83.40000
# Fold: 1, Epoch: 17, Mini Batch: 18, Loss= 1189.362793, Training Accuracy= 83.80000
#
# Fold: 1, Epoch: 17, Validation Accuracy= 87.45000
#
# Fold: 1, Epoch: 18, Mini Batch: 10, Loss= 1042.670654, Training Accuracy= 83.80000
# Fold: 1, Epoch: 18, Mini Batch: 18, Loss= 1151.913452, Training Accuracy= 85.10000
#
# Fold: 1, Epoch: 18, Validation Accuracy= 87.45000
#
# Fold: 1, Epoch: 19, Mini Batch: 10, Loss= 965.567871, Training Accuracy= 84.20000
# Fold: 1, Epoch: 19, Mini Batch: 18, Loss= 1014.173767, Training Accuracy= 84.20000
#
# Fold: 1, Epoch: 19, Validation Accuracy= 87.40000
#
# Fold: 1, Epoch: 20, Mini Batch: 10, Loss= 799.898499, Training Accuracy= 85.10000
# Fold: 1, Epoch: 20, Mini Batch: 18, Loss= 995.765869, Training Accuracy= 84.60000
#
# Fold: 1, Epoch: 20, Validation Accuracy= 87.40000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           856   108   964
# 1           144   892  1036
# All        1000  1000  2000
#
# Fold: 1, Epoch: 21, Mini Batch: 10, Loss= 902.323975, Training Accuracy= 83.30000
# Fold: 1, Epoch: 21, Mini Batch: 18, Loss= 959.902832, Training Accuracy= 84.70000
#
# Fold: 1, Epoch: 21, Validation Accuracy= 88.05000
#
# Fold: 1, Epoch: 22, Mini Batch: 10, Loss= 849.669617, Training Accuracy= 85.20000
# Fold: 1, Epoch: 22, Mini Batch: 18, Loss= 778.011047, Training Accuracy= 84.40000
#
# Fold: 1, Epoch: 22, Validation Accuracy= 87.50000
#
# Fold: 1, Epoch: 23, Mini Batch: 10, Loss= 700.035645, Training Accuracy= 84.20000
# Fold: 1, Epoch: 23, Mini Batch: 18, Loss= 708.856079, Training Accuracy= 84.90000
#
# Fold: 1, Epoch: 23, Validation Accuracy= 87.60000
#
# Fold: 1, Epoch: 24, Mini Batch: 10, Loss= 753.311279, Training Accuracy= 83.50000
# Fold: 1, Epoch: 24, Mini Batch: 18, Loss= 666.153931, Training Accuracy= 85.40000
#
# Fold: 1, Epoch: 24, Validation Accuracy= 87.35000
#
# Fold: 1, Epoch: 25, Mini Batch: 10, Loss= 584.572754, Training Accuracy= 85.60000
# Fold: 1, Epoch: 25, Mini Batch: 18, Loss= 573.237183, Training Accuracy= 84.30000
#
# Fold: 1, Epoch: 25, Validation Accuracy= 87.20000
#
# Fold: 1, Epoch: 26, Mini Batch: 10, Loss= 649.158875, Training Accuracy= 84.80000
# Fold: 1, Epoch: 26, Mini Batch: 18, Loss= 603.505005, Training Accuracy= 85.60000
#
# Fold: 1, Epoch: 26, Validation Accuracy= 87.50000
#
# Fold: 1, Epoch: 27, Mini Batch: 10, Loss= 523.558777, Training Accuracy= 85.40000
# Fold: 1, Epoch: 27, Mini Batch: 18, Loss= 451.526337, Training Accuracy= 86.80000
#
# Fold: 1, Epoch: 27, Validation Accuracy= 87.55000
#
# Fold: 1, Epoch: 28, Mini Batch: 10, Loss= 486.833435, Training Accuracy= 87.80000
# Fold: 1, Epoch: 28, Mini Batch: 18, Loss= 585.653015, Training Accuracy= 83.80000
#
# Fold: 1, Epoch: 28, Validation Accuracy= 87.95000
#
# Fold: 1, Epoch: 29, Mini Batch: 10, Loss= 482.662598, Training Accuracy= 83.20000
# Fold: 1, Epoch: 29, Mini Batch: 18, Loss= 452.190948, Training Accuracy= 85.30000
#
# Fold: 1, Epoch: 29, Validation Accuracy= 87.40000
#
# Fold: 1, Epoch: 30, Mini Batch: 10, Loss= 481.345612, Training Accuracy= 85.20000
# Fold: 1, Epoch: 30, Mini Batch: 18, Loss= 549.794922, Training Accuracy= 85.40000
#
# Fold: 1, Epoch: 30, Validation Accuracy= 87.05000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           844   103   947
# 1           156   897  1053
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.006}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 2, Epoch: 1, Mini Batch: 10, Loss= 19563.494141, Training Accuracy= 75.30000
# Fold: 2, Epoch: 1, Mini Batch: 18, Loss= 20046.115234, Training Accuracy= 75.60000
#
# Fold: 2, Epoch: 1, Validation Accuracy= 81.85000
#
# Fold: 2, Epoch: 2, Mini Batch: 10, Loss= 10496.424805, Training Accuracy= 79.40000
# Fold: 2, Epoch: 2, Mini Batch: 18, Loss= 9684.053711, Training Accuracy= 77.10000
#
# Fold: 2, Epoch: 2, Validation Accuracy= 85.80000
#
# Fold: 2, Epoch: 3, Mini Batch: 10, Loss= 8333.009766, Training Accuracy= 78.50000
# Fold: 2, Epoch: 3, Mini Batch: 18, Loss= 6963.747070, Training Accuracy= 78.80000
#
# Fold: 2, Epoch: 3, Validation Accuracy= 84.80000
#
# Fold: 2, Epoch: 4, Mini Batch: 10, Loss= 5769.497070, Training Accuracy= 77.80000
# Fold: 2, Epoch: 4, Mini Batch: 18, Loss= 5416.011230, Training Accuracy= 80.60000
#
# Fold: 2, Epoch: 4, Validation Accuracy= 85.50000
#
# Fold: 2, Epoch: 5, Mini Batch: 10, Loss= 5073.136719, Training Accuracy= 79.10000
# Fold: 2, Epoch: 5, Mini Batch: 18, Loss= 4797.339844, Training Accuracy= 80.50000
#
# Fold: 2, Epoch: 5, Validation Accuracy= 85.90000
#
# Fold: 2, Epoch: 6, Mini Batch: 10, Loss= 4751.178711, Training Accuracy= 81.00000
# Fold: 2, Epoch: 6, Mini Batch: 18, Loss= 4244.308105, Training Accuracy= 79.70000
#
# Fold: 2, Epoch: 6, Validation Accuracy= 86.20000
#
# Fold: 2, Epoch: 7, Mini Batch: 10, Loss= 2964.785156, Training Accuracy= 82.20000
# Fold: 2, Epoch: 7, Mini Batch: 18, Loss= 3616.477051, Training Accuracy= 80.90000
#
# Fold: 2, Epoch: 7, Validation Accuracy= 86.35000
#
# Fold: 2, Epoch: 8, Mini Batch: 10, Loss= 2968.885742, Training Accuracy= 81.20000
# Fold: 2, Epoch: 8, Mini Batch: 18, Loss= 3230.790527, Training Accuracy= 81.00000
#
# Fold: 2, Epoch: 8, Validation Accuracy= 86.40000
#
# Fold: 2, Epoch: 9, Mini Batch: 10, Loss= 2789.610107, Training Accuracy= 80.30000
# Fold: 2, Epoch: 9, Mini Batch: 18, Loss= 3088.983887, Training Accuracy= 82.40000
#
# Fold: 2, Epoch: 9, Validation Accuracy= 86.55000
#
# Fold: 2, Epoch: 10, Mini Batch: 10, Loss= 2402.366455, Training Accuracy= 82.20000
# Fold: 2, Epoch: 10, Mini Batch: 18, Loss= 2429.208252, Training Accuracy= 83.00000
#
# Fold: 2, Epoch: 10, Validation Accuracy= 87.00000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           867   127   994
# 1           133   873  1006
# All        1000  1000  2000
#
# Fold: 2, Epoch: 11, Mini Batch: 10, Loss= 2491.148438, Training Accuracy= 81.60000
# Fold: 2, Epoch: 11, Mini Batch: 18, Loss= 2228.179688, Training Accuracy= 81.90000
#
# Fold: 2, Epoch: 11, Validation Accuracy= 87.50000
#
# Fold: 2, Epoch: 12, Mini Batch: 10, Loss= 2159.583984, Training Accuracy= 81.80000
# Fold: 2, Epoch: 12, Mini Batch: 18, Loss= 1986.891235, Training Accuracy= 82.50000
#
# Fold: 2, Epoch: 12, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 13, Mini Batch: 10, Loss= 1778.411377, Training Accuracy= 82.10000
# Fold: 2, Epoch: 13, Mini Batch: 18, Loss= 1824.289795, Training Accuracy= 83.40000
#
# Fold: 2, Epoch: 13, Validation Accuracy= 87.55000
#
# Fold: 2, Epoch: 14, Mini Batch: 10, Loss= 1693.619141, Training Accuracy= 82.60000
# Fold: 2, Epoch: 14, Mini Batch: 18, Loss= 1611.910645, Training Accuracy= 82.60000
#
# Fold: 2, Epoch: 14, Validation Accuracy= 87.60000
#
# Fold: 2, Epoch: 15, Mini Batch: 10, Loss= 1471.094604, Training Accuracy= 83.40000
# Fold: 2, Epoch: 15, Mini Batch: 18, Loss= 1478.673462, Training Accuracy= 83.90000
#
# Fold: 2, Epoch: 15, Validation Accuracy= 87.70000
#
# Fold: 2, Epoch: 16, Mini Batch: 10, Loss= 1532.687012, Training Accuracy= 83.00000
# Fold: 2, Epoch: 16, Mini Batch: 18, Loss= 1415.025024, Training Accuracy= 84.50000
#
# Fold: 2, Epoch: 16, Validation Accuracy= 87.55000
#
# Fold: 2, Epoch: 17, Mini Batch: 10, Loss= 1263.105225, Training Accuracy= 84.30000
# Fold: 2, Epoch: 17, Mini Batch: 18, Loss= 1413.800781, Training Accuracy= 82.20000
#
# Fold: 2, Epoch: 17, Validation Accuracy= 87.45000
#
# Fold: 2, Epoch: 18, Mini Batch: 10, Loss= 1201.818726, Training Accuracy= 84.00000
# Fold: 2, Epoch: 18, Mini Batch: 18, Loss= 1175.005737, Training Accuracy= 82.70000
#
# Fold: 2, Epoch: 18, Validation Accuracy= 87.25000
#
# Fold: 2, Epoch: 19, Mini Batch: 10, Loss= 969.673950, Training Accuracy= 85.10000
# Fold: 2, Epoch: 19, Mini Batch: 18, Loss= 967.264893, Training Accuracy= 84.60000
#
# Fold: 2, Epoch: 19, Validation Accuracy= 87.05000
#
# Fold: 2, Epoch: 20, Mini Batch: 10, Loss= 837.767395, Training Accuracy= 84.60000
# Fold: 2, Epoch: 20, Mini Batch: 18, Loss= 977.197266, Training Accuracy= 84.50000
#
# Fold: 2, Epoch: 20, Validation Accuracy= 87.40000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           854   106   960
# 1           146   894  1040
# All        1000  1000  2000
#
# Fold: 2, Epoch: 21, Mini Batch: 10, Loss= 1054.955811, Training Accuracy= 84.40000
# Fold: 2, Epoch: 21, Mini Batch: 18, Loss= 945.725525, Training Accuracy= 83.30000
#
# Fold: 2, Epoch: 21, Validation Accuracy= 87.15000
#
# Fold: 2, Epoch: 22, Mini Batch: 10, Loss= 888.912598, Training Accuracy= 84.10000
# Fold: 2, Epoch: 22, Mini Batch: 18, Loss= 882.987000, Training Accuracy= 84.00000
#
# Fold: 2, Epoch: 22, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 23, Mini Batch: 10, Loss= 732.893250, Training Accuracy= 84.30000
# Fold: 2, Epoch: 23, Mini Batch: 18, Loss= 803.461609, Training Accuracy= 84.20000
#
# Fold: 2, Epoch: 23, Validation Accuracy= 86.70000
#
# Fold: 2, Epoch: 24, Mini Batch: 10, Loss= 743.304688, Training Accuracy= 85.10000
# Fold: 2, Epoch: 24, Mini Batch: 18, Loss= 736.001648, Training Accuracy= 84.60000
#
# Fold: 2, Epoch: 24, Validation Accuracy= 87.05000
#
# Fold: 2, Epoch: 25, Mini Batch: 10, Loss= 650.617737, Training Accuracy= 85.00000
# Fold: 2, Epoch: 25, Mini Batch: 18, Loss= 714.732239, Training Accuracy= 84.30000
#
# Fold: 2, Epoch: 25, Validation Accuracy= 87.40000
#
# Fold: 2, Epoch: 26, Mini Batch: 10, Loss= 526.697998, Training Accuracy= 86.20000
# Fold: 2, Epoch: 26, Mini Batch: 18, Loss= 550.442566, Training Accuracy= 87.20000
#
# Fold: 2, Epoch: 26, Validation Accuracy= 86.85000
#
# Fold: 2, Epoch: 27, Mini Batch: 10, Loss= 586.321167, Training Accuracy= 83.70000
# Fold: 2, Epoch: 27, Mini Batch: 18, Loss= 490.130219, Training Accuracy= 86.10000
#
# Fold: 2, Epoch: 27, Validation Accuracy= 87.05000
#
# Fold: 2, Epoch: 28, Mini Batch: 10, Loss= 551.870667, Training Accuracy= 84.90000
# Fold: 2, Epoch: 28, Mini Batch: 18, Loss= 638.273254, Training Accuracy= 84.20000
#
# Fold: 2, Epoch: 28, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 29, Mini Batch: 10, Loss= 448.044495, Training Accuracy= 87.70000
# Fold: 2, Epoch: 29, Mini Batch: 18, Loss= 497.236389, Training Accuracy= 86.60000
#
# Fold: 2, Epoch: 29, Validation Accuracy= 86.75000
#
# Fold: 2, Epoch: 30, Mini Batch: 10, Loss= 459.984924, Training Accuracy= 86.40000
# Fold: 2, Epoch: 30, Mini Batch: 18, Loss= 465.683167, Training Accuracy= 86.10000
#
# Fold: 2, Epoch: 30, Validation Accuracy= 86.60000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           842   110   952
# 1           158   890  1048
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.006}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 3, Epoch: 1, Mini Batch: 10, Loss= 21692.832031, Training Accuracy= 72.90000
# Fold: 3, Epoch: 1, Mini Batch: 18, Loss= 14317.443359, Training Accuracy= 77.50000
#
# Fold: 3, Epoch: 1, Validation Accuracy= 82.75000
#
# Fold: 3, Epoch: 2, Mini Batch: 10, Loss= 11017.681641, Training Accuracy= 75.80000
# Fold: 3, Epoch: 2, Mini Batch: 18, Loss= 8262.995117, Training Accuracy= 79.60000
#
# Fold: 3, Epoch: 2, Validation Accuracy= 86.05000
#
# Fold: 3, Epoch: 3, Mini Batch: 10, Loss= 6983.765625, Training Accuracy= 78.60000
# Fold: 3, Epoch: 3, Mini Batch: 18, Loss= 7286.810547, Training Accuracy= 78.10000
#
# Fold: 3, Epoch: 3, Validation Accuracy= 86.65000
#
# Fold: 3, Epoch: 4, Mini Batch: 10, Loss= 5654.121094, Training Accuracy= 81.20000
# Fold: 3, Epoch: 4, Mini Batch: 18, Loss= 4846.938477, Training Accuracy= 80.70000
#
# Fold: 3, Epoch: 4, Validation Accuracy= 87.85000
#
# Fold: 3, Epoch: 5, Mini Batch: 10, Loss= 5121.493164, Training Accuracy= 77.70000
# Fold: 3, Epoch: 5, Mini Batch: 18, Loss= 4835.715332, Training Accuracy= 81.40000
#
# Fold: 3, Epoch: 5, Validation Accuracy= 87.55000
#
# Fold: 3, Epoch: 6, Mini Batch: 10, Loss= 4266.936035, Training Accuracy= 80.00000
# Fold: 3, Epoch: 6, Mini Batch: 18, Loss= 3872.509033, Training Accuracy= 82.10000
#
# Fold: 3, Epoch: 6, Validation Accuracy= 88.20000
#
# Fold: 3, Epoch: 7, Mini Batch: 10, Loss= 3639.325928, Training Accuracy= 79.20000
# Fold: 3, Epoch: 7, Mini Batch: 18, Loss= 3645.174805, Training Accuracy= 80.70000
#
# Fold: 3, Epoch: 7, Validation Accuracy= 88.45000
#
# Fold: 3, Epoch: 8, Mini Batch: 10, Loss= 2690.038086, Training Accuracy= 82.80000
# Fold: 3, Epoch: 8, Mini Batch: 18, Loss= 3078.912354, Training Accuracy= 80.20000
#
# Fold: 3, Epoch: 8, Validation Accuracy= 87.80000
#
# Fold: 3, Epoch: 9, Mini Batch: 10, Loss= 2792.799561, Training Accuracy= 81.40000
# Fold: 3, Epoch: 9, Mini Batch: 18, Loss= 2662.239014, Training Accuracy= 81.80000
#
# Fold: 3, Epoch: 9, Validation Accuracy= 87.95000
#
# Fold: 3, Epoch: 10, Mini Batch: 10, Loss= 2411.691162, Training Accuracy= 82.30000
# Fold: 3, Epoch: 10, Mini Batch: 18, Loss= 2073.104004, Training Accuracy= 83.00000
#
# Fold: 3, Epoch: 10, Validation Accuracy= 88.65000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           869    96   965
# 1           131   904  1035
# All        1000  1000  2000
#
# Fold: 3, Epoch: 11, Mini Batch: 10, Loss= 2227.919434, Training Accuracy= 81.20000
# Fold: 3, Epoch: 11, Mini Batch: 18, Loss= 1882.693359, Training Accuracy= 84.10000
#
# Fold: 3, Epoch: 11, Validation Accuracy= 88.05000
#
# Fold: 3, Epoch: 12, Mini Batch: 10, Loss= 1903.455811, Training Accuracy= 82.40000
# Fold: 3, Epoch: 12, Mini Batch: 18, Loss= 1800.402710, Training Accuracy= 82.60000
#
# Fold: 3, Epoch: 12, Validation Accuracy= 88.45000
#
# Fold: 3, Epoch: 13, Mini Batch: 10, Loss= 1795.051880, Training Accuracy= 80.60000
# Fold: 3, Epoch: 13, Mini Batch: 18, Loss= 1745.100342, Training Accuracy= 84.20000
#
# Fold: 3, Epoch: 13, Validation Accuracy= 88.25000
#
# Fold: 3, Epoch: 14, Mini Batch: 10, Loss= 1454.256470, Training Accuracy= 83.70000
# Fold: 3, Epoch: 14, Mini Batch: 18, Loss= 1549.645508, Training Accuracy= 82.10000
#
# Fold: 3, Epoch: 14, Validation Accuracy= 88.90000
#
# Fold: 3, Epoch: 15, Mini Batch: 10, Loss= 1431.304443, Training Accuracy= 82.40000
# Fold: 3, Epoch: 15, Mini Batch: 18, Loss= 1398.769531, Training Accuracy= 82.90000
#
# Fold: 3, Epoch: 15, Validation Accuracy= 88.40000
#
# Fold: 3, Epoch: 16, Mini Batch: 10, Loss= 1162.389038, Training Accuracy= 83.90000
# Fold: 3, Epoch: 16, Mini Batch: 18, Loss= 1303.709717, Training Accuracy= 82.80000
#
# Fold: 3, Epoch: 16, Validation Accuracy= 88.15000
#
# Fold: 3, Epoch: 17, Mini Batch: 10, Loss= 1383.946533, Training Accuracy= 82.50000
# Fold: 3, Epoch: 17, Mini Batch: 18, Loss= 1170.884766, Training Accuracy= 83.60000
#
# Fold: 3, Epoch: 17, Validation Accuracy= 88.65000
#
# Fold: 3, Epoch: 18, Mini Batch: 10, Loss= 1256.578125, Training Accuracy= 82.40000
# Fold: 3, Epoch: 18, Mini Batch: 18, Loss= 1112.576294, Training Accuracy= 83.00000
#
# Fold: 3, Epoch: 18, Validation Accuracy= 88.95000
#
# Fold: 3, Epoch: 19, Mini Batch: 10, Loss= 1317.563110, Training Accuracy= 80.60000
# Fold: 3, Epoch: 19, Mini Batch: 18, Loss= 1120.193970, Training Accuracy= 83.30000
#
# Fold: 3, Epoch: 19, Validation Accuracy= 88.20000
#
# Fold: 3, Epoch: 20, Mini Batch: 10, Loss= 916.443176, Training Accuracy= 84.20000
# Fold: 3, Epoch: 20, Mini Batch: 18, Loss= 816.425354, Training Accuracy= 85.50000
#
# Fold: 3, Epoch: 20, Validation Accuracy= 88.20000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           888   124  1012
# 1           112   876   988
# All        1000  1000  2000
#
# Fold: 3, Epoch: 21, Mini Batch: 10, Loss= 845.129639, Training Accuracy= 83.10000
# Fold: 3, Epoch: 21, Mini Batch: 18, Loss= 729.925720, Training Accuracy= 83.30000
#
# Fold: 3, Epoch: 21, Validation Accuracy= 88.30000
#
# Fold: 3, Epoch: 22, Mini Batch: 10, Loss= 633.317627, Training Accuracy= 84.70000
# Fold: 3, Epoch: 22, Mini Batch: 18, Loss= 833.528503, Training Accuracy= 84.70000
#
# Fold: 3, Epoch: 22, Validation Accuracy= 88.30000
#
# Fold: 3, Epoch: 23, Mini Batch: 10, Loss= 679.018982, Training Accuracy= 85.40000
# Fold: 3, Epoch: 23, Mini Batch: 18, Loss= 752.296936, Training Accuracy= 84.90000
#
# Fold: 3, Epoch: 23, Validation Accuracy= 88.80000
#
# Fold: 3, Epoch: 24, Mini Batch: 10, Loss= 738.254822, Training Accuracy= 84.70000
# Fold: 3, Epoch: 24, Mini Batch: 18, Loss= 590.071838, Training Accuracy= 85.90000
#
# Fold: 3, Epoch: 24, Validation Accuracy= 88.60000
#
# Fold: 3, Epoch: 25, Mini Batch: 10, Loss= 635.291382, Training Accuracy= 85.30000
# Fold: 3, Epoch: 25, Mini Batch: 18, Loss= 699.924744, Training Accuracy= 84.50000
#
# Fold: 3, Epoch: 25, Validation Accuracy= 88.25000
#
# Fold: 3, Epoch: 26, Mini Batch: 10, Loss= 632.988525, Training Accuracy= 84.10000
# Fold: 3, Epoch: 26, Mini Batch: 18, Loss= 602.948730, Training Accuracy= 82.80000
#
# Fold: 3, Epoch: 26, Validation Accuracy= 88.35000
#
# Fold: 3, Epoch: 27, Mini Batch: 10, Loss= 510.780060, Training Accuracy= 85.60000
# Fold: 3, Epoch: 27, Mini Batch: 18, Loss= 644.834229, Training Accuracy= 84.40000
#
# Fold: 3, Epoch: 27, Validation Accuracy= 88.15000
#
# Fold: 3, Epoch: 28, Mini Batch: 10, Loss= 515.285034, Training Accuracy= 85.00000
# Fold: 3, Epoch: 28, Mini Batch: 18, Loss= 480.311188, Training Accuracy= 84.30000
#
# Fold: 3, Epoch: 28, Validation Accuracy= 87.95000
#
# Fold: 3, Epoch: 29, Mini Batch: 10, Loss= 454.028320, Training Accuracy= 86.40000
# Fold: 3, Epoch: 29, Mini Batch: 18, Loss= 440.443451, Training Accuracy= 86.00000
#
# Fold: 3, Epoch: 29, Validation Accuracy= 88.50000
#
# Fold: 3, Epoch: 30, Mini Batch: 10, Loss= 379.414001, Training Accuracy= 85.90000
# Fold: 3, Epoch: 30, Mini Batch: 18, Loss= 459.546844, Training Accuracy= 86.10000
#
# Fold: 3, Epoch: 30, Validation Accuracy= 88.20000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           858    94   952
# 1           142   906  1048
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.006}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 4, Epoch: 1, Mini Batch: 10, Loss= 21238.662109, Training Accuracy= 73.10000
# Fold: 4, Epoch: 1, Mini Batch: 18, Loss= 14908.133789, Training Accuracy= 77.20000
#
# Fold: 4, Epoch: 1, Validation Accuracy= 83.85000
#
# Fold: 4, Epoch: 2, Mini Batch: 10, Loss= 10098.024414, Training Accuracy= 79.40000
# Fold: 4, Epoch: 2, Mini Batch: 18, Loss= 8602.362305, Training Accuracy= 78.50000
#
# Fold: 4, Epoch: 2, Validation Accuracy= 85.40000
#
# Fold: 4, Epoch: 3, Mini Batch: 10, Loss= 8161.608887, Training Accuracy= 79.40000
# Fold: 4, Epoch: 3, Mini Batch: 18, Loss= 7727.783203, Training Accuracy= 79.50000
#
# Fold: 4, Epoch: 3, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 4, Mini Batch: 10, Loss= 6526.206055, Training Accuracy= 79.60000
# Fold: 4, Epoch: 4, Mini Batch: 18, Loss= 5535.535645, Training Accuracy= 80.40000
#
# Fold: 4, Epoch: 4, Validation Accuracy= 86.00000
#
# Fold: 4, Epoch: 5, Mini Batch: 10, Loss= 5214.470215, Training Accuracy= 80.00000
# Fold: 4, Epoch: 5, Mini Batch: 18, Loss= 4904.256836, Training Accuracy= 79.90000
#
# Fold: 4, Epoch: 5, Validation Accuracy= 86.75000
#
# Fold: 4, Epoch: 6, Mini Batch: 10, Loss= 4314.394043, Training Accuracy= 80.10000
# Fold: 4, Epoch: 6, Mini Batch: 18, Loss= 4095.652832, Training Accuracy= 80.90000
#
# Fold: 4, Epoch: 6, Validation Accuracy= 86.05000
#
# Fold: 4, Epoch: 7, Mini Batch: 10, Loss= 4262.857910, Training Accuracy= 79.70000
# Fold: 4, Epoch: 7, Mini Batch: 18, Loss= 3529.224365, Training Accuracy= 81.40000
#
# Fold: 4, Epoch: 7, Validation Accuracy= 86.25000
#
# Fold: 4, Epoch: 8, Mini Batch: 10, Loss= 3384.488770, Training Accuracy= 80.70000
# Fold: 4, Epoch: 8, Mini Batch: 18, Loss= 3096.951904, Training Accuracy= 81.80000
#
# Fold: 4, Epoch: 8, Validation Accuracy= 86.55000
#
# Fold: 4, Epoch: 9, Mini Batch: 10, Loss= 3005.331787, Training Accuracy= 80.40000
# Fold: 4, Epoch: 9, Mini Batch: 18, Loss= 2558.870605, Training Accuracy= 82.80000
#
# Fold: 4, Epoch: 9, Validation Accuracy= 86.40000
#
# Fold: 4, Epoch: 10, Mini Batch: 10, Loss= 2428.583984, Training Accuracy= 81.80000
# Fold: 4, Epoch: 10, Mini Batch: 18, Loss= 2625.915283, Training Accuracy= 80.30000
#
# Fold: 4, Epoch: 10, Validation Accuracy= 86.45000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           850   121   971
# 1           150   879  1029
# All        1000  1000  2000
#
# Fold: 4, Epoch: 11, Mini Batch: 10, Loss= 2168.626465, Training Accuracy= 82.50000
# Fold: 4, Epoch: 11, Mini Batch: 18, Loss= 2051.671387, Training Accuracy= 83.90000
#
# Fold: 4, Epoch: 11, Validation Accuracy= 86.80000
#
# Fold: 4, Epoch: 12, Mini Batch: 10, Loss= 2046.815796, Training Accuracy= 82.40000
# Fold: 4, Epoch: 12, Mini Batch: 18, Loss= 1847.970703, Training Accuracy= 83.90000
#
# Fold: 4, Epoch: 12, Validation Accuracy= 86.30000
#
# Fold: 4, Epoch: 13, Mini Batch: 10, Loss= 2078.768555, Training Accuracy= 80.50000
# Fold: 4, Epoch: 13, Mini Batch: 18, Loss= 1860.093140, Training Accuracy= 80.90000
#
# Fold: 4, Epoch: 13, Validation Accuracy= 86.15000
#
# Fold: 4, Epoch: 14, Mini Batch: 10, Loss= 1755.088989, Training Accuracy= 84.00000
# Fold: 4, Epoch: 14, Mini Batch: 18, Loss= 1584.312988, Training Accuracy= 83.40000
#
# Fold: 4, Epoch: 14, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 15, Mini Batch: 10, Loss= 1510.651489, Training Accuracy= 83.50000
# Fold: 4, Epoch: 15, Mini Batch: 18, Loss= 1236.643677, Training Accuracy= 85.50000
#
# Fold: 4, Epoch: 15, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 16, Mini Batch: 10, Loss= 1341.404297, Training Accuracy= 82.50000
# Fold: 4, Epoch: 16, Mini Batch: 18, Loss= 1448.305420, Training Accuracy= 83.90000
#
# Fold: 4, Epoch: 16, Validation Accuracy= 86.00000
#
# Fold: 4, Epoch: 17, Mini Batch: 10, Loss= 1223.637451, Training Accuracy= 82.40000
# Fold: 4, Epoch: 17, Mini Batch: 18, Loss= 1429.377930, Training Accuracy= 82.10000
#
# Fold: 4, Epoch: 17, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 18, Mini Batch: 10, Loss= 1177.985474, Training Accuracy= 83.50000
# Fold: 4, Epoch: 18, Mini Batch: 18, Loss= 1143.302246, Training Accuracy= 83.00000
#
# Fold: 4, Epoch: 18, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 19, Mini Batch: 10, Loss= 1086.902832, Training Accuracy= 83.70000
# Fold: 4, Epoch: 19, Mini Batch: 18, Loss= 1110.427612, Training Accuracy= 82.90000
#
# Fold: 4, Epoch: 19, Validation Accuracy= 85.90000
#
# Fold: 4, Epoch: 20, Mini Batch: 10, Loss= 993.567566, Training Accuracy= 83.30000
# Fold: 4, Epoch: 20, Mini Batch: 18, Loss= 757.830139, Training Accuracy= 84.90000
#
# Fold: 4, Epoch: 20, Validation Accuracy= 85.95000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           833   114   947
# 1           167   886  1053
# All        1000  1000  2000
#
# Fold: 4, Epoch: 21, Mini Batch: 10, Loss= 909.846985, Training Accuracy= 82.70000
# Fold: 4, Epoch: 21, Mini Batch: 18, Loss= 816.037903, Training Accuracy= 83.80000
#
# Fold: 4, Epoch: 21, Validation Accuracy= 85.90000
#
# Fold: 4, Epoch: 22, Mini Batch: 10, Loss= 878.535400, Training Accuracy= 84.20000
# Fold: 4, Epoch: 22, Mini Batch: 18, Loss= 699.437317, Training Accuracy= 85.50000
#
# Fold: 4, Epoch: 22, Validation Accuracy= 86.60000
#
# Fold: 4, Epoch: 23, Mini Batch: 10, Loss= 668.130920, Training Accuracy= 86.00000
# Fold: 4, Epoch: 23, Mini Batch: 18, Loss= 799.948181, Training Accuracy= 83.70000
#
# Fold: 4, Epoch: 23, Validation Accuracy= 86.25000
#
# Fold: 4, Epoch: 24, Mini Batch: 10, Loss= 664.327271, Training Accuracy= 84.40000
# Fold: 4, Epoch: 24, Mini Batch: 18, Loss= 705.330322, Training Accuracy= 85.00000
#
# Fold: 4, Epoch: 24, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 25, Mini Batch: 10, Loss= 618.353882, Training Accuracy= 85.20000
# Fold: 4, Epoch: 25, Mini Batch: 18, Loss= 641.948914, Training Accuracy= 83.90000
#
# Fold: 4, Epoch: 25, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 26, Mini Batch: 10, Loss= 533.593384, Training Accuracy= 85.00000
# Fold: 4, Epoch: 26, Mini Batch: 18, Loss= 586.636108, Training Accuracy= 84.30000
#
# Fold: 4, Epoch: 26, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 27, Mini Batch: 10, Loss= 516.631714, Training Accuracy= 85.80000
# Fold: 4, Epoch: 27, Mini Batch: 18, Loss= 572.596313, Training Accuracy= 84.30000
#
# Fold: 4, Epoch: 27, Validation Accuracy= 86.25000
#
# Fold: 4, Epoch: 28, Mini Batch: 10, Loss= 505.546448, Training Accuracy= 86.10000
# Fold: 4, Epoch: 28, Mini Batch: 18, Loss= 549.226074, Training Accuracy= 85.90000
#
# Fold: 4, Epoch: 28, Validation Accuracy= 86.60000
#
# Fold: 4, Epoch: 29, Mini Batch: 10, Loss= 505.547302, Training Accuracy= 84.70000
# Fold: 4, Epoch: 29, Mini Batch: 18, Loss= 515.316772, Training Accuracy= 85.00000
#
# Fold: 4, Epoch: 29, Validation Accuracy= 86.80000
#
# Fold: 4, Epoch: 30, Mini Batch: 10, Loss= 364.847687, Training Accuracy= 86.40000
# Fold: 4, Epoch: 30, Mini Batch: 18, Loss= 502.282196, Training Accuracy= 83.80000
#
# Fold: 4, Epoch: 30, Validation Accuracy= 87.00000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           838    98   936
# 1           162   902  1064
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.006}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 5, Epoch: 1, Mini Batch: 10, Loss= 19188.740234, Training Accuracy= 74.20000
# Fold: 5, Epoch: 1, Mini Batch: 18, Loss= 19292.000000, Training Accuracy= 75.90000
#
# Fold: 5, Epoch: 1, Validation Accuracy= 82.90000
#
# Fold: 5, Epoch: 2, Mini Batch: 10, Loss= 11192.666016, Training Accuracy= 77.30000
# Fold: 5, Epoch: 2, Mini Batch: 18, Loss= 9038.745117, Training Accuracy= 78.80000
#
# Fold: 5, Epoch: 2, Validation Accuracy= 86.70000
#
# Fold: 5, Epoch: 3, Mini Batch: 10, Loss= 7551.086914, Training Accuracy= 78.90000
# Fold: 5, Epoch: 3, Mini Batch: 18, Loss= 6749.986816, Training Accuracy= 80.40000
#
# Fold: 5, Epoch: 3, Validation Accuracy= 85.85000
#
# Fold: 5, Epoch: 4, Mini Batch: 10, Loss= 5975.569824, Training Accuracy= 80.80000
# Fold: 5, Epoch: 4, Mini Batch: 18, Loss= 5946.812500, Training Accuracy= 79.20000
#
# Fold: 5, Epoch: 4, Validation Accuracy= 87.40000
#
# Fold: 5, Epoch: 5, Mini Batch: 10, Loss= 5110.063477, Training Accuracy= 79.60000
# Fold: 5, Epoch: 5, Mini Batch: 18, Loss= 4760.765625, Training Accuracy= 79.80000
#
# Fold: 5, Epoch: 5, Validation Accuracy= 87.40000
#
# Fold: 5, Epoch: 6, Mini Batch: 10, Loss= 4540.842773, Training Accuracy= 78.80000
# Fold: 5, Epoch: 6, Mini Batch: 18, Loss= 4116.092773, Training Accuracy= 81.40000
#
# Fold: 5, Epoch: 6, Validation Accuracy= 87.80000
#
# Fold: 5, Epoch: 7, Mini Batch: 10, Loss= 3200.213379, Training Accuracy= 83.50000
# Fold: 5, Epoch: 7, Mini Batch: 18, Loss= 3440.353760, Training Accuracy= 80.80000
#
# Fold: 5, Epoch: 7, Validation Accuracy= 87.70000
#
# Fold: 5, Epoch: 8, Mini Batch: 10, Loss= 3241.376953, Training Accuracy= 83.20000
# Fold: 5, Epoch: 8, Mini Batch: 18, Loss= 3029.306396, Training Accuracy= 81.20000
#
# Fold: 5, Epoch: 8, Validation Accuracy= 88.00000
#
# Fold: 5, Epoch: 9, Mini Batch: 10, Loss= 3312.827148, Training Accuracy= 78.80000
# Fold: 5, Epoch: 9, Mini Batch: 18, Loss= 2963.432861, Training Accuracy= 81.20000
#
# Fold: 5, Epoch: 9, Validation Accuracy= 88.35000
#
# Fold: 5, Epoch: 10, Mini Batch: 10, Loss= 2713.254395, Training Accuracy= 81.30000
# Fold: 5, Epoch: 10, Mini Batch: 18, Loss= 2391.210449, Training Accuracy= 82.30000
#
# Fold: 5, Epoch: 10, Validation Accuracy= 88.75000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           874    99   973
# 1           126   901  1027
# All        1000  1000  2000
#
# Fold: 5, Epoch: 11, Mini Batch: 10, Loss= 2090.080322, Training Accuracy= 82.30000
# Fold: 5, Epoch: 11, Mini Batch: 18, Loss= 2302.846924, Training Accuracy= 81.60000
#
# Fold: 5, Epoch: 11, Validation Accuracy= 88.30000
#
# Fold: 5, Epoch: 12, Mini Batch: 10, Loss= 2070.535645, Training Accuracy= 81.10000
# Fold: 5, Epoch: 12, Mini Batch: 18, Loss= 2060.900635, Training Accuracy= 82.10000
#
# Fold: 5, Epoch: 12, Validation Accuracy= 88.30000
#
# Fold: 5, Epoch: 13, Mini Batch: 10, Loss= 1684.680054, Training Accuracy= 83.20000
# Fold: 5, Epoch: 13, Mini Batch: 18, Loss= 1837.758789, Training Accuracy= 83.40000
#
# Fold: 5, Epoch: 13, Validation Accuracy= 88.15000
#
# Fold: 5, Epoch: 14, Mini Batch: 10, Loss= 1727.015747, Training Accuracy= 83.70000
# Fold: 5, Epoch: 14, Mini Batch: 18, Loss= 1625.551758, Training Accuracy= 84.00000
#
# Fold: 5, Epoch: 14, Validation Accuracy= 88.10000
#
# Fold: 5, Epoch: 15, Mini Batch: 10, Loss= 1500.105469, Training Accuracy= 83.30000
# Fold: 5, Epoch: 15, Mini Batch: 18, Loss= 1436.632690, Training Accuracy= 83.10000
#
# Fold: 5, Epoch: 15, Validation Accuracy= 88.05000
#
# Fold: 5, Epoch: 16, Mini Batch: 10, Loss= 1419.766235, Training Accuracy= 83.80000
# Fold: 5, Epoch: 16, Mini Batch: 18, Loss= 1213.640869, Training Accuracy= 83.80000
#
# Fold: 5, Epoch: 16, Validation Accuracy= 87.75000
#
# Fold: 5, Epoch: 17, Mini Batch: 10, Loss= 1074.896973, Training Accuracy= 85.50000
# Fold: 5, Epoch: 17, Mini Batch: 18, Loss= 1096.927490, Training Accuracy= 84.50000
#
# Fold: 5, Epoch: 17, Validation Accuracy= 88.20000
#
# Fold: 5, Epoch: 18, Mini Batch: 10, Loss= 1188.471558, Training Accuracy= 82.00000
# Fold: 5, Epoch: 18, Mini Batch: 18, Loss= 1142.586792, Training Accuracy= 83.40000
#
# Fold: 5, Epoch: 18, Validation Accuracy= 88.20000
#
# Fold: 5, Epoch: 19, Mini Batch: 10, Loss= 1124.569214, Training Accuracy= 82.40000
# Fold: 5, Epoch: 19, Mini Batch: 18, Loss= 977.285339, Training Accuracy= 85.90000
#
# Fold: 5, Epoch: 19, Validation Accuracy= 88.05000
#
# Fold: 5, Epoch: 20, Mini Batch: 10, Loss= 1081.147461, Training Accuracy= 82.30000
# Fold: 5, Epoch: 20, Mini Batch: 18, Loss= 1055.363525, Training Accuracy= 83.50000
#
# Fold: 5, Epoch: 20, Validation Accuracy= 88.15000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           861    98   959
# 1           139   902  1041
# All        1000  1000  2000
#
# Fold: 5, Epoch: 21, Mini Batch: 10, Loss= 904.875244, Training Accuracy= 84.90000
# Fold: 5, Epoch: 21, Mini Batch: 18, Loss= 902.279602, Training Accuracy= 83.00000
#
# Fold: 5, Epoch: 21, Validation Accuracy= 87.95000
#
# Fold: 5, Epoch: 22, Mini Batch: 10, Loss= 892.641296, Training Accuracy= 84.90000
# Fold: 5, Epoch: 22, Mini Batch: 18, Loss= 667.799622, Training Accuracy= 85.30000
#
# Fold: 5, Epoch: 22, Validation Accuracy= 88.40000
#
# Fold: 5, Epoch: 23, Mini Batch: 10, Loss= 696.468018, Training Accuracy= 85.60000
# Fold: 5, Epoch: 23, Mini Batch: 18, Loss= 837.865356, Training Accuracy= 83.50000
#
# Fold: 5, Epoch: 23, Validation Accuracy= 88.10000
#
# Fold: 5, Epoch: 24, Mini Batch: 10, Loss= 800.438599, Training Accuracy= 83.30000
# Fold: 5, Epoch: 24, Mini Batch: 18, Loss= 658.053040, Training Accuracy= 86.50000
#
# Fold: 5, Epoch: 24, Validation Accuracy= 87.75000
#
# Fold: 5, Epoch: 25, Mini Batch: 10, Loss= 536.771057, Training Accuracy= 86.50000
# Fold: 5, Epoch: 25, Mini Batch: 18, Loss= 806.188721, Training Accuracy= 82.80000
#
# Fold: 5, Epoch: 25, Validation Accuracy= 87.45000
#
# Fold: 5, Epoch: 26, Mini Batch: 10, Loss= 575.983398, Training Accuracy= 86.20000
# Fold: 5, Epoch: 26, Mini Batch: 18, Loss= 598.891846, Training Accuracy= 82.80000
#
# Fold: 5, Epoch: 26, Validation Accuracy= 87.60000
#
# Fold: 5, Epoch: 27, Mini Batch: 10, Loss= 569.544556, Training Accuracy= 85.10000
# Fold: 5, Epoch: 27, Mini Batch: 18, Loss= 566.104492, Training Accuracy= 85.50000
#
# Fold: 5, Epoch: 27, Validation Accuracy= 87.10000
#
# Fold: 5, Epoch: 28, Mini Batch: 10, Loss= 498.085999, Training Accuracy= 86.00000
# Fold: 5, Epoch: 28, Mini Batch: 18, Loss= 486.653992, Training Accuracy= 87.10000
#
# Fold: 5, Epoch: 28, Validation Accuracy= 87.60000
#
# Fold: 5, Epoch: 29, Mini Batch: 10, Loss= 523.232910, Training Accuracy= 84.60000
# Fold: 5, Epoch: 29, Mini Batch: 18, Loss= 511.312622, Training Accuracy= 85.90000
#
# Fold: 5, Epoch: 29, Validation Accuracy= 87.45000
#
# Fold: 5, Epoch: 30, Mini Batch: 10, Loss= 597.801514, Training Accuracy= 84.90000
# Fold: 5, Epoch: 30, Mini Batch: 18, Loss= 531.875244, Training Accuracy= 85.70000
#
# Fold: 5, Epoch: 30, Validation Accuracy= 87.30000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           859   113   972
# 1           141   887  1028
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.006}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 6, Epoch: 1, Mini Batch: 10, Loss= 23460.580078, Training Accuracy= 74.40000
# Fold: 6, Epoch: 1, Mini Batch: 18, Loss= 14217.018555, Training Accuracy= 77.20000
#
# Fold: 6, Epoch: 1, Validation Accuracy= 85.65000
#
# Fold: 6, Epoch: 2, Mini Batch: 10, Loss= 9872.775391, Training Accuracy= 77.80000
# Fold: 6, Epoch: 2, Mini Batch: 18, Loss= 10737.931641, Training Accuracy= 77.10000
#
# Fold: 6, Epoch: 2, Validation Accuracy= 84.65000
#
# Fold: 6, Epoch: 3, Mini Batch: 10, Loss= 6507.324707, Training Accuracy= 80.00000
# Fold: 6, Epoch: 3, Mini Batch: 18, Loss= 6137.043457, Training Accuracy= 80.40000
#
# Fold: 6, Epoch: 3, Validation Accuracy= 86.40000
#
# Fold: 6, Epoch: 4, Mini Batch: 10, Loss= 4817.653809, Training Accuracy= 82.90000
# Fold: 6, Epoch: 4, Mini Batch: 18, Loss= 5697.149902, Training Accuracy= 81.30000
#
# Fold: 6, Epoch: 4, Validation Accuracy= 86.55000
#
# Fold: 6, Epoch: 5, Mini Batch: 10, Loss= 4434.716797, Training Accuracy= 79.80000
# Fold: 6, Epoch: 5, Mini Batch: 18, Loss= 4661.293457, Training Accuracy= 79.40000
#
# Fold: 6, Epoch: 5, Validation Accuracy= 86.05000
#
# Fold: 6, Epoch: 6, Mini Batch: 10, Loss= 3435.498047, Training Accuracy= 81.70000
# Fold: 6, Epoch: 6, Mini Batch: 18, Loss= 3348.540527, Training Accuracy= 81.80000
#
# Fold: 6, Epoch: 6, Validation Accuracy= 86.55000
#
# Fold: 6, Epoch: 7, Mini Batch: 10, Loss= 3061.300293, Training Accuracy= 80.20000
# Fold: 6, Epoch: 7, Mini Batch: 18, Loss= 3296.918457, Training Accuracy= 81.60000
#
# Fold: 6, Epoch: 7, Validation Accuracy= 86.75000
#
# Fold: 6, Epoch: 8, Mini Batch: 10, Loss= 2714.407715, Training Accuracy= 81.80000
# Fold: 6, Epoch: 8, Mini Batch: 18, Loss= 3014.022217, Training Accuracy= 81.40000
#
# Fold: 6, Epoch: 8, Validation Accuracy= 87.05000
#
# Fold: 6, Epoch: 9, Mini Batch: 10, Loss= 2244.167480, Training Accuracy= 82.20000
# Fold: 6, Epoch: 9, Mini Batch: 18, Loss= 2696.571533, Training Accuracy= 80.30000
#
# Fold: 6, Epoch: 9, Validation Accuracy= 86.60000
#
# Fold: 6, Epoch: 10, Mini Batch: 10, Loss= 2044.309692, Training Accuracy= 83.40000
# Fold: 6, Epoch: 10, Mini Batch: 18, Loss= 2027.659668, Training Accuracy= 81.10000
#
# Fold: 6, Epoch: 10, Validation Accuracy= 86.30000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           851   125   976
# 1           149   875  1024
# All        1000  1000  2000
#
# Fold: 6, Epoch: 11, Mini Batch: 10, Loss= 1706.222046, Training Accuracy= 84.40000
# Fold: 6, Epoch: 11, Mini Batch: 18, Loss= 1988.395630, Training Accuracy= 81.80000
#
# Fold: 6, Epoch: 11, Validation Accuracy= 86.85000
#
# Fold: 6, Epoch: 12, Mini Batch: 10, Loss= 1514.157959, Training Accuracy= 83.30000
# Fold: 6, Epoch: 12, Mini Batch: 18, Loss= 1440.827026, Training Accuracy= 83.10000
#
# Fold: 6, Epoch: 12, Validation Accuracy= 86.20000
#
# Fold: 6, Epoch: 13, Mini Batch: 10, Loss= 1522.660034, Training Accuracy= 83.20000
# Fold: 6, Epoch: 13, Mini Batch: 18, Loss= 1480.530518, Training Accuracy= 82.50000
#
# Fold: 6, Epoch: 13, Validation Accuracy= 86.30000
#
# Fold: 6, Epoch: 14, Mini Batch: 10, Loss= 1476.379517, Training Accuracy= 83.00000
# Fold: 6, Epoch: 14, Mini Batch: 18, Loss= 1225.898926, Training Accuracy= 84.00000
#
# Fold: 6, Epoch: 14, Validation Accuracy= 86.25000
#
# Fold: 6, Epoch: 15, Mini Batch: 10, Loss= 1176.505737, Training Accuracy= 84.40000
# Fold: 6, Epoch: 15, Mini Batch: 18, Loss= 1458.530029, Training Accuracy= 82.80000
#
# Fold: 6, Epoch: 15, Validation Accuracy= 86.40000
#
# Fold: 6, Epoch: 16, Mini Batch: 10, Loss= 1151.517456, Training Accuracy= 82.80000
# Fold: 6, Epoch: 16, Mini Batch: 18, Loss= 1177.806763, Training Accuracy= 82.60000
#
# Fold: 6, Epoch: 16, Validation Accuracy= 86.25000
#
# Fold: 6, Epoch: 17, Mini Batch: 10, Loss= 1084.253906, Training Accuracy= 83.70000
# Fold: 6, Epoch: 17, Mini Batch: 18, Loss= 981.322571, Training Accuracy= 84.30000
#
# Fold: 6, Epoch: 17, Validation Accuracy= 86.05000
#
# Fold: 6, Epoch: 18, Mini Batch: 10, Loss= 905.558472, Training Accuracy= 84.90000
# Fold: 6, Epoch: 18, Mini Batch: 18, Loss= 1100.716675, Training Accuracy= 82.70000
#
# Fold: 6, Epoch: 18, Validation Accuracy= 86.30000
#
# Fold: 6, Epoch: 19, Mini Batch: 10, Loss= 802.635132, Training Accuracy= 83.30000
# Fold: 6, Epoch: 19, Mini Batch: 18, Loss= 842.516174, Training Accuracy= 83.60000
#
# Fold: 6, Epoch: 19, Validation Accuracy= 87.10000
#
# Fold: 6, Epoch: 20, Mini Batch: 10, Loss= 755.106201, Training Accuracy= 86.60000
# Fold: 6, Epoch: 20, Mini Batch: 18, Loss= 786.689514, Training Accuracy= 86.20000
#
# Fold: 6, Epoch: 20, Validation Accuracy= 87.00000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           840   100   940
# 1           160   900  1060
# All        1000  1000  2000
#
# Fold: 6, Epoch: 21, Mini Batch: 10, Loss= 676.666382, Training Accuracy= 85.70000
# Fold: 6, Epoch: 21, Mini Batch: 18, Loss= 736.766174, Training Accuracy= 84.50000
#
# Fold: 6, Epoch: 21, Validation Accuracy= 86.90000
#
# Fold: 6, Epoch: 22, Mini Batch: 10, Loss= 727.611328, Training Accuracy= 83.90000
# Fold: 6, Epoch: 22, Mini Batch: 18, Loss= 647.226257, Training Accuracy= 85.00000
#
# Fold: 6, Epoch: 22, Validation Accuracy= 86.10000
#
# Fold: 6, Epoch: 23, Mini Batch: 10, Loss= 660.505798, Training Accuracy= 84.10000
# Fold: 6, Epoch: 23, Mini Batch: 18, Loss= 646.322266, Training Accuracy= 84.40000
#
# Fold: 6, Epoch: 23, Validation Accuracy= 86.95000
#
# Fold: 6, Epoch: 24, Mini Batch: 10, Loss= 575.242981, Training Accuracy= 86.50000
# Fold: 6, Epoch: 24, Mini Batch: 18, Loss= 528.872009, Training Accuracy= 86.10000
#
# Fold: 6, Epoch: 24, Validation Accuracy= 86.55000
#
# Fold: 6, Epoch: 25, Mini Batch: 10, Loss= 516.541321, Training Accuracy= 85.40000
# Fold: 6, Epoch: 25, Mini Batch: 18, Loss= 589.334045, Training Accuracy= 84.70000
#
# Fold: 6, Epoch: 25, Validation Accuracy= 87.00000
#
# Fold: 6, Epoch: 26, Mini Batch: 10, Loss= 513.960327, Training Accuracy= 84.40000
# Fold: 6, Epoch: 26, Mini Batch: 18, Loss= 550.213989, Training Accuracy= 84.30000
#
# Fold: 6, Epoch: 26, Validation Accuracy= 86.75000
#
# Fold: 6, Epoch: 27, Mini Batch: 10, Loss= 450.127167, Training Accuracy= 85.70000
# Fold: 6, Epoch: 27, Mini Batch: 18, Loss= 444.553986, Training Accuracy= 85.20000
#
# Fold: 6, Epoch: 27, Validation Accuracy= 86.80000
#
# Fold: 6, Epoch: 28, Mini Batch: 10, Loss= 398.746826, Training Accuracy= 86.40000
# Fold: 6, Epoch: 28, Mini Batch: 18, Loss= 405.266449, Training Accuracy= 86.80000
#
# Fold: 6, Epoch: 28, Validation Accuracy= 86.10000
#
# Fold: 6, Epoch: 29, Mini Batch: 10, Loss= 491.855255, Training Accuracy= 85.40000
# Fold: 6, Epoch: 29, Mini Batch: 18, Loss= 403.630890, Training Accuracy= 86.80000
#
# Fold: 6, Epoch: 29, Validation Accuracy= 86.10000
#
# Fold: 6, Epoch: 30, Mini Batch: 10, Loss= 345.255127, Training Accuracy= 87.00000
# Fold: 6, Epoch: 30, Mini Batch: 18, Loss= 411.777802, Training Accuracy= 86.30000
#
# Fold: 6, Epoch: 30, Validation Accuracy= 86.30000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           841   115   956
# 1           159   885  1044
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.006}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 7, Epoch: 1, Mini Batch: 10, Loss= 21656.847656, Training Accuracy= 73.50000
# Fold: 7, Epoch: 1, Mini Batch: 18, Loss= 16839.146484, Training Accuracy= 76.10000
#
# Fold: 7, Epoch: 1, Validation Accuracy= 83.50000
#
# Fold: 7, Epoch: 2, Mini Batch: 10, Loss= 12311.708008, Training Accuracy= 77.90000
# Fold: 7, Epoch: 2, Mini Batch: 18, Loss= 10083.305664, Training Accuracy= 78.30000
#
# Fold: 7, Epoch: 2, Validation Accuracy= 86.75000
#
# Fold: 7, Epoch: 3, Mini Batch: 10, Loss= 6732.580078, Training Accuracy= 79.20000
# Fold: 7, Epoch: 3, Mini Batch: 18, Loss= 6770.006836, Training Accuracy= 80.70000
#
# Fold: 7, Epoch: 3, Validation Accuracy= 86.65000
#
# Fold: 7, Epoch: 4, Mini Batch: 10, Loss= 5778.987305, Training Accuracy= 81.40000
# Fold: 7, Epoch: 4, Mini Batch: 18, Loss= 5546.562988, Training Accuracy= 81.80000
#
# Fold: 7, Epoch: 4, Validation Accuracy= 87.25000
#
# Fold: 7, Epoch: 5, Mini Batch: 10, Loss= 5642.791016, Training Accuracy= 80.00000
# Fold: 7, Epoch: 5, Mini Batch: 18, Loss= 4605.766602, Training Accuracy= 81.70000
#
# Fold: 7, Epoch: 5, Validation Accuracy= 87.45000
#
# Fold: 7, Epoch: 6, Mini Batch: 10, Loss= 3968.666016, Training Accuracy= 81.80000
# Fold: 7, Epoch: 6, Mini Batch: 18, Loss= 3859.867432, Training Accuracy= 80.70000
#
# Fold: 7, Epoch: 6, Validation Accuracy= 87.25000
#
# Fold: 7, Epoch: 7, Mini Batch: 10, Loss= 3385.014648, Training Accuracy= 80.90000
# Fold: 7, Epoch: 7, Mini Batch: 18, Loss= 3314.712402, Training Accuracy= 82.00000
#
# Fold: 7, Epoch: 7, Validation Accuracy= 87.60000
#
# Fold: 7, Epoch: 8, Mini Batch: 10, Loss= 2764.219482, Training Accuracy= 82.50000
# Fold: 7, Epoch: 8, Mini Batch: 18, Loss= 3256.968994, Training Accuracy= 82.70000
#
# Fold: 7, Epoch: 8, Validation Accuracy= 87.45000
#
# Fold: 7, Epoch: 9, Mini Batch: 10, Loss= 2345.201904, Training Accuracy= 83.30000
# Fold: 7, Epoch: 9, Mini Batch: 18, Loss= 2771.499756, Training Accuracy= 82.10000
#
# Fold: 7, Epoch: 9, Validation Accuracy= 87.35000
#
# ...
#
# Fold: 8, Epoch: 28, Validation Accuracy= 86.65000
#
# Fold: 8, Epoch: 29, Mini Batch: 10, Loss= 427.338257, Training Accuracy= 87.10000
# Fold: 8, Epoch: 29, Mini Batch: 18, Loss= 469.620270, Training Accuracy= 85.00000
#
# Fold: 8, Epoch: 29, Validation Accuracy= 86.55000
#
# Fold: 8, Epoch: 30, Mini Batch: 10, Loss= 356.457062, Training Accuracy= 87.30000
# Fold: 8, Epoch: 30, Mini Batch: 18, Loss= 402.917938, Training Accuracy= 87.20000
#
# Fold: 8, Epoch: 30, Validation Accuracy= 86.75000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           847   112   959
# 1           153   888  1041
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.006}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 9, Epoch: 1, Mini Batch: 10, Loss= 21016.525391, Training Accuracy= 73.50000
# Fold: 9, Epoch: 1, Mini Batch: 18, Loss= 14075.026367, Training Accuracy= 78.60000
#
# Fold: 9, Epoch: 1, Validation Accuracy= 85.00000
#
# Fold: 9, Epoch: 2, Mini Batch: 10, Loss= 11237.131836, Training Accuracy= 78.60000
# Fold: 9, Epoch: 2, Mini Batch: 18, Loss= 9195.841797, Training Accuracy= 78.10000
#
# Fold: 9, Epoch: 2, Validation Accuracy= 85.75000
#
# Fold: 9, Epoch: 3, Mini Batch: 10, Loss= 7194.754883, Training Accuracy= 79.00000
# Fold: 9, Epoch: 3, Mini Batch: 18, Loss= 7200.008789, Training Accuracy= 78.00000
#
# Fold: 9, Epoch: 3, Validation Accuracy= 86.50000
#
# Fold: 9, Epoch: 4, Mini Batch: 10, Loss= 5115.970703, Training Accuracy= 81.80000
# Fold: 9, Epoch: 4, Mini Batch: 18, Loss= 5282.351074, Training Accuracy= 80.50000
#
# Fold: 9, Epoch: 4, Validation Accuracy= 86.75000
#
# Fold: 9, Epoch: 5, Mini Batch: 10, Loss= 4435.892090, Training Accuracy= 80.90000
# Fold: 9, Epoch: 5, Mini Batch: 18, Loss= 4714.213867, Training Accuracy= 80.60000
#
# Fold: 9, Epoch: 5, Validation Accuracy= 86.20000
#
# Fold: 9, Epoch: 6, Mini Batch: 10, Loss= 4077.499756, Training Accuracy= 81.60000
# Fold: 9, Epoch: 6, Mini Batch: 18, Loss= 4249.872559, Training Accuracy= 80.60000
#
# Fold: 9, Epoch: 6, Validation Accuracy= 86.25000
#
# Fold: 9, Epoch: 7, Mini Batch: 10, Loss= 3347.607422, Training Accuracy= 81.20000
# Fold: 9, Epoch: 7, Mini Batch: 18, Loss= 3673.216797, Training Accuracy= 80.20000
#
# Fold: 9, Epoch: 7, Validation Accuracy= 86.20000
#
# Fold: 9, Epoch: 8, Mini Batch: 10, Loss= 3152.246338, Training Accuracy= 81.80000
# Fold: 9, Epoch: 8, Mini Batch: 18, Loss= 3217.999512, Training Accuracy= 81.00000
#
# Fold: 9, Epoch: 8, Validation Accuracy= 86.25000
#
# Fold: 9, Epoch: 9, Mini Batch: 10, Loss= 2206.720459, Training Accuracy= 83.20000
# Fold: 9, Epoch: 9, Mini Batch: 18, Loss= 3092.360596, Training Accuracy= 80.70000
#
# Fold: 9, Epoch: 9, Validation Accuracy= 86.80000
#
# Fold: 9, Epoch: 10, Mini Batch: 10, Loss= 2232.451904, Training Accuracy= 83.40000
# Fold: 9, Epoch: 10, Mini Batch: 18, Loss= 2235.877441, Training Accuracy= 83.20000
#
# Fold: 9, Epoch: 10, Validation Accuracy= 86.65000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           838   105   943
# 1           162   895  1057
# All        1000  1000  2000
#
# Fold: 9, Epoch: 11, Mini Batch: 10, Loss= 1678.897461, Training Accuracy= 84.20000
# Fold: 9, Epoch: 11, Mini Batch: 18, Loss= 2264.043945, Training Accuracy= 80.70000
#
# Fold: 9, Epoch: 11, Validation Accuracy= 86.55000
#
# Fold: 9, Epoch: 12, Mini Batch: 10, Loss= 1749.967041, Training Accuracy= 82.70000
# Fold: 9, Epoch: 12, Mini Batch: 18, Loss= 2108.822510, Training Accuracy= 80.20000
#
# Fold: 9, Epoch: 12, Validation Accuracy= 86.05000
#
# Fold: 9, Epoch: 13, Mini Batch: 10, Loss= 1413.833496, Training Accuracy= 84.30000
# Fold: 9, Epoch: 13, Mini Batch: 18, Loss= 1867.783325, Training Accuracy= 83.20000
#
# Fold: 9, Epoch: 13, Validation Accuracy= 86.10000
#
# Fold: 9, Epoch: 14, Mini Batch: 10, Loss= 1506.169922, Training Accuracy= 83.50000
# Fold: 9, Epoch: 14, Mini Batch: 18, Loss= 1445.077393, Training Accuracy= 82.90000
#
# Fold: 9, Epoch: 14, Validation Accuracy= 85.90000
#
# Fold: 9, Epoch: 15, Mini Batch: 10, Loss= 1663.025757, Training Accuracy= 81.20000
# Fold: 9, Epoch: 15, Mini Batch: 18, Loss= 1350.325073, Training Accuracy= 83.20000
#
# Fold: 9, Epoch: 15, Validation Accuracy= 86.75000
#
# Fold: 9, Epoch: 16, Mini Batch: 10, Loss= 1321.470459, Training Accuracy= 83.40000
# Fold: 9, Epoch: 16, Mini Batch: 18, Loss= 1195.319702, Training Accuracy= 85.10000
#
# Fold: 9, Epoch: 16, Validation Accuracy= 86.20000
#
# Fold: 9, Epoch: 17, Mini Batch: 10, Loss= 1249.366211, Training Accuracy= 84.30000
# Fold: 9, Epoch: 17, Mini Batch: 18, Loss= 1280.295532, Training Accuracy= 83.80000
#
# Fold: 9, Epoch: 17, Validation Accuracy= 87.20000
#
# Fold: 9, Epoch: 18, Mini Batch: 10, Loss= 1002.012146, Training Accuracy= 84.50000
# Fold: 9, Epoch: 18, Mini Batch: 18, Loss= 1033.272217, Training Accuracy= 84.80000
#
# Fold: 9, Epoch: 18, Validation Accuracy= 86.90000
#
# Fold: 9, Epoch: 19, Mini Batch: 10, Loss= 937.418701, Training Accuracy= 83.30000
# Fold: 9, Epoch: 19, Mini Batch: 18, Loss= 965.491516, Training Accuracy= 85.70000
#
# Fold: 9, Epoch: 19, Validation Accuracy= 86.30000
#
# Fold: 9, Epoch: 20, Mini Batch: 10, Loss= 673.493896, Training Accuracy= 87.30000
# Fold: 9, Epoch: 20, Mini Batch: 18, Loss= 945.803772, Training Accuracy= 82.70000
#
# Fold: 9, Epoch: 20, Validation Accuracy= 85.60000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           818   106   924
# 1           182   894  1076
# All        1000  1000  2000
#
# Fold: 9, Epoch: 21, Mini Batch: 10, Loss= 874.331787, Training Accuracy= 83.70000
# Fold: 9, Epoch: 21, Mini Batch: 18, Loss= 703.150146, Training Accuracy= 86.00000
#
# Fold: 9, Epoch: 21, Validation Accuracy= 85.50000
#
# Fold: 9, Epoch: 22, Mini Batch: 10, Loss= 694.865845, Training Accuracy= 84.80000
# Fold: 9, Epoch: 22, Mini Batch: 18, Loss= 705.191528, Training Accuracy= 84.10000
#
# Fold: 9, Epoch: 22, Validation Accuracy= 85.95000
#
# Fold: 9, Epoch: 23, Mini Batch: 10, Loss= 729.889099, Training Accuracy= 85.50000
# Fold: 9, Epoch: 23, Mini Batch: 18, Loss= 680.560913, Training Accuracy= 84.10000
#
# Fold: 9, Epoch: 23, Validation Accuracy= 86.80000
#
# Fold: 9, Epoch: 24, Mini Batch: 10, Loss= 705.133972, Training Accuracy= 84.80000
# Fold: 9, Epoch: 24, Mini Batch: 18, Loss= 635.667175, Training Accuracy= 85.10000
#
# Fold: 9, Epoch: 24, Validation Accuracy= 86.25000
#
# Fold: 9, Epoch: 25, Mini Batch: 10, Loss= 469.347473, Training Accuracy= 86.70000
# Fold: 9, Epoch: 25, Mini Batch: 18, Loss= 554.092651, Training Accuracy= 85.90000
#
# Fold: 9, Epoch: 25, Validation Accuracy= 86.00000
#
# Fold: 9, Epoch: 26, Mini Batch: 10, Loss= 559.451416, Training Accuracy= 87.10000
# Fold: 9, Epoch: 26, Mini Batch: 18, Loss= 522.180054, Training Accuracy= 86.80000
#
# Fold: 9, Epoch: 26, Validation Accuracy= 85.90000
#
# Fold: 9, Epoch: 27, Mini Batch: 10, Loss= 504.537262, Training Accuracy= 86.20000
# Fold: 9, Epoch: 27, Mini Batch: 18, Loss= 525.566223, Training Accuracy= 85.40000
#
# Fold: 9, Epoch: 27, Validation Accuracy= 86.85000
#
# Fold: 9, Epoch: 28, Mini Batch: 10, Loss= 373.217621, Training Accuracy= 87.60000
# Fold: 9, Epoch: 28, Mini Batch: 18, Loss= 470.743988, Training Accuracy= 85.80000
#
# Fold: 9, Epoch: 28, Validation Accuracy= 86.20000
#
# Fold: 9, Epoch: 29, Mini Batch: 10, Loss= 371.557709, Training Accuracy= 87.20000
# Fold: 9, Epoch: 29, Mini Batch: 18, Loss= 502.342438, Training Accuracy= 84.50000
#
# Fold: 9, Epoch: 29, Validation Accuracy= 86.30000
#
# Fold: 9, Epoch: 30, Mini Batch: 10, Loss= 419.545807, Training Accuracy= 86.50000
# Fold: 9, Epoch: 30, Mini Batch: 18, Loss= 480.028442, Training Accuracy= 85.10000
#
# Fold: 9, Epoch: 30, Validation Accuracy= 86.50000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           831   101   932
# 1           169   899  1068
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.006}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 10, Epoch: 1, Mini Batch: 10, Loss= 19385.007812, Training Accuracy= 75.20000
# Fold: 10, Epoch: 1, Mini Batch: 18, Loss= 14680.416016, Training Accuracy= 77.10000
#
# Fold: 10, Epoch: 1, Validation Accuracy= 83.25000
#
# Fold: 10, Epoch: 2, Mini Batch: 10, Loss= 10341.757812, Training Accuracy= 79.30000
# Fold: 10, Epoch: 2, Mini Batch: 18, Loss= 8557.188477, Training Accuracy= 77.60000
#
# Fold: 10, Epoch: 2, Validation Accuracy= 86.25000
#
# Fold: 10, Epoch: 3, Mini Batch: 10, Loss= 7687.706543, Training Accuracy= 77.70000
# Fold: 10, Epoch: 3, Mini Batch: 18, Loss= 6134.349121, Training Accuracy= 80.50000
#
# Fold: 10, Epoch: 3, Validation Accuracy= 85.95000
#
# Fold: 10, Epoch: 4, Mini Batch: 10, Loss= 5885.818848, Training Accuracy= 80.90000
# Fold: 10, Epoch: 4, Mini Batch: 18, Loss= 4576.851562, Training Accuracy= 80.80000
#
# Fold: 10, Epoch: 4, Validation Accuracy= 86.70000
#
# Fold: 10, Epoch: 5, Mini Batch: 10, Loss= 4137.352539, Training Accuracy= 81.70000
# Fold: 10, Epoch: 5, Mini Batch: 18, Loss= 4922.539551, Training Accuracy= 78.80000
#
# Fold: 10, Epoch: 5, Validation Accuracy= 86.60000
#
# Fold: 10, Epoch: 6, Mini Batch: 10, Loss= 4361.494141, Training Accuracy= 80.20000
# Fold: 10, Epoch: 6, Mini Batch: 18, Loss= 3950.627197, Training Accuracy= 80.90000
#
# Fold: 10, Epoch: 6, Validation Accuracy= 86.40000
#
# Fold: 10, Epoch: 7, Mini Batch: 10, Loss= 3653.811279, Training Accuracy= 83.00000
# Fold: 10, Epoch: 7, Mini Batch: 18, Loss= 3416.777100, Training Accuracy= 81.20000
#
# Fold: 10, Epoch: 7, Validation Accuracy= 87.15000
#
# Fold: 10, Epoch: 8, Mini Batch: 10, Loss= 3004.956299, Training Accuracy= 81.90000
# Fold: 10, Epoch: 8, Mini Batch: 18, Loss= 2590.593994, Training Accuracy= 81.60000
#
# Fold: 10, Epoch: 8, Validation Accuracy= 87.25000
#
# Fold: 10, Epoch: 9, Mini Batch: 10, Loss= 2935.954590, Training Accuracy= 81.80000
# Fold: 10, Epoch: 9, Mini Batch: 18, Loss= 2320.121582, Training Accuracy= 82.60000
#
# Fold: 10, Epoch: 9, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 10, Mini Batch: 10, Loss= 2492.907959, Training Accuracy= 82.30000
# Fold: 10, Epoch: 10, Mini Batch: 18, Loss= 2166.268555, Training Accuracy= 82.10000
#
# Fold: 10, Epoch: 10, Validation Accuracy= 87.20000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           861   117   978
# 1           139   883  1022
# All        1000  1000  2000
#
# Fold: 10, Epoch: 11, Mini Batch: 10, Loss= 2144.541016, Training Accuracy= 82.80000
# Fold: 10, Epoch: 11, Mini Batch: 18, Loss= 1793.576782, Training Accuracy= 85.20000
#
# Fold: 10, Epoch: 11, Validation Accuracy= 87.50000
#
# Fold: 10, Epoch: 12, Mini Batch: 10, Loss= 2013.895386, Training Accuracy= 81.70000
# Fold: 10, Epoch: 12, Mini Batch: 18, Loss= 1930.048950, Training Accuracy= 81.30000
#
# Fold: 10, Epoch: 12, Validation Accuracy= 87.25000
#
# Fold: 10, Epoch: 13, Mini Batch: 10, Loss= 1783.224365, Training Accuracy= 83.60000
# Fold: 10, Epoch: 13, Mini Batch: 18, Loss= 1677.249878, Training Accuracy= 83.80000
#
# Fold: 10, Epoch: 13, Validation Accuracy= 87.10000
#
# Fold: 10, Epoch: 14, Mini Batch: 10, Loss= 1452.508789, Training Accuracy= 83.80000
# Fold: 10, Epoch: 14, Mini Batch: 18, Loss= 1466.426270, Training Accuracy= 84.00000
#
# Fold: 10, Epoch: 14, Validation Accuracy= 87.35000
#
# Fold: 10, Epoch: 15, Mini Batch: 10, Loss= 1460.084351, Training Accuracy= 84.00000
# Fold: 10, Epoch: 15, Mini Batch: 18, Loss= 1172.704224, Training Accuracy= 83.90000
#
# Fold: 10, Epoch: 15, Validation Accuracy= 86.95000
#
# Fold: 10, Epoch: 16, Mini Batch: 10, Loss= 1259.513428, Training Accuracy= 84.00000
# Fold: 10, Epoch: 16, Mini Batch: 18, Loss= 1100.190308, Training Accuracy= 85.80000
#
# Fold: 10, Epoch: 16, Validation Accuracy= 86.75000
#
# Fold: 10, Epoch: 17, Mini Batch: 10, Loss= 1195.343872, Training Accuracy= 83.30000
# Fold: 10, Epoch: 17, Mini Batch: 18, Loss= 1142.906494, Training Accuracy= 83.20000
#
# Fold: 10, Epoch: 17, Validation Accuracy= 86.70000
#
# Fold: 10, Epoch: 18, Mini Batch: 10, Loss= 1077.822021, Training Accuracy= 84.40000
# Fold: 10, Epoch: 18, Mini Batch: 18, Loss= 1124.396729, Training Accuracy= 83.00000
#
# Fold: 10, Epoch: 18, Validation Accuracy= 86.45000
#
# Fold: 10, Epoch: 19, Mini Batch: 10, Loss= 926.511108, Training Accuracy= 85.80000
# Fold: 10, Epoch: 19, Mini Batch: 18, Loss= 859.872986, Training Accuracy= 85.60000
#
# Fold: 10, Epoch: 19, Validation Accuracy= 86.55000
#
# Fold: 10, Epoch: 20, Mini Batch: 10, Loss= 932.861328, Training Accuracy= 84.40000
# Fold: 10, Epoch: 20, Mini Batch: 18, Loss= 783.910217, Training Accuracy= 86.10000
#
# Fold: 10, Epoch: 20, Validation Accuracy= 86.85000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           846   109   955
# 1           154   891  1045
# All        1000  1000  2000
#
# Fold: 10, Epoch: 21, Mini Batch: 10, Loss= 818.858643, Training Accuracy= 86.30000
# Fold: 10, Epoch: 21, Mini Batch: 18, Loss= 824.525269, Training Accuracy= 84.90000
#
# Fold: 10, Epoch: 21, Validation Accuracy= 86.70000
#
# Fold: 10, Epoch: 22, Mini Batch: 10, Loss= 922.058044, Training Accuracy= 83.30000
# Fold: 10, Epoch: 22, Mini Batch: 18, Loss= 741.505249, Training Accuracy= 84.60000
#
# Fold: 10, Epoch: 22, Validation Accuracy= 86.65000
#
# Fold: 10, Epoch: 23, Mini Batch: 10, Loss= 833.901062, Training Accuracy= 83.50000
# Fold: 10, Epoch: 23, Mini Batch: 18, Loss= 581.652588, Training Accuracy= 85.10000
#
# Fold: 10, Epoch: 23, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 24, Mini Batch: 10, Loss= 782.221130, Training Accuracy= 85.40000
# Fold: 10, Epoch: 24, Mini Batch: 18, Loss= 660.225098, Training Accuracy= 85.30000
#
# Fold: 10, Epoch: 24, Validation Accuracy= 86.70000
#
# Fold: 10, Epoch: 25, Mini Batch: 10, Loss= 654.758362, Training Accuracy= 84.70000
# Fold: 10, Epoch: 25, Mini Batch: 18, Loss= 656.611816, Training Accuracy= 82.90000
#
# Fold: 10, Epoch: 25, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 26, Mini Batch: 10, Loss= 597.056519, Training Accuracy= 85.40000
# Fold: 10, Epoch: 26, Mini Batch: 18, Loss= 482.926910, Training Accuracy= 85.40000
#
# Fold: 10, Epoch: 26, Validation Accuracy= 87.40000
#
# Fold: 10, Epoch: 27, Mini Batch: 10, Loss= 514.558044, Training Accuracy= 87.10000
# Fold: 10, Epoch: 27, Mini Batch: 18, Loss= 556.293274, Training Accuracy= 85.30000
#
# Fold: 10, Epoch: 27, Validation Accuracy= 87.30000
#
# Fold: 10, Epoch: 28, Mini Batch: 10, Loss= 436.214996, Training Accuracy= 85.60000
# Fold: 10, Epoch: 28, Mini Batch: 18, Loss= 480.549347, Training Accuracy= 83.20000
#
# Fold: 10, Epoch: 28, Validation Accuracy= 86.85000
#
# Fold: 10, Epoch: 29, Mini Batch: 10, Loss= 448.544128, Training Accuracy= 86.00000
# Fold: 10, Epoch: 29, Mini Batch: 18, Loss= 475.249939, Training Accuracy= 84.90000
#
# Fold: 10, Epoch: 29, Validation Accuracy= 86.10000
#
# Fold: 10, Epoch: 30, Mini Batch: 10, Loss= 428.914062, Training Accuracy= 86.70000
# Fold: 10, Epoch: 30, Mini Batch: 18, Loss= 441.918732, Training Accuracy= 84.30000
#
# Fold: 10, Epoch: 30, Validation Accuracy= 86.45000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           835   106   941
# 1           165   894  1059
# All        1000  1000  2000
#
# The mean Valid Accuracy is :  87.005

# %%
rows = 2
columns = 5
vizualize(vaccPerEpochPerFold, taccPerEpochPerFold, meanValidAcc=meanValidAcc, rows=rows, columns=columns, figsize=(5*columns, 5*rows))

# %%
featureDIR = HOGp4batchAug_dir
params = dict(imageSize = 32,
              numLabels = 2,
              
              # Network params
              numHidden1 = 1024,
              numHidden2 = 1280,
              numHidden3 = 1280, 

              # Batch Variables
              numFolds = 10,
              epochs = 30,
              batchSize = 1000,
             
              # Optimization Params
              keepProb = dict(hid1=0.75, hid2=0.5, hid3=0.5),
              optimizerParam = dict(optimizer='ADAM', learning_rate=0.003)
             )

# optimizer = tf.train.AdamOptimizer(learning_rate=0.008).minimize(lossCE)

(out, meanValidAcc, lossPerEpochPerFold, taccPerEpochPerFold, vaccPerEpochPerFold) = SessionExec(featureDIR, params).execute() 

print ('The mean Valid Accuracy is : ', meanValidAcc)


# To'dos:
# 1. Have to lower the weight 
# 2. Have to use L1 norm with dropout
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.003}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 1, Epoch: 1, Mini Batch: 10, Loss= 27663.427734, Training Accuracy= 69.90000
# Fold: 1, Epoch: 1, Mini Batch: 18, Loss= 19493.794922, Training Accuracy= 76.20000
#
# Fold: 1, Epoch: 1, Validation Accuracy= 82.70000
#
# Fold: 1, Epoch: 2, Mini Batch: 10, Loss= 14519.716797, Training Accuracy= 76.80000
# Fold: 1, Epoch: 2, Mini Batch: 18, Loss= 14975.638672, Training Accuracy= 76.40000
#
# Fold: 1, Epoch: 2, Validation Accuracy= 87.05000
#
# Fold: 1, Epoch: 3, Mini Batch: 10, Loss= 11002.881836, Training Accuracy= 76.60000
# Fold: 1, Epoch: 3, Mini Batch: 18, Loss= 9537.255859, Training Accuracy= 79.70000
#
# Fold: 1, Epoch: 3, Validation Accuracy= 86.95000
#
# Fold: 1, Epoch: 4, Mini Batch: 10, Loss= 8228.356445, Training Accuracy= 78.30000
# Fold: 1, Epoch: 4, Mini Batch: 18, Loss= 7973.774414, Training Accuracy= 80.20000
#
# Fold: 1, Epoch: 4, Validation Accuracy= 87.30000
#
# Fold: 1, Epoch: 5, Mini Batch: 10, Loss= 8035.224121, Training Accuracy= 78.20000
# Fold: 1, Epoch: 5, Mini Batch: 18, Loss= 6673.371094, Training Accuracy= 80.90000
#
# Fold: 1, Epoch: 5, Validation Accuracy= 87.05000
#
# Fold: 1, Epoch: 6, Mini Batch: 10, Loss= 6990.780762, Training Accuracy= 77.10000
# Fold: 1, Epoch: 6, Mini Batch: 18, Loss= 6227.804199, Training Accuracy= 79.90000
#
# Fold: 1, Epoch: 6, Validation Accuracy= 87.65000
#
# Fold: 1, Epoch: 7, Mini Batch: 10, Loss= 6382.449219, Training Accuracy= 77.10000
# Fold: 1, Epoch: 7, Mini Batch: 18, Loss= 6143.590820, Training Accuracy= 80.40000
#
# Fold: 1, Epoch: 7, Validation Accuracy= 86.75000
#
# Fold: 1, Epoch: 8, Mini Batch: 10, Loss= 4279.594238, Training Accuracy= 80.40000
# Fold: 1, Epoch: 8, Mini Batch: 18, Loss= 4912.386230, Training Accuracy= 82.60000
#
# Fold: 1, Epoch: 8, Validation Accuracy= 87.75000
#
# Fold: 1, Epoch: 9, Mini Batch: 10, Loss= 4433.433105, Training Accuracy= 80.40000
# Fold: 1, Epoch: 9, Mini Batch: 18, Loss= 4857.338867, Training Accuracy= 80.60000
#
# Fold: 1, Epoch: 9, Validation Accuracy= 87.90000
#
# Fold: 1, Epoch: 10, Mini Batch: 10, Loss= 3946.606934, Training Accuracy= 80.20000
# Fold: 1, Epoch: 10, Mini Batch: 18, Loss= 3976.301270, Training Accuracy= 80.90000
#
# Fold: 1, Epoch: 10, Validation Accuracy= 87.90000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           850    92   942
# 1           150   908  1058
# All        1000  1000  2000
#
# Fold: 1, Epoch: 11, Mini Batch: 10, Loss= 3852.835693, Training Accuracy= 80.10000
# Fold: 1, Epoch: 11, Mini Batch: 18, Loss= 3833.702881, Training Accuracy= 80.40000
#
# Fold: 1, Epoch: 11, Validation Accuracy= 87.90000
#
# Fold: 1, Epoch: 12, Mini Batch: 10, Loss= 3312.981445, Training Accuracy= 80.80000
# Fold: 1, Epoch: 12, Mini Batch: 18, Loss= 3565.672119, Training Accuracy= 78.50000
#
# Fold: 1, Epoch: 12, Validation Accuracy= 87.80000
#
# Fold: 1, Epoch: 13, Mini Batch: 10, Loss= 3103.417969, Training Accuracy= 80.20000
# Fold: 1, Epoch: 13, Mini Batch: 18, Loss= 3039.780518, Training Accuracy= 80.70000
#
# Fold: 1, Epoch: 13, Validation Accuracy= 87.75000
#
# Fold: 1, Epoch: 14, Mini Batch: 10, Loss= 3173.830078, Training Accuracy= 80.60000
# Fold: 1, Epoch: 14, Mini Batch: 18, Loss= 2984.887207, Training Accuracy= 82.60000
#
# Fold: 1, Epoch: 14, Validation Accuracy= 87.60000
#
# Fold: 1, Epoch: 15, Mini Batch: 10, Loss= 2508.091553, Training Accuracy= 83.40000
# Fold: 1, Epoch: 15, Mini Batch: 18, Loss= 2383.173096, Training Accuracy= 82.60000
#
# Fold: 1, Epoch: 15, Validation Accuracy= 87.75000
#
# Fold: 1, Epoch: 16, Mini Batch: 10, Loss= 2445.866455, Training Accuracy= 81.70000
# Fold: 1, Epoch: 16, Mini Batch: 18, Loss= 2394.747070, Training Accuracy= 81.80000
#
# Fold: 1, Epoch: 16, Validation Accuracy= 87.80000
#
# Fold: 1, Epoch: 17, Mini Batch: 10, Loss= 2293.517578, Training Accuracy= 82.20000
# Fold: 1, Epoch: 17, Mini Batch: 18, Loss= 2396.586426, Training Accuracy= 82.00000
#
# Fold: 1, Epoch: 17, Validation Accuracy= 87.70000
#
# Fold: 1, Epoch: 18, Mini Batch: 10, Loss= 2329.370605, Training Accuracy= 81.30000
# Fold: 1, Epoch: 18, Mini Batch: 18, Loss= 2198.412354, Training Accuracy= 81.20000
#
# Fold: 1, Epoch: 18, Validation Accuracy= 88.10000
#
# Fold: 1, Epoch: 19, Mini Batch: 10, Loss= 1912.437012, Training Accuracy= 82.20000
# Fold: 1, Epoch: 19, Mini Batch: 18, Loss= 1908.002808, Training Accuracy= 83.20000
#
# Fold: 1, Epoch: 19, Validation Accuracy= 88.30000
#
# Fold: 1, Epoch: 20, Mini Batch: 10, Loss= 1774.330933, Training Accuracy= 82.60000
# Fold: 1, Epoch: 20, Mini Batch: 18, Loss= 1638.904541, Training Accuracy= 84.30000
#
# Fold: 1, Epoch: 20, Validation Accuracy= 88.55000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           857    86   943
# 1           143   914  1057
# All        1000  1000  2000
#
# Fold: 1, Epoch: 21, Mini Batch: 10, Loss= 1981.618530, Training Accuracy= 81.90000
# Fold: 1, Epoch: 21, Mini Batch: 18, Loss= 1902.420410, Training Accuracy= 83.10000
#
# Fold: 1, Epoch: 21, Validation Accuracy= 88.75000
#
# Fold: 1, Epoch: 22, Mini Batch: 10, Loss= 1696.172974, Training Accuracy= 82.50000
# Fold: 1, Epoch: 22, Mini Batch: 18, Loss= 1629.461548, Training Accuracy= 83.10000
#
# Fold: 1, Epoch: 22, Validation Accuracy= 88.70000
#
# Fold: 1, Epoch: 23, Mini Batch: 10, Loss= 1615.796021, Training Accuracy= 82.70000
# Fold: 1, Epoch: 23, Mini Batch: 18, Loss= 1511.447021, Training Accuracy= 81.70000
#
# Fold: 1, Epoch: 23, Validation Accuracy= 88.15000
#
# Fold: 1, Epoch: 24, Mini Batch: 10, Loss= 1581.176758, Training Accuracy= 82.20000
# Fold: 1, Epoch: 24, Mini Batch: 18, Loss= 1756.820190, Training Accuracy= 81.50000
#
# Fold: 1, Epoch: 24, Validation Accuracy= 88.40000
#
# Fold: 1, Epoch: 25, Mini Batch: 10, Loss= 1545.918823, Training Accuracy= 81.50000
# Fold: 1, Epoch: 25, Mini Batch: 18, Loss= 1316.921265, Training Accuracy= 83.60000
#
# Fold: 1, Epoch: 25, Validation Accuracy= 87.70000
#
# Fold: 1, Epoch: 26, Mini Batch: 10, Loss= 1244.563110, Training Accuracy= 82.40000
# Fold: 1, Epoch: 26, Mini Batch: 18, Loss= 1460.098145, Training Accuracy= 83.80000
#
# Fold: 1, Epoch: 26, Validation Accuracy= 88.30000
#
# Fold: 1, Epoch: 27, Mini Batch: 10, Loss= 1115.174316, Training Accuracy= 84.10000
# Fold: 1, Epoch: 27, Mini Batch: 18, Loss= 999.835999, Training Accuracy= 84.20000
#
# Fold: 1, Epoch: 27, Validation Accuracy= 88.45000
#
# Fold: 1, Epoch: 28, Mini Batch: 10, Loss= 1263.457275, Training Accuracy= 84.30000
# Fold: 1, Epoch: 28, Mini Batch: 18, Loss= 1345.165649, Training Accuracy= 83.30000
#
# Fold: 1, Epoch: 28, Validation Accuracy= 88.50000
#
# Fold: 1, Epoch: 29, Mini Batch: 10, Loss= 1006.218140, Training Accuracy= 84.70000
# Fold: 1, Epoch: 29, Mini Batch: 18, Loss= 1064.282715, Training Accuracy= 82.30000
#
# Fold: 1, Epoch: 29, Validation Accuracy= 87.90000
#
# Fold: 1, Epoch: 30, Mini Batch: 10, Loss= 1073.779053, Training Accuracy= 82.40000
# Fold: 1, Epoch: 30, Mini Batch: 18, Loss= 933.256775, Training Accuracy= 83.40000
#
# Fold: 1, Epoch: 30, Validation Accuracy= 88.55000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           867    96   963
# 1           133   904  1037
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.003}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 2, Epoch: 1, Mini Batch: 10, Loss= 25302.640625, Training Accuracy= 70.90000
# Fold: 2, Epoch: 1, Mini Batch: 18, Loss= 20266.679688, Training Accuracy= 77.20000
#
# Fold: 2, Epoch: 1, Validation Accuracy= 82.90000
#
# Fold: 2, Epoch: 2, Mini Batch: 10, Loss= 14469.212891, Training Accuracy= 78.50000
# Fold: 2, Epoch: 2, Mini Batch: 18, Loss= 13538.547852, Training Accuracy= 78.20000
#
# Fold: 2, Epoch: 2, Validation Accuracy= 85.50000
#
# Fold: 2, Epoch: 3, Mini Batch: 10, Loss= 11367.441406, Training Accuracy= 79.20000
# Fold: 2, Epoch: 3, Mini Batch: 18, Loss= 10361.872070, Training Accuracy= 78.70000
#
# Fold: 2, Epoch: 3, Validation Accuracy= 85.75000
#
# Fold: 2, Epoch: 4, Mini Batch: 10, Loss= 8888.492188, Training Accuracy= 78.70000
# Fold: 2, Epoch: 4, Mini Batch: 18, Loss= 8665.090820, Training Accuracy= 79.70000
#
# Fold: 2, Epoch: 4, Validation Accuracy= 85.80000
#
# Fold: 2, Epoch: 5, Mini Batch: 10, Loss= 7190.267090, Training Accuracy= 79.30000
# Fold: 2, Epoch: 5, Mini Batch: 18, Loss= 7919.731934, Training Accuracy= 78.50000
#
# Fold: 2, Epoch: 5, Validation Accuracy= 86.10000
#
# Fold: 2, Epoch: 6, Mini Batch: 10, Loss= 6498.828613, Training Accuracy= 79.90000
# Fold: 2, Epoch: 6, Mini Batch: 18, Loss= 5959.922363, Training Accuracy= 78.50000
#
# Fold: 2, Epoch: 6, Validation Accuracy= 86.20000
#
# Fold: 2, Epoch: 7, Mini Batch: 10, Loss= 5339.164062, Training Accuracy= 80.50000
# Fold: 2, Epoch: 7, Mini Batch: 18, Loss= 5349.644043, Training Accuracy= 81.70000
#
# Fold: 2, Epoch: 7, Validation Accuracy= 85.85000
#
# Fold: 2, Epoch: 8, Mini Batch: 10, Loss= 4777.309570, Training Accuracy= 80.70000
# Fold: 2, Epoch: 8, Mini Batch: 18, Loss= 5137.748535, Training Accuracy= 80.50000
#
# Fold: 2, Epoch: 8, Validation Accuracy= 86.10000
#
# Fold: 2, Epoch: 9, Mini Batch: 10, Loss= 4642.112305, Training Accuracy= 80.90000
# Fold: 2, Epoch: 9, Mini Batch: 18, Loss= 4517.180664, Training Accuracy= 80.70000
#
# Fold: 2, Epoch: 9, Validation Accuracy= 86.20000
#
# Fold: 2, Epoch: 10, Mini Batch: 10, Loss= 3834.091309, Training Accuracy= 81.80000
# Fold: 2, Epoch: 10, Mini Batch: 18, Loss= 3570.095459, Training Accuracy= 81.40000
#
# Fold: 2, Epoch: 10, Validation Accuracy= 85.85000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           827   110   937
# 1           173   890  1063
# All        1000  1000  2000
#
# Fold: 2, Epoch: 11, Mini Batch: 10, Loss= 4213.300781, Training Accuracy= 79.70000
# Fold: 2, Epoch: 11, Mini Batch: 18, Loss= 3811.755371, Training Accuracy= 79.40000
#
# Fold: 2, Epoch: 11, Validation Accuracy= 85.95000
#
# Fold: 2, Epoch: 12, Mini Batch: 10, Loss= 3358.327148, Training Accuracy= 80.20000
# Fold: 2, Epoch: 12, Mini Batch: 18, Loss= 3137.697510, Training Accuracy= 82.30000
#
# Fold: 2, Epoch: 12, Validation Accuracy= 86.10000
#
# Fold: 2, Epoch: 13, Mini Batch: 10, Loss= 3214.920654, Training Accuracy= 81.00000
# Fold: 2, Epoch: 13, Mini Batch: 18, Loss= 3330.870117, Training Accuracy= 80.70000
#
# Fold: 2, Epoch: 13, Validation Accuracy= 86.50000
#
# Fold: 2, Epoch: 14, Mini Batch: 10, Loss= 2762.806885, Training Accuracy= 82.80000
# Fold: 2, Epoch: 14, Mini Batch: 18, Loss= 2777.099609, Training Accuracy= 83.50000
#
# Fold: 2, Epoch: 14, Validation Accuracy= 87.05000
#
# Fold: 2, Epoch: 15, Mini Batch: 10, Loss= 2834.050049, Training Accuracy= 80.70000
# Fold: 2, Epoch: 15, Mini Batch: 18, Loss= 2728.139404, Training Accuracy= 81.80000
#
# Fold: 2, Epoch: 15, Validation Accuracy= 87.00000
#
# Fold: 2, Epoch: 16, Mini Batch: 10, Loss= 2636.366211, Training Accuracy= 81.10000
# Fold: 2, Epoch: 16, Mini Batch: 18, Loss= 2501.922119, Training Accuracy= 81.10000
#
# Fold: 2, Epoch: 16, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 17, Mini Batch: 10, Loss= 2148.347900, Training Accuracy= 82.20000
# Fold: 2, Epoch: 17, Mini Batch: 18, Loss= 2103.250977, Training Accuracy= 82.60000
#
# Fold: 2, Epoch: 17, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 18, Mini Batch: 10, Loss= 2342.217529, Training Accuracy= 83.10000
# Fold: 2, Epoch: 18, Mini Batch: 18, Loss= 2391.654541, Training Accuracy= 81.40000
#
# Fold: 2, Epoch: 18, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 19, Mini Batch: 10, Loss= 2102.383545, Training Accuracy= 82.00000
# Fold: 2, Epoch: 19, Mini Batch: 18, Loss= 2073.105469, Training Accuracy= 81.90000
#
# Fold: 2, Epoch: 19, Validation Accuracy= 87.25000
#
# Fold: 2, Epoch: 20, Mini Batch: 10, Loss= 1967.910034, Training Accuracy= 80.60000
# Fold: 2, Epoch: 20, Mini Batch: 18, Loss= 2019.999146, Training Accuracy= 82.00000
#
# Fold: 2, Epoch: 20, Validation Accuracy= 87.20000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           853   109   962
# 1           147   891  1038
# All        1000  1000  2000
#
# Fold: 2, Epoch: 21, Mini Batch: 10, Loss= 1952.226074, Training Accuracy= 82.50000
# Fold: 2, Epoch: 21, Mini Batch: 18, Loss= 1895.953491, Training Accuracy= 82.60000
#
# Fold: 2, Epoch: 21, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 22, Mini Batch: 10, Loss= 1844.996948, Training Accuracy= 81.90000
# Fold: 2, Epoch: 22, Mini Batch: 18, Loss= 1644.107910, Training Accuracy= 82.90000
#
# Fold: 2, Epoch: 22, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 23, Mini Batch: 10, Loss= 1580.099731, Training Accuracy= 83.50000
# Fold: 2, Epoch: 23, Mini Batch: 18, Loss= 1328.601440, Training Accuracy= 83.60000
#
# Fold: 2, Epoch: 23, Validation Accuracy= 87.50000
#
# Fold: 2, Epoch: 24, Mini Batch: 10, Loss= 1497.998047, Training Accuracy= 81.60000
# Fold: 2, Epoch: 24, Mini Batch: 18, Loss= 1560.263672, Training Accuracy= 82.40000
#
# Fold: 2, Epoch: 24, Validation Accuracy= 87.40000
#
# Fold: 2, Epoch: 25, Mini Batch: 10, Loss= 1509.083252, Training Accuracy= 80.50000
# Fold: 2, Epoch: 25, Mini Batch: 18, Loss= 1421.838867, Training Accuracy= 81.90000
#
# Fold: 2, Epoch: 25, Validation Accuracy= 87.00000
#
# Fold: 2, Epoch: 26, Mini Batch: 10, Loss= 1229.216797, Training Accuracy= 84.40000
# Fold: 2, Epoch: 26, Mini Batch: 18, Loss= 1189.681763, Training Accuracy= 83.00000
#
# Fold: 2, Epoch: 26, Validation Accuracy= 87.15000
#
# Fold: 2, Epoch: 27, Mini Batch: 10, Loss= 1243.881836, Training Accuracy= 84.20000
# Fold: 2, Epoch: 27, Mini Batch: 18, Loss= 1310.325928, Training Accuracy= 83.70000
#
# Fold: 2, Epoch: 27, Validation Accuracy= 87.05000
#
# Fold: 2, Epoch: 28, Mini Batch: 10, Loss= 1162.212158, Training Accuracy= 84.80000
# Fold: 2, Epoch: 28, Mini Batch: 18, Loss= 1234.749268, Training Accuracy= 83.20000
#
# Fold: 2, Epoch: 28, Validation Accuracy= 87.85000
#
# Fold: 2, Epoch: 29, Mini Batch: 10, Loss= 1142.974487, Training Accuracy= 82.80000
# Fold: 2, Epoch: 29, Mini Batch: 18, Loss= 1018.896973, Training Accuracy= 84.90000
#
# Fold: 2, Epoch: 29, Validation Accuracy= 87.75000
#
# Fold: 2, Epoch: 30, Mini Batch: 10, Loss= 990.438904, Training Accuracy= 84.00000
# Fold: 2, Epoch: 30, Mini Batch: 18, Loss= 1124.233154, Training Accuracy= 84.00000
#
# Fold: 2, Epoch: 30, Validation Accuracy= 87.95000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           859   100   959
# 1           141   900  1041
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.003}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 3, Epoch: 1, Mini Batch: 10, Loss= 26097.316406, Training Accuracy= 70.20000
# Fold: 3, Epoch: 1, Mini Batch: 18, Loss= 21913.181641, Training Accuracy= 74.90000
#
# Fold: 3, Epoch: 1, Validation Accuracy= 83.15000
#
# Fold: 3, Epoch: 2, Mini Batch: 10, Loss= 15648.233398, Training Accuracy= 76.00000
# Fold: 3, Epoch: 2, Mini Batch: 18, Loss= 11951.708008, Training Accuracy= 78.30000
#
# Fold: 3, Epoch: 2, Validation Accuracy= 86.45000
#
# Fold: 3, Epoch: 3, Mini Batch: 10, Loss= 11759.830078, Training Accuracy= 77.10000
# Fold: 3, Epoch: 3, Mini Batch: 18, Loss= 10227.820312, Training Accuracy= 78.00000
#
# Fold: 3, Epoch: 3, Validation Accuracy= 86.80000
#
# Fold: 3, Epoch: 4, Mini Batch: 10, Loss= 8857.589844, Training Accuracy= 79.90000
# Fold: 3, Epoch: 4, Mini Batch: 18, Loss= 7533.057129, Training Accuracy= 80.20000
#
# Fold: 3, Epoch: 4, Validation Accuracy= 86.20000
#
# Fold: 3, Epoch: 5, Mini Batch: 10, Loss= 8554.453125, Training Accuracy= 78.20000
# Fold: 3, Epoch: 5, Mini Batch: 18, Loss= 6496.133789, Training Accuracy= 78.00000
#
# Fold: 3, Epoch: 5, Validation Accuracy= 86.50000
#
# Fold: 3, Epoch: 6, Mini Batch: 10, Loss= 7205.647949, Training Accuracy= 77.70000
# Fold: 3, Epoch: 6, Mini Batch: 18, Loss= 5893.290039, Training Accuracy= 80.30000
#
# Fold: 3, Epoch: 6, Validation Accuracy= 86.85000
#
# Fold: 3, Epoch: 7, Mini Batch: 10, Loss= 5744.807129, Training Accuracy= 80.00000
# Fold: 3, Epoch: 7, Mini Batch: 18, Loss= 5634.003906, Training Accuracy= 79.20000
#
# Fold: 3, Epoch: 7, Validation Accuracy= 87.00000
#
# Fold: 3, Epoch: 8, Mini Batch: 10, Loss= 4584.648926, Training Accuracy= 81.50000
# Fold: 3, Epoch: 8, Mini Batch: 18, Loss= 5102.521973, Training Accuracy= 80.30000
#
# Fold: 3, Epoch: 8, Validation Accuracy= 87.20000
#
# Fold: 3, Epoch: 9, Mini Batch: 10, Loss= 4034.080566, Training Accuracy= 80.40000
# Fold: 3, Epoch: 9, Mini Batch: 18, Loss= 4116.038086, Training Accuracy= 81.60000
#
# Fold: 3, Epoch: 9, Validation Accuracy= 87.35000
#
# Fold: 3, Epoch: 10, Mini Batch: 10, Loss= 4634.684082, Training Accuracy= 80.00000
# Fold: 3, Epoch: 10, Mini Batch: 18, Loss= 4682.742676, Training Accuracy= 81.40000
#
# Fold: 3, Epoch: 10, Validation Accuracy= 87.80000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           845    89   934
# 1           155   911  1066
# All        1000  1000  2000
#
# Fold: 3, Epoch: 11, Mini Batch: 10, Loss= 4129.041016, Training Accuracy= 81.10000
# Fold: 3, Epoch: 11, Mini Batch: 18, Loss= 4082.713379, Training Accuracy= 79.40000
#
# Fold: 3, Epoch: 11, Validation Accuracy= 87.85000
#
# Fold: 3, Epoch: 12, Mini Batch: 10, Loss= 3673.100586, Training Accuracy= 80.40000
# Fold: 3, Epoch: 12, Mini Batch: 18, Loss= 3576.342529, Training Accuracy= 82.00000
#
# Fold: 3, Epoch: 12, Validation Accuracy= 87.95000
#
# Fold: 3, Epoch: 13, Mini Batch: 10, Loss= 3340.720215, Training Accuracy= 79.80000
# Fold: 3, Epoch: 13, Mini Batch: 18, Loss= 3262.465576, Training Accuracy= 80.30000
#
# Fold: 3, Epoch: 13, Validation Accuracy= 87.70000
#
# Fold: 3, Epoch: 14, Mini Batch: 10, Loss= 3156.235107, Training Accuracy= 78.50000
# Fold: 3, Epoch: 14, Mini Batch: 18, Loss= 3106.120117, Training Accuracy= 81.30000
#
# Fold: 3, Epoch: 14, Validation Accuracy= 88.30000
#
# Fold: 3, Epoch: 15, Mini Batch: 10, Loss= 2885.091797, Training Accuracy= 82.20000
# Fold: 3, Epoch: 15, Mini Batch: 18, Loss= 2645.849609, Training Accuracy= 80.30000
#
# Fold: 3, Epoch: 15, Validation Accuracy= 88.15000
#
# Fold: 3, Epoch: 16, Mini Batch: 10, Loss= 2404.474121, Training Accuracy= 80.70000
# Fold: 3, Epoch: 16, Mini Batch: 18, Loss= 2451.086914, Training Accuracy= 82.60000
#
# Fold: 3, Epoch: 16, Validation Accuracy= 88.00000
#
# Fold: 3, Epoch: 17, Mini Batch: 10, Loss= 2656.216553, Training Accuracy= 79.60000
# Fold: 3, Epoch: 17, Mini Batch: 18, Loss= 2489.494629, Training Accuracy= 82.60000
#
# Fold: 3, Epoch: 17, Validation Accuracy= 88.20000
#
# Fold: 3, Epoch: 18, Mini Batch: 10, Loss= 2352.379395, Training Accuracy= 82.10000
# Fold: 3, Epoch: 18, Mini Batch: 18, Loss= 1907.374756, Training Accuracy= 83.30000
#
# Fold: 3, Epoch: 18, Validation Accuracy= 88.40000
#
# Fold: 3, Epoch: 19, Mini Batch: 10, Loss= 2167.867920, Training Accuracy= 82.40000
# Fold: 3, Epoch: 19, Mini Batch: 18, Loss= 2041.397705, Training Accuracy= 83.80000
#
# Fold: 3, Epoch: 19, Validation Accuracy= 88.15000
#
# Fold: 3, Epoch: 20, Mini Batch: 10, Loss= 1905.964966, Training Accuracy= 81.40000
# Fold: 3, Epoch: 20, Mini Batch: 18, Loss= 2022.044189, Training Accuracy= 82.90000
#
# Fold: 3, Epoch: 20, Validation Accuracy= 88.45000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           851    82   933
# 1           149   918  1067
# All        1000  1000  2000
#
# Fold: 3, Epoch: 21, Mini Batch: 10, Loss= 1904.386719, Training Accuracy= 81.30000
# Fold: 3, Epoch: 21, Mini Batch: 18, Loss= 1729.917725, Training Accuracy= 83.20000
#
# Fold: 3, Epoch: 21, Validation Accuracy= 88.25000
#
# Fold: 3, Epoch: 22, Mini Batch: 10, Loss= 1703.500000, Training Accuracy= 82.10000
# Fold: 3, Epoch: 22, Mini Batch: 18, Loss= 1875.326172, Training Accuracy= 83.50000
#
# Fold: 3, Epoch: 22, Validation Accuracy= 88.00000
#
# Fold: 3, Epoch: 23, Mini Batch: 10, Loss= 1648.722656, Training Accuracy= 82.80000
# Fold: 3, Epoch: 23, Mini Batch: 18, Loss= 1618.886475, Training Accuracy= 82.40000
#
# Fold: 3, Epoch: 23, Validation Accuracy= 87.80000
#
# Fold: 3, Epoch: 24, Mini Batch: 10, Loss= 1598.939209, Training Accuracy= 82.50000
# Fold: 3, Epoch: 24, Mini Batch: 18, Loss= 1503.718018, Training Accuracy= 82.60000
#
# Fold: 3, Epoch: 24, Validation Accuracy= 88.00000
#
# Fold: 3, Epoch: 25, Mini Batch: 10, Loss= 1621.627930, Training Accuracy= 82.80000
# Fold: 3, Epoch: 25, Mini Batch: 18, Loss= 1456.831299, Training Accuracy= 83.40000
#
# Fold: 3, Epoch: 25, Validation Accuracy= 87.95000
#
# Fold: 3, Epoch: 26, Mini Batch: 10, Loss= 1819.159424, Training Accuracy= 79.80000
# Fold: 3, Epoch: 26, Mini Batch: 18, Loss= 1319.118530, Training Accuracy= 83.50000
#
# Fold: 3, Epoch: 26, Validation Accuracy= 87.65000
#
# Fold: 3, Epoch: 27, Mini Batch: 10, Loss= 1334.706543, Training Accuracy= 83.10000
# Fold: 3, Epoch: 27, Mini Batch: 18, Loss= 1168.785156, Training Accuracy= 83.40000
#
# Fold: 3, Epoch: 27, Validation Accuracy= 87.95000
#
# Fold: 3, Epoch: 28, Mini Batch: 10, Loss= 1043.805542, Training Accuracy= 84.60000
# Fold: 3, Epoch: 28, Mini Batch: 18, Loss= 1243.705933, Training Accuracy= 82.70000
#
# Fold: 3, Epoch: 28, Validation Accuracy= 88.30000
#
# Fold: 3, Epoch: 29, Mini Batch: 10, Loss= 1098.719727, Training Accuracy= 83.60000
# Fold: 3, Epoch: 29, Mini Batch: 18, Loss= 1242.881470, Training Accuracy= 83.70000
#
# Fold: 3, Epoch: 29, Validation Accuracy= 88.10000
#
# Fold: 3, Epoch: 30, Mini Batch: 10, Loss= 1302.808228, Training Accuracy= 81.40000
# Fold: 3, Epoch: 30, Mini Batch: 18, Loss= 1089.208740, Training Accuracy= 84.10000
#
# Fold: 3, Epoch: 30, Validation Accuracy= 88.10000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           856    94   950
# 1           144   906  1050
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.003}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 4, Epoch: 1, Mini Batch: 10, Loss= 26066.250000, Training Accuracy= 71.30000
# Fold: 4, Epoch: 1, Mini Batch: 18, Loss= 18516.484375, Training Accuracy= 76.10000
#
# Fold: 4, Epoch: 1, Validation Accuracy= 82.95000
#
# Fold: 4, Epoch: 2, Mini Batch: 10, Loss= 16509.652344, Training Accuracy= 77.60000
# Fold: 4, Epoch: 2, Mini Batch: 18, Loss= 14426.484375, Training Accuracy= 77.70000
#
# Fold: 4, Epoch: 2, Validation Accuracy= 84.80000
#
# Fold: 4, Epoch: 3, Mini Batch: 10, Loss= 9047.124023, Training Accuracy= 80.00000
# Fold: 4, Epoch: 3, Mini Batch: 18, Loss= 10381.491211, Training Accuracy= 78.80000
#
# Fold: 4, Epoch: 3, Validation Accuracy= 84.85000
#
# Fold: 4, Epoch: 4, Mini Batch: 10, Loss= 8171.647461, Training Accuracy= 80.50000
# Fold: 4, Epoch: 4, Mini Batch: 18, Loss= 8117.726074, Training Accuracy= 79.50000
#
# Fold: 4, Epoch: 4, Validation Accuracy= 84.95000
#
# Fold: 4, Epoch: 5, Mini Batch: 10, Loss= 6491.907715, Training Accuracy= 80.60000
# Fold: 4, Epoch: 5, Mini Batch: 18, Loss= 6802.037109, Training Accuracy= 78.70000
#
# Fold: 4, Epoch: 5, Validation Accuracy= 85.75000
#
# Fold: 4, Epoch: 6, Mini Batch: 10, Loss= 5974.383301, Training Accuracy= 80.50000
# Fold: 4, Epoch: 6, Mini Batch: 18, Loss= 6327.561035, Training Accuracy= 80.30000
#
# Fold: 4, Epoch: 6, Validation Accuracy= 85.90000
#
# Fold: 4, Epoch: 7, Mini Batch: 10, Loss= 6662.130859, Training Accuracy= 78.50000
# Fold: 4, Epoch: 7, Mini Batch: 18, Loss= 5549.065430, Training Accuracy= 80.70000
#
# Fold: 4, Epoch: 7, Validation Accuracy= 85.55000
#
# Fold: 4, Epoch: 8, Mini Batch: 10, Loss= 5057.466797, Training Accuracy= 79.90000
# Fold: 4, Epoch: 8, Mini Batch: 18, Loss= 4306.555664, Training Accuracy= 80.40000
#
# Fold: 4, Epoch: 8, Validation Accuracy= 85.55000
#
# Fold: 4, Epoch: 9, Mini Batch: 10, Loss= 4287.018066, Training Accuracy= 79.70000
# Fold: 4, Epoch: 9, Mini Batch: 18, Loss= 4100.360840, Training Accuracy= 82.00000
#
# Fold: 4, Epoch: 9, Validation Accuracy= 85.90000
#
# Fold: 4, Epoch: 10, Mini Batch: 10, Loss= 3866.616943, Training Accuracy= 82.60000
# Fold: 4, Epoch: 10, Mini Batch: 18, Loss= 4362.055176, Training Accuracy= 81.60000
#
# Fold: 4, Epoch: 10, Validation Accuracy= 85.65000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           811    98   909
# 1           189   902  1091
# All        1000  1000  2000
#
# Fold: 4, Epoch: 11, Mini Batch: 10, Loss= 3929.106445, Training Accuracy= 81.00000
# Fold: 4, Epoch: 11, Mini Batch: 18, Loss= 3591.554443, Training Accuracy= 80.70000
#
# Fold: 4, Epoch: 11, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 12, Mini Batch: 10, Loss= 3920.411865, Training Accuracy= 80.10000
# Fold: 4, Epoch: 12, Mini Batch: 18, Loss= 3481.210693, Training Accuracy= 83.50000
#
# Fold: 4, Epoch: 12, Validation Accuracy= 86.20000
#
# Fold: 4, Epoch: 13, Mini Batch: 10, Loss= 3228.656738, Training Accuracy= 81.40000
# Fold: 4, Epoch: 13, Mini Batch: 18, Loss= 3033.767578, Training Accuracy= 81.10000
#
# Fold: 4, Epoch: 13, Validation Accuracy= 86.25000
#
# Fold: 4, Epoch: 14, Mini Batch: 10, Loss= 2997.431152, Training Accuracy= 79.80000
# Fold: 4, Epoch: 14, Mini Batch: 18, Loss= 3178.311279, Training Accuracy= 80.50000
#
# Fold: 4, Epoch: 14, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 15, Mini Batch: 10, Loss= 2456.965088, Training Accuracy= 83.20000
# Fold: 4, Epoch: 15, Mini Batch: 18, Loss= 2763.152588, Training Accuracy= 81.80000
#
# Fold: 4, Epoch: 15, Validation Accuracy= 85.90000
#
# Fold: 4, Epoch: 16, Mini Batch: 10, Loss= 2510.788574, Training Accuracy= 81.50000
# Fold: 4, Epoch: 16, Mini Batch: 18, Loss= 2955.997803, Training Accuracy= 81.20000
#
# Fold: 4, Epoch: 16, Validation Accuracy= 86.00000
#
# Fold: 4, Epoch: 17, Mini Batch: 10, Loss= 2267.765381, Training Accuracy= 81.30000
# Fold: 4, Epoch: 17, Mini Batch: 18, Loss= 2228.444824, Training Accuracy= 81.70000
#
# Fold: 4, Epoch: 17, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 18, Mini Batch: 10, Loss= 1897.064209, Training Accuracy= 83.10000
# Fold: 4, Epoch: 18, Mini Batch: 18, Loss= 2230.204590, Training Accuracy= 83.50000
#
# Fold: 4, Epoch: 18, Validation Accuracy= 85.75000
#
# Fold: 4, Epoch: 19, Mini Batch: 10, Loss= 2034.377075, Training Accuracy= 81.40000
# Fold: 4, Epoch: 19, Mini Batch: 18, Loss= 2300.170410, Training Accuracy= 81.10000
#
# Fold: 4, Epoch: 19, Validation Accuracy= 85.75000
#
# Fold: 4, Epoch: 20, Mini Batch: 10, Loss= 2059.402588, Training Accuracy= 81.90000
# Fold: 4, Epoch: 20, Mini Batch: 18, Loss= 1877.481689, Training Accuracy= 83.50000
#
# Fold: 4, Epoch: 20, Validation Accuracy= 85.80000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           826   110   936
# 1           174   890  1064
# All        1000  1000  2000
#
# Fold: 4, Epoch: 21, Mini Batch: 10, Loss= 1891.537231, Training Accuracy= 81.20000
# Fold: 4, Epoch: 21, Mini Batch: 18, Loss= 1757.275391, Training Accuracy= 84.00000
#
# Fold: 4, Epoch: 21, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 22, Mini Batch: 10, Loss= 1730.184448, Training Accuracy= 82.80000
# Fold: 4, Epoch: 22, Mini Batch: 18, Loss= 1618.990967, Training Accuracy= 83.90000
#
# Fold: 4, Epoch: 22, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 23, Mini Batch: 10, Loss= 1624.426270, Training Accuracy= 83.70000
# Fold: 4, Epoch: 23, Mini Batch: 18, Loss= 1712.075439, Training Accuracy= 84.30000
#
# Fold: 4, Epoch: 23, Validation Accuracy= 86.15000
#
# Fold: 4, Epoch: 24, Mini Batch: 10, Loss= 1580.328003, Training Accuracy= 83.20000
# Fold: 4, Epoch: 24, Mini Batch: 18, Loss= 1475.529297, Training Accuracy= 84.60000
#
# Fold: 4, Epoch: 24, Validation Accuracy= 85.75000
#
# Fold: 4, Epoch: 25, Mini Batch: 10, Loss= 1341.926636, Training Accuracy= 83.70000
# Fold: 4, Epoch: 25, Mini Batch: 18, Loss= 1438.814697, Training Accuracy= 82.30000
#
# Fold: 4, Epoch: 25, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 26, Mini Batch: 10, Loss= 1374.369629, Training Accuracy= 82.80000
# Fold: 4, Epoch: 26, Mini Batch: 18, Loss= 1525.526978, Training Accuracy= 82.40000
#
# Fold: 4, Epoch: 26, Validation Accuracy= 85.70000
#
# Fold: 4, Epoch: 27, Mini Batch: 10, Loss= 1347.453125, Training Accuracy= 81.80000
# Fold: 4, Epoch: 27, Mini Batch: 18, Loss= 1278.955933, Training Accuracy= 82.90000
#
# Fold: 4, Epoch: 27, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 28, Mini Batch: 10, Loss= 1213.214844, Training Accuracy= 83.00000
# Fold: 4, Epoch: 28, Mini Batch: 18, Loss= 1133.379272, Training Accuracy= 84.60000
#
# Fold: 4, Epoch: 28, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 29, Mini Batch: 10, Loss= 1061.794189, Training Accuracy= 85.40000
# Fold: 4, Epoch: 29, Mini Batch: 18, Loss= 1251.890259, Training Accuracy= 83.00000
#
# Fold: 4, Epoch: 29, Validation Accuracy= 85.70000
#
# Fold: 4, Epoch: 30, Mini Batch: 10, Loss= 1002.584229, Training Accuracy= 84.20000
# Fold: 4, Epoch: 30, Mini Batch: 18, Loss= 1278.327515, Training Accuracy= 82.40000
#
# Fold: 4, Epoch: 30, Validation Accuracy= 86.40000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           829   101   930
# 1           171   899  1070
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.003}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 5, Epoch: 1, Mini Batch: 10, Loss= 23928.144531, Training Accuracy= 69.60000
# Fold: 5, Epoch: 1, Mini Batch: 18, Loss= 21380.220703, Training Accuracy= 74.20000
#
# Fold: 5, Epoch: 1, Validation Accuracy= 83.65000
#
# Fold: 5, Epoch: 2, Mini Batch: 10, Loss= 14334.374023, Training Accuracy= 78.70000
# Fold: 5, Epoch: 2, Mini Batch: 18, Loss= 13552.292969, Training Accuracy= 78.00000
#
# Fold: 5, Epoch: 2, Validation Accuracy= 85.85000
#
# Fold: 5, Epoch: 3, Mini Batch: 10, Loss= 11783.728516, Training Accuracy= 76.50000
# Fold: 5, Epoch: 3, Mini Batch: 18, Loss= 10181.480469, Training Accuracy= 77.90000
#
# Fold: 5, Epoch: 3, Validation Accuracy= 86.60000
#
# Fold: 5, Epoch: 4, Mini Batch: 10, Loss= 8113.774902, Training Accuracy= 78.40000
# Fold: 5, Epoch: 4, Mini Batch: 18, Loss= 8856.866211, Training Accuracy= 79.80000
#
# Fold: 5, Epoch: 4, Validation Accuracy= 86.35000
#
# Fold: 5, Epoch: 5, Mini Batch: 10, Loss= 6936.146973, Training Accuracy= 80.50000
# Fold: 5, Epoch: 5, Mini Batch: 18, Loss= 6876.171387, Training Accuracy= 79.80000
#
# Fold: 5, Epoch: 5, Validation Accuracy= 86.40000
#
# Fold: 5, Epoch: 6, Mini Batch: 10, Loss= 6441.506836, Training Accuracy= 79.40000
# Fold: 5, Epoch: 6, Mini Batch: 18, Loss= 5754.472168, Training Accuracy= 80.10000
#
# Fold: 5, Epoch: 6, Validation Accuracy= 86.80000
#
# Fold: 5, Epoch: 7, Mini Batch: 10, Loss= 5576.687988, Training Accuracy= 79.50000
# Fold: 5, Epoch: 7, Mini Batch: 18, Loss= 5521.243164, Training Accuracy= 80.30000
#
# Fold: 5, Epoch: 7, Validation Accuracy= 87.10000
#
# Fold: 5, Epoch: 8, Mini Batch: 10, Loss= 5151.708008, Training Accuracy= 78.40000
# Fold: 5, Epoch: 8, Mini Batch: 18, Loss= 4328.667969, Training Accuracy= 82.10000
#
# Fold: 5, Epoch: 8, Validation Accuracy= 87.10000
#
# Fold: 5, Epoch: 9, Mini Batch: 10, Loss= 4047.448486, Training Accuracy= 80.10000
# Fold: 5, Epoch: 9, Mini Batch: 18, Loss= 4374.180176, Training Accuracy= 80.60000
#
# Fold: 5, Epoch: 9, Validation Accuracy= 87.70000
#
# Fold: 5, Epoch: 10, Mini Batch: 10, Loss= 3615.985596, Training Accuracy= 81.70000
# Fold: 5, Epoch: 10, Mini Batch: 18, Loss= 4280.123047, Training Accuracy= 80.10000
#
# Fold: 5, Epoch: 10, Validation Accuracy= 87.75000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           859   104   963
# 1           141   896  1037
# All        1000  1000  2000
#
# Fold: 5, Epoch: 11, Mini Batch: 10, Loss= 4020.938721, Training Accuracy= 80.00000
# Fold: 5, Epoch: 11, Mini Batch: 18, Loss= 3721.860840, Training Accuracy= 81.20000
#
# Fold: 5, Epoch: 11, Validation Accuracy= 88.25000
#
# Fold: 5, Epoch: 12, Mini Batch: 10, Loss= 3252.696777, Training Accuracy= 80.30000
# Fold: 5, Epoch: 12, Mini Batch: 18, Loss= 3142.238281, Training Accuracy= 80.10000
#
# Fold: 5, Epoch: 12, Validation Accuracy= 87.85000
#
# Fold: 5, Epoch: 13, Mini Batch: 10, Loss= 3355.754883, Training Accuracy= 79.50000
# Fold: 5, Epoch: 13, Mini Batch: 18, Loss= 3128.637939, Training Accuracy= 81.60000
#
# Fold: 5, Epoch: 13, Validation Accuracy= 88.20000
#
# Fold: 5, Epoch: 14, Mini Batch: 10, Loss= 2633.102051, Training Accuracy= 82.90000
# Fold: 5, Epoch: 14, Mini Batch: 18, Loss= 2376.349609, Training Accuracy= 80.70000
#
# Fold: 5, Epoch: 14, Validation Accuracy= 88.40000
#
# Fold: 5, Epoch: 15, Mini Batch: 10, Loss= 2488.664307, Training Accuracy= 82.60000
# Fold: 5, Epoch: 15, Mini Batch: 18, Loss= 2638.949219, Training Accuracy= 80.90000
#
# Fold: 5, Epoch: 15, Validation Accuracy= 87.80000
#
# Fold: 5, Epoch: 16, Mini Batch: 10, Loss= 2481.542480, Training Accuracy= 81.20000
# Fold: 5, Epoch: 16, Mini Batch: 18, Loss= 2448.038818, Training Accuracy= 80.50000
#
# Fold: 5, Epoch: 16, Validation Accuracy= 88.10000
#
# Fold: 5, Epoch: 17, Mini Batch: 10, Loss= 2291.918213, Training Accuracy= 81.70000
# Fold: 5, Epoch: 17, Mini Batch: 18, Loss= 2068.112549, Training Accuracy= 82.20000
#
# Fold: 5, Epoch: 17, Validation Accuracy= 88.00000
#
# Fold: 5, Epoch: 18, Mini Batch: 10, Loss= 2114.726318, Training Accuracy= 81.80000
# Fold: 5, Epoch: 18, Mini Batch: 18, Loss= 2057.663086, Training Accuracy= 82.80000
#
# Fold: 5, Epoch: 18, Validation Accuracy= 88.25000
#
# Fold: 5, Epoch: 19, Mini Batch: 10, Loss= 1934.093018, Training Accuracy= 81.90000
# Fold: 5, Epoch: 19, Mini Batch: 18, Loss= 2108.071045, Training Accuracy= 80.20000
#
# Fold: 5, Epoch: 19, Validation Accuracy= 88.10000
#
# Fold: 5, Epoch: 20, Mini Batch: 10, Loss= 1982.888916, Training Accuracy= 80.80000
# Fold: 5, Epoch: 20, Mini Batch: 18, Loss= 1605.663452, Training Accuracy= 84.20000
#
# Fold: 5, Epoch: 20, Validation Accuracy= 88.05000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           852    91   943
# 1           148   909  1057
# All        1000  1000  2000
#
# Fold: 5, Epoch: 21, Mini Batch: 10, Loss= 1665.371338, Training Accuracy= 81.70000
# Fold: 5, Epoch: 21, Mini Batch: 18, Loss= 1655.167236, Training Accuracy= 84.10000
#
# Fold: 5, Epoch: 21, Validation Accuracy= 87.50000
#
# Fold: 5, Epoch: 22, Mini Batch: 10, Loss= 1408.562500, Training Accuracy= 83.70000
# Fold: 5, Epoch: 22, Mini Batch: 18, Loss= 1481.974121, Training Accuracy= 83.20000
#
# Fold: 5, Epoch: 22, Validation Accuracy= 87.45000
#
# Fold: 5, Epoch: 23, Mini Batch: 10, Loss= 1391.079956, Training Accuracy= 83.00000
# Fold: 5, Epoch: 23, Mini Batch: 18, Loss= 1726.920776, Training Accuracy= 81.60000
#
# Fold: 5, Epoch: 23, Validation Accuracy= 87.70000
#
# Fold: 5, Epoch: 24, Mini Batch: 10, Loss= 1551.291504, Training Accuracy= 81.90000
# Fold: 5, Epoch: 24, Mini Batch: 18, Loss= 1405.762573, Training Accuracy= 82.50000
#
# Fold: 5, Epoch: 24, Validation Accuracy= 87.35000
#
# Fold: 5, Epoch: 25, Mini Batch: 10, Loss= 1523.801514, Training Accuracy= 81.20000
# Fold: 5, Epoch: 25, Mini Batch: 18, Loss= 1327.709595, Training Accuracy= 85.00000
#
# Fold: 5, Epoch: 25, Validation Accuracy= 87.85000
#
# Fold: 5, Epoch: 26, Mini Batch: 10, Loss= 1328.320801, Training Accuracy= 82.30000
# Fold: 5, Epoch: 26, Mini Batch: 18, Loss= 1418.183228, Training Accuracy= 82.70000
#
# Fold: 5, Epoch: 26, Validation Accuracy= 87.80000
#
# Fold: 5, Epoch: 27, Mini Batch: 10, Loss= 1305.826050, Training Accuracy= 83.40000
# Fold: 5, Epoch: 27, Mini Batch: 18, Loss= 1183.479736, Training Accuracy= 84.20000
#
# Fold: 5, Epoch: 27, Validation Accuracy= 87.75000
#
# Fold: 5, Epoch: 28, Mini Batch: 10, Loss= 1068.818237, Training Accuracy= 84.80000
# Fold: 5, Epoch: 28, Mini Batch: 18, Loss= 1026.459961, Training Accuracy= 84.30000
#
# Fold: 5, Epoch: 28, Validation Accuracy= 87.65000
#
# Fold: 5, Epoch: 29, Mini Batch: 10, Loss= 1125.587402, Training Accuracy= 83.50000
# Fold: 5, Epoch: 29, Mini Batch: 18, Loss= 1031.892212, Training Accuracy= 84.30000
#
# Fold: 5, Epoch: 29, Validation Accuracy= 88.20000
#
# Fold: 5, Epoch: 30, Mini Batch: 10, Loss= 1128.664795, Training Accuracy= 82.70000
# Fold: 5, Epoch: 30, Mini Batch: 18, Loss= 928.519653, Training Accuracy= 84.80000
#
# Fold: 5, Epoch: 30, Validation Accuracy= 88.05000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           855    94   949
# 1           145   906  1051
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.003}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 6, Epoch: 1, Mini Batch: 10, Loss= 22506.371094, Training Accuracy= 73.90000
# Fold: 6, Epoch: 1, Mini Batch: 18, Loss= 18315.919922, Training Accuracy= 77.80000
#
# Fold: 6, Epoch: 1, Validation Accuracy= 84.15000
#
# Fold: 6, Epoch: 2, Mini Batch: 10, Loss= 12603.345703, Training Accuracy= 77.20000
# Fold: 6, Epoch: 2, Mini Batch: 18, Loss= 12015.576172, Training Accuracy= 76.40000
#
# Fold: 6, Epoch: 2, Validation Accuracy= 86.05000
#
# Fold: 6, Epoch: 3, Mini Batch: 10, Loss= 10144.914062, Training Accuracy= 78.30000
# Fold: 6, Epoch: 3, Mini Batch: 18, Loss= 10875.596680, Training Accuracy= 77.60000
#
# Fold: 6, Epoch: 3, Validation Accuracy= 86.30000
#
# Fold: 6, Epoch: 4, Mini Batch: 10, Loss= 7701.962891, Training Accuracy= 78.90000
# Fold: 6, Epoch: 4, Mini Batch: 18, Loss= 7436.621094, Training Accuracy= 77.70000
#
# Fold: 6, Epoch: 4, Validation Accuracy= 86.00000
#
# Fold: 6, Epoch: 5, Mini Batch: 10, Loss= 5747.375000, Training Accuracy= 81.40000
# Fold: 6, Epoch: 5, Mini Batch: 18, Loss= 6412.232910, Training Accuracy= 78.10000
#
# Fold: 6, Epoch: 5, Validation Accuracy= 85.95000
#
# Fold: 6, Epoch: 6, Mini Batch: 10, Loss= 5341.856445, Training Accuracy= 81.40000
# Fold: 6, Epoch: 6, Mini Batch: 18, Loss= 5033.861816, Training Accuracy= 81.50000
#
# Fold: 6, Epoch: 6, Validation Accuracy= 87.05000
#
# Fold: 6, Epoch: 7, Mini Batch: 10, Loss= 4532.103027, Training Accuracy= 81.60000
# Fold: 6, Epoch: 7, Mini Batch: 18, Loss= 5029.165039, Training Accuracy= 81.00000
#
# Fold: 6, Epoch: 7, Validation Accuracy= 86.80000
#
# Fold: 6, Epoch: 8, Mini Batch: 10, Loss= 4026.997559, Training Accuracy= 81.30000
# Fold: 6, Epoch: 8, Mini Batch: 18, Loss= 3886.740479, Training Accuracy= 81.30000
#
# Fold: 6, Epoch: 8, Validation Accuracy= 86.85000
#
# Fold: 6, Epoch: 9, Mini Batch: 10, Loss= 3801.311035, Training Accuracy= 80.90000
# Fold: 6, Epoch: 9, Mini Batch: 18, Loss= 4412.673340, Training Accuracy= 79.10000
#
# Fold: 6, Epoch: 9, Validation Accuracy= 86.45000
#
# Fold: 6, Epoch: 10, Mini Batch: 10, Loss= 3248.870605, Training Accuracy= 81.70000
# Fold: 6, Epoch: 10, Mini Batch: 18, Loss= 3544.795898, Training Accuracy= 78.80000
#
# Fold: 6, Epoch: 10, Validation Accuracy= 86.30000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           825    99   924
# 1           175   901  1076
# All        1000  1000  2000
#
# Fold: 6, Epoch: 11, Mini Batch: 10, Loss= 3031.794189, Training Accuracy= 82.60000
# Fold: 6, Epoch: 11, Mini Batch: 18, Loss= 3929.959717, Training Accuracy= 79.10000
#
# Fold: 6, Epoch: 11, Validation Accuracy= 86.25000
#
# Fold: 6, Epoch: 12, Mini Batch: 10, Loss= 2736.069580, Training Accuracy= 81.80000
# Fold: 6, Epoch: 12, Mini Batch: 18, Loss= 2786.830078, Training Accuracy= 82.60000
#
# Fold: 6, Epoch: 12, Validation Accuracy= 85.85000
#
# Fold: 6, Epoch: 13, Mini Batch: 10, Loss= 2563.227051, Training Accuracy= 82.20000
# Fold: 6, Epoch: 13, Mini Batch: 18, Loss= 2423.006104, Training Accuracy= 82.30000
#
# Fold: 6, Epoch: 13, Validation Accuracy= 86.45000
#
# Fold: 6, Epoch: 14, Mini Batch: 10, Loss= 2472.752686, Training Accuracy= 81.90000
# Fold: 6, Epoch: 14, Mini Batch: 18, Loss= 2353.053467, Training Accuracy= 81.50000
#
# Fold: 6, Epoch: 14, Validation Accuracy= 86.50000
#
# Fold: 6, Epoch: 15, Mini Batch: 10, Loss= 1959.202026, Training Accuracy= 84.40000
# Fold: 6, Epoch: 15, Mini Batch: 18, Loss= 2380.902344, Training Accuracy= 82.50000
#
# Fold: 6, Epoch: 15, Validation Accuracy= 86.20000
#
# Fold: 6, Epoch: 16, Mini Batch: 10, Loss= 1849.198364, Training Accuracy= 84.30000
# Fold: 6, Epoch: 16, Mini Batch: 18, Loss= 2128.174561, Training Accuracy= 83.50000
#
# Fold: 6, Epoch: 16, Validation Accuracy= 86.25000
#
# Fold: 6, Epoch: 17, Mini Batch: 10, Loss= 1858.656494, Training Accuracy= 83.90000
# Fold: 6, Epoch: 17, Mini Batch: 18, Loss= 2084.144775, Training Accuracy= 81.20000
#
# Fold: 6, Epoch: 17, Validation Accuracy= 86.35000
#
# Fold: 6, Epoch: 18, Mini Batch: 10, Loss= 1799.065552, Training Accuracy= 82.60000
# Fold: 6, Epoch: 18, Mini Batch: 18, Loss= 2071.846191, Training Accuracy= 82.20000
#
# Fold: 6, Epoch: 18, Validation Accuracy= 85.85000
#
# Fold: 6, Epoch: 19, Mini Batch: 10, Loss= 1756.622314, Training Accuracy= 83.50000
# Fold: 6, Epoch: 19, Mini Batch: 18, Loss= 1502.848755, Training Accuracy= 83.60000
#
# Fold: 6, Epoch: 19, Validation Accuracy= 85.75000
#
# Fold: 6, Epoch: 20, Mini Batch: 10, Loss= 1249.383667, Training Accuracy= 84.20000
# Fold: 6, Epoch: 20, Mini Batch: 18, Loss= 1661.551025, Training Accuracy= 83.50000
#
# Fold: 6, Epoch: 20, Validation Accuracy= 86.15000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           833   110   943
# 1           167   890  1057
# All        1000  1000  2000
#
# Fold: 6, Epoch: 21, Mini Batch: 10, Loss= 1495.130249, Training Accuracy= 82.50000
# Fold: 6, Epoch: 21, Mini Batch: 18, Loss= 1564.627808, Training Accuracy= 82.90000
#
# Fold: 6, Epoch: 21, Validation Accuracy= 86.20000
#
# Fold: 6, Epoch: 22, Mini Batch: 10, Loss= 1327.386719, Training Accuracy= 83.90000
# Fold: 6, Epoch: 22, Mini Batch: 18, Loss= 1655.173828, Training Accuracy= 81.80000
#
# Fold: 6, Epoch: 22, Validation Accuracy= 86.00000
#
# Fold: 6, Epoch: 23, Mini Batch: 10, Loss= 1233.928833, Training Accuracy= 84.50000
# Fold: 6, Epoch: 23, Mini Batch: 18, Loss= 1460.701294, Training Accuracy= 82.20000
#
# Fold: 6, Epoch: 23, Validation Accuracy= 86.05000
#
# Fold: 6, Epoch: 24, Mini Batch: 10, Loss= 1269.680298, Training Accuracy= 82.40000
# Fold: 6, Epoch: 24, Mini Batch: 18, Loss= 1391.791016, Training Accuracy= 84.00000
#
# Fold: 6, Epoch: 24, Validation Accuracy= 85.95000
#
# Fold: 6, Epoch: 25, Mini Batch: 10, Loss= 1055.699219, Training Accuracy= 84.00000
# Fold: 6, Epoch: 25, Mini Batch: 18, Loss= 1220.950806, Training Accuracy= 83.90000
#
# Fold: 6, Epoch: 25, Validation Accuracy= 85.95000
#
# Fold: 6, Epoch: 26, Mini Batch: 10, Loss= 1029.294434, Training Accuracy= 83.30000
# Fold: 6, Epoch: 26, Mini Batch: 18, Loss= 1208.077026, Training Accuracy= 83.40000
#
# Fold: 6, Epoch: 26, Validation Accuracy= 86.15000
#
# Fold: 6, Epoch: 27, Mini Batch: 10, Loss= 945.875366, Training Accuracy= 85.30000
# Fold: 6, Epoch: 27, Mini Batch: 18, Loss= 984.790894, Training Accuracy= 83.90000
#
# Fold: 6, Epoch: 27, Validation Accuracy= 86.00000
#
# Fold: 6, Epoch: 28, Mini Batch: 10, Loss= 953.954712, Training Accuracy= 84.90000
# Fold: 6, Epoch: 28, Mini Batch: 18, Loss= 1098.253540, Training Accuracy= 83.50000
#
# Fold: 6, Epoch: 28, Validation Accuracy= 85.65000
#
# Fold: 6, Epoch: 29, Mini Batch: 10, Loss= 835.076965, Training Accuracy= 86.40000
# Fold: 6, Epoch: 29, Mini Batch: 18, Loss= 1065.040039, Training Accuracy= 83.30000
#
# Fold: 6, Epoch: 29, Validation Accuracy= 86.10000
#
# Fold: 6, Epoch: 30, Mini Batch: 10, Loss= 796.614136, Training Accuracy= 86.40000
# Fold: 6, Epoch: 30, Mini Batch: 18, Loss= 850.422852, Training Accuracy= 84.60000
#
# Fold: 6, Epoch: 30, Validation Accuracy= 86.60000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           838   106   944
# 1           162   894  1056
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.003}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 7, Epoch: 1, Mini Batch: 10, Loss= 25728.896484, Training Accuracy= 72.20000
# Fold: 7, Epoch: 1, Mini Batch: 18, Loss= 20229.917969, Training Accuracy= 76.70000
#
# Fold: 7, Epoch: 1, Validation Accuracy= 83.85000
#
# Fold: 7, Epoch: 2, Mini Batch: 10, Loss= 13995.966797, Training Accuracy= 78.40000
# Fold: 7, Epoch: 2, Mini Batch: 18, Loss= 14423.207031, Training Accuracy= 78.70000
#
# Fold: 7, Epoch: 2, Validation Accuracy= 85.85000
#
# Fold: 7, Epoch: 3, Mini Batch: 10, Loss= 8584.017578, Training Accuracy= 80.20000
# Fold: 7, Epoch: 3, Mini Batch: 18, Loss= 10367.228516, Training Accuracy= 77.70000
#
# Fold: 7, Epoch: 3, Validation Accuracy= 86.60000
#
# Fold: 7, Epoch: 4, Mini Batch: 10, Loss= 7979.582031, Training Accuracy= 80.70000
# Fold: 7, Epoch: 4, Mini Batch: 18, Loss= 7749.237305, Training Accuracy= 79.90000
#
# Fold: 7, Epoch: 4, Validation Accuracy= 87.20000
#
# Fold: 7, Epoch: 5, Mini Batch: 10, Loss= 7629.041992, Training Accuracy= 78.70000
# Fold: 7, Epoch: 5, Mini Batch: 18, Loss= 7094.206543, Training Accuracy= 78.60000
#
# Fold: 7, Epoch: 5, Validation Accuracy= 87.25000
#
# Fold: 7, Epoch: 6, Mini Batch: 10, Loss= 5928.969238, Training Accuracy= 79.30000
# Fold: 7, Epoch: 6, Mini Batch: 18, Loss= 5862.999023, Training Accuracy= 78.80000
#
# Fold: 7, Epoch: 6, Validation Accuracy= 87.55000
#
# Fold: 7, Epoch: 7, Mini Batch: 10, Loss= 4438.362793, Training Accuracy= 82.60000
# Fold: 7, Epoch: 7, Mini Batch: 18, Loss= 5533.104980, Training Accuracy= 79.30000
#
# Fold: 7, Epoch: 7, Validation Accuracy= 87.55000
#
# Fold: 7, Epoch: 8, Mini Batch: 10, Loss= 4344.678223, Training Accuracy= 81.70000
# Fold: 7, Epoch: 8, Mini Batch: 18, Loss= 4873.898438, Training Accuracy= 81.00000
#
# Fold: 7, Epoch: 8, Validation Accuracy= 87.70000
#
# Fold: 7, Epoch: 9, Mini Batch: 10, Loss= 4574.270508, Training Accuracy= 82.00000
# ...
#
# Fold: 8, Epoch: 28, Validation Accuracy= 86.25000
#
# Fold: 8, Epoch: 29, Mini Batch: 10, Loss= 1185.683472, Training Accuracy= 83.10000
# Fold: 8, Epoch: 29, Mini Batch: 18, Loss= 1152.177979, Training Accuracy= 84.70000
#
# Fold: 8, Epoch: 29, Validation Accuracy= 86.20000
#
# Fold: 8, Epoch: 30, Mini Batch: 10, Loss= 965.577271, Training Accuracy= 84.70000
# Fold: 8, Epoch: 30, Mini Batch: 18, Loss= 1104.523560, Training Accuracy= 84.10000
#
# Fold: 8, Epoch: 30, Validation Accuracy= 86.45000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           836   107   943
# 1           164   893  1057
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.003}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 9, Epoch: 1, Mini Batch: 10, Loss= 24048.941406, Training Accuracy= 73.00000
# Fold: 9, Epoch: 1, Mini Batch: 18, Loss= 20567.404297, Training Accuracy= 77.10000
#
# Fold: 9, Epoch: 1, Validation Accuracy= 83.65000
#
# Fold: 9, Epoch: 2, Mini Batch: 10, Loss= 15676.164062, Training Accuracy= 76.80000
# Fold: 9, Epoch: 2, Mini Batch: 18, Loss= 11906.841797, Training Accuracy= 77.60000
#
# Fold: 9, Epoch: 2, Validation Accuracy= 85.70000
#
# Fold: 9, Epoch: 3, Mini Batch: 10, Loss= 10530.377930, Training Accuracy= 77.30000
# Fold: 9, Epoch: 3, Mini Batch: 18, Loss= 9668.710938, Training Accuracy= 78.80000
#
# Fold: 9, Epoch: 3, Validation Accuracy= 86.00000
#
# Fold: 9, Epoch: 4, Mini Batch: 10, Loss= 8038.102051, Training Accuracy= 78.80000
# Fold: 9, Epoch: 4, Mini Batch: 18, Loss= 7898.366699, Training Accuracy= 80.00000
#
# Fold: 9, Epoch: 4, Validation Accuracy= 86.10000
#
# Fold: 9, Epoch: 5, Mini Batch: 10, Loss= 6877.759766, Training Accuracy= 78.80000
# Fold: 9, Epoch: 5, Mini Batch: 18, Loss= 6681.088867, Training Accuracy= 78.10000
#
# Fold: 9, Epoch: 5, Validation Accuracy= 85.85000
#
# Fold: 9, Epoch: 6, Mini Batch: 10, Loss= 5229.152344, Training Accuracy= 81.40000
# Fold: 9, Epoch: 6, Mini Batch: 18, Loss= 6682.514160, Training Accuracy= 79.20000
#
# Fold: 9, Epoch: 6, Validation Accuracy= 85.80000
#
# Fold: 9, Epoch: 7, Mini Batch: 10, Loss= 5452.832031, Training Accuracy= 81.40000
# Fold: 9, Epoch: 7, Mini Batch: 18, Loss= 5336.691895, Training Accuracy= 80.70000
#
# Fold: 9, Epoch: 7, Validation Accuracy= 86.20000
#
# Fold: 9, Epoch: 8, Mini Batch: 10, Loss= 4060.636230, Training Accuracy= 81.60000
# Fold: 9, Epoch: 8, Mini Batch: 18, Loss= 4866.578125, Training Accuracy= 79.00000
#
# Fold: 9, Epoch: 8, Validation Accuracy= 86.50000
#
# Fold: 9, Epoch: 9, Mini Batch: 10, Loss= 4398.627930, Training Accuracy= 80.70000
# Fold: 9, Epoch: 9, Mini Batch: 18, Loss= 3683.662598, Training Accuracy= 81.00000
#
# Fold: 9, Epoch: 9, Validation Accuracy= 86.15000
#
# Fold: 9, Epoch: 10, Mini Batch: 10, Loss= 3508.270508, Training Accuracy= 82.70000
# Fold: 9, Epoch: 10, Mini Batch: 18, Loss= 3594.208496, Training Accuracy= 81.60000
#
# Fold: 9, Epoch: 10, Validation Accuracy= 85.50000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           790    80   870
# 1           210   920  1130
# All        1000  1000  2000
#
# Fold: 9, Epoch: 11, Mini Batch: 10, Loss= 3648.988037, Training Accuracy= 79.40000
# Fold: 9, Epoch: 11, Mini Batch: 18, Loss= 3694.547852, Training Accuracy= 81.50000
#
# Fold: 9, Epoch: 11, Validation Accuracy= 85.80000
#
# Fold: 9, Epoch: 12, Mini Batch: 10, Loss= 3282.117920, Training Accuracy= 80.70000
# Fold: 9, Epoch: 12, Mini Batch: 18, Loss= 3167.508057, Training Accuracy= 81.70000
#
# Fold: 9, Epoch: 12, Validation Accuracy= 85.75000
#
# Fold: 9, Epoch: 13, Mini Batch: 10, Loss= 2978.732178, Training Accuracy= 81.50000
# Fold: 9, Epoch: 13, Mini Batch: 18, Loss= 3103.733154, Training Accuracy= 79.70000
#
# Fold: 9, Epoch: 13, Validation Accuracy= 85.65000
#
# Fold: 9, Epoch: 14, Mini Batch: 10, Loss= 2547.384033, Training Accuracy= 81.60000
# Fold: 9, Epoch: 14, Mini Batch: 18, Loss= 2541.845459, Training Accuracy= 83.30000
#
# Fold: 9, Epoch: 14, Validation Accuracy= 85.75000
#
# Fold: 9, Epoch: 15, Mini Batch: 10, Loss= 2324.186279, Training Accuracy= 83.20000
# Fold: 9, Epoch: 15, Mini Batch: 18, Loss= 2699.745605, Training Accuracy= 83.00000
#
# Fold: 9, Epoch: 15, Validation Accuracy= 86.00000
#
# Fold: 9, Epoch: 16, Mini Batch: 10, Loss= 2362.983398, Training Accuracy= 82.00000
# Fold: 9, Epoch: 16, Mini Batch: 18, Loss= 2276.936768, Training Accuracy= 81.70000
#
# Fold: 9, Epoch: 16, Validation Accuracy= 85.60000
#
# Fold: 9, Epoch: 17, Mini Batch: 10, Loss= 2000.094238, Training Accuracy= 82.80000
# Fold: 9, Epoch: 17, Mini Batch: 18, Loss= 2168.533936, Training Accuracy= 83.30000
#
# Fold: 9, Epoch: 17, Validation Accuracy= 85.60000
#
# Fold: 9, Epoch: 18, Mini Batch: 10, Loss= 1831.323853, Training Accuracy= 83.70000
# Fold: 9, Epoch: 18, Mini Batch: 18, Loss= 2192.916260, Training Accuracy= 82.30000
#
# Fold: 9, Epoch: 18, Validation Accuracy= 85.85000
#
# Fold: 9, Epoch: 19, Mini Batch: 10, Loss= 1906.052856, Training Accuracy= 83.40000
# Fold: 9, Epoch: 19, Mini Batch: 18, Loss= 1895.573730, Training Accuracy= 83.10000
#
# Fold: 9, Epoch: 19, Validation Accuracy= 85.60000
#
# Fold: 9, Epoch: 20, Mini Batch: 10, Loss= 1595.369019, Training Accuracy= 84.10000
# Fold: 9, Epoch: 20, Mini Batch: 18, Loss= 2054.916016, Training Accuracy= 82.10000
#
# Fold: 9, Epoch: 20, Validation Accuracy= 85.15000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           798    95   893
# 1           202   905  1107
# All        1000  1000  2000
#
# Fold: 9, Epoch: 21, Mini Batch: 10, Loss= 1670.863037, Training Accuracy= 84.30000
# Fold: 9, Epoch: 21, Mini Batch: 18, Loss= 1689.683472, Training Accuracy= 82.80000
#
# Fold: 9, Epoch: 21, Validation Accuracy= 84.80000
#
# Fold: 9, Epoch: 22, Mini Batch: 10, Loss= 1537.579712, Training Accuracy= 82.70000
# Fold: 9, Epoch: 22, Mini Batch: 18, Loss= 1534.167969, Training Accuracy= 82.80000
#
# Fold: 9, Epoch: 22, Validation Accuracy= 85.50000
#
# Fold: 9, Epoch: 23, Mini Batch: 10, Loss= 1565.209961, Training Accuracy= 83.50000
# Fold: 9, Epoch: 23, Mini Batch: 18, Loss= 1655.696533, Training Accuracy= 83.60000
#
# Fold: 9, Epoch: 23, Validation Accuracy= 85.55000
#
# Fold: 9, Epoch: 24, Mini Batch: 10, Loss= 1336.938232, Training Accuracy= 82.80000
# Fold: 9, Epoch: 24, Mini Batch: 18, Loss= 1283.031494, Training Accuracy= 84.60000
#
# Fold: 9, Epoch: 24, Validation Accuracy= 85.45000
#
# Fold: 9, Epoch: 25, Mini Batch: 10, Loss= 1073.056030, Training Accuracy= 85.80000
# Fold: 9, Epoch: 25, Mini Batch: 18, Loss= 1338.061279, Training Accuracy= 82.10000
#
# Fold: 9, Epoch: 25, Validation Accuracy= 86.00000
#
# Fold: 9, Epoch: 26, Mini Batch: 10, Loss= 1102.551025, Training Accuracy= 85.20000
# Fold: 9, Epoch: 26, Mini Batch: 18, Loss= 1400.181030, Training Accuracy= 83.00000
#
# Fold: 9, Epoch: 26, Validation Accuracy= 85.40000
#
# Fold: 9, Epoch: 27, Mini Batch: 10, Loss= 1265.235840, Training Accuracy= 83.80000
# Fold: 9, Epoch: 27, Mini Batch: 18, Loss= 1347.758789, Training Accuracy= 82.80000
#
# Fold: 9, Epoch: 27, Validation Accuracy= 85.65000
#
# Fold: 9, Epoch: 28, Mini Batch: 10, Loss= 1043.782837, Training Accuracy= 84.60000
# Fold: 9, Epoch: 28, Mini Batch: 18, Loss= 1081.587280, Training Accuracy= 83.90000
#
# Fold: 9, Epoch: 28, Validation Accuracy= 85.85000
#
# Fold: 9, Epoch: 29, Mini Batch: 10, Loss= 1140.565552, Training Accuracy= 84.00000
# Fold: 9, Epoch: 29, Mini Batch: 18, Loss= 1086.975708, Training Accuracy= 84.40000
#
# Fold: 9, Epoch: 29, Validation Accuracy= 86.00000
#
# Fold: 9, Epoch: 30, Mini Batch: 10, Loss= 935.309998, Training Accuracy= 85.20000
# Fold: 9, Epoch: 30, Mini Batch: 18, Loss= 1043.182129, Training Accuracy= 82.70000
#
# Fold: 9, Epoch: 30, Validation Accuracy= 85.90000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           823   105   928
# 1           177   895  1072
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.003}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1280, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 10, Epoch: 1, Mini Batch: 10, Loss= 23387.660156, Training Accuracy= 72.80000
# Fold: 10, Epoch: 1, Mini Batch: 18, Loss= 20434.357422, Training Accuracy= 76.40000
#
# Fold: 10, Epoch: 1, Validation Accuracy= 84.65000
#
# Fold: 10, Epoch: 2, Mini Batch: 10, Loss= 12593.461914, Training Accuracy= 78.20000
# Fold: 10, Epoch: 2, Mini Batch: 18, Loss= 11550.977539, Training Accuracy= 77.70000
#
# Fold: 10, Epoch: 2, Validation Accuracy= 86.65000
#
# Fold: 10, Epoch: 3, Mini Batch: 10, Loss= 10433.211914, Training Accuracy= 79.30000
# Fold: 10, Epoch: 3, Mini Batch: 18, Loss= 9247.340820, Training Accuracy= 78.70000
#
# Fold: 10, Epoch: 3, Validation Accuracy= 86.85000
#
# Fold: 10, Epoch: 4, Mini Batch: 10, Loss= 9194.801758, Training Accuracy= 79.60000
# Fold: 10, Epoch: 4, Mini Batch: 18, Loss= 7887.819336, Training Accuracy= 78.80000
#
# Fold: 10, Epoch: 4, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 5, Mini Batch: 10, Loss= 5775.608887, Training Accuracy= 81.40000
# Fold: 10, Epoch: 5, Mini Batch: 18, Loss= 6241.523926, Training Accuracy= 79.80000
#
# Fold: 10, Epoch: 5, Validation Accuracy= 87.25000
#
# Fold: 10, Epoch: 6, Mini Batch: 10, Loss= 5946.437012, Training Accuracy= 80.10000
# Fold: 10, Epoch: 6, Mini Batch: 18, Loss= 5708.854492, Training Accuracy= 78.60000
#
# Fold: 10, Epoch: 6, Validation Accuracy= 87.55000
#
# Fold: 10, Epoch: 7, Mini Batch: 10, Loss= 4929.143066, Training Accuracy= 82.40000
# Fold: 10, Epoch: 7, Mini Batch: 18, Loss= 4497.337402, Training Accuracy= 80.80000
#
# Fold: 10, Epoch: 7, Validation Accuracy= 87.30000
#
# Fold: 10, Epoch: 8, Mini Batch: 10, Loss= 4858.982910, Training Accuracy= 81.30000
# Fold: 10, Epoch: 8, Mini Batch: 18, Loss= 4234.093262, Training Accuracy= 81.90000
#
# Fold: 10, Epoch: 8, Validation Accuracy= 86.95000
#
# Fold: 10, Epoch: 9, Mini Batch: 10, Loss= 4112.667480, Training Accuracy= 82.30000
# Fold: 10, Epoch: 9, Mini Batch: 18, Loss= 3942.101807, Training Accuracy= 82.50000
#
# Fold: 10, Epoch: 9, Validation Accuracy= 87.35000
#
# Fold: 10, Epoch: 10, Mini Batch: 10, Loss= 3855.089844, Training Accuracy= 80.10000
# Fold: 10, Epoch: 10, Mini Batch: 18, Loss= 3205.233398, Training Accuracy= 81.00000
#
# Fold: 10, Epoch: 10, Validation Accuracy= 87.55000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           858   107   965
# 1           142   893  1035
# All        1000  1000  2000
#
# Fold: 10, Epoch: 11, Mini Batch: 10, Loss= 3944.509521, Training Accuracy= 78.80000
# Fold: 10, Epoch: 11, Mini Batch: 18, Loss= 3600.971436, Training Accuracy= 80.10000
#
# Fold: 10, Epoch: 11, Validation Accuracy= 87.85000
#
# Fold: 10, Epoch: 12, Mini Batch: 10, Loss= 3252.764404, Training Accuracy= 81.30000
# Fold: 10, Epoch: 12, Mini Batch: 18, Loss= 2945.775391, Training Accuracy= 83.10000
#
# Fold: 10, Epoch: 12, Validation Accuracy= 87.25000
#
# Fold: 10, Epoch: 13, Mini Batch: 10, Loss= 2431.224609, Training Accuracy= 83.40000
# Fold: 10, Epoch: 13, Mini Batch: 18, Loss= 2671.398193, Training Accuracy= 81.90000
#
# Fold: 10, Epoch: 13, Validation Accuracy= 86.90000
#
# Fold: 10, Epoch: 14, Mini Batch: 10, Loss= 2256.538574, Training Accuracy= 83.80000
# Fold: 10, Epoch: 14, Mini Batch: 18, Loss= 2524.824951, Training Accuracy= 81.10000
#
# Fold: 10, Epoch: 14, Validation Accuracy= 87.35000
#
# Fold: 10, Epoch: 15, Mini Batch: 10, Loss= 2253.082764, Training Accuracy= 82.50000
# Fold: 10, Epoch: 15, Mini Batch: 18, Loss= 2614.153564, Training Accuracy= 80.60000
#
# Fold: 10, Epoch: 15, Validation Accuracy= 86.75000
#
# Fold: 10, Epoch: 16, Mini Batch: 10, Loss= 2396.127197, Training Accuracy= 81.40000
# Fold: 10, Epoch: 16, Mini Batch: 18, Loss= 2121.119629, Training Accuracy= 81.30000
#
# Fold: 10, Epoch: 16, Validation Accuracy= 87.00000
#
# Fold: 10, Epoch: 17, Mini Batch: 10, Loss= 2349.172363, Training Accuracy= 83.80000
# Fold: 10, Epoch: 17, Mini Batch: 18, Loss= 2267.109863, Training Accuracy= 82.60000
#
# Fold: 10, Epoch: 17, Validation Accuracy= 87.35000
#
# Fold: 10, Epoch: 18, Mini Batch: 10, Loss= 2081.627930, Training Accuracy= 81.20000
# Fold: 10, Epoch: 18, Mini Batch: 18, Loss= 1764.799072, Training Accuracy= 83.60000
#
# Fold: 10, Epoch: 18, Validation Accuracy= 87.50000
#
# Fold: 10, Epoch: 19, Mini Batch: 10, Loss= 1834.730225, Training Accuracy= 81.90000
# Fold: 10, Epoch: 19, Mini Batch: 18, Loss= 1677.082275, Training Accuracy= 82.70000
#
# Fold: 10, Epoch: 19, Validation Accuracy= 87.20000
#
# Fold: 10, Epoch: 20, Mini Batch: 10, Loss= 1472.969604, Training Accuracy= 84.40000
# Fold: 10, Epoch: 20, Mini Batch: 18, Loss= 1656.472900, Training Accuracy= 83.70000
#
# Fold: 10, Epoch: 20, Validation Accuracy= 86.90000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           842   104   946
# 1           158   896  1054
# All        1000  1000  2000
#
# Fold: 10, Epoch: 21, Mini Batch: 10, Loss= 1482.917969, Training Accuracy= 85.00000
# Fold: 10, Epoch: 21, Mini Batch: 18, Loss= 1685.866333, Training Accuracy= 81.60000
#
# Fold: 10, Epoch: 21, Validation Accuracy= 87.20000
#
# Fold: 10, Epoch: 22, Mini Batch: 10, Loss= 1478.695068, Training Accuracy= 84.10000
# Fold: 10, Epoch: 22, Mini Batch: 18, Loss= 1465.827026, Training Accuracy= 83.70000
#
# Fold: 10, Epoch: 22, Validation Accuracy= 87.15000
#
# Fold: 10, Epoch: 23, Mini Batch: 10, Loss= 1505.664551, Training Accuracy= 84.20000
# Fold: 10, Epoch: 23, Mini Batch: 18, Loss= 1340.887451, Training Accuracy= 84.30000
#
# Fold: 10, Epoch: 23, Validation Accuracy= 87.20000
#
# Fold: 10, Epoch: 24, Mini Batch: 10, Loss= 1296.241577, Training Accuracy= 83.00000
# Fold: 10, Epoch: 24, Mini Batch: 18, Loss= 1521.410278, Training Accuracy= 82.50000
#
# Fold: 10, Epoch: 24, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 25, Mini Batch: 10, Loss= 1260.873291, Training Accuracy= 83.70000
# Fold: 10, Epoch: 25, Mini Batch: 18, Loss= 1358.651978, Training Accuracy= 82.20000
#
# Fold: 10, Epoch: 25, Validation Accuracy= 87.00000
#
# Fold: 10, Epoch: 26, Mini Batch: 10, Loss= 1173.953125, Training Accuracy= 83.50000
# Fold: 10, Epoch: 26, Mini Batch: 18, Loss= 1208.451172, Training Accuracy= 84.10000
#
# Fold: 10, Epoch: 26, Validation Accuracy= 87.20000
#
# Fold: 10, Epoch: 27, Mini Batch: 10, Loss= 943.170044, Training Accuracy= 84.90000
# Fold: 10, Epoch: 27, Mini Batch: 18, Loss= 1031.908691, Training Accuracy= 84.40000
#
# Fold: 10, Epoch: 27, Validation Accuracy= 86.55000
#
# Fold: 10, Epoch: 28, Mini Batch: 10, Loss= 964.420410, Training Accuracy= 83.70000
# Fold: 10, Epoch: 28, Mini Batch: 18, Loss= 1037.056885, Training Accuracy= 83.20000
#
# Fold: 10, Epoch: 28, Validation Accuracy= 87.00000
#
# Fold: 10, Epoch: 29, Mini Batch: 10, Loss= 1106.451538, Training Accuracy= 83.60000
# Fold: 10, Epoch: 29, Mini Batch: 18, Loss= 1185.537842, Training Accuracy= 82.10000
#
# Fold: 10, Epoch: 29, Validation Accuracy= 86.60000
#
# Fold: 10, Epoch: 30, Mini Batch: 10, Loss= 910.656982, Training Accuracy= 84.00000
# Fold: 10, Epoch: 30, Mini Batch: 18, Loss= 889.275452, Training Accuracy= 84.30000
#
# Fold: 10, Epoch: 30, Validation Accuracy= 87.00000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           855   115   970
# 1           145   885  1030
# All        1000  1000  2000
#
# The mean Valid Accuracy is :  87.255

# %%
rows = 2
columns = 5
vizualize(vaccPerEpochPerFold, taccPerEpochPerFold, meanValidAcc=meanValidAcc, rows=rows, columns=columns, figsize=(5*columns, 5*rows))

# %% [markdown]
# ## 4-kernels : HOG - Adam Optimizer / Non- Augmented / Hidden Unit : 1024x1280x1024
# ------

# %%
featureDIR = HOGp4batch_dir

params = dict(imageSize = 32,
              numLabels = 2,
              
              # Network params
              numHidden1 = 1024,
              numHidden2 = 1280,
              numHidden3 = 1024, 

              # Batch Variables
              numFolds = 10,
              epochs = 30,
              batchSize = 1000,
             
              # Optimization Params
              keepProb = dict(hid1=0.75, hid2=0.5, hid3=0.5),
              optimizerParam = dict(optimizer='ADAM', learning_rate=0.007)
             )

# optimizer = tf.train.AdamOptimizer(learning_rate=0.008).minimize(lossCE)

(out, meanValidAcc, lossPerEpochPerFold, taccPerEpochPerFold, vaccPerEpochPerFold) = SessionExec(featureDIR, params).execute() 

print ('The mean Valid Accuracy is : ', meanValidAcc)
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 1, Epoch: 1, Mini Batch: 9, Loss= 22548.992188, Training Accuracy= 70.80000
#
# Fold: 1, Epoch: 1, Validation Accuracy= 82.80000
#
# Fold: 1, Epoch: 2, Mini Batch: 9, Loss= 13756.709961, Training Accuracy= 74.10000
#
# Fold: 1, Epoch: 2, Validation Accuracy= 85.70000
#
# Fold: 1, Epoch: 3, Mini Batch: 9, Loss= 7813.561523, Training Accuracy= 78.70000
#
# Fold: 1, Epoch: 3, Validation Accuracy= 85.00000
#
# Fold: 1, Epoch: 4, Mini Batch: 9, Loss= 6168.707031, Training Accuracy= 80.10000
#
# Fold: 1, Epoch: 4, Validation Accuracy= 83.20000
#
# Fold: 1, Epoch: 5, Mini Batch: 9, Loss= 5246.653809, Training Accuracy= 80.50000
#
# Fold: 1, Epoch: 5, Validation Accuracy= 86.20000
#
# Fold: 1, Epoch: 6, Mini Batch: 9, Loss= 5391.428711, Training Accuracy= 80.20000
#
# Fold: 1, Epoch: 6, Validation Accuracy= 86.60000
#
# Fold: 1, Epoch: 7, Mini Batch: 9, Loss= 4612.091797, Training Accuracy= 80.80000
#
# Fold: 1, Epoch: 7, Validation Accuracy= 86.10000
#
# Fold: 1, Epoch: 8, Mini Batch: 9, Loss= 4171.254395, Training Accuracy= 80.80000
#
# Fold: 1, Epoch: 8, Validation Accuracy= 86.60000
#
# Fold: 1, Epoch: 9, Mini Batch: 9, Loss= 3094.539551, Training Accuracy= 84.60000
#
# Fold: 1, Epoch: 9, Validation Accuracy= 86.00000
#
# Fold: 1, Epoch: 10, Mini Batch: 9, Loss= 3064.071533, Training Accuracy= 82.60000
#
# Fold: 1, Epoch: 10, Validation Accuracy= 86.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          413   50   463
# 1           87  450   537
# All        500  500  1000
#
# Fold: 1, Epoch: 11, Mini Batch: 9, Loss= 2558.959229, Training Accuracy= 85.30000
#
# Fold: 1, Epoch: 11, Validation Accuracy= 86.50000
#
# Fold: 1, Epoch: 12, Mini Batch: 9, Loss= 2697.437744, Training Accuracy= 83.30000
#
# Fold: 1, Epoch: 12, Validation Accuracy= 86.80000
#
# Fold: 1, Epoch: 13, Mini Batch: 9, Loss= 2483.583008, Training Accuracy= 83.60000
#
# Fold: 1, Epoch: 13, Validation Accuracy= 86.50000
#
# Fold: 1, Epoch: 14, Mini Batch: 9, Loss= 2088.355957, Training Accuracy= 84.90000
#
# Fold: 1, Epoch: 14, Validation Accuracy= 87.10000
#
# Fold: 1, Epoch: 15, Mini Batch: 9, Loss= 1656.109253, Training Accuracy= 87.10000
#
# Fold: 1, Epoch: 15, Validation Accuracy= 87.50000
#
# Fold: 1, Epoch: 16, Mini Batch: 9, Loss= 1767.168701, Training Accuracy= 85.30000
#
# Fold: 1, Epoch: 16, Validation Accuracy= 87.70000
#
# Fold: 1, Epoch: 17, Mini Batch: 9, Loss= 1563.988770, Training Accuracy= 86.20000
#
# Fold: 1, Epoch: 17, Validation Accuracy= 87.50000
#
# Fold: 1, Epoch: 18, Mini Batch: 9, Loss= 1652.208984, Training Accuracy= 86.10000
#
# Fold: 1, Epoch: 18, Validation Accuracy= 87.80000
#
# Fold: 1, Epoch: 19, Mini Batch: 9, Loss= 1614.216553, Training Accuracy= 84.60000
#
# Fold: 1, Epoch: 19, Validation Accuracy= 87.90000
#
# Fold: 1, Epoch: 20, Mini Batch: 9, Loss= 1365.558228, Training Accuracy= 87.20000
#
# Fold: 1, Epoch: 20, Validation Accuracy= 87.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   46   464
# 1           82  454   536
# All        500  500  1000
#
# Fold: 1, Epoch: 21, Mini Batch: 9, Loss= 1366.495728, Training Accuracy= 85.00000
#
# Fold: 1, Epoch: 21, Validation Accuracy= 87.60000
#
# Fold: 1, Epoch: 22, Mini Batch: 9, Loss= 1360.480347, Training Accuracy= 84.90000
#
# Fold: 1, Epoch: 22, Validation Accuracy= 86.90000
#
# Fold: 1, Epoch: 23, Mini Batch: 9, Loss= 1147.754272, Training Accuracy= 86.00000
#
# Fold: 1, Epoch: 23, Validation Accuracy= 87.30000
#
# Fold: 1, Epoch: 24, Mini Batch: 9, Loss= 1007.230042, Training Accuracy= 87.80000
#
# Fold: 1, Epoch: 24, Validation Accuracy= 87.20000
#
# Fold: 1, Epoch: 25, Mini Batch: 9, Loss= 1005.012512, Training Accuracy= 88.10000
#
# Fold: 1, Epoch: 25, Validation Accuracy= 87.70000
#
# Fold: 1, Epoch: 26, Mini Batch: 9, Loss= 979.116272, Training Accuracy= 87.20000
#
# Fold: 1, Epoch: 26, Validation Accuracy= 88.00000
#
# Fold: 1, Epoch: 27, Mini Batch: 9, Loss= 933.625305, Training Accuracy= 86.20000
#
# Fold: 1, Epoch: 27, Validation Accuracy= 87.70000
#
# Fold: 1, Epoch: 28, Mini Batch: 9, Loss= 777.720337, Training Accuracy= 89.40000
#
# Fold: 1, Epoch: 28, Validation Accuracy= 87.50000
#
# Fold: 1, Epoch: 29, Mini Batch: 9, Loss= 767.378601, Training Accuracy= 89.80000
#
# Fold: 1, Epoch: 29, Validation Accuracy= 88.10000
#
# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 660.739563, Training Accuracy= 88.60000
#
# Fold: 1, Epoch: 30, Validation Accuracy= 88.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          432   45   477
# 1           68  455   523
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 2, Epoch: 1, Mini Batch: 9, Loss= 26405.943359, Training Accuracy= 67.80000
#
# Fold: 2, Epoch: 1, Validation Accuracy= 81.50000
#
# Fold: 2, Epoch: 2, Mini Batch: 9, Loss= 12511.940430, Training Accuracy= 75.70000
#
# Fold: 2, Epoch: 2, Validation Accuracy= 84.60000
#
# Fold: 2, Epoch: 3, Mini Batch: 9, Loss= 8949.641602, Training Accuracy= 78.20000
#
# Fold: 2, Epoch: 3, Validation Accuracy= 83.20000
#
# Fold: 2, Epoch: 4, Mini Batch: 9, Loss= 6613.327637, Training Accuracy= 79.50000
#
# Fold: 2, Epoch: 4, Validation Accuracy= 85.30000
#
# Fold: 2, Epoch: 5, Mini Batch: 9, Loss= 6209.959961, Training Accuracy= 78.70000
#
# Fold: 2, Epoch: 5, Validation Accuracy= 86.90000
#
# Fold: 2, Epoch: 6, Mini Batch: 9, Loss= 4289.320801, Training Accuracy= 83.10000
#
# Fold: 2, Epoch: 6, Validation Accuracy= 85.40000
#
# Fold: 2, Epoch: 7, Mini Batch: 9, Loss= 4233.997070, Training Accuracy= 82.30000
#
# Fold: 2, Epoch: 7, Validation Accuracy= 86.30000
#
# Fold: 2, Epoch: 8, Mini Batch: 9, Loss= 3238.601562, Training Accuracy= 83.40000
#
# Fold: 2, Epoch: 8, Validation Accuracy= 85.70000
#
# Fold: 2, Epoch: 9, Mini Batch: 9, Loss= 3121.702393, Training Accuracy= 82.70000
#
# Fold: 2, Epoch: 9, Validation Accuracy= 86.10000
#
# Fold: 2, Epoch: 10, Mini Batch: 9, Loss= 3492.117920, Training Accuracy= 83.10000
#
# Fold: 2, Epoch: 10, Validation Accuracy= 85.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          411   53   464
# 1           89  447   536
# All        500  500  1000
#
# Fold: 2, Epoch: 11, Mini Batch: 9, Loss= 3069.770020, Training Accuracy= 82.00000
#
# Fold: 2, Epoch: 11, Validation Accuracy= 86.30000
#
# Fold: 2, Epoch: 12, Mini Batch: 9, Loss= 2752.659668, Training Accuracy= 83.40000
#
# Fold: 2, Epoch: 12, Validation Accuracy= 86.70000
#
# Fold: 2, Epoch: 13, Mini Batch: 9, Loss= 2607.000000, Training Accuracy= 84.90000
#
# Fold: 2, Epoch: 13, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 14, Mini Batch: 9, Loss= 2151.346436, Training Accuracy= 85.80000
#
# Fold: 2, Epoch: 14, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 15, Mini Batch: 9, Loss= 1899.376343, Training Accuracy= 86.30000
#
# Fold: 2, Epoch: 15, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 16, Mini Batch: 9, Loss= 1999.626709, Training Accuracy= 84.60000
#
# Fold: 2, Epoch: 16, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 17, Mini Batch: 9, Loss= 1601.235107, Training Accuracy= 84.70000
#
# Fold: 2, Epoch: 17, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 18, Mini Batch: 9, Loss= 1672.916992, Training Accuracy= 85.10000
#
# Fold: 2, Epoch: 18, Validation Accuracy= 87.50000
#
# Fold: 2, Epoch: 19, Mini Batch: 9, Loss= 1619.874023, Training Accuracy= 85.40000
#
# Fold: 2, Epoch: 19, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 20, Mini Batch: 9, Loss= 1422.940308, Training Accuracy= 87.00000
#
# Fold: 2, Epoch: 20, Validation Accuracy= 87.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          427   56   483
# 1           73  444   517
# All        500  500  1000
#
# Fold: 2, Epoch: 21, Mini Batch: 9, Loss= 1597.401978, Training Accuracy= 85.80000
#
# Fold: 2, Epoch: 21, Validation Accuracy= 87.40000
#
# Fold: 2, Epoch: 22, Mini Batch: 9, Loss= 1321.292236, Training Accuracy= 85.70000
#
# Fold: 2, Epoch: 22, Validation Accuracy= 88.00000
#
# Fold: 2, Epoch: 23, Mini Batch: 9, Loss= 1313.969727, Training Accuracy= 86.80000
#
# Fold: 2, Epoch: 23, Validation Accuracy= 87.60000
#
# Fold: 2, Epoch: 24, Mini Batch: 9, Loss= 1237.767578, Training Accuracy= 86.60000
#
# Fold: 2, Epoch: 24, Validation Accuracy= 87.50000
#
# Fold: 2, Epoch: 25, Mini Batch: 9, Loss= 1206.934204, Training Accuracy= 85.50000
#
# Fold: 2, Epoch: 25, Validation Accuracy= 87.40000
#
# Fold: 2, Epoch: 26, Mini Batch: 9, Loss= 996.100098, Training Accuracy= 87.30000
#
# Fold: 2, Epoch: 26, Validation Accuracy= 87.40000
#
# Fold: 2, Epoch: 27, Mini Batch: 9, Loss= 881.970398, Training Accuracy= 87.50000
#
# Fold: 2, Epoch: 27, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 28, Mini Batch: 9, Loss= 978.989868, Training Accuracy= 87.10000
#
# Fold: 2, Epoch: 28, Validation Accuracy= 86.80000
#
# Fold: 2, Epoch: 29, Mini Batch: 9, Loss= 751.151001, Training Accuracy= 88.90000
#
# Fold: 2, Epoch: 29, Validation Accuracy= 86.90000
#
# Fold: 2, Epoch: 30, Mini Batch: 9, Loss= 794.433655, Training Accuracy= 88.80000
#
# Fold: 2, Epoch: 30, Validation Accuracy= 86.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          431   68   499
# 1           69  432   501
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 3, Epoch: 1, Mini Batch: 9, Loss= 20068.164062, Training Accuracy= 72.50000
#
# Fold: 3, Epoch: 1, Validation Accuracy= 81.20000
#
# Fold: 3, Epoch: 2, Mini Batch: 9, Loss= 13343.420898, Training Accuracy= 77.80000
#
# Fold: 3, Epoch: 2, Validation Accuracy= 84.10000
#
# Fold: 3, Epoch: 3, Mini Batch: 9, Loss= 9440.818359, Training Accuracy= 77.60000
#
# Fold: 3, Epoch: 3, Validation Accuracy= 83.10000
#
# Fold: 3, Epoch: 4, Mini Batch: 9, Loss= 8021.296875, Training Accuracy= 78.50000
#
# Fold: 3, Epoch: 4, Validation Accuracy= 80.40000
#
# Fold: 3, Epoch: 5, Mini Batch: 9, Loss= 5273.130859, Training Accuracy= 80.80000
#
# Fold: 3, Epoch: 5, Validation Accuracy= 84.20000
#
# Fold: 3, Epoch: 6, Mini Batch: 9, Loss= 4886.849609, Training Accuracy= 80.00000
#
# Fold: 3, Epoch: 6, Validation Accuracy= 85.10000
#
# Fold: 3, Epoch: 7, Mini Batch: 9, Loss= 4064.611328, Training Accuracy= 81.70000
#
# Fold: 3, Epoch: 7, Validation Accuracy= 84.60000
#
# Fold: 3, Epoch: 8, Mini Batch: 9, Loss= 3719.252441, Training Accuracy= 82.30000
#
# Fold: 3, Epoch: 8, Validation Accuracy= 85.30000
#
# Fold: 3, Epoch: 9, Mini Batch: 9, Loss= 3210.996338, Training Accuracy= 84.00000
#
# Fold: 3, Epoch: 9, Validation Accuracy= 85.60000
#
# Fold: 3, Epoch: 10, Mini Batch: 9, Loss= 2675.070801, Training Accuracy= 85.10000
#
# Fold: 3, Epoch: 10, Validation Accuracy= 84.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          392   49   441
# 1          108  451   559
# All        500  500  1000
#
# Fold: 3, Epoch: 11, Mini Batch: 9, Loss= 2384.906494, Training Accuracy= 85.00000
#
# Fold: 3, Epoch: 11, Validation Accuracy= 84.10000
#
# Fold: 3, Epoch: 12, Mini Batch: 9, Loss= 2606.113770, Training Accuracy= 84.30000
#
# Fold: 3, Epoch: 12, Validation Accuracy= 84.90000
#
# Fold: 3, Epoch: 13, Mini Batch: 9, Loss= 2288.812012, Training Accuracy= 84.50000
#
# Fold: 3, Epoch: 13, Validation Accuracy= 85.00000
#
# Fold: 3, Epoch: 14, Mini Batch: 9, Loss= 2123.871582, Training Accuracy= 86.50000
#
# Fold: 3, Epoch: 14, Validation Accuracy= 84.50000
#
# Fold: 3, Epoch: 15, Mini Batch: 9, Loss= 2166.431396, Training Accuracy= 85.20000
#
# Fold: 3, Epoch: 15, Validation Accuracy= 84.80000
#
# Fold: 3, Epoch: 16, Mini Batch: 9, Loss= 1915.299194, Training Accuracy= 86.60000
#
# Fold: 3, Epoch: 16, Validation Accuracy= 85.00000
#
# Fold: 3, Epoch: 17, Mini Batch: 9, Loss= 1778.724976, Training Accuracy= 84.90000
#
# Fold: 3, Epoch: 17, Validation Accuracy= 84.90000
#
# Fold: 3, Epoch: 18, Mini Batch: 9, Loss= 1650.657471, Training Accuracy= 86.40000
#
# Fold: 3, Epoch: 18, Validation Accuracy= 85.10000
#
# Fold: 3, Epoch: 19, Mini Batch: 9, Loss= 1665.827637, Training Accuracy= 84.40000
#
# Fold: 3, Epoch: 19, Validation Accuracy= 84.80000
#
# Fold: 3, Epoch: 20, Mini Batch: 9, Loss= 1441.317993, Training Accuracy= 85.90000
#
# Fold: 3, Epoch: 20, Validation Accuracy= 84.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          396   51   447
# 1          104  449   553
# All        500  500  1000
#
# Fold: 3, Epoch: 21, Mini Batch: 9, Loss= 1246.499512, Training Accuracy= 85.40000
#
# Fold: 3, Epoch: 21, Validation Accuracy= 84.50000
#
# Fold: 3, Epoch: 22, Mini Batch: 9, Loss= 1041.733276, Training Accuracy= 87.80000
#
# Fold: 3, Epoch: 22, Validation Accuracy= 85.00000
#
# Fold: 3, Epoch: 23, Mini Batch: 9, Loss= 979.228210, Training Accuracy= 89.00000
#
# Fold: 3, Epoch: 23, Validation Accuracy= 84.60000
#
# Fold: 3, Epoch: 24, Mini Batch: 9, Loss= 1209.200195, Training Accuracy= 86.10000
#
# Fold: 3, Epoch: 24, Validation Accuracy= 84.10000
#
# Fold: 3, Epoch: 25, Mini Batch: 9, Loss= 973.237000, Training Accuracy= 87.50000
#
# Fold: 3, Epoch: 25, Validation Accuracy= 84.60000
#
# Fold: 3, Epoch: 26, Mini Batch: 9, Loss= 977.702576, Training Accuracy= 87.20000
#
# Fold: 3, Epoch: 26, Validation Accuracy= 85.00000
#
# Fold: 3, Epoch: 27, Mini Batch: 9, Loss= 972.261230, Training Accuracy= 88.20000
#
# Fold: 3, Epoch: 27, Validation Accuracy= 85.10000
#
# Fold: 3, Epoch: 28, Mini Batch: 9, Loss= 769.585693, Training Accuracy= 88.80000
#
# Fold: 3, Epoch: 28, Validation Accuracy= 85.80000
#
# Fold: 3, Epoch: 29, Mini Batch: 9, Loss= 738.078857, Training Accuracy= 87.90000
#
# Fold: 3, Epoch: 29, Validation Accuracy= 85.60000
#
# Fold: 3, Epoch: 30, Mini Batch: 9, Loss= 656.655396, Training Accuracy= 89.30000
#
# Fold: 3, Epoch: 30, Validation Accuracy= 85.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          406   53   459
# 1           94  447   541
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 4, Epoch: 1, Mini Batch: 9, Loss= 19261.863281, Training Accuracy= 73.60000
#
# Fold: 4, Epoch: 1, Validation Accuracy= 81.00000
#
# Fold: 4, Epoch: 2, Mini Batch: 9, Loss= 13736.956055, Training Accuracy= 77.30000
#
# Fold: 4, Epoch: 2, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 3, Mini Batch: 9, Loss= 8288.302734, Training Accuracy= 77.60000
#
# Fold: 4, Epoch: 3, Validation Accuracy= 86.40000
#
# Fold: 4, Epoch: 4, Mini Batch: 9, Loss= 7117.187012, Training Accuracy= 80.20000
#
# Fold: 4, Epoch: 4, Validation Accuracy= 84.40000
#
# Fold: 4, Epoch: 5, Mini Batch: 9, Loss= 5156.891113, Training Accuracy= 82.00000
#
# Fold: 4, Epoch: 5, Validation Accuracy= 85.10000
#
# Fold: 4, Epoch: 6, Mini Batch: 9, Loss= 4432.075195, Training Accuracy= 81.30000
#
# Fold: 4, Epoch: 6, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 7, Mini Batch: 9, Loss= 3774.277588, Training Accuracy= 83.00000
#
# Fold: 4, Epoch: 7, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 8, Mini Batch: 9, Loss= 3636.498047, Training Accuracy= 82.40000
#
# Fold: 4, Epoch: 8, Validation Accuracy= 86.60000
#
# Fold: 4, Epoch: 9, Mini Batch: 9, Loss= 3605.643555, Training Accuracy= 81.50000
#
# Fold: 4, Epoch: 9, Validation Accuracy= 87.40000
#
# Fold: 4, Epoch: 10, Mini Batch: 9, Loss= 2730.903564, Training Accuracy= 83.30000
#
# Fold: 4, Epoch: 10, Validation Accuracy= 87.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          428   51   479
# 1           72  449   521
# All        500  500  1000
#
# Fold: 4, Epoch: 11, Mini Batch: 9, Loss= 2445.916992, Training Accuracy= 84.30000
#
# Fold: 4, Epoch: 11, Validation Accuracy= 87.50000
#
# Fold: 4, Epoch: 12, Mini Batch: 9, Loss= 2429.112305, Training Accuracy= 84.60000
#
# Fold: 4, Epoch: 12, Validation Accuracy= 87.60000
#
# Fold: 4, Epoch: 13, Mini Batch: 9, Loss= 2242.173584, Training Accuracy= 84.50000
#
# Fold: 4, Epoch: 13, Validation Accuracy= 87.10000
#
# Fold: 4, Epoch: 14, Mini Batch: 9, Loss= 2171.122070, Training Accuracy= 84.30000
#
# Fold: 4, Epoch: 14, Validation Accuracy= 86.70000
#
# Fold: 4, Epoch: 15, Mini Batch: 9, Loss= 1901.206055, Training Accuracy= 85.10000
#
# Fold: 4, Epoch: 15, Validation Accuracy= 86.30000
#
# Fold: 4, Epoch: 16, Mini Batch: 9, Loss= 1688.206299, Training Accuracy= 85.50000
#
# Fold: 4, Epoch: 16, Validation Accuracy= 86.60000
#
# Fold: 4, Epoch: 17, Mini Batch: 9, Loss= 1646.436279, Training Accuracy= 85.40000
#
# Fold: 4, Epoch: 17, Validation Accuracy= 86.40000
#
# Fold: 4, Epoch: 18, Mini Batch: 9, Loss= 1399.177734, Training Accuracy= 85.50000
#
# Fold: 4, Epoch: 18, Validation Accuracy= 86.20000
#
# Fold: 4, Epoch: 19, Mini Batch: 9, Loss= 1362.740601, Training Accuracy= 85.70000
#
# Fold: 4, Epoch: 19, Validation Accuracy= 86.90000
#
# Fold: 4, Epoch: 20, Mini Batch: 9, Loss= 1264.274536, Training Accuracy= 86.80000
#
# Fold: 4, Epoch: 20, Validation Accuracy= 86.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          434   65   499
# 1           66  435   501
# All        500  500  1000
#
# Fold: 4, Epoch: 21, Mini Batch: 9, Loss= 1360.240967, Training Accuracy= 86.10000
#
# Fold: 4, Epoch: 21, Validation Accuracy= 86.60000
#
# Fold: 4, Epoch: 22, Mini Batch: 9, Loss= 1097.494995, Training Accuracy= 87.90000
#
# Fold: 4, Epoch: 22, Validation Accuracy= 86.50000
#
# Fold: 4, Epoch: 23, Mini Batch: 9, Loss= 1138.896240, Training Accuracy= 87.10000
#
# Fold: 4, Epoch: 23, Validation Accuracy= 86.50000
#
# Fold: 4, Epoch: 24, Mini Batch: 9, Loss= 1069.005737, Training Accuracy= 87.50000
#
# Fold: 4, Epoch: 24, Validation Accuracy= 86.80000
#
# Fold: 4, Epoch: 25, Mini Batch: 9, Loss= 925.567200, Training Accuracy= 87.60000
#
# Fold: 4, Epoch: 25, Validation Accuracy= 86.60000
#
# Fold: 4, Epoch: 26, Mini Batch: 9, Loss= 969.412048, Training Accuracy= 87.00000
#
# Fold: 4, Epoch: 26, Validation Accuracy= 86.00000
#
# Fold: 4, Epoch: 27, Mini Batch: 9, Loss= 991.755432, Training Accuracy= 87.80000
#
# Fold: 4, Epoch: 27, Validation Accuracy= 87.20000
#
# Fold: 4, Epoch: 28, Mini Batch: 9, Loss= 828.445862, Training Accuracy= 87.60000
#
# Fold: 4, Epoch: 28, Validation Accuracy= 86.30000
#
# Fold: 4, Epoch: 29, Mini Batch: 9, Loss= 739.130371, Training Accuracy= 88.40000
#
# Fold: 4, Epoch: 29, Validation Accuracy= 87.00000
#
# Fold: 4, Epoch: 30, Mini Batch: 9, Loss= 745.234497, Training Accuracy= 87.30000
#
# Fold: 4, Epoch: 30, Validation Accuracy= 86.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          431   63   494
# 1           69  437   506
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 5, Epoch: 1, Mini Batch: 9, Loss= 24068.039062, Training Accuracy= 69.30000
#
# Fold: 5, Epoch: 1, Validation Accuracy= 82.70000
#
# Fold: 5, Epoch: 2, Mini Batch: 9, Loss= 14151.940430, Training Accuracy= 74.80000
#
# Fold: 5, Epoch: 2, Validation Accuracy= 85.00000
#
# Fold: 5, Epoch: 3, Mini Batch: 9, Loss= 7635.722656, Training Accuracy= 79.90000
#
# Fold: 5, Epoch: 3, Validation Accuracy= 85.20000
#
# Fold: 5, Epoch: 4, Mini Batch: 9, Loss= 6510.022461, Training Accuracy= 79.90000
#
# Fold: 5, Epoch: 4, Validation Accuracy= 83.60000
#
# Fold: 5, Epoch: 5, Mini Batch: 9, Loss= 5604.894531, Training Accuracy= 79.60000
#
# Fold: 5, Epoch: 5, Validation Accuracy= 85.80000
#
# Fold: 5, Epoch: 6, Mini Batch: 9, Loss= 4719.741211, Training Accuracy= 81.00000
#
# Fold: 5, Epoch: 6, Validation Accuracy= 86.00000
#
# Fold: 5, Epoch: 7, Mini Batch: 9, Loss= 4424.640625, Training Accuracy= 83.10000
#
# Fold: 5, Epoch: 7, Validation Accuracy= 85.30000
#
# Fold: 5, Epoch: 8, Mini Batch: 9, Loss= 3975.750488, Training Accuracy= 81.70000
#
# Fold: 5, Epoch: 8, Validation Accuracy= 86.90000
#
# Fold: 5, Epoch: 9, Mini Batch: 9, Loss= 3581.731689, Training Accuracy= 83.10000
#
# Fold: 5, Epoch: 9, Validation Accuracy= 87.00000
#
# Fold: 5, Epoch: 10, Mini Batch: 9, Loss= 3129.209473, Training Accuracy= 81.60000
#
# Fold: 5, Epoch: 10, Validation Accuracy= 87.00000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          403   33   436
# 1           97  467   564
# All        500  500  1000
#
# Fold: 5, Epoch: 11, Mini Batch: 9, Loss= 2929.021484, Training Accuracy= 82.30000
#
# Fold: 5, Epoch: 11, Validation Accuracy= 86.90000
#
# Fold: 5, Epoch: 12, Mini Batch: 9, Loss= 2667.131104, Training Accuracy= 83.10000
#
# Fold: 5, Epoch: 12, Validation Accuracy= 86.40000
#
# Fold: 5, Epoch: 13, Mini Batch: 9, Loss= 2472.543701, Training Accuracy= 83.00000
#
# Fold: 5, Epoch: 13, Validation Accuracy= 87.20000
#
# Fold: 5, Epoch: 14, Mini Batch: 9, Loss= 2208.162842, Training Accuracy= 83.90000
#
# Fold: 5, Epoch: 14, Validation Accuracy= 87.80000
#
# Fold: 5, Epoch: 15, Mini Batch: 9, Loss= 2083.176025, Training Accuracy= 83.50000
#
# Fold: 5, Epoch: 15, Validation Accuracy= 87.10000
#
# Fold: 5, Epoch: 16, Mini Batch: 9, Loss= 1795.687378, Training Accuracy= 84.90000
#
# Fold: 5, Epoch: 16, Validation Accuracy= 86.80000
#
# Fold: 5, Epoch: 17, Mini Batch: 9, Loss= 1578.137695, Training Accuracy= 86.70000
#
# Fold: 5, Epoch: 17, Validation Accuracy= 87.00000
#
# Fold: 5, Epoch: 18, Mini Batch: 9, Loss= 1676.760864, Training Accuracy= 84.20000
#
# Fold: 5, Epoch: 18, Validation Accuracy= 87.00000
#
# Fold: 5, Epoch: 19, Mini Batch: 9, Loss= 1699.675781, Training Accuracy= 85.70000
#
# Fold: 5, Epoch: 19, Validation Accuracy= 87.00000
#
# Fold: 5, Epoch: 20, Mini Batch: 9, Loss= 1437.581909, Training Accuracy= 85.70000
#
# Fold: 5, Epoch: 20, Validation Accuracy= 86.60000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   52   470
# 1           82  448   530
# All        500  500  1000
#
# Fold: 5, Epoch: 21, Mini Batch: 9, Loss= 1379.302979, Training Accuracy= 86.90000
#
# Fold: 5, Epoch: 21, Validation Accuracy= 86.80000
#
# Fold: 5, Epoch: 22, Mini Batch: 9, Loss= 1312.904785, Training Accuracy= 87.00000
#
# Fold: 5, Epoch: 22, Validation Accuracy= 87.00000
#
# Fold: 5, Epoch: 23, Mini Batch: 9, Loss= 1071.004517, Training Accuracy= 85.80000
#
# Fold: 5, Epoch: 23, Validation Accuracy= 86.20000
#
# Fold: 5, Epoch: 24, Mini Batch: 9, Loss= 1015.140930, Training Accuracy= 87.10000
#
# Fold: 5, Epoch: 24, Validation Accuracy= 86.00000
#
# Fold: 5, Epoch: 25, Mini Batch: 9, Loss= 959.732605, Training Accuracy= 87.00000
#
# Fold: 5, Epoch: 25, Validation Accuracy= 86.50000
#
# Fold: 5, Epoch: 26, Mini Batch: 9, Loss= 948.881042, Training Accuracy= 87.80000
#
# Fold: 5, Epoch: 26, Validation Accuracy= 85.90000
#
# Fold: 5, Epoch: 27, Mini Batch: 9, Loss= 768.030823, Training Accuracy= 88.00000
#
# Fold: 5, Epoch: 27, Validation Accuracy= 86.90000
#
# Fold: 5, Epoch: 28, Mini Batch: 9, Loss= 800.059143, Training Accuracy= 88.90000
#
# Fold: 5, Epoch: 28, Validation Accuracy= 86.40000
#
# Fold: 5, Epoch: 29, Mini Batch: 9, Loss= 747.861755, Training Accuracy= 88.30000
#
# Fold: 5, Epoch: 29, Validation Accuracy= 87.30000
#
# Fold: 5, Epoch: 30, Mini Batch: 9, Loss= 755.499268, Training Accuracy= 87.80000
#
# Fold: 5, Epoch: 30, Validation Accuracy= 86.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          408   41   449
# 1           92  459   551
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 6, Epoch: 1, Mini Batch: 9, Loss= 21049.035156, Training Accuracy= 71.80000
#
# Fold: 6, Epoch: 1, Validation Accuracy= 82.80000
#
# Fold: 6, Epoch: 2, Mini Batch: 9, Loss= 13777.981445, Training Accuracy= 75.90000
#
# Fold: 6, Epoch: 2, Validation Accuracy= 86.00000
#
# Fold: 6, Epoch: 3, Mini Batch: 9, Loss= 8100.185547, Training Accuracy= 78.60000
#
# Fold: 6, Epoch: 3, Validation Accuracy= 86.20000
#
# Fold: 6, Epoch: 4, Mini Batch: 9, Loss= 6592.650879, Training Accuracy= 81.10000
#
# Fold: 6, Epoch: 4, Validation Accuracy= 85.90000
#
# Fold: 6, Epoch: 5, Mini Batch: 9, Loss= 5571.086914, Training Accuracy= 81.00000
#
# Fold: 6, Epoch: 5, Validation Accuracy= 86.60000
#
# Fold: 6, Epoch: 6, Mini Batch: 9, Loss= 4868.614258, Training Accuracy= 81.30000
#
# Fold: 6, Epoch: 6, Validation Accuracy= 87.10000
#
# Fold: 6, Epoch: 7, Mini Batch: 9, Loss= 4293.670410, Training Accuracy= 82.20000
#
# Fold: 6, Epoch: 7, Validation Accuracy= 86.90000
#
# Fold: 6, Epoch: 8, Mini Batch: 9, Loss= 3773.706299, Training Accuracy= 82.00000
#
# Fold: 6, Epoch: 8, Validation Accuracy= 86.40000
#
# Fold: 6, Epoch: 9, Mini Batch: 9, Loss= 3208.567383, Training Accuracy= 82.00000
#
# Fold: 6, Epoch: 9, Validation Accuracy= 86.80000
#
# Fold: 6, Epoch: 10, Mini Batch: 9, Loss= 2790.855713, Training Accuracy= 83.80000
#
# Fold: 6, Epoch: 10, Validation Accuracy= 86.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          412   45   457
# 1           88  455   543
# All        500  500  1000
#
# Fold: 6, Epoch: 11, Mini Batch: 9, Loss= 2549.425049, Training Accuracy= 82.40000
#
# Fold: 6, Epoch: 11, Validation Accuracy= 86.80000
#
# Fold: 6, Epoch: 12, Mini Batch: 9, Loss= 2275.027588, Training Accuracy= 85.00000
#
# Fold: 6, Epoch: 12, Validation Accuracy= 86.70000
#
# Fold: 6, Epoch: 13, Mini Batch: 9, Loss= 2579.967529, Training Accuracy= 83.50000
#
# Fold: 6, Epoch: 13, Validation Accuracy= 86.60000
#
# Fold: 6, Epoch: 14, Mini Batch: 9, Loss= 2114.954834, Training Accuracy= 83.10000
#
# Fold: 6, Epoch: 14, Validation Accuracy= 86.50000
#
# Fold: 6, Epoch: 15, Mini Batch: 9, Loss= 1765.330811, Training Accuracy= 85.70000
#
# Fold: 6, Epoch: 15, Validation Accuracy= 86.40000
#
# Fold: 6, Epoch: 16, Mini Batch: 9, Loss= 1926.902100, Training Accuracy= 84.10000
#
# Fold: 6, Epoch: 16, Validation Accuracy= 87.40000
#
# Fold: 6, Epoch: 17, Mini Batch: 9, Loss= 1688.657227, Training Accuracy= 85.40000
#
# Fold: 6, Epoch: 17, Validation Accuracy= 86.60000
#
# Fold: 6, Epoch: 18, Mini Batch: 9, Loss= 1681.211792, Training Accuracy= 85.00000
#
# Fold: 6, Epoch: 18, Validation Accuracy= 86.80000
#
# Fold: 6, Epoch: 19, Mini Batch: 9, Loss= 1402.588257, Training Accuracy= 85.40000
#
# Fold: 6, Epoch: 19, Validation Accuracy= 87.10000
#
# Fold: 6, Epoch: 20, Mini Batch: 9, Loss= 1334.756714, Training Accuracy= 86.50000
#
# Fold: 6, Epoch: 20, Validation Accuracy= 87.10000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          434   63   497
# 1           66  437   503
# All        500  500  1000
#
# Fold: 6, Epoch: 21, Mini Batch: 9, Loss= 1348.009766, Training Accuracy= 87.30000
#
# Fold: 6, Epoch: 21, Validation Accuracy= 87.30000
#
# Fold: 6, Epoch: 22, Mini Batch: 9, Loss= 1253.663086, Training Accuracy= 86.80000
#
# Fold: 6, Epoch: 22, Validation Accuracy= 86.60000
#
# Fold: 6, Epoch: 23, Mini Batch: 9, Loss= 1149.979004, Training Accuracy= 87.80000
#
# Fold: 6, Epoch: 23, Validation Accuracy= 87.20000
#
# Fold: 6, Epoch: 24, Mini Batch: 9, Loss= 1089.457031, Training Accuracy= 86.20000
#
# Fold: 6, Epoch: 24, Validation Accuracy= 87.60000
#
# Fold: 6, Epoch: 25, Mini Batch: 9, Loss= 887.617371, Training Accuracy= 87.00000
#
# Fold: 6, Epoch: 25, Validation Accuracy= 87.20000
#
# Fold: 6, Epoch: 26, Mini Batch: 9, Loss= 965.857605, Training Accuracy= 88.30000
#
# Fold: 6, Epoch: 26, Validation Accuracy= 86.80000
#
# Fold: 6, Epoch: 27, Mini Batch: 9, Loss= 851.372864, Training Accuracy= 86.80000
#
# Fold: 6, Epoch: 27, Validation Accuracy= 86.90000
#
# Fold: 6, Epoch: 28, Mini Batch: 9, Loss= 734.293518, Training Accuracy= 87.70000
#
# Fold: 6, Epoch: 28, Validation Accuracy= 87.20000
#
# Fold: 6, Epoch: 29, Mini Batch: 9, Loss= 700.509521, Training Accuracy= 88.90000
#
# Fold: 6, Epoch: 29, Validation Accuracy= 87.50000
#
# Fold: 6, Epoch: 30, Mini Batch: 9, Loss= 653.941528, Training Accuracy= 90.00000
#
# Fold: 6, Epoch: 30, Validation Accuracy= 87.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          429   56   485
# 1           71  444   515
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 7, Epoch: 1, Mini Batch: 9, Loss= 28313.835938, Training Accuracy= 68.60000
#
# Fold: 7, Epoch: 1, Validation Accuracy= 79.00000
#
# Fold: 7, Epoch: 2, Mini Batch: 9, Loss= 13278.832031, Training Accuracy= 75.50000
#
# Fold: 7, Epoch: 2, Validation Accuracy= 83.80000
#
# Fold: 7, Epoch: 3, Mini Batch: 9, Loss= 9260.952148, Training Accuracy= 77.80000
#
# Fold: 7, Epoch: 3, Validation Accuracy= 80.70000
#
# Fold: 7, Epoch: 4, Mini Batch: 9, Loss= 6617.645996, Training Accuracy= 81.40000
#
# Fold: 7, Epoch: 4, Validation Accuracy= 85.10000
#
# Fold: 7, Epoch: 5, Mini Batch: 9, Loss= 5514.882812, Training Accuracy= 80.30000
#
# Fold: 7, Epoch: 5, Validation Accuracy= 85.50000
#
# Fold: 7, Epoch: 6, Mini Batch: 9, Loss= 4756.256348, Training Accuracy= 81.50000
#
# Fold: 7, Epoch: 6, Validation Accuracy= 85.20000
#
# Fold: 7, Epoch: 7, Mini Batch: 9, Loss= 4243.789062, Training Accuracy= 81.10000
#
# Fold: 7, Epoch: 7, Validation Accuracy= 85.80000
#
# Fold: 7, Epoch: 8, Mini Batch: 9, Loss= 3542.311768, Training Accuracy= 82.00000
#
# Fold: 7, Epoch: 8, Validation Accuracy= 86.00000
#
# Fold: 7, Epoch: 9, Mini Batch: 9, Loss= 3110.874512, Training Accuracy= 81.40000
#
# Fold: 7, Epoch: 9, Validation Accuracy= 86.40000
#
# Fold: 7, Epoch: 10, Mini Batch: 9, Loss= 3311.772949, Training Accuracy= 82.90000
#
# Fold: 7, Epoch: 10, Validation Accuracy= 85.90000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          404   45   449
# 1           96  455   551
# All        500  500  1000
#
# Fold: 7, Epoch: 11, Mini Batch: 9, Loss= 2542.872559, Training Accuracy= 85.70000
#
# Fold: 7, Epoch: 11, Validation Accuracy= 86.00000
#
# Fold: 7, Epoch: 12, Mini Batch: 9, Loss= 2837.922607, Training Accuracy= 83.30000
#
# Fold: 7, Epoch: 12, Validation Accuracy= 86.10000
#
# Fold: 7, Epoch: 13, Mini Batch: 9, Loss= 2186.359863, Training Accuracy= 84.80000
#
# Fold: 7, Epoch: 13, Validation Accuracy= 86.40000
#
# Fold: 7, Epoch: 14, Mini Batch: 9, Loss= 2528.624023, Training Accuracy= 81.40000
#
# Fold: 7, Epoch: 14, Validation Accuracy= 87.70000
#
# Fold: 7, Epoch: 15, Mini Batch: 9, Loss= 2238.530029, Training Accuracy= 84.40000
#
# Fold: 7, Epoch: 15, Validation Accuracy= 87.10000
#
# Fold: 7, Epoch: 16, Mini Batch: 9, Loss= 2077.094238, Training Accuracy= 83.30000
#
# Fold: 7, Epoch: 16, Validation Accuracy= 86.80000
#
# Fold: 7, Epoch: 17, Mini Batch: 9, Loss= 1967.555298, Training Accuracy= 85.70000
#
# Fold: 7, Epoch: 17, Validation Accuracy= 86.90000
#
# Fold: 7, Epoch: 18, Mini Batch: 9, Loss= 1781.211304, Training Accuracy= 84.40000
#
# Fold: 7, Epoch: 18, Validation Accuracy= 86.60000
#
# Fold: 7, Epoch: 19, Mini Batch: 9, Loss= 1640.084839, Training Accuracy= 84.20000
#
# Fold: 7, Epoch: 19, Validation Accuracy= 86.60000
#
# Fold: 7, Epoch: 20, Mini Batch: 9, Loss= 1419.229980, Training Accuracy= 86.20000
#
# Fold: 7, Epoch: 20, Validation Accuracy= 86.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          423   58   481
# 1           77  442   519
# All        500  500  1000
#
# Fold: 7, Epoch: 21, Mini Batch: 9, Loss= 1564.697510, Training Accuracy= 86.40000
#
# Fold: 7, Epoch: 21, Validation Accuracy= 86.90000
#
# Fold: 7, Epoch: 22, Mini Batch: 9, Loss= 1304.897949, Training Accuracy= 87.20000
#
# Fold: 7, Epoch: 22, Validation Accuracy= 87.20000
#
# Fold: 7, Epoch: 23, Mini Batch: 9, Loss= 1239.436768, Training Accuracy= 85.60000
#
# Fold: 7, Epoch: 23, Validation Accuracy= 87.30000
#
# Fold: 7, Epoch: 24, Mini Batch: 9, Loss= 1195.945923, Training Accuracy= 86.40000
#
# Fold: 7, Epoch: 24, Validation Accuracy= 87.40000
#
# Fold: 7, Epoch: 25, Mini Batch: 9, Loss= 1145.249146, Training Accuracy= 86.60000
#
# Fold: 7, Epoch: 25, Validation Accuracy= 86.70000
#
# Fold: 7, Epoch: 26, Mini Batch: 9, Loss= 1016.692200, Training Accuracy= 88.20000
#
# Fold: 7, Epoch: 26, Validation Accuracy= 87.60000
#
# Fold: 7, Epoch: 27, Mini Batch: 9, Loss= 920.397461, Training Accuracy= 87.50000
#
# Fold: 7, Epoch: 27, Validation Accuracy= 87.90000
#
# Fold: 7, Epoch: 28, Mini Batch: 9, Loss= 1056.307495, Training Accuracy= 86.80000
#
# Fold: 7, Epoch: 28, Validation Accuracy= 88.50000
#
# Fold: 7, Epoch: 29, Mini Batch: 9, Loss= 899.057373, Training Accuracy= 87.20000
#
# Fold: 7, Epoch: 29, Validation Accuracy= 87.50000
#
# Fold: 7, Epoch: 30, Mini Batch: 9, Loss= 717.072388, Training Accuracy= 88.50000
#
# Fold: 7, Epoch: 30, Validation Accuracy= 88.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          434   49   483
# 1           66  451   517
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 8, Epoch: 1, Mini Batch: 9, Loss= 28656.861328, Training Accuracy= 67.60000
#
# Fold: 8, Epoch: 1, Validation Accuracy= 78.50000
#
# Fold: 8, Epoch: 2, Mini Batch: 9, Loss= 12103.259766, Training Accuracy= 75.60000
#
# Fold: 8, Epoch: 2, Validation Accuracy= 83.10000
#
# Fold: 8, Epoch: 3, Mini Batch: 9, Loss= 9635.807617, Training Accuracy= 78.80000
#
# Fold: 8, Epoch: 3, Validation Accuracy= 80.50000
#
# Fold: 8, Epoch: 4, Mini Batch: 9, Loss= 7455.149902, Training Accuracy= 77.70000
#
# Fold: 8, Epoch: 4, Validation Accuracy= 84.10000
#
# Fold: 8, Epoch: 5, Mini Batch: 9, Loss= 5988.652832, Training Accuracy= 79.20000
#
# Fold: 8, Epoch: 5, Validation Accuracy= 84.80000
#
# Fold: 8, Epoch: 6, Mini Batch: 9, Loss= 4944.441895, Training Accuracy= 80.80000
#
# Fold: 8, Epoch: 6, Validation Accuracy= 83.70000
#
# Fold: 8, Epoch: 7, Mini Batch: 9, Loss= 3862.910889, Training Accuracy= 82.40000
#
# Fold: 8, Epoch: 7, Validation Accuracy= 85.10000
#
# Fold: 8, Epoch: 8, Mini Batch: 9, Loss= 3662.091309, Training Accuracy= 83.90000
#
# Fold: 8, Epoch: 8, Validation Accuracy= 85.30000
#
# Fold: 8, Epoch: 9, Mini Batch: 9, Loss= 3441.710449, Training Accuracy= 82.60000
#
# Fold: 8, Epoch: 9, Validation Accuracy= 85.50000
#
# Fold: 8, Epoch: 10, Mini Batch: 9, Loss= 3190.111328, Training Accuracy= 83.80000
#
# Fold: 8, Epoch: 10, Validation Accuracy= 85.80000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          427   69   496
# 1           73  431   504
# All        500  500  1000
#
# Fold: 8, Epoch: 11, Mini Batch: 9, Loss= 3052.662598, Training Accuracy= 82.00000
#
# Fold: 8, Epoch: 11, Validation Accuracy= 85.50000
#
# Fold: 8, Epoch: 12, Mini Batch: 9, Loss= 2466.578613, Training Accuracy= 83.80000
#
# Fold: 8, Epoch: 12, Validation Accuracy= 85.10000
#
# Fold: 8, Epoch: 13, Mini Batch: 9, Loss= 2303.230713, Training Accuracy= 84.40000
#
# Fold: 8, Epoch: 13, Validation Accuracy= 85.20000
#
# Fold: 8, Epoch: 14, Mini Batch: 9, Loss= 2324.760986, Training Accuracy= 83.80000
#
# Fold: 8, Epoch: 14, Validation Accuracy= 84.30000
#
# Fold: 8, Epoch: 15, Mini Batch: 9, Loss= 2222.084229, Training Accuracy= 84.50000
#
# Fold: 8, Epoch: 15, Validation Accuracy= 85.10000
#
# Fold: 8, Epoch: 16, Mini Batch: 9, Loss= 1984.704834, Training Accuracy= 83.60000
#
# Fold: 8, Epoch: 16, Validation Accuracy= 85.90000
#
# Fold: 8, Epoch: 17, Mini Batch: 9, Loss= 1952.590698, Training Accuracy= 85.60000
#
# Fold: 8, Epoch: 17, Validation Accuracy= 85.40000
#
# Fold: 8, Epoch: 18, Mini Batch: 9, Loss= 1625.116821, Training Accuracy= 85.70000
#
# Fold: 8, Epoch: 18, Validation Accuracy= 86.30000
#
# Fold: 8, Epoch: 19, Mini Batch: 9, Loss= 1532.981445, Training Accuracy= 87.50000
#
# Fold: 8, Epoch: 19, Validation Accuracy= 86.60000
#
# Fold: 8, Epoch: 20, Mini Batch: 9, Loss= 1432.343994, Training Accuracy= 87.00000
#
# Fold: 8, Epoch: 20, Validation Accuracy= 86.30000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          418   55   473
# 1           82  445   527
# All        500  500  1000
#
# Fold: 8, Epoch: 21, Mini Batch: 9, Loss= 1413.619263, Training Accuracy= 86.60000
#
# Fold: 8, Epoch: 21, Validation Accuracy= 86.20000
#
# Fold: 8, Epoch: 22, Mini Batch: 9, Loss= 1483.877441, Training Accuracy= 84.60000
#
# Fold: 8, Epoch: 22, Validation Accuracy= 86.30000
#
# Fold: 8, Epoch: 23, Mini Batch: 9, Loss= 1288.276733, Training Accuracy= 86.60000
#
# Fold: 8, Epoch: 23, Validation Accuracy= 86.00000
#
# Fold: 8, Epoch: 24, Mini Batch: 9, Loss= 1275.181519, Training Accuracy= 86.50000
#
# Fold: 8, Epoch: 24, Validation Accuracy= 85.90000
#
# Fold: 8, Epoch: 25, Mini Batch: 9, Loss= 996.956482, Training Accuracy= 87.50000
#
# Fold: 8, Epoch: 25, Validation Accuracy= 86.10000
#
# Fold: 8, Epoch: 26, Mini Batch: 9, Loss= 908.677368, Training Accuracy= 87.70000
#
# Fold: 8, Epoch: 26, Validation Accuracy= 86.60000
#
# Fold: 8, Epoch: 27, Mini Batch: 9, Loss= 881.518860, Training Accuracy= 87.60000
#
# Fold: 8, Epoch: 27, Validation Accuracy= 85.90000
#
# Fold: 8, Epoch: 28, Mini Batch: 9, Loss= 955.362854, Training Accuracy= 88.80000
#
# Fold: 8, Epoch: 28, Validation Accuracy= 85.80000
#
# Fold: 8, Epoch: 29, Mini Batch: 9, Loss= 986.155518, Training Accuracy= 87.50000
#
# Fold: 8, Epoch: 29, Validation Accuracy= 85.90000
#
# Fold: 8, Epoch: 30, Mini Batch: 9, Loss= 770.341736, Training Accuracy= 87.20000
#
# Fold: 8, Epoch: 30, Validation Accuracy= 85.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          414   60   474
# 1           86  440   526
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 9, Epoch: 1, Mini Batch: 9, Loss= 26648.992188, Training Accuracy= 69.20000
#
# Fold: 9, Epoch: 1, Validation Accuracy= 82.90000
#
# Fold: 9, Epoch: 2, Mini Batch: 9, Loss= 13963.994141, Training Accuracy= 74.40000
#
# Fold: 9, Epoch: 2, Validation Accuracy= 83.90000
#
# Fold: 9, Epoch: 3, Mini Batch: 9, Loss= 8596.990234, Training Accuracy= 80.70000
#
# Fold: 9, Epoch: 3, Validation Accuracy= 84.40000
#
# Fold: 9, Epoch: 4, Mini Batch: 9, Loss= 6178.222168, Training Accuracy= 80.30000
#
# Fold: 9, Epoch: 4, Validation Accuracy= 85.70000
#
# Fold: 9, Epoch: 5, Mini Batch: 9, Loss= 5333.980469, Training Accuracy= 79.90000
#
# Fold: 9, Epoch: 5, Validation Accuracy= 88.10000
#
# Fold: 9, Epoch: 6, Mini Batch: 9, Loss= 4992.868652, Training Accuracy= 80.80000
#
# Fold: 9, Epoch: 6, Validation Accuracy= 86.30000
#
# Fold: 9, Epoch: 7, Mini Batch: 9, Loss= 3574.850586, Training Accuracy= 84.20000
#
# Fold: 9, Epoch: 7, Validation Accuracy= 87.80000
#
# Fold: 9, Epoch: 8, Mini Batch: 9, Loss= 3725.751953, Training Accuracy= 82.90000
#
# Fold: 9, Epoch: 8, Validation Accuracy= 87.50000
#
# Fold: 9, Epoch: 9, Mini Batch: 9, Loss= 3067.196533, Training Accuracy= 83.20000
#
# Fold: 9, Epoch: 9, Validation Accuracy= 86.50000
#
# Fold: 9, Epoch: 10, Mini Batch: 9, Loss= 3677.791992, Training Accuracy= 80.00000
#
# Fold: 9, Epoch: 10, Validation Accuracy= 87.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          428   54   482
# 1           72  446   518
# All        500  500  1000
#
# Fold: 9, Epoch: 11, Mini Batch: 9, Loss= 2959.749512, Training Accuracy= 83.70000
#
# Fold: 9, Epoch: 11, Validation Accuracy= 86.90000
#
# Fold: 9, Epoch: 12, Mini Batch: 9, Loss= 2516.366455, Training Accuracy= 84.10000
#
# Fold: 9, Epoch: 12, Validation Accuracy= 87.20000
#
# Fold: 9, Epoch: 13, Mini Batch: 9, Loss= 2385.771973, Training Accuracy= 84.40000
#
# Fold: 9, Epoch: 13, Validation Accuracy= 87.30000
#
# Fold: 9, Epoch: 14, Mini Batch: 9, Loss= 2340.697021, Training Accuracy= 84.00000
#
# Fold: 9, Epoch: 14, Validation Accuracy= 87.30000
#
# Fold: 9, Epoch: 15, Mini Batch: 9, Loss= 2328.994385, Training Accuracy= 83.20000
#
# Fold: 9, Epoch: 15, Validation Accuracy= 87.20000
#
# Fold: 9, Epoch: 16, Mini Batch: 9, Loss= 1993.078125, Training Accuracy= 86.10000
#
# Fold: 9, Epoch: 16, Validation Accuracy= 87.40000
#
# Fold: 9, Epoch: 17, Mini Batch: 9, Loss= 2194.790039, Training Accuracy= 83.80000
#
# Fold: 9, Epoch: 17, Validation Accuracy= 88.00000
#
# Fold: 9, Epoch: 18, Mini Batch: 9, Loss= 1598.963257, Training Accuracy= 86.50000
#
# Fold: 9, Epoch: 18, Validation Accuracy= 88.00000
#
# Fold: 9, Epoch: 19, Mini Batch: 9, Loss= 1741.220947, Training Accuracy= 84.30000
#
# Fold: 9, Epoch: 19, Validation Accuracy= 88.00000
#
# Fold: 9, Epoch: 20, Mini Batch: 9, Loss= 1749.045532, Training Accuracy= 84.10000
#
# Fold: 9, Epoch: 20, Validation Accuracy= 88.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          431   49   480
# 1           69  451   520
# All        500  500  1000
#
# Fold: 9, Epoch: 21, Mini Batch: 9, Loss= 1401.458496, Training Accuracy= 86.00000
#
# Fold: 9, Epoch: 21, Validation Accuracy= 88.40000
#
# Fold: 9, Epoch: 22, Mini Batch: 9, Loss= 1370.196655, Training Accuracy= 86.90000
#
# Fold: 9, Epoch: 22, Validation Accuracy= 87.90000
#
# Fold: 9, Epoch: 23, Mini Batch: 9, Loss= 1207.209473, Training Accuracy= 86.20000
#
# Fold: 9, Epoch: 23, Validation Accuracy= 88.20000
#
# Fold: 9, Epoch: 24, Mini Batch: 9, Loss= 1163.754883, Training Accuracy= 87.00000
#
# Fold: 9, Epoch: 24, Validation Accuracy= 87.80000
#
# Fold: 9, Epoch: 25, Mini Batch: 9, Loss= 979.728149, Training Accuracy= 87.40000
#
# Fold: 9, Epoch: 25, Validation Accuracy= 88.50000
#
# Fold: 9, Epoch: 26, Mini Batch: 9, Loss= 905.132019, Training Accuracy= 87.70000
#
# Fold: 9, Epoch: 26, Validation Accuracy= 88.40000
#
# Fold: 9, Epoch: 27, Mini Batch: 9, Loss= 870.126770, Training Accuracy= 87.80000
#
# Fold: 9, Epoch: 27, Validation Accuracy= 88.90000
#
# Fold: 9, Epoch: 28, Mini Batch: 9, Loss= 776.425659, Training Accuracy= 88.50000
#
# Fold: 9, Epoch: 28, Validation Accuracy= 88.70000
#
# Fold: 9, Epoch: 29, Mini Batch: 9, Loss= 1006.826538, Training Accuracy= 88.20000
#
# Fold: 9, Epoch: 29, Validation Accuracy= 88.50000
#
# Fold: 9, Epoch: 30, Mini Batch: 9, Loss= 848.545410, Training Accuracy= 88.80000
#
# Fold: 9, Epoch: 30, Validation Accuracy= 88.40000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          427   43   470
# 1           73  457   530
# All        500  500  1000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (1000, 1179) (1000, 2)
# Training Data and Labels shape:  (9000, 1179) (9000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'optimizerParam': {'learning_rate': 0.007, 'optimizer': 'ADAM'}, 'epochs': 30, 'numHidden1': 1024, 'imageSize': 32, 'numFolds': 10, 'numLabels': 2, 'batchSize': 1000, 'numHidden2': 1280, 'keepProb': {'hid2': 0.5, 'hid1': 0.75, 'hid3': 0.5}, 'numHidden3': 1024}
# Fold: 10, Epoch: 1, Mini Batch: 9, Loss= 21220.146484, Training Accuracy= 72.50000
#
# Fold: 10, Epoch: 1, Validation Accuracy= 81.90000
#
# Fold: 10, Epoch: 2, Mini Batch: 9, Loss= 11579.501953, Training Accuracy= 76.00000
#
# Fold: 10, Epoch: 2, Validation Accuracy= 84.20000
#
# Fold: 10, Epoch: 3, Mini Batch: 9, Loss= 7153.854004, Training Accuracy= 81.20000
#
# Fold: 10, Epoch: 3, Validation Accuracy= 86.50000
#
# Fold: 10, Epoch: 4, Mini Batch: 9, Loss= 6011.813477, Training Accuracy= 79.70000
#
# Fold: 10, Epoch: 4, Validation Accuracy= 86.00000
#
# Fold: 10, Epoch: 5, Mini Batch: 9, Loss= 6112.984863, Training Accuracy= 78.80000
#
# Fold: 10, Epoch: 5, Validation Accuracy= 87.80000
#
# Fold: 10, Epoch: 6, Mini Batch: 9, Loss= 4809.647949, Training Accuracy= 80.70000
#
# Fold: 10, Epoch: 6, Validation Accuracy= 87.80000
#
# Fold: 10, Epoch: 7, Mini Batch: 9, Loss= 3758.300537, Training Accuracy= 83.40000
#
# Fold: 10, Epoch: 7, Validation Accuracy= 87.40000
#
# Fold: 10, Epoch: 8, Mini Batch: 9, Loss= 3944.225098, Training Accuracy= 83.00000
#
# Fold: 10, Epoch: 8, Validation Accuracy= 87.50000
#
# Fold: 10, Epoch: 9, Mini Batch: 9, Loss= 3488.278320, Training Accuracy= 81.80000
#
# Fold: 10, Epoch: 9, Validation Accuracy= 87.90000
#
# Fold: 10, Epoch: 10, Mini Batch: 9, Loss= 3073.201416, Training Accuracy= 82.50000
#
# Fold: 10, Epoch: 10, Validation Accuracy= 87.70000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          441   64   505
# 1           59  436   495
# All        500  500  1000
#
# Fold: 10, Epoch: 11, Mini Batch: 9, Loss= 2948.014160, Training Accuracy= 82.00000
#
# Fold: 10, Epoch: 11, Validation Accuracy= 88.20000
#
# Fold: 10, Epoch: 12, Mini Batch: 9, Loss= 2298.247803, Training Accuracy= 83.60000
#
# Fold: 10, Epoch: 12, Validation Accuracy= 87.80000
#
# Fold: 10, Epoch: 13, Mini Batch: 9, Loss= 2403.474121, Training Accuracy= 83.50000
#
# Fold: 10, Epoch: 13, Validation Accuracy= 87.40000
#
# Fold: 10, Epoch: 14, Mini Batch: 9, Loss= 2230.861084, Training Accuracy= 83.40000
#
# Fold: 10, Epoch: 14, Validation Accuracy= 87.40000
#
# Fold: 10, Epoch: 15, Mini Batch: 9, Loss= 2036.686768, Training Accuracy= 84.80000
#
# Fold: 10, Epoch: 15, Validation Accuracy= 87.90000
#
# Fold: 10, Epoch: 16, Mini Batch: 9, Loss= 1671.302979, Training Accuracy= 84.30000
#
# Fold: 10, Epoch: 16, Validation Accuracy= 87.90000
#
# Fold: 10, Epoch: 17, Mini Batch: 9, Loss= 1729.068237, Training Accuracy= 84.20000
#
# Fold: 10, Epoch: 17, Validation Accuracy= 88.00000
#
# Fold: 10, Epoch: 18, Mini Batch: 9, Loss= 1694.124268, Training Accuracy= 84.50000
#
# Fold: 10, Epoch: 18, Validation Accuracy= 88.40000
#
# Fold: 10, Epoch: 19, Mini Batch: 9, Loss= 1365.545410, Training Accuracy= 86.40000
#
# Fold: 10, Epoch: 19, Validation Accuracy= 88.10000
#
# Fold: 10, Epoch: 20, Mini Batch: 9, Loss= 1486.946289, Training Accuracy= 85.00000
#
# Fold: 10, Epoch: 20, Validation Accuracy= 88.50000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          437   52   489
# 1           63  448   511
# All        500  500  1000
#
# Fold: 10, Epoch: 21, Mini Batch: 9, Loss= 1227.855835, Training Accuracy= 86.60000
#
# Fold: 10, Epoch: 21, Validation Accuracy= 88.20000
#
# Fold: 10, Epoch: 22, Mini Batch: 9, Loss= 1130.811279, Training Accuracy= 86.90000
#
# Fold: 10, Epoch: 22, Validation Accuracy= 88.30000
#
# Fold: 10, Epoch: 23, Mini Batch: 9, Loss= 997.964294, Training Accuracy= 86.90000
#
# Fold: 10, Epoch: 23, Validation Accuracy= 87.90000
#
# Fold: 10, Epoch: 24, Mini Batch: 9, Loss= 1008.804138, Training Accuracy= 86.70000
#
# Fold: 10, Epoch: 24, Validation Accuracy= 88.00000
#
# Fold: 10, Epoch: 25, Mini Batch: 9, Loss= 1163.038330, Training Accuracy= 85.90000
#
# Fold: 10, Epoch: 25, Validation Accuracy= 88.40000
#
# Fold: 10, Epoch: 26, Mini Batch: 9, Loss= 909.911499, Training Accuracy= 88.00000
#
# Fold: 10, Epoch: 26, Validation Accuracy= 88.10000
#
# Fold: 10, Epoch: 27, Mini Batch: 9, Loss= 956.198486, Training Accuracy= 87.00000
#
# Fold: 10, Epoch: 27, Validation Accuracy= 88.00000
#
# Fold: 10, Epoch: 28, Mini Batch: 9, Loss= 1023.537598, Training Accuracy= 84.80000
#
# Fold: 10, Epoch: 28, Validation Accuracy= 88.80000
#
# Fold: 10, Epoch: 29, Mini Batch: 9, Loss= 921.547363, Training Accuracy= 85.40000
#
# Fold: 10, Epoch: 29, Validation Accuracy= 88.20000
#
# Fold: 10, Epoch: 30, Mini Batch: 9, Loss= 717.243103, Training Accuracy= 88.50000
#
# Fold: 10, Epoch: 30, Validation Accuracy= 88.20000
#
# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True
# 0          439   57   496
# 1           61  443   504
# All        500  500  1000
#
# The mean Valid Accuracy is :  87.16

# %%
rows = 2
columns = 5
vizualize(vaccPerEpochPerFold, taccPerEpochPerFold, meanValidAcc=meanValidAcc, rows=rows, columns=columns, figsize=(5*columns, 5*rows))

# %% [markdown]
# ## 4-kernels : HOG - Adam Optimizer / Augmented / Hidden Layer : 1024x1280x1024
# ------

# %%
featureDIR = HOGp4batchAug_dir

params = dict(imageSize = 32,
              numLabels = 2,
              
              # Network params
              numHidden1 = 1024,
              numHidden2 = 1280,
              numHidden3 = 1024, 

              # Batch Variables
              numFolds = 10,
              epochs = 30,
              batchSize = 1000,
             
              # Optimization Params
              keepProb = dict(hid1=0.75, hid2=0.5, hid3=0.5),
              optimizerParam = dict(optimizer='ADAM', learning_rate=0.001)
             )

# optimizer = tf.train.AdamOptimizer(learning_rate=0.008).minimize(lossCE)

(out, meanValidAcc, lossPerEpochPerFold, taccPerEpochPerFold, vaccPerEpochPerFold) = SessionExec(featureDIR, params).execute() 

print ('The mean Valid Accuracy is : ', meanValidAcc)
# Out:
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.001}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1024, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 1, Epoch: 1, Mini Batch: 10, Loss= 36885.031250, Training Accuracy= 57.50000
# Fold: 1, Epoch: 1, Mini Batch: 18, Loss= 28528.148438, Training Accuracy= 66.80000
#
# Fold: 1, Epoch: 1, Validation Accuracy= 80.80000
#
# Fold: 1, Epoch: 2, Mini Batch: 10, Loss= 23732.388672, Training Accuracy= 69.40000
# Fold: 1, Epoch: 2, Mini Batch: 18, Loss= 18812.720703, Training Accuracy= 74.20000
#
# Fold: 1, Epoch: 2, Validation Accuracy= 83.65000
#
# Fold: 1, Epoch: 3, Mini Batch: 10, Loss= 17551.578125, Training Accuracy= 72.50000
# Fold: 1, Epoch: 3, Mini Batch: 18, Loss= 15051.069336, Training Accuracy= 75.30000
#
# Fold: 1, Epoch: 3, Validation Accuracy= 84.35000
#
# Fold: 1, Epoch: 4, Mini Batch: 10, Loss= 14373.526367, Training Accuracy= 74.80000
# Fold: 1, Epoch: 4, Mini Batch: 18, Loss= 13813.796875, Training Accuracy= 74.70000
#
# Fold: 1, Epoch: 4, Validation Accuracy= 85.55000
#
# Fold: 1, Epoch: 5, Mini Batch: 10, Loss= 12761.473633, Training Accuracy= 75.80000
# Fold: 1, Epoch: 5, Mini Batch: 18, Loss= 14169.704102, Training Accuracy= 75.20000
#
# Fold: 1, Epoch: 5, Validation Accuracy= 85.65000
#
# Fold: 1, Epoch: 6, Mini Batch: 10, Loss= 11294.164062, Training Accuracy= 77.70000
# Fold: 1, Epoch: 6, Mini Batch: 18, Loss= 12090.179688, Training Accuracy= 76.20000
#
# Fold: 1, Epoch: 6, Validation Accuracy= 85.80000
#
# Fold: 1, Epoch: 7, Mini Batch: 10, Loss= 9828.473633, Training Accuracy= 77.80000
# Fold: 1, Epoch: 7, Mini Batch: 18, Loss= 10754.078125, Training Accuracy= 78.30000
#
# Fold: 1, Epoch: 7, Validation Accuracy= 86.50000
#
# Fold: 1, Epoch: 8, Mini Batch: 10, Loss= 10476.331055, Training Accuracy= 75.90000
# Fold: 1, Epoch: 8, Mini Batch: 18, Loss= 9069.082031, Training Accuracy= 78.40000
#
# Fold: 1, Epoch: 8, Validation Accuracy= 86.85000
#
# Fold: 1, Epoch: 9, Mini Batch: 10, Loss= 7658.541992, Training Accuracy= 80.20000
# Fold: 1, Epoch: 9, Mini Batch: 18, Loss= 7912.893555, Training Accuracy= 78.70000
#
# Fold: 1, Epoch: 9, Validation Accuracy= 87.20000
#
# Fold: 1, Epoch: 10, Mini Batch: 10, Loss= 8632.013672, Training Accuracy= 79.20000
# Fold: 1, Epoch: 10, Mini Batch: 18, Loss= 8720.411133, Training Accuracy= 78.50000
#
# Fold: 1, Epoch: 10, Validation Accuracy= 86.50000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           802    72   874
# 1           198   928  1126
# All        1000  1000  2000
#
# Fold: 1, Epoch: 11, Mini Batch: 10, Loss= 7818.633789, Training Accuracy= 78.00000
# Fold: 1, Epoch: 11, Mini Batch: 18, Loss= 7561.346191, Training Accuracy= 79.90000
#
# Fold: 1, Epoch: 11, Validation Accuracy= 86.75000
#
# Fold: 1, Epoch: 12, Mini Batch: 10, Loss= 7185.339355, Training Accuracy= 79.10000
# Fold: 1, Epoch: 12, Mini Batch: 18, Loss= 6793.879883, Training Accuracy= 79.30000
#
# Fold: 1, Epoch: 12, Validation Accuracy= 86.95000
#
# Fold: 1, Epoch: 13, Mini Batch: 10, Loss= 6964.854980, Training Accuracy= 78.20000
# Fold: 1, Epoch: 13, Mini Batch: 18, Loss= 6629.185059, Training Accuracy= 79.20000
#
# Fold: 1, Epoch: 13, Validation Accuracy= 86.75000
#
# Fold: 1, Epoch: 14, Mini Batch: 10, Loss= 6573.816895, Training Accuracy= 79.20000
# Fold: 1, Epoch: 14, Mini Batch: 18, Loss= 6319.444336, Training Accuracy= 78.60000
#
# Fold: 1, Epoch: 14, Validation Accuracy= 86.65000
#
# Fold: 1, Epoch: 15, Mini Batch: 10, Loss= 5418.249512, Training Accuracy= 80.40000
# Fold: 1, Epoch: 15, Mini Batch: 18, Loss= 5465.602051, Training Accuracy= 80.00000
#
# Fold: 1, Epoch: 15, Validation Accuracy= 87.00000
#
# Fold: 1, Epoch: 16, Mini Batch: 10, Loss= 5751.953125, Training Accuracy= 80.70000
# Fold: 1, Epoch: 16, Mini Batch: 18, Loss= 5696.251953, Training Accuracy= 80.70000
#
# Fold: 1, Epoch: 16, Validation Accuracy= 86.70000
#
# Fold: 1, Epoch: 17, Mini Batch: 10, Loss= 5793.000977, Training Accuracy= 79.10000
# Fold: 1, Epoch: 17, Mini Batch: 18, Loss= 5625.642090, Training Accuracy= 78.00000
#
# Fold: 1, Epoch: 17, Validation Accuracy= 86.75000
#
# Fold: 1, Epoch: 18, Mini Batch: 10, Loss= 4947.861816, Training Accuracy= 79.80000
# Fold: 1, Epoch: 18, Mini Batch: 18, Loss= 5179.252930, Training Accuracy= 79.40000
#
# Fold: 1, Epoch: 18, Validation Accuracy= 87.10000
#
# Fold: 1, Epoch: 19, Mini Batch: 10, Loss= 5101.979004, Training Accuracy= 79.20000
# Fold: 1, Epoch: 19, Mini Batch: 18, Loss= 4284.833984, Training Accuracy= 80.40000
#
# Fold: 1, Epoch: 19, Validation Accuracy= 87.25000
#
# Fold: 1, Epoch: 20, Mini Batch: 10, Loss= 5314.957031, Training Accuracy= 78.80000
# Fold: 1, Epoch: 20, Mini Batch: 18, Loss= 4554.709961, Training Accuracy= 80.20000
#
# Fold: 1, Epoch: 20, Validation Accuracy= 87.60000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           832    80   912
# 1           168   920  1088
# All        1000  1000  2000
#
# Fold: 1, Epoch: 21, Mini Batch: 10, Loss= 3769.274658, Training Accuracy= 81.90000
# Fold: 1, Epoch: 21, Mini Batch: 18, Loss= 4490.841309, Training Accuracy= 79.40000
#
# Fold: 1, Epoch: 21, Validation Accuracy= 87.60000
#
# Fold: 1, Epoch: 22, Mini Batch: 10, Loss= 4238.217773, Training Accuracy= 80.20000
# Fold: 1, Epoch: 22, Mini Batch: 18, Loss= 4216.085938, Training Accuracy= 79.70000
#
# Fold: 1, Epoch: 22, Validation Accuracy= 87.85000
#
# Fold: 1, Epoch: 23, Mini Batch: 10, Loss= 3781.211426, Training Accuracy= 79.10000
# Fold: 1, Epoch: 23, Mini Batch: 18, Loss= 4651.855469, Training Accuracy= 78.70000
#
# Fold: 1, Epoch: 23, Validation Accuracy= 87.55000
#
# Fold: 1, Epoch: 24, Mini Batch: 10, Loss= 3810.155273, Training Accuracy= 80.40000
# Fold: 1, Epoch: 24, Mini Batch: 18, Loss= 3708.650879, Training Accuracy= 83.80000
#
# Fold: 1, Epoch: 24, Validation Accuracy= 87.45000
#
# Fold: 1, Epoch: 25, Mini Batch: 10, Loss= 3804.303955, Training Accuracy= 80.40000
# Fold: 1, Epoch: 25, Mini Batch: 18, Loss= 3915.356445, Training Accuracy= 80.30000
#
# Fold: 1, Epoch: 25, Validation Accuracy= 87.70000
#
# Fold: 1, Epoch: 26, Mini Batch: 10, Loss= 3608.997070, Training Accuracy= 79.00000
# Fold: 1, Epoch: 26, Mini Batch: 18, Loss= 3686.689453, Training Accuracy= 80.40000
#
# Fold: 1, Epoch: 26, Validation Accuracy= 87.55000
#
# Fold: 1, Epoch: 27, Mini Batch: 10, Loss= 3669.697021, Training Accuracy= 80.90000
# Fold: 1, Epoch: 27, Mini Batch: 18, Loss= 3687.636230, Training Accuracy= 80.60000
#
# Fold: 1, Epoch: 27, Validation Accuracy= 87.65000
#
# Fold: 1, Epoch: 28, Mini Batch: 10, Loss= 3366.711914, Training Accuracy= 82.70000
# Fold: 1, Epoch: 28, Mini Batch: 18, Loss= 3092.174805, Training Accuracy= 83.00000
#
# Fold: 1, Epoch: 28, Validation Accuracy= 87.60000
#
# Fold: 1, Epoch: 29, Mini Batch: 10, Loss= 3281.291504, Training Accuracy= 81.30000
# Fold: 1, Epoch: 29, Mini Batch: 18, Loss= 3107.953613, Training Accuracy= 81.30000
#
# Fold: 1, Epoch: 29, Validation Accuracy= 87.85000
#
# Fold: 1, Epoch: 30, Mini Batch: 10, Loss= 2890.454590, Training Accuracy= 81.50000
# Fold: 1, Epoch: 30, Mini Batch: 18, Loss= 3238.542969, Training Accuracy= 80.10000
#
# Fold: 1, Epoch: 30, Validation Accuracy= 87.95000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           843    84   927
# 1           157   916  1073
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.001}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1024, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 2, Epoch: 1, Mini Batch: 10, Loss= 32185.449219, Training Accuracy= 61.90000
# Fold: 2, Epoch: 1, Mini Batch: 18, Loss= 29205.105469, Training Accuracy= 66.30000
#
# Fold: 2, Epoch: 1, Validation Accuracy= 80.80000
#
# Fold: 2, Epoch: 2, Mini Batch: 10, Loss= 21880.343750, Training Accuracy= 71.80000
# Fold: 2, Epoch: 2, Mini Batch: 18, Loss= 19376.136719, Training Accuracy= 72.60000
#
# Fold: 2, Epoch: 2, Validation Accuracy= 82.55000
#
# Fold: 2, Epoch: 3, Mini Batch: 10, Loss= 16310.464844, Training Accuracy= 76.90000
# Fold: 2, Epoch: 3, Mini Batch: 18, Loss= 17112.183594, Training Accuracy= 72.90000
#
# Fold: 2, Epoch: 3, Validation Accuracy= 83.55000
#
# Fold: 2, Epoch: 4, Mini Batch: 10, Loss= 14158.247070, Training Accuracy= 75.80000
# Fold: 2, Epoch: 4, Mini Batch: 18, Loss= 13000.864258, Training Accuracy= 75.70000
#
# Fold: 2, Epoch: 4, Validation Accuracy= 83.60000
#
# Fold: 2, Epoch: 5, Mini Batch: 10, Loss= 12635.824219, Training Accuracy= 75.00000
# Fold: 2, Epoch: 5, Mini Batch: 18, Loss= 12363.106445, Training Accuracy= 76.60000
#
# Fold: 2, Epoch: 5, Validation Accuracy= 84.40000
#
# Fold: 2, Epoch: 6, Mini Batch: 10, Loss= 10574.186523, Training Accuracy= 77.90000
# Fold: 2, Epoch: 6, Mini Batch: 18, Loss= 9706.536133, Training Accuracy= 79.20000
#
# Fold: 2, Epoch: 6, Validation Accuracy= 84.20000
#
# Fold: 2, Epoch: 7, Mini Batch: 10, Loss= 10594.421875, Training Accuracy= 76.90000
# Fold: 2, Epoch: 7, Mini Batch: 18, Loss= 9728.051758, Training Accuracy= 78.50000
#
# Fold: 2, Epoch: 7, Validation Accuracy= 84.55000
#
# Fold: 2, Epoch: 8, Mini Batch: 10, Loss= 9661.764648, Training Accuracy= 78.00000
# Fold: 2, Epoch: 8, Mini Batch: 18, Loss= 8876.751953, Training Accuracy= 79.00000
#
# Fold: 2, Epoch: 8, Validation Accuracy= 85.50000
#
# Fold: 2, Epoch: 9, Mini Batch: 10, Loss= 8526.280273, Training Accuracy= 78.70000
# Fold: 2, Epoch: 9, Mini Batch: 18, Loss= 7924.556641, Training Accuracy= 81.50000
#
# Fold: 2, Epoch: 9, Validation Accuracy= 86.05000
#
# Fold: 2, Epoch: 10, Mini Batch: 10, Loss= 8551.719727, Training Accuracy= 76.60000
# Fold: 2, Epoch: 10, Mini Batch: 18, Loss= 8176.138672, Training Accuracy= 78.80000
#
# Fold: 2, Epoch: 10, Validation Accuracy= 85.30000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           801    95   896
# 1           199   905  1104
# All        1000  1000  2000
#
# Fold: 2, Epoch: 11, Mini Batch: 10, Loss= 7384.175781, Training Accuracy= 78.90000
# Fold: 2, Epoch: 11, Mini Batch: 18, Loss= 6710.856934, Training Accuracy= 81.60000
#
# Fold: 2, Epoch: 11, Validation Accuracy= 86.00000
#
# Fold: 2, Epoch: 12, Mini Batch: 10, Loss= 7656.041016, Training Accuracy= 77.20000
# Fold: 2, Epoch: 12, Mini Batch: 18, Loss= 7646.388184, Training Accuracy= 78.10000
#
# Fold: 2, Epoch: 12, Validation Accuracy= 86.15000
#
# Fold: 2, Epoch: 13, Mini Batch: 10, Loss= 6907.249512, Training Accuracy= 77.00000
# Fold: 2, Epoch: 13, Mini Batch: 18, Loss= 5860.592285, Training Accuracy= 80.10000
#
# Fold: 2, Epoch: 13, Validation Accuracy= 86.25000
#
# Fold: 2, Epoch: 14, Mini Batch: 10, Loss= 5299.958496, Training Accuracy= 82.70000
# Fold: 2, Epoch: 14, Mini Batch: 18, Loss= 5680.277832, Training Accuracy= 80.20000
#
# Fold: 2, Epoch: 14, Validation Accuracy= 86.50000
#
# Fold: 2, Epoch: 15, Mini Batch: 10, Loss= 5536.850098, Training Accuracy= 80.10000
# Fold: 2, Epoch: 15, Mini Batch: 18, Loss= 5476.111816, Training Accuracy= 82.10000
#
# Fold: 2, Epoch: 15, Validation Accuracy= 86.75000
#
# Fold: 2, Epoch: 16, Mini Batch: 10, Loss= 5534.978027, Training Accuracy= 80.20000
# Fold: 2, Epoch: 16, Mini Batch: 18, Loss= 5761.675781, Training Accuracy= 80.80000
#
# Fold: 2, Epoch: 16, Validation Accuracy= 86.55000
#
# Fold: 2, Epoch: 17, Mini Batch: 10, Loss= 4951.593262, Training Accuracy= 80.00000
# Fold: 2, Epoch: 17, Mini Batch: 18, Loss= 5675.122070, Training Accuracy= 79.30000
#
# Fold: 2, Epoch: 17, Validation Accuracy= 86.85000
#
# Fold: 2, Epoch: 18, Mini Batch: 10, Loss= 4196.478027, Training Accuracy= 82.00000
# Fold: 2, Epoch: 18, Mini Batch: 18, Loss= 4948.323242, Training Accuracy= 81.00000
#
# Fold: 2, Epoch: 18, Validation Accuracy= 86.55000
#
# Fold: 2, Epoch: 19, Mini Batch: 10, Loss= 5417.779785, Training Accuracy= 79.20000
# Fold: 2, Epoch: 19, Mini Batch: 18, Loss= 4558.935547, Training Accuracy= 79.90000
#
# Fold: 2, Epoch: 19, Validation Accuracy= 86.95000
#
# Fold: 2, Epoch: 20, Mini Batch: 10, Loss= 4548.645020, Training Accuracy= 80.80000
# Fold: 2, Epoch: 20, Mini Batch: 18, Loss= 4973.053223, Training Accuracy= 79.20000
#
# Fold: 2, Epoch: 20, Validation Accuracy= 86.85000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           832    95   927
# 1           168   905  1073
# All        1000  1000  2000
#
# Fold: 2, Epoch: 21, Mini Batch: 10, Loss= 4688.753906, Training Accuracy= 79.70000
# Fold: 2, Epoch: 21, Mini Batch: 18, Loss= 4663.834961, Training Accuracy= 81.60000
#
# Fold: 2, Epoch: 21, Validation Accuracy= 86.50000
#
# Fold: 2, Epoch: 22, Mini Batch: 10, Loss= 3927.037598, Training Accuracy= 80.80000
# Fold: 2, Epoch: 22, Mini Batch: 18, Loss= 4675.886230, Training Accuracy= 80.20000
#
# Fold: 2, Epoch: 22, Validation Accuracy= 86.70000
#
# Fold: 2, Epoch: 23, Mini Batch: 10, Loss= 4320.250488, Training Accuracy= 79.50000
# Fold: 2, Epoch: 23, Mini Batch: 18, Loss= 3901.113281, Training Accuracy= 80.90000
#
# Fold: 2, Epoch: 23, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 24, Mini Batch: 10, Loss= 3856.475830, Training Accuracy= 79.80000
# Fold: 2, Epoch: 24, Mini Batch: 18, Loss= 4078.369385, Training Accuracy= 80.40000
#
# Fold: 2, Epoch: 24, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 25, Mini Batch: 10, Loss= 4236.187500, Training Accuracy= 78.90000
# Fold: 2, Epoch: 25, Mini Batch: 18, Loss= 4230.188965, Training Accuracy= 78.20000
#
# Fold: 2, Epoch: 25, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 26, Mini Batch: 10, Loss= 3847.345703, Training Accuracy= 80.70000
# Fold: 2, Epoch: 26, Mini Batch: 18, Loss= 3628.158936, Training Accuracy= 79.80000
#
# Fold: 2, Epoch: 26, Validation Accuracy= 87.20000
#
# Fold: 2, Epoch: 27, Mini Batch: 10, Loss= 3732.751465, Training Accuracy= 78.10000
# Fold: 2, Epoch: 27, Mini Batch: 18, Loss= 3686.175537, Training Accuracy= 80.60000
#
# Fold: 2, Epoch: 27, Validation Accuracy= 87.30000
#
# Fold: 2, Epoch: 28, Mini Batch: 10, Loss= 3415.587891, Training Accuracy= 79.50000
# Fold: 2, Epoch: 28, Mini Batch: 18, Loss= 2959.130859, Training Accuracy= 82.60000
#
# Fold: 2, Epoch: 28, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 29, Mini Batch: 10, Loss= 3663.810547, Training Accuracy= 79.00000
# Fold: 2, Epoch: 29, Mini Batch: 18, Loss= 3086.112061, Training Accuracy= 82.70000
#
# Fold: 2, Epoch: 29, Validation Accuracy= 87.10000
#
# Fold: 2, Epoch: 30, Mini Batch: 10, Loss= 3128.278564, Training Accuracy= 80.30000
# Fold: 2, Epoch: 30, Mini Batch: 18, Loss= 3334.997559, Training Accuracy= 80.70000
#
# Fold: 2, Epoch: 30, Validation Accuracy= 87.50000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           853   103   956
# 1           147   897  1044
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.001}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1024, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 3, Epoch: 1, Mini Batch: 10, Loss= 39258.542969, Training Accuracy= 58.90000
# Fold: 3, Epoch: 1, Mini Batch: 18, Loss= 26778.675781, Training Accuracy= 66.80000
#
# Fold: 3, Epoch: 1, Validation Accuracy= 80.70000
#
# Fold: 3, Epoch: 2, Mini Batch: 10, Loss= 22710.326172, Training Accuracy= 70.50000
# Fold: 3, Epoch: 2, Mini Batch: 18, Loss= 19324.916016, Training Accuracy= 74.10000
#
# Fold: 3, Epoch: 2, Validation Accuracy= 82.70000
#
# Fold: 3, Epoch: 3, Mini Batch: 10, Loss= 18929.162109, Training Accuracy= 72.90000
# Fold: 3, Epoch: 3, Mini Batch: 18, Loss= 17340.816406, Training Accuracy= 75.50000
#
# Fold: 3, Epoch: 3, Validation Accuracy= 84.20000
#
# Fold: 3, Epoch: 4, Mini Batch: 10, Loss= 16511.585938, Training Accuracy= 72.60000
# Fold: 3, Epoch: 4, Mini Batch: 18, Loss= 14673.235352, Training Accuracy= 75.20000
#
# Fold: 3, Epoch: 4, Validation Accuracy= 84.45000
#
# Fold: 3, Epoch: 5, Mini Batch: 10, Loss= 12132.143555, Training Accuracy= 75.60000
# Fold: 3, Epoch: 5, Mini Batch: 18, Loss= 11704.740234, Training Accuracy= 75.80000
#
# Fold: 3, Epoch: 5, Validation Accuracy= 85.20000
#
# Fold: 3, Epoch: 6, Mini Batch: 10, Loss= 10861.484375, Training Accuracy= 78.00000
# Fold: 3, Epoch: 6, Mini Batch: 18, Loss= 11646.361328, Training Accuracy= 76.00000
#
# Fold: 3, Epoch: 6, Validation Accuracy= 86.30000
#
# Fold: 3, Epoch: 7, Mini Batch: 10, Loss= 9632.391602, Training Accuracy= 77.80000
# Fold: 3, Epoch: 7, Mini Batch: 18, Loss= 10129.307617, Training Accuracy= 78.00000
#
# Fold: 3, Epoch: 7, Validation Accuracy= 86.55000
#
# Fold: 3, Epoch: 8, Mini Batch: 10, Loss= 8964.577148, Training Accuracy= 77.60000
# Fold: 3, Epoch: 8, Mini Batch: 18, Loss= 10485.410156, Training Accuracy= 76.50000
#
# Fold: 3, Epoch: 8, Validation Accuracy= 86.40000
#
# Fold: 3, Epoch: 9, Mini Batch: 10, Loss= 9028.597656, Training Accuracy= 77.70000
# Fold: 3, Epoch: 9, Mini Batch: 18, Loss= 8145.318848, Training Accuracy= 78.90000
#
# Fold: 3, Epoch: 9, Validation Accuracy= 87.05000
#
# Fold: 3, Epoch: 10, Mini Batch: 10, Loss= 8035.958984, Training Accuracy= 79.20000
# Fold: 3, Epoch: 10, Mini Batch: 18, Loss= 6980.537109, Training Accuracy= 79.10000
#
# Fold: 3, Epoch: 10, Validation Accuracy= 87.15000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           825    82   907
# 1           175   918  1093
# All        1000  1000  2000
#
# Fold: 3, Epoch: 11, Mini Batch: 10, Loss= 6301.834961, Training Accuracy= 79.30000
# Fold: 3, Epoch: 11, Mini Batch: 18, Loss= 7620.738281, Training Accuracy= 78.60000
#
# Fold: 3, Epoch: 11, Validation Accuracy= 86.65000
#
# Fold: 3, Epoch: 12, Mini Batch: 10, Loss= 7027.819824, Training Accuracy= 79.70000
# Fold: 3, Epoch: 12, Mini Batch: 18, Loss= 6672.634277, Training Accuracy= 80.20000
#
# Fold: 3, Epoch: 12, Validation Accuracy= 86.85000
#
# Fold: 3, Epoch: 13, Mini Batch: 10, Loss= 6778.008789, Training Accuracy= 77.80000
# Fold: 3, Epoch: 13, Mini Batch: 18, Loss= 6717.404785, Training Accuracy= 77.60000
#
# Fold: 3, Epoch: 13, Validation Accuracy= 86.35000
#
# Fold: 3, Epoch: 14, Mini Batch: 10, Loss= 6363.958008, Training Accuracy= 80.20000
# Fold: 3, Epoch: 14, Mini Batch: 18, Loss= 5963.130371, Training Accuracy= 79.60000
#
# Fold: 3, Epoch: 14, Validation Accuracy= 86.80000
#
# Fold: 3, Epoch: 15, Mini Batch: 10, Loss= 5697.387207, Training Accuracy= 77.90000
# Fold: 3, Epoch: 15, Mini Batch: 18, Loss= 6856.387695, Training Accuracy= 78.40000
#
# Fold: 3, Epoch: 15, Validation Accuracy= 86.40000
#
# Fold: 3, Epoch: 16, Mini Batch: 10, Loss= 5175.727051, Training Accuracy= 81.50000
# Fold: 3, Epoch: 16, Mini Batch: 18, Loss= 5547.556152, Training Accuracy= 79.80000
#
# Fold: 3, Epoch: 16, Validation Accuracy= 86.80000
#
# Fold: 3, Epoch: 17, Mini Batch: 10, Loss= 5139.323242, Training Accuracy= 80.30000
# Fold: 3, Epoch: 17, Mini Batch: 18, Loss= 5720.599121, Training Accuracy= 79.30000
#
# Fold: 3, Epoch: 17, Validation Accuracy= 86.90000
#
# Fold: 3, Epoch: 18, Mini Batch: 10, Loss= 4817.624023, Training Accuracy= 79.00000
# Fold: 3, Epoch: 18, Mini Batch: 18, Loss= 4990.787109, Training Accuracy= 78.70000
#
# Fold: 3, Epoch: 18, Validation Accuracy= 85.95000
#
# Fold: 3, Epoch: 19, Mini Batch: 10, Loss= 4996.837891, Training Accuracy= 79.20000
# Fold: 3, Epoch: 19, Mini Batch: 18, Loss= 4702.515137, Training Accuracy= 80.20000
#
# Fold: 3, Epoch: 19, Validation Accuracy= 86.85000
#
# Fold: 3, Epoch: 20, Mini Batch: 10, Loss= 3734.795166, Training Accuracy= 80.30000
# Fold: 3, Epoch: 20, Mini Batch: 18, Loss= 4487.497070, Training Accuracy= 79.70000
#
# Fold: 3, Epoch: 20, Validation Accuracy= 86.50000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           813    83   896
# 1           187   917  1104
# All        1000  1000  2000
#
# Fold: 3, Epoch: 21, Mini Batch: 10, Loss= 4388.247559, Training Accuracy= 80.10000
# Fold: 3, Epoch: 21, Mini Batch: 18, Loss= 4504.290039, Training Accuracy= 80.20000
#
# Fold: 3, Epoch: 21, Validation Accuracy= 86.65000
#
# Fold: 3, Epoch: 22, Mini Batch: 10, Loss= 4170.932129, Training Accuracy= 79.90000
# Fold: 3, Epoch: 22, Mini Batch: 18, Loss= 4252.141113, Training Accuracy= 80.70000
#
# Fold: 3, Epoch: 22, Validation Accuracy= 86.70000
#
# Fold: 3, Epoch: 23, Mini Batch: 10, Loss= 4363.374023, Training Accuracy= 79.90000
# Fold: 3, Epoch: 23, Mini Batch: 18, Loss= 3798.980469, Training Accuracy= 81.10000
#
# Fold: 3, Epoch: 23, Validation Accuracy= 86.40000
#
# Fold: 3, Epoch: 24, Mini Batch: 10, Loss= 3969.031982, Training Accuracy= 78.50000
# Fold: 3, Epoch: 24, Mini Batch: 18, Loss= 4089.784912, Training Accuracy= 80.80000
#
# Fold: 3, Epoch: 24, Validation Accuracy= 86.65000
#
# Fold: 3, Epoch: 25, Mini Batch: 10, Loss= 3665.805420, Training Accuracy= 80.40000
# Fold: 3, Epoch: 25, Mini Batch: 18, Loss= 3785.812012, Training Accuracy= 80.20000
#
# Fold: 3, Epoch: 25, Validation Accuracy= 86.60000
#
# Fold: 3, Epoch: 26, Mini Batch: 10, Loss= 3526.194824, Training Accuracy= 78.80000
# Fold: 3, Epoch: 26, Mini Batch: 18, Loss= 3483.396973, Training Accuracy= 81.40000
#
# Fold: 3, Epoch: 26, Validation Accuracy= 86.45000
#
# Fold: 3, Epoch: 27, Mini Batch: 10, Loss= 3779.211426, Training Accuracy= 80.60000
# Fold: 3, Epoch: 27, Mini Batch: 18, Loss= 3237.320557, Training Accuracy= 82.00000
#
# Fold: 3, Epoch: 27, Validation Accuracy= 86.80000
#
# Fold: 3, Epoch: 28, Mini Batch: 10, Loss= 3333.312012, Training Accuracy= 79.40000
# Fold: 3, Epoch: 28, Mini Batch: 18, Loss= 3174.151367, Training Accuracy= 81.90000
#
# Fold: 3, Epoch: 28, Validation Accuracy= 86.70000
#
# Fold: 3, Epoch: 29, Mini Batch: 10, Loss= 3120.288086, Training Accuracy= 80.20000
# Fold: 3, Epoch: 29, Mini Batch: 18, Loss= 3053.477295, Training Accuracy= 81.50000
#
# Fold: 3, Epoch: 29, Validation Accuracy= 87.50000
#
# Fold: 3, Epoch: 30, Mini Batch: 10, Loss= 3203.998047, Training Accuracy= 81.60000
# Fold: 3, Epoch: 30, Mini Batch: 18, Loss= 3119.211426, Training Accuracy= 82.80000
#
# Fold: 3, Epoch: 30, Validation Accuracy= 87.05000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           819    78   897
# 1           181   922  1103
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.001}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1024, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 4, Epoch: 1, Mini Batch: 10, Loss= 33609.054688, Training Accuracy= 61.20000
# Fold: 4, Epoch: 1, Mini Batch: 18, Loss= 25860.765625, Training Accuracy= 66.70000
#
# Fold: 4, Epoch: 1, Validation Accuracy= 79.55000
#
# Fold: 4, Epoch: 2, Mini Batch: 10, Loss= 22086.355469, Training Accuracy= 69.50000
# Fold: 4, Epoch: 2, Mini Batch: 18, Loss= 19813.261719, Training Accuracy= 72.70000
#
# Fold: 4, Epoch: 2, Validation Accuracy= 81.95000
#
# Fold: 4, Epoch: 3, Mini Batch: 10, Loss= 18027.283203, Training Accuracy= 72.80000
# Fold: 4, Epoch: 3, Mini Batch: 18, Loss= 15767.832031, Training Accuracy= 75.30000
#
# Fold: 4, Epoch: 3, Validation Accuracy= 83.25000
#
# Fold: 4, Epoch: 4, Mini Batch: 10, Loss= 15562.345703, Training Accuracy= 74.30000
# Fold: 4, Epoch: 4, Mini Batch: 18, Loss= 12585.928711, Training Accuracy= 77.20000
#
# Fold: 4, Epoch: 4, Validation Accuracy= 83.85000
#
# Fold: 4, Epoch: 5, Mini Batch: 10, Loss= 13455.466797, Training Accuracy= 73.70000
# Fold: 4, Epoch: 5, Mini Batch: 18, Loss= 11355.564453, Training Accuracy= 78.50000
#
# Fold: 4, Epoch: 5, Validation Accuracy= 84.05000
#
# Fold: 4, Epoch: 6, Mini Batch: 10, Loss= 11405.470703, Training Accuracy= 77.20000
# Fold: 4, Epoch: 6, Mini Batch: 18, Loss= 10776.610352, Training Accuracy= 76.40000
#
# Fold: 4, Epoch: 6, Validation Accuracy= 84.40000
#
# Fold: 4, Epoch: 7, Mini Batch: 10, Loss= 10087.097656, Training Accuracy= 78.40000
# Fold: 4, Epoch: 7, Mini Batch: 18, Loss= 9086.276367, Training Accuracy= 79.50000
#
# Fold: 4, Epoch: 7, Validation Accuracy= 84.70000
#
# Fold: 4, Epoch: 8, Mini Batch: 10, Loss= 9813.988281, Training Accuracy= 76.70000
# Fold: 4, Epoch: 8, Mini Batch: 18, Loss= 9886.381836, Training Accuracy= 78.20000
#
# Fold: 4, Epoch: 8, Validation Accuracy= 84.80000
#
# Fold: 4, Epoch: 9, Mini Batch: 10, Loss= 8873.676758, Training Accuracy= 77.20000
# Fold: 4, Epoch: 9, Mini Batch: 18, Loss= 8809.328125, Training Accuracy= 76.50000
#
# Fold: 4, Epoch: 9, Validation Accuracy= 85.40000
#
# Fold: 4, Epoch: 10, Mini Batch: 10, Loss= 7701.354980, Training Accuracy= 79.30000
# Fold: 4, Epoch: 10, Mini Batch: 18, Loss= 7849.623047, Training Accuracy= 78.70000
#
# Fold: 4, Epoch: 10, Validation Accuracy= 85.30000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           804    98   902
# 1           196   902  1098
# All        1000  1000  2000
#
# Fold: 4, Epoch: 11, Mini Batch: 10, Loss= 6840.952637, Training Accuracy= 79.50000
# Fold: 4, Epoch: 11, Mini Batch: 18, Loss= 8446.587891, Training Accuracy= 78.60000
#
# Fold: 4, Epoch: 11, Validation Accuracy= 85.40000
#
# Fold: 4, Epoch: 12, Mini Batch: 10, Loss= 7427.420410, Training Accuracy= 79.00000
# Fold: 4, Epoch: 12, Mini Batch: 18, Loss= 7894.066406, Training Accuracy= 77.40000
#
# Fold: 4, Epoch: 12, Validation Accuracy= 85.60000
#
# Fold: 4, Epoch: 13, Mini Batch: 10, Loss= 6172.807129, Training Accuracy= 80.50000
# Fold: 4, Epoch: 13, Mini Batch: 18, Loss= 6572.061523, Training Accuracy= 79.20000
#
# Fold: 4, Epoch: 13, Validation Accuracy= 85.55000
#
# Fold: 4, Epoch: 14, Mini Batch: 10, Loss= 6943.720703, Training Accuracy= 79.80000
# Fold: 4, Epoch: 14, Mini Batch: 18, Loss= 6518.090820, Training Accuracy= 80.80000
#
# Fold: 4, Epoch: 14, Validation Accuracy= 85.55000
#
# Fold: 4, Epoch: 15, Mini Batch: 10, Loss= 6116.219238, Training Accuracy= 79.20000
# Fold: 4, Epoch: 15, Mini Batch: 18, Loss= 5771.257812, Training Accuracy= 78.70000
#
# Fold: 4, Epoch: 15, Validation Accuracy= 85.65000
#
# Fold: 4, Epoch: 16, Mini Batch: 10, Loss= 5273.334961, Training Accuracy= 80.00000
# Fold: 4, Epoch: 16, Mini Batch: 18, Loss= 5214.193848, Training Accuracy= 81.10000
#
# Fold: 4, Epoch: 16, Validation Accuracy= 85.80000
#
# Fold: 4, Epoch: 17, Mini Batch: 10, Loss= 4913.389648, Training Accuracy= 80.00000
# Fold: 4, Epoch: 17, Mini Batch: 18, Loss= 5557.637207, Training Accuracy= 79.20000
#
# Fold: 4, Epoch: 17, Validation Accuracy= 85.70000
#
# Fold: 4, Epoch: 18, Mini Batch: 10, Loss= 5255.280762, Training Accuracy= 79.00000
# Fold: 4, Epoch: 18, Mini Batch: 18, Loss= 5013.961914, Training Accuracy= 79.90000
#
# Fold: 4, Epoch: 18, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 19, Mini Batch: 10, Loss= 4941.905273, Training Accuracy= 79.70000
# Fold: 4, Epoch: 19, Mini Batch: 18, Loss= 5426.167969, Training Accuracy= 78.60000
#
# Fold: 4, Epoch: 19, Validation Accuracy= 85.95000
#
# Fold: 4, Epoch: 20, Mini Batch: 10, Loss= 3951.067383, Training Accuracy= 81.50000
# Fold: 4, Epoch: 20, Mini Batch: 18, Loss= 4725.749512, Training Accuracy= 79.90000
#
# Fold: 4, Epoch: 20, Validation Accuracy= 86.20000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           818    94   912
# 1           182   906  1088
# All        1000  1000  2000
#
# Fold: 4, Epoch: 21, Mini Batch: 10, Loss= 4461.127930, Training Accuracy= 79.70000
# Fold: 4, Epoch: 21, Mini Batch: 18, Loss= 5020.518066, Training Accuracy= 79.10000
#
# Fold: 4, Epoch: 21, Validation Accuracy= 86.25000
#
# Fold: 4, Epoch: 22, Mini Batch: 10, Loss= 4381.887207, Training Accuracy= 79.90000
# Fold: 4, Epoch: 22, Mini Batch: 18, Loss= 3828.851074, Training Accuracy= 84.00000
#
# Fold: 4, Epoch: 22, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 23, Mini Batch: 10, Loss= 3757.022217, Training Accuracy= 80.10000
# Fold: 4, Epoch: 23, Mini Batch: 18, Loss= 4210.720703, Training Accuracy= 81.80000
#
# Fold: 4, Epoch: 23, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 24, Mini Batch: 10, Loss= 3589.035400, Training Accuracy= 79.70000
# Fold: 4, Epoch: 24, Mini Batch: 18, Loss= 4199.209961, Training Accuracy= 80.50000
#
# Fold: 4, Epoch: 24, Validation Accuracy= 85.85000
#
# Fold: 4, Epoch: 25, Mini Batch: 10, Loss= 4100.013672, Training Accuracy= 80.50000
# Fold: 4, Epoch: 25, Mini Batch: 18, Loss= 4066.796143, Training Accuracy= 80.80000
#
# Fold: 4, Epoch: 25, Validation Accuracy= 86.10000
#
# Fold: 4, Epoch: 26, Mini Batch: 10, Loss= 3556.239990, Training Accuracy= 80.00000
# Fold: 4, Epoch: 26, Mini Batch: 18, Loss= 4027.537598, Training Accuracy= 79.80000
#
# Fold: 4, Epoch: 26, Validation Accuracy= 86.00000
#
# Fold: 4, Epoch: 27, Mini Batch: 10, Loss= 3889.241211, Training Accuracy= 79.70000
# Fold: 4, Epoch: 27, Mini Batch: 18, Loss= 3119.798828, Training Accuracy= 81.90000
#
# Fold: 4, Epoch: 27, Validation Accuracy= 85.75000
#
# Fold: 4, Epoch: 28, Mini Batch: 10, Loss= 3462.876465, Training Accuracy= 81.20000
# Fold: 4, Epoch: 28, Mini Batch: 18, Loss= 3508.548096, Training Accuracy= 81.20000
#
# Fold: 4, Epoch: 28, Validation Accuracy= 85.90000
#
# Fold: 4, Epoch: 29, Mini Batch: 10, Loss= 2906.583496, Training Accuracy= 82.10000
# Fold: 4, Epoch: 29, Mini Batch: 18, Loss= 3607.208252, Training Accuracy= 79.90000
#
# Fold: 4, Epoch: 29, Validation Accuracy= 86.00000
#
# Fold: 4, Epoch: 30, Mini Batch: 10, Loss= 3690.809570, Training Accuracy= 78.20000
# Fold: 4, Epoch: 30, Mini Batch: 18, Loss= 3171.916992, Training Accuracy= 79.50000
#
# Fold: 4, Epoch: 30, Validation Accuracy= 85.60000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           810    98   908
# 1           190   902  1092
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.001}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1024, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 5, Epoch: 1, Mini Batch: 10, Loss= 39891.984375, Training Accuracy= 59.20000
# Fold: 5, Epoch: 1, Mini Batch: 18, Loss= 27893.154297, Training Accuracy= 66.00000
#
# Fold: 5, Epoch: 1, Validation Accuracy= 79.75000
#
# Fold: 5, Epoch: 2, Mini Batch: 10, Loss= 21482.396484, Training Accuracy= 70.60000
# Fold: 5, Epoch: 2, Mini Batch: 18, Loss= 20357.763672, Training Accuracy= 72.40000
#
# Fold: 5, Epoch: 2, Validation Accuracy= 82.30000
#
# Fold: 5, Epoch: 3, Mini Batch: 10, Loss= 19852.240234, Training Accuracy= 70.30000
# Fold: 5, Epoch: 3, Mini Batch: 18, Loss= 14798.194336, Training Accuracy= 75.20000
#
# Fold: 5, Epoch: 3, Validation Accuracy= 83.85000
#
# Fold: 5, Epoch: 4, Mini Batch: 10, Loss= 15268.958008, Training Accuracy= 73.70000
# Fold: 5, Epoch: 4, Mini Batch: 18, Loss= 13563.935547, Training Accuracy= 76.80000
#
# Fold: 5, Epoch: 4, Validation Accuracy= 84.15000
#
# Fold: 5, Epoch: 5, Mini Batch: 10, Loss= 13236.525391, Training Accuracy= 75.70000
# Fold: 5, Epoch: 5, Mini Batch: 18, Loss= 12930.141602, Training Accuracy= 77.90000
#
# Fold: 5, Epoch: 5, Validation Accuracy= 84.60000
#
# Fold: 5, Epoch: 6, Mini Batch: 10, Loss= 11612.718750, Training Accuracy= 76.70000
# Fold: 5, Epoch: 6, Mini Batch: 18, Loss= 11044.556641, Training Accuracy= 78.10000
#
# Fold: 5, Epoch: 6, Validation Accuracy= 85.30000
#
# Fold: 5, Epoch: 7, Mini Batch: 10, Loss= 10107.398438, Training Accuracy= 76.50000
# Fold: 5, Epoch: 7, Mini Batch: 18, Loss= 9744.295898, Training Accuracy= 79.10000
#
# Fold: 5, Epoch: 7, Validation Accuracy= 85.30000
#
# Fold: 5, Epoch: 8, Mini Batch: 10, Loss= 9765.931641, Training Accuracy= 78.10000
# Fold: 5, Epoch: 8, Mini Batch: 18, Loss= 10511.598633, Training Accuracy= 75.30000
#
# Fold: 5, Epoch: 8, Validation Accuracy= 85.45000
#
# Fold: 5, Epoch: 9, Mini Batch: 10, Loss= 8928.379883, Training Accuracy= 78.80000
# Fold: 5, Epoch: 9, Mini Batch: 18, Loss= 7785.963379, Training Accuracy= 79.90000
#
# Fold: 5, Epoch: 9, Validation Accuracy= 85.85000
#
# Fold: 5, Epoch: 10, Mini Batch: 10, Loss= 8893.750000, Training Accuracy= 78.30000
# Fold: 5, Epoch: 10, Mini Batch: 18, Loss= 8119.326660, Training Accuracy= 79.30000
#
# Fold: 5, Epoch: 10, Validation Accuracy= 86.00000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           810    90   900
# 1           190   910  1100
# All        1000  1000  2000
#
# Fold: 5, Epoch: 11, Mini Batch: 10, Loss= 7335.943848, Training Accuracy= 77.60000
# Fold: 5, Epoch: 11, Mini Batch: 18, Loss= 6890.835938, Training Accuracy= 78.30000
#
# Fold: 5, Epoch: 11, Validation Accuracy= 85.80000
#
# Fold: 5, Epoch: 12, Mini Batch: 10, Loss= 7370.939941, Training Accuracy= 78.50000
# Fold: 5, Epoch: 12, Mini Batch: 18, Loss= 6824.887207, Training Accuracy= 78.70000
#
# Fold: 5, Epoch: 12, Validation Accuracy= 85.95000
#
# Fold: 5, Epoch: 13, Mini Batch: 10, Loss= 6954.166992, Training Accuracy= 78.10000
# Fold: 5, Epoch: 13, Mini Batch: 18, Loss= 6728.578613, Training Accuracy= 80.50000
#
# Fold: 5, Epoch: 13, Validation Accuracy= 86.95000
#
# Fold: 5, Epoch: 14, Mini Batch: 10, Loss= 5965.060547, Training Accuracy= 78.40000
# Fold: 5, Epoch: 14, Mini Batch: 18, Loss= 6592.463867, Training Accuracy= 78.10000
#
# Fold: 5, Epoch: 14, Validation Accuracy= 86.30000
#
# Fold: 5, Epoch: 15, Mini Batch: 10, Loss= 5196.892090, Training Accuracy= 79.70000
# Fold: 5, Epoch: 15, Mini Batch: 18, Loss= 5886.602539, Training Accuracy= 79.70000
#
# Fold: 5, Epoch: 15, Validation Accuracy= 86.30000
#
# Fold: 5, Epoch: 16, Mini Batch: 10, Loss= 5785.758789, Training Accuracy= 78.80000
# Fold: 5, Epoch: 16, Mini Batch: 18, Loss= 5858.875000, Training Accuracy= 80.90000
#
# Fold: 5, Epoch: 16, Validation Accuracy= 86.25000
#
# Fold: 5, Epoch: 17, Mini Batch: 10, Loss= 5454.666992, Training Accuracy= 78.00000
# Fold: 5, Epoch: 17, Mini Batch: 18, Loss= 5849.929199, Training Accuracy= 78.50000
#
# Fold: 5, Epoch: 17, Validation Accuracy= 86.90000
#
# Fold: 5, Epoch: 18, Mini Batch: 10, Loss= 5139.506836, Training Accuracy= 79.90000
# Fold: 5, Epoch: 18, Mini Batch: 18, Loss= 4895.779297, Training Accuracy= 80.40000
#
# Fold: 5, Epoch: 18, Validation Accuracy= 86.40000
#
# Fold: 5, Epoch: 19, Mini Batch: 10, Loss= 5200.400879, Training Accuracy= 79.10000
# Fold: 5, Epoch: 19, Mini Batch: 18, Loss= 4880.240723, Training Accuracy= 80.30000
#
# Fold: 5, Epoch: 19, Validation Accuracy= 86.55000
#
# Fold: 5, Epoch: 20, Mini Batch: 10, Loss= 4822.548828, Training Accuracy= 79.80000
# Fold: 5, Epoch: 20, Mini Batch: 18, Loss= 5148.524902, Training Accuracy= 80.60000
#
# Fold: 5, Epoch: 20, Validation Accuracy= 86.60000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           818    86   904
# 1           182   914  1096
# All        1000  1000  2000
#
# Fold: 5, Epoch: 21, Mini Batch: 10, Loss= 3904.856445, Training Accuracy= 81.40000
# Fold: 5, Epoch: 21, Mini Batch: 18, Loss= 4805.397949, Training Accuracy= 80.60000
#
# Fold: 5, Epoch: 21, Validation Accuracy= 86.90000
#
# Fold: 5, Epoch: 22, Mini Batch: 10, Loss= 4714.569824, Training Accuracy= 79.90000
# Fold: 5, Epoch: 22, Mini Batch: 18, Loss= 4344.346191, Training Accuracy= 80.00000
#
# Fold: 5, Epoch: 22, Validation Accuracy= 86.80000
#
# Fold: 5, Epoch: 23, Mini Batch: 10, Loss= 3910.982422, Training Accuracy= 80.20000
# Fold: 5, Epoch: 23, Mini Batch: 18, Loss= 4479.765137, Training Accuracy= 80.40000
#
# Fold: 5, Epoch: 23, Validation Accuracy= 86.85000
#
# Fold: 5, Epoch: 24, Mini Batch: 10, Loss= 4094.858887, Training Accuracy= 80.20000
# Fold: 5, Epoch: 24, Mini Batch: 18, Loss= 4105.321289, Training Accuracy= 81.40000
#
# Fold: 5, Epoch: 24, Validation Accuracy= 86.60000
#
# Fold: 5, Epoch: 25, Mini Batch: 10, Loss= 4468.383789, Training Accuracy= 78.80000
# Fold: 5, Epoch: 25, Mini Batch: 18, Loss= 3704.982422, Training Accuracy= 81.60000
#
# Fold: 5, Epoch: 25, Validation Accuracy= 87.15000
#
# Fold: 5, Epoch: 26, Mini Batch: 10, Loss= 3438.751465, Training Accuracy= 81.40000
# Fold: 5, Epoch: 26, Mini Batch: 18, Loss= 3691.913330, Training Accuracy= 81.00000
#
# Fold: 5, Epoch: 26, Validation Accuracy= 87.25000
#
# Fold: 5, Epoch: 27, Mini Batch: 10, Loss= 3336.018066, Training Accuracy= 81.90000
# Fold: 5, Epoch: 27, Mini Batch: 18, Loss= 3323.548584, Training Accuracy= 81.40000
#
# Fold: 5, Epoch: 27, Validation Accuracy= 87.20000
#
# Fold: 5, Epoch: 28, Mini Batch: 10, Loss= 3413.038086, Training Accuracy= 81.30000
# Fold: 5, Epoch: 28, Mini Batch: 18, Loss= 3527.545410, Training Accuracy= 80.30000
#
# Fold: 5, Epoch: 28, Validation Accuracy= 87.65000
#
# Fold: 5, Epoch: 29, Mini Batch: 10, Loss= 3283.414062, Training Accuracy= 79.90000
# Fold: 5, Epoch: 29, Mini Batch: 18, Loss= 2805.014404, Training Accuracy= 82.50000
#
# Fold: 5, Epoch: 29, Validation Accuracy= 87.70000
#
# Fold: 5, Epoch: 30, Mini Batch: 10, Loss= 3004.136719, Training Accuracy= 80.20000
# Fold: 5, Epoch: 30, Mini Batch: 18, Loss= 3217.045410, Training Accuracy= 80.10000
#
# Fold: 5, Epoch: 30, Validation Accuracy= 87.45000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           826    77   903
# 1           174   923  1097
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.001}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1024, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 6, Epoch: 1, Mini Batch: 10, Loss= 32546.783203, Training Accuracy= 60.90000
# Fold: 6, Epoch: 1, Mini Batch: 18, Loss= 27109.478516, Training Accuracy= 68.20000
#
# Fold: 6, Epoch: 1, Validation Accuracy= 79.35000
#
# Fold: 6, Epoch: 2, Mini Batch: 10, Loss= 21685.019531, Training Accuracy= 72.00000
# Fold: 6, Epoch: 2, Mini Batch: 18, Loss= 20877.798828, Training Accuracy= 73.40000
#
# Fold: 6, Epoch: 2, Validation Accuracy= 81.85000
#
# Fold: 6, Epoch: 3, Mini Batch: 10, Loss= 17819.716797, Training Accuracy= 75.10000
# Fold: 6, Epoch: 3, Mini Batch: 18, Loss= 15185.717773, Training Accuracy= 75.70000
#
# Fold: 6, Epoch: 3, Validation Accuracy= 83.60000
#
# Fold: 6, Epoch: 4, Mini Batch: 10, Loss= 15219.073242, Training Accuracy= 76.40000
# Fold: 6, Epoch: 4, Mini Batch: 18, Loss= 14008.713867, Training Accuracy= 75.90000
#
# Fold: 6, Epoch: 4, Validation Accuracy= 84.40000
#
# Fold: 6, Epoch: 5, Mini Batch: 10, Loss= 14385.690430, Training Accuracy= 76.30000
# Fold: 6, Epoch: 5, Mini Batch: 18, Loss= 12025.736328, Training Accuracy= 76.20000
#
# Fold: 6, Epoch: 5, Validation Accuracy= 84.65000
#
# Fold: 6, Epoch: 6, Mini Batch: 10, Loss= 10599.414062, Training Accuracy= 77.70000
# Fold: 6, Epoch: 6, Mini Batch: 18, Loss= 10074.267578, Training Accuracy= 78.00000
#
# Fold: 6, Epoch: 6, Validation Accuracy= 84.75000
#
# Fold: 6, Epoch: 7, Mini Batch: 10, Loss= 9810.041992, Training Accuracy= 77.50000
# Fold: 6, Epoch: 7, Mini Batch: 18, Loss= 9778.869141, Training Accuracy= 77.00000
#
# Fold: 6, Epoch: 7, Validation Accuracy= 84.85000
#
# Fold: 6, Epoch: 8, Mini Batch: 10, Loss= 8138.638184, Training Accuracy= 79.40000
# Fold: 6, Epoch: 8, Mini Batch: 18, Loss= 9220.424805, Training Accuracy= 76.90000
#
# Fold: 6, Epoch: 8, Validation Accuracy= 85.00000
#
# Fold: 6, Epoch: 9, Mini Batch: 10, Loss= 8531.114258, Training Accuracy= 79.20000
# Fold: 6, Epoch: 9, Mini Batch: 18, Loss= 7982.725098, Training Accuracy= 78.80000
#
# Fold: 6, Epoch: 9, Validation Accuracy= 84.65000
#
# Fold: 6, Epoch: 10, Mini Batch: 10, Loss= 6787.755859, Training Accuracy= 80.00000
# Fold: 6, Epoch: 10, Mini Batch: 18, Loss= 8043.469238, Training Accuracy= 80.10000
#
# Fold: 6, Epoch: 10, Validation Accuracy= 85.65000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           806    93   899
# 1           194   907  1101
# All        1000  1000  2000
#
# Fold: 6, Epoch: 11, Mini Batch: 10, Loss= 7950.251465, Training Accuracy= 78.00000
# Fold: 6, Epoch: 11, Mini Batch: 18, Loss= 7839.621582, Training Accuracy= 80.00000
#
# Fold: 6, Epoch: 11, Validation Accuracy= 85.15000
#
# Fold: 6, Epoch: 12, Mini Batch: 10, Loss= 6490.452148, Training Accuracy= 80.80000
# Fold: 6, Epoch: 12, Mini Batch: 18, Loss= 7146.101074, Training Accuracy= 78.10000
#
# Fold: 6, Epoch: 12, Validation Accuracy= 85.60000
#
# Fold: 6, Epoch: 13, Mini Batch: 10, Loss= 6281.178223, Training Accuracy= 78.60000
# Fold: 6, Epoch: 13, Mini Batch: 18, Loss= 6790.420410, Training Accuracy= 77.80000
#
# Fold: 6, Epoch: 13, Validation Accuracy= 85.25000
#
# Fold: 6, Epoch: 14, Mini Batch: 10, Loss= 6351.778809, Training Accuracy= 78.80000
# Fold: 6, Epoch: 14, Mini Batch: 18, Loss= 5795.609863, Training Accuracy= 79.00000
#
# Fold: 6, Epoch: 14, Validation Accuracy= 85.80000
#
# Fold: 6, Epoch: 15, Mini Batch: 10, Loss= 5606.252930, Training Accuracy= 79.60000
# Fold: 6, Epoch: 15, Mini Batch: 18, Loss= 5496.396973, Training Accuracy= 81.10000
#
# Fold: 6, Epoch: 15, Validation Accuracy= 85.65000
#
# Fold: 6, Epoch: 16, Mini Batch: 10, Loss= 5601.729980, Training Accuracy= 79.30000
# Fold: 6, Epoch: 16, Mini Batch: 18, Loss= 5059.671875, Training Accuracy= 80.40000
#
# Fold: 6, Epoch: 16, Validation Accuracy= 85.65000
#
# Fold: 6, Epoch: 17, Mini Batch: 10, Loss= 4772.165527, Training Accuracy= 80.60000
# Fold: 6, Epoch: 17, Mini Batch: 18, Loss= 5204.392090, Training Accuracy= 81.40000
#
# Fold: 6, Epoch: 17, Validation Accuracy= 85.40000
#
# Fold: 6, Epoch: 18, Mini Batch: 10, Loss= 4734.716797, Training Accuracy= 79.70000
# Fold: 6, Epoch: 18, Mini Batch: 18, Loss= 5119.618652, Training Accuracy= 79.20000
#
# Fold: 6, Epoch: 18, Validation Accuracy= 85.60000
#
# Fold: 6, Epoch: 19, Mini Batch: 10, Loss= 4341.255859, Training Accuracy= 79.90000
# Fold: 6, Epoch: 19, Mini Batch: 18, Loss= 5050.900879, Training Accuracy= 79.60000
#
# Fold: 6, Epoch: 19, Validation Accuracy= 85.75000
#
# Fold: 6, Epoch: 20, Mini Batch: 10, Loss= 4289.285156, Training Accuracy= 79.80000
# Fold: 6, Epoch: 20, Mini Batch: 18, Loss= 4794.896973, Training Accuracy= 79.80000
#
# Fold: 6, Epoch: 20, Validation Accuracy= 86.05000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           818    97   915
# 1           182   903  1085
# All        1000  1000  2000
#
# Fold: 6, Epoch: 21, Mini Batch: 10, Loss= 4406.223633, Training Accuracy= 80.00000
# Fold: 6, Epoch: 21, Mini Batch: 18, Loss= 4214.462891, Training Accuracy= 80.90000
#
# Fold: 6, Epoch: 21, Validation Accuracy= 86.05000
#
# Fold: 6, Epoch: 22, Mini Batch: 10, Loss= 3885.387451, Training Accuracy= 81.40000
# Fold: 6, Epoch: 22, Mini Batch: 18, Loss= 4339.212402, Training Accuracy= 80.30000
#
# Fold: 6, Epoch: 22, Validation Accuracy= 85.60000
#
# Fold: 6, Epoch: 23, Mini Batch: 10, Loss= 4044.601318, Training Accuracy= 80.10000
# Fold: 6, Epoch: 23, Mini Batch: 18, Loss= 4154.528809, Training Accuracy= 80.30000
#
# Fold: 6, Epoch: 23, Validation Accuracy= 86.25000
#
# Fold: 6, Epoch: 24, Mini Batch: 10, Loss= 3421.915771, Training Accuracy= 81.00000
# Fold: 6, Epoch: 24, Mini Batch: 18, Loss= 3829.806396, Training Accuracy= 81.60000
#
# Fold: 6, Epoch: 24, Validation Accuracy= 85.90000
#
# Fold: 6, Epoch: 25, Mini Batch: 10, Loss= 3526.416992, Training Accuracy= 81.40000
# Fold: 6, Epoch: 25, Mini Batch: 18, Loss= 3663.544434, Training Accuracy= 81.20000
#
# Fold: 6, Epoch: 25, Validation Accuracy= 86.10000
#
# Fold: 6, Epoch: 26, Mini Batch: 10, Loss= 3061.976562, Training Accuracy= 81.80000
# Fold: 6, Epoch: 26, Mini Batch: 18, Loss= 3285.759277, Training Accuracy= 82.20000
#
# Fold: 6, Epoch: 26, Validation Accuracy= 85.85000
#
# Fold: 6, Epoch: 27, Mini Batch: 10, Loss= 2704.804443, Training Accuracy= 83.40000
# Fold: 6, Epoch: 27, Mini Batch: 18, Loss= 3787.072510, Training Accuracy= 80.70000
#
# Fold: 6, Epoch: 27, Validation Accuracy= 85.65000
#
# Fold: 6, Epoch: 28, Mini Batch: 10, Loss= 3325.761719, Training Accuracy= 79.60000
# Fold: 6, Epoch: 28, Mini Batch: 18, Loss= 2983.891602, Training Accuracy= 82.90000
#
# Fold: 6, Epoch: 28, Validation Accuracy= 85.80000
#
# Fold: 6, Epoch: 29, Mini Batch: 10, Loss= 3286.416504, Training Accuracy= 80.50000
# Fold: 6, Epoch: 29, Mini Batch: 18, Loss= 3509.626465, Training Accuracy= 81.00000
#
# Fold: 6, Epoch: 29, Validation Accuracy= 85.65000
#
# Fold: 6, Epoch: 30, Mini Batch: 10, Loss= 2980.478760, Training Accuracy= 81.80000
# Fold: 6, Epoch: 30, Mini Batch: 18, Loss= 3226.563232, Training Accuracy= 83.60000
#
# Fold: 6, Epoch: 30, Validation Accuracy= 85.75000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           812    97   909
# 1           188   903  1091
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.001}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1024, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 7, Epoch: 1, Mini Batch: 10, Loss= 35068.296875, Training Accuracy= 61.00000
# Fold: 7, Epoch: 1, Mini Batch: 18, Loss= 26915.718750, Training Accuracy= 67.10000
#
# Fold: 7, Epoch: 1, Validation Accuracy= 81.05000
#
# Fold: 7, Epoch: 2, Mini Batch: 10, Loss= 24034.775391, Training Accuracy= 71.60000
# Fold: 7, Epoch: 2, Mini Batch: 18, Loss= 22092.179688, Training Accuracy= 72.40000
#
# Fold: 7, Epoch: 2, Validation Accuracy= 83.70000
#
# Fold: 7, Epoch: 3, Mini Batch: 10, Loss= 16294.150391, Training Accuracy= 75.80000
# Fold: 7, Epoch: 3, Mini Batch: 18, Loss= 17779.330078, Training Accuracy= 73.00000
#
# Fold: 7, Epoch: 3, Validation Accuracy= 84.80000
#
# Fold: 7, Epoch: 4, Mini Batch: 10, Loss= 15184.751953, Training Accuracy= 75.00000
# Fold: 7, Epoch: 4, Mini Batch: 18, Loss= 13632.541992, Training Accuracy= 75.70000
#
# Fold: 7, Epoch: 4, Validation Accuracy= 84.90000
#
# Fold: 7, Epoch: 5, Mini Batch: 10, Loss= 12664.404297, Training Accuracy= 77.70000
# Fold: 7, Epoch: 5, Mini Batch: 18, Loss= 14245.486328, Training Accuracy= 75.00000
#
# Fold: 7, Epoch: 5, Validation Accuracy= 85.60000
#
# Fold: 7, Epoch: 6, Mini Batch: 10, Loss= 12119.897461, Training Accuracy= 75.70000
# Fold: 7, Epoch: 6, Mini Batch: 18, Loss= 12118.078125, Training Accuracy= 77.40000
#
# Fold: 7, Epoch: 6, Validation Accuracy= 85.80000
#
# Fold: 7, Epoch: 7, Mini Batch: 10, Loss= 9595.795898, Training Accuracy= 78.60000
# Fold: 7, Epoch: 7, Mini Batch: 18, Loss= 11551.884766, Training Accuracy= 76.20000
#
# Fold: 7, Epoch: 7, Validation Accuracy= 85.80000
#
# Fold: 7, Epoch: 8, Mini Batch: 10, Loss= 9919.223633, Training Accuracy= 77.10000
# Fold: 7, Epoch: 8, Mini Batch: 18, Loss= 9673.142578, Training Accuracy= 78.30000
#
# Fold: 7, Epoch: 8, Validation Accuracy= 85.55000
#
# ...
#
# Fold: 8, Epoch: 29, Mini Batch: 10, Loss= 2336.976074, Training Accuracy= 83.90000
# Fold: 8, Epoch: 29, Mini Batch: 18, Loss= 3455.938965, Training Accuracy= 80.40000
#
# Fold: 8, Epoch: 29, Validation Accuracy= 86.10000
#
# Fold: 8, Epoch: 30, Mini Batch: 10, Loss= 3304.080811, Training Accuracy= 80.70000
# Fold: 8, Epoch: 30, Mini Batch: 18, Loss= 3310.697754, Training Accuracy= 80.00000
#
# Fold: 8, Epoch: 30, Validation Accuracy= 86.30000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           819    93   912
# 1           181   907  1088
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.001}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1024, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 9, Epoch: 1, Mini Batch: 10, Loss= 34962.625000, Training Accuracy= 59.90000
# Fold: 9, Epoch: 1, Mini Batch: 18, Loss= 27412.158203, Training Accuracy= 67.50000
#
# Fold: 9, Epoch: 1, Validation Accuracy= 80.85000
#
# Fold: 9, Epoch: 2, Mini Batch: 10, Loss= 22638.373047, Training Accuracy= 71.70000
# Fold: 9, Epoch: 2, Mini Batch: 18, Loss= 19151.154297, Training Accuracy= 71.50000
#
# Fold: 9, Epoch: 2, Validation Accuracy= 83.00000
#
# Fold: 9, Epoch: 3, Mini Batch: 10, Loss= 17572.164062, Training Accuracy= 73.30000
# Fold: 9, Epoch: 3, Mini Batch: 18, Loss= 15195.782227, Training Accuracy= 75.00000
#
# Fold: 9, Epoch: 3, Validation Accuracy= 84.00000
#
# Fold: 9, Epoch: 4, Mini Batch: 10, Loss= 13569.808594, Training Accuracy= 76.90000
# Fold: 9, Epoch: 4, Mini Batch: 18, Loss= 14241.940430, Training Accuracy= 74.80000
#
# Fold: 9, Epoch: 4, Validation Accuracy= 84.95000
#
# Fold: 9, Epoch: 5, Mini Batch: 10, Loss= 11823.111328, Training Accuracy= 77.70000
# Fold: 9, Epoch: 5, Mini Batch: 18, Loss= 12606.159180, Training Accuracy= 75.30000
#
# Fold: 9, Epoch: 5, Validation Accuracy= 85.50000
#
# Fold: 9, Epoch: 6, Mini Batch: 10, Loss= 11169.705078, Training Accuracy= 79.70000
# Fold: 9, Epoch: 6, Mini Batch: 18, Loss= 11510.013672, Training Accuracy= 76.40000
#
# Fold: 9, Epoch: 6, Validation Accuracy= 85.45000
#
# Fold: 9, Epoch: 7, Mini Batch: 10, Loss= 10186.444336, Training Accuracy= 79.00000
# Fold: 9, Epoch: 7, Mini Batch: 18, Loss= 9653.652344, Training Accuracy= 77.80000
#
# Fold: 9, Epoch: 7, Validation Accuracy= 85.35000
#
# Fold: 9, Epoch: 8, Mini Batch: 10, Loss= 9729.122070, Training Accuracy= 76.20000
# Fold: 9, Epoch: 8, Mini Batch: 18, Loss= 10020.558594, Training Accuracy= 78.20000
#
# Fold: 9, Epoch: 8, Validation Accuracy= 85.10000
#
# Fold: 9, Epoch: 9, Mini Batch: 10, Loss= 7860.626953, Training Accuracy= 79.20000
# Fold: 9, Epoch: 9, Mini Batch: 18, Loss= 8721.744141, Training Accuracy= 78.10000
#
# Fold: 9, Epoch: 9, Validation Accuracy= 85.45000
#
# Fold: 9, Epoch: 10, Mini Batch: 10, Loss= 8014.305176, Training Accuracy= 78.20000
# Fold: 9, Epoch: 10, Mini Batch: 18, Loss= 8456.480469, Training Accuracy= 78.00000
#
# Fold: 9, Epoch: 10, Validation Accuracy= 85.55000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           790    79   869
# 1           210   921  1131
# All        1000  1000  2000
#
# Fold: 9, Epoch: 11, Mini Batch: 10, Loss= 7445.608398, Training Accuracy= 78.80000
# Fold: 9, Epoch: 11, Mini Batch: 18, Loss= 7318.877930, Training Accuracy= 79.00000
#
# Fold: 9, Epoch: 11, Validation Accuracy= 85.30000
#
# Fold: 9, Epoch: 12, Mini Batch: 10, Loss= 7112.700195, Training Accuracy= 79.80000
# Fold: 9, Epoch: 12, Mini Batch: 18, Loss= 6649.667969, Training Accuracy= 81.10000
#
# Fold: 9, Epoch: 12, Validation Accuracy= 85.50000
#
# Fold: 9, Epoch: 13, Mini Batch: 10, Loss= 6138.748535, Training Accuracy= 79.60000
# Fold: 9, Epoch: 13, Mini Batch: 18, Loss= 7025.067383, Training Accuracy= 78.50000
#
# Fold: 9, Epoch: 13, Validation Accuracy= 85.60000
#
# Fold: 9, Epoch: 14, Mini Batch: 10, Loss= 6599.029297, Training Accuracy= 79.00000
# Fold: 9, Epoch: 14, Mini Batch: 18, Loss= 6353.482422, Training Accuracy= 78.00000
#
# Fold: 9, Epoch: 14, Validation Accuracy= 85.80000
#
# Fold: 9, Epoch: 15, Mini Batch: 10, Loss= 5549.788086, Training Accuracy= 79.40000
# Fold: 9, Epoch: 15, Mini Batch: 18, Loss= 6411.837891, Training Accuracy= 77.90000
#
# Fold: 9, Epoch: 15, Validation Accuracy= 85.80000
#
# Fold: 9, Epoch: 16, Mini Batch: 10, Loss= 5080.543945, Training Accuracy= 81.00000
# Fold: 9, Epoch: 16, Mini Batch: 18, Loss= 5176.630859, Training Accuracy= 81.00000
#
# Fold: 9, Epoch: 16, Validation Accuracy= 85.70000
#
# Fold: 9, Epoch: 17, Mini Batch: 10, Loss= 4948.488770, Training Accuracy= 79.40000
# Fold: 9, Epoch: 17, Mini Batch: 18, Loss= 5728.648438, Training Accuracy= 80.60000
#
# Fold: 9, Epoch: 17, Validation Accuracy= 85.45000
#
# Fold: 9, Epoch: 18, Mini Batch: 10, Loss= 5146.233398, Training Accuracy= 79.80000
# Fold: 9, Epoch: 18, Mini Batch: 18, Loss= 4683.413574, Training Accuracy= 80.70000
#
# Fold: 9, Epoch: 18, Validation Accuracy= 85.60000
#
# Fold: 9, Epoch: 19, Mini Batch: 10, Loss= 4789.071777, Training Accuracy= 80.90000
# Fold: 9, Epoch: 19, Mini Batch: 18, Loss= 5457.333984, Training Accuracy= 78.80000
#
# Fold: 9, Epoch: 19, Validation Accuracy= 85.75000
#
# Fold: 9, Epoch: 20, Mini Batch: 10, Loss= 4797.744629, Training Accuracy= 79.00000
# Fold: 9, Epoch: 20, Mini Batch: 18, Loss= 4796.586426, Training Accuracy= 79.70000
#
# Fold: 9, Epoch: 20, Validation Accuracy= 85.65000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           803    90   893
# 1           197   910  1107
# All        1000  1000  2000
#
# Fold: 9, Epoch: 21, Mini Batch: 10, Loss= 4286.370117, Training Accuracy= 79.60000
# Fold: 9, Epoch: 21, Mini Batch: 18, Loss= 4130.269531, Training Accuracy= 82.00000
#
# Fold: 9, Epoch: 21, Validation Accuracy= 85.90000
#
# Fold: 9, Epoch: 22, Mini Batch: 10, Loss= 3997.964600, Training Accuracy= 81.80000
# Fold: 9, Epoch: 22, Mini Batch: 18, Loss= 3986.976074, Training Accuracy= 81.60000
#
# Fold: 9, Epoch: 22, Validation Accuracy= 85.85000
#
# Fold: 9, Epoch: 23, Mini Batch: 10, Loss= 3811.439209, Training Accuracy= 81.90000
# Fold: 9, Epoch: 23, Mini Batch: 18, Loss= 4184.739258, Training Accuracy= 79.80000
#
# Fold: 9, Epoch: 23, Validation Accuracy= 85.65000
#
# Fold: 9, Epoch: 24, Mini Batch: 10, Loss= 3504.311035, Training Accuracy= 81.40000
# Fold: 9, Epoch: 24, Mini Batch: 18, Loss= 3855.303467, Training Accuracy= 81.10000
#
# Fold: 9, Epoch: 24, Validation Accuracy= 85.55000
#
# Fold: 9, Epoch: 25, Mini Batch: 10, Loss= 3769.284912, Training Accuracy= 79.70000
# Fold: 9, Epoch: 25, Mini Batch: 18, Loss= 3488.912598, Training Accuracy= 81.60000
#
# Fold: 9, Epoch: 25, Validation Accuracy= 85.50000
#
# Fold: 9, Epoch: 26, Mini Batch: 10, Loss= 3464.802002, Training Accuracy= 81.60000
# Fold: 9, Epoch: 26, Mini Batch: 18, Loss= 3850.460449, Training Accuracy= 80.30000
#
# Fold: 9, Epoch: 26, Validation Accuracy= 85.65000
#
# Fold: 9, Epoch: 27, Mini Batch: 10, Loss= 3535.787354, Training Accuracy= 79.20000
# Fold: 9, Epoch: 27, Mini Batch: 18, Loss= 3888.260010, Training Accuracy= 79.00000
#
# Fold: 9, Epoch: 27, Validation Accuracy= 85.60000
#
# Fold: 9, Epoch: 28, Mini Batch: 10, Loss= 3272.715332, Training Accuracy= 79.70000
# Fold: 9, Epoch: 28, Mini Batch: 18, Loss= 3685.631104, Training Accuracy= 81.70000
#
# Fold: 9, Epoch: 28, Validation Accuracy= 85.65000
#
# Fold: 9, Epoch: 29, Mini Batch: 10, Loss= 2861.474121, Training Accuracy= 81.90000
# Fold: 9, Epoch: 29, Mini Batch: 18, Loss= 3390.082031, Training Accuracy= 80.10000
#
# Fold: 9, Epoch: 29, Validation Accuracy= 85.60000
#
# Fold: 9, Epoch: 30, Mini Batch: 10, Loss= 2768.623047, Training Accuracy= 81.50000
# Fold: 9, Epoch: 30, Mini Batch: 18, Loss= 2896.825684, Training Accuracy= 81.80000
#
# Fold: 9, Epoch: 30, Validation Accuracy= 85.55000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           794    83   877
# 1           206   917  1123
# All        1000  1000  2000
#
#
# ##########################################################################################
#
# Validation Data and Labels shape:  (2000, 1179) (2000, 2)
# Training Data and Labels shape:  (18000, 1179) (18000, 2)
# The Label Dictionary is given as:  {0: 'trainDataAirplane.pickle', 1: 'trainDataCat.pickle'}
#
# {'numFolds': 10, 'batchSize': 1000, 'epochs': 30, 'keepProb': {'hid1': 0.75, 'hid2': 0.5, 'hid3': 0.5}, 'optimizerParam': {'optimizer': 'ADAM', 'learning_rate': 0.001}, 'numLabels': 2, 'numHidden2': 1280, 'numHidden3': 1024, 'imageSize': 32, 'numHidden1': 1024}
# Fold: 10, Epoch: 1, Mini Batch: 10, Loss= 34188.800781, Training Accuracy= 61.90000
# Fold: 10, Epoch: 1, Mini Batch: 18, Loss= 26311.785156, Training Accuracy= 66.70000
#
# Fold: 10, Epoch: 1, Validation Accuracy= 81.90000
#
# Fold: 10, Epoch: 2, Mini Batch: 10, Loss= 22854.900391, Training Accuracy= 70.40000
# Fold: 10, Epoch: 2, Mini Batch: 18, Loss= 19686.068359, Training Accuracy= 71.80000
#
# Fold: 10, Epoch: 2, Validation Accuracy= 84.15000
#
# Fold: 10, Epoch: 3, Mini Batch: 10, Loss= 17520.480469, Training Accuracy= 74.10000
# Fold: 10, Epoch: 3, Mini Batch: 18, Loss= 15045.013672, Training Accuracy= 75.70000
#
# Fold: 10, Epoch: 3, Validation Accuracy= 84.45000
#
# Fold: 10, Epoch: 4, Mini Batch: 10, Loss= 14976.959961, Training Accuracy= 74.60000
# Fold: 10, Epoch: 4, Mini Batch: 18, Loss= 13893.774414, Training Accuracy= 75.80000
#
# Fold: 10, Epoch: 4, Validation Accuracy= 85.30000
#
# Fold: 10, Epoch: 5, Mini Batch: 10, Loss= 12169.819336, Training Accuracy= 76.80000
# Fold: 10, Epoch: 5, Mini Batch: 18, Loss= 11352.204102, Training Accuracy= 77.10000
#
# Fold: 10, Epoch: 5, Validation Accuracy= 85.80000
#
# Fold: 10, Epoch: 6, Mini Batch: 10, Loss= 11910.532227, Training Accuracy= 76.00000
# Fold: 10, Epoch: 6, Mini Batch: 18, Loss= 9398.130859, Training Accuracy= 80.00000
#
# Fold: 10, Epoch: 6, Validation Accuracy= 85.85000
#
# Fold: 10, Epoch: 7, Mini Batch: 10, Loss= 10270.618164, Training Accuracy= 77.10000
# Fold: 10, Epoch: 7, Mini Batch: 18, Loss= 9323.510742, Training Accuracy= 77.90000
#
# Fold: 10, Epoch: 7, Validation Accuracy= 86.20000
#
# Fold: 10, Epoch: 8, Mini Batch: 10, Loss= 8838.592773, Training Accuracy= 79.10000
# Fold: 10, Epoch: 8, Mini Batch: 18, Loss= 8141.678711, Training Accuracy= 78.80000
#
# Fold: 10, Epoch: 8, Validation Accuracy= 86.50000
#
# Fold: 10, Epoch: 9, Mini Batch: 10, Loss= 8754.572266, Training Accuracy= 77.10000
# Fold: 10, Epoch: 9, Mini Batch: 18, Loss= 8282.121094, Training Accuracy= 78.50000
#
# Fold: 10, Epoch: 9, Validation Accuracy= 86.50000
#
# Fold: 10, Epoch: 10, Mini Batch: 10, Loss= 8147.636230, Training Accuracy= 78.20000
# Fold: 10, Epoch: 10, Mini Batch: 18, Loss= 7464.750977, Training Accuracy= 78.20000
#
# Fold: 10, Epoch: 10, Validation Accuracy= 86.05000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           806    85   891
# 1           194   915  1109
# All        1000  1000  2000
#
# Fold: 10, Epoch: 11, Mini Batch: 10, Loss= 7205.386230, Training Accuracy= 78.20000
# Fold: 10, Epoch: 11, Mini Batch: 18, Loss= 6644.360352, Training Accuracy= 79.30000
#
# Fold: 10, Epoch: 11, Validation Accuracy= 86.75000
#
# Fold: 10, Epoch: 12, Mini Batch: 10, Loss= 6934.230957, Training Accuracy= 78.80000
# Fold: 10, Epoch: 12, Mini Batch: 18, Loss= 6027.900879, Training Accuracy= 80.70000
#
# Fold: 10, Epoch: 12, Validation Accuracy= 87.40000
#
# Fold: 10, Epoch: 13, Mini Batch: 10, Loss= 5924.081055, Training Accuracy= 80.20000
# Fold: 10, Epoch: 13, Mini Batch: 18, Loss= 5591.057617, Training Accuracy= 81.00000
#
# Fold: 10, Epoch: 13, Validation Accuracy= 86.65000
#
# Fold: 10, Epoch: 14, Mini Batch: 10, Loss= 4978.839844, Training Accuracy= 80.90000
# Fold: 10, Epoch: 14, Mini Batch: 18, Loss= 5869.268066, Training Accuracy= 80.40000
#
# Fold: 10, Epoch: 14, Validation Accuracy= 87.05000
#
# Fold: 10, Epoch: 15, Mini Batch: 10, Loss= 6137.685059, Training Accuracy= 79.40000
# Fold: 10, Epoch: 15, Mini Batch: 18, Loss= 5858.171875, Training Accuracy= 78.60000
#
# Fold: 10, Epoch: 15, Validation Accuracy= 87.10000
#
# Fold: 10, Epoch: 16, Mini Batch: 10, Loss= 4776.525391, Training Accuracy= 79.90000
# Fold: 10, Epoch: 16, Mini Batch: 18, Loss= 5495.930664, Training Accuracy= 78.70000
#
# Fold: 10, Epoch: 16, Validation Accuracy= 87.55000
#
# Fold: 10, Epoch: 17, Mini Batch: 10, Loss= 3906.976074, Training Accuracy= 83.40000
# Fold: 10, Epoch: 17, Mini Batch: 18, Loss= 4389.092773, Training Accuracy= 81.00000
#
# Fold: 10, Epoch: 17, Validation Accuracy= 87.50000
#
# Fold: 10, Epoch: 18, Mini Batch: 10, Loss= 4198.146484, Training Accuracy= 81.80000
# Fold: 10, Epoch: 18, Mini Batch: 18, Loss= 3773.685791, Training Accuracy= 82.10000
#
# Fold: 10, Epoch: 18, Validation Accuracy= 87.20000
#
# Fold: 10, Epoch: 19, Mini Batch: 10, Loss= 4936.159668, Training Accuracy= 80.10000
# Fold: 10, Epoch: 19, Mini Batch: 18, Loss= 4321.408203, Training Accuracy= 80.60000
#
# Fold: 10, Epoch: 19, Validation Accuracy= 87.15000
#
# Fold: 10, Epoch: 20, Mini Batch: 10, Loss= 4537.733887, Training Accuracy= 82.00000
# Fold: 10, Epoch: 20, Mini Batch: 18, Loss= 4145.759766, Training Accuracy= 81.20000
#
# Fold: 10, Epoch: 20, Validation Accuracy= 87.20000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           825    81   906
# 1           175   919  1094
# All        1000  1000  2000
#
# Fold: 10, Epoch: 21, Mini Batch: 10, Loss= 4464.233887, Training Accuracy= 79.00000
# Fold: 10, Epoch: 21, Mini Batch: 18, Loss= 4036.385742, Training Accuracy= 80.20000
#
# Fold: 10, Epoch: 21, Validation Accuracy= 87.15000
#
# Fold: 10, Epoch: 22, Mini Batch: 10, Loss= 3873.465576, Training Accuracy= 81.80000
# Fold: 10, Epoch: 22, Mini Batch: 18, Loss= 3940.733643, Training Accuracy= 80.00000
#
# Fold: 10, Epoch: 22, Validation Accuracy= 87.35000
#
# Fold: 10, Epoch: 23, Mini Batch: 10, Loss= 3913.445312, Training Accuracy= 80.70000
# Fold: 10, Epoch: 23, Mini Batch: 18, Loss= 3923.613770, Training Accuracy= 80.50000
#
# Fold: 10, Epoch: 23, Validation Accuracy= 87.25000
#
# Fold: 10, Epoch: 24, Mini Batch: 10, Loss= 3479.591064, Training Accuracy= 80.60000
# Fold: 10, Epoch: 24, Mini Batch: 18, Loss= 3678.991699, Training Accuracy= 81.50000
#
# Fold: 10, Epoch: 24, Validation Accuracy= 87.05000
#
# Fold: 10, Epoch: 25, Mini Batch: 10, Loss= 3188.574951, Training Accuracy= 81.20000
# Fold: 10, Epoch: 25, Mini Batch: 18, Loss= 3663.069092, Training Accuracy= 79.90000
#
# Fold: 10, Epoch: 25, Validation Accuracy= 87.15000
#
# Fold: 10, Epoch: 26, Mini Batch: 10, Loss= 3433.221436, Training Accuracy= 81.40000
# Fold: 10, Epoch: 26, Mini Batch: 18, Loss= 3277.937012, Training Accuracy= 81.50000
#
# Fold: 10, Epoch: 26, Validation Accuracy= 87.05000
#
# Fold: 10, Epoch: 27, Mini Batch: 10, Loss= 3200.490479, Training Accuracy= 82.80000
# Fold: 10, Epoch: 27, Mini Batch: 18, Loss= 3281.308594, Training Accuracy= 82.40000
#
# Fold: 10, Epoch: 27, Validation Accuracy= 86.80000
#
# Fold: 10, Epoch: 28, Mini Batch: 10, Loss= 2703.468994, Training Accuracy= 82.20000
# Fold: 10, Epoch: 28, Mini Batch: 18, Loss= 2974.876465, Training Accuracy= 82.90000
#
# Fold: 10, Epoch: 28, Validation Accuracy= 87.05000
#
# Fold: 10, Epoch: 29, Mini Batch: 10, Loss= 3697.482178, Training Accuracy= 80.40000
# Fold: 10, Epoch: 29, Mini Batch: 18, Loss= 2497.786865, Training Accuracy= 82.70000
#
# Fold: 10, Epoch: 29, Validation Accuracy= 86.85000
#
# Fold: 10, Epoch: 30, Mini Batch: 10, Loss= 3165.107178, Training Accuracy= 81.60000
# Fold: 10, Epoch: 30, Mini Batch: 18, Loss= 2802.472412, Training Accuracy= 82.20000
#
# Fold: 10, Epoch: 30, Validation Accuracy= 86.95000
#
# Confusion Matrix CrossValid Set
# Predicted     0     1   All
# True
# 0           836    97   933
# 1           164   903  1067
# All        1000  1000  2000
#
# The mean Valid Accuracy is :  86.765

# %%
rows = 2
columns = 5
vizualize(vaccPerEpochPerFold, taccPerEpochPerFold, meanValidAcc=meanValidAcc, rows=rows, columns=columns, figsize=(5*columns, 5*rows))

# %% [markdown]
# # MODEL 2: HOG Multi-Filter with RMSPROP

# %%
# self.seed = 2316
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 50
# self.batchSize = 1000


# Fold: 1, Epoch: 50, Mini Batch: 9, Loss= 43.558125, Training Accuracy= 97.50000

# Fold: 1, Epoch: 50, Validation Accuracy= 88.30000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          452   69   521
# 1           48  431   479
# All        500  500  1000

# optimizer = tf.train.RMSPropOptimizer(learning_rate=0.0005, momentum=0.9).minimize(lossCE) 


ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 50
# self.batchSize = 1000


# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 249.902252, Training Accuracy= 92.40000

# Fold: 1, Epoch: 30, Validation Accuracy= 88.60000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          452   66   518
# 1           48  434   482
# All        500  500  1000

# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

# optimizer = tf.train.RMSPropOptimizer(learning_rate=0.0008, momentum=0.8).minimize(lossCE)

ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# learning_rate = 0.01
# momentum = 0.8


# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 249.902252, Training Accuracy= 92.40000

# Fold: 1, Epoch: 30, Validation Accuracy= 88.60000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          452   66   518
# 1           48  434   482
# All        500  500  1000

# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# learning_rate = 0.01
# momentum = 0.8


# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 131.296799, Training Accuracy= 94.40000

# Fold: 1, Epoch: 30, Validation Accuracy= 87.80000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          442   64   506
# 1           58  436   494
# All        500  500  1000

# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# learning_rate = 0.01
# momentum = 0.7


# Fold: 1, Epoch: 30, Mini Batch: 9, Loss= 332.687378, Training Accuracy= 91.20000

# Fold: 1, Epoch: 30, Validation Accuracy= 87.30000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          452   79   531
# 1           48  421   469
# All        500  500  1000

# hid1 = dropoutProb=0.5
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with RMS Prop:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1024
# self.numHidden3 = 1024
# self.numLabels = 2
# self.momentum = 0.5        # Momentum for momentum Optimizer
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# learning_rate=0.001, momentum=0.8

# Fold: 1, Epoch: 30, Validation Accuracy= 86.90000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          446   77   523
# 1           54  423   477
# All        500  500  1000

# hid1 = dropoutProb=0.5
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75


ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with Adam Optimizer:

# Learning_rate = 0.001
# self.seed = 2316
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1280
# self.numHidden3 = 1024
# self.numLabels = 2
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000


# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          425   55   480
# 1           75  445   520
# All        500  500  1000


# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75

x = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer For RELU activation layer with Adam Optimizer:
# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1024
# self.numHidden3 = 1024
# self.numLabels = 2
# self.alpha = 0.001          # Learning Rate 
# self.momentum = 0.9        # Momentum for momentum Optimizer
# self.numFolds = 10

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# Fold: 1, Epoch: 30, Validation Accuracy= 87.70000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          421   44   465
# 1           79  456   535
# All        500  500  1000

# hid1 = dropoutProb=0.5
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75


ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()

# %%
# Plotting Weight Change for every Hidden Layer for LOGIT units:

# self.imageSize = 32
# self.numHidden1 = 1024
# self.numHidden2 = 1024
# self.numHidden3 = 1024
# self.numLabels = 2
# self.alpha = 0.001          # Learning Rate 
# self.momentum = 0.9        # Momentum for momentum Optimizer
# self.numFolds = 10
# self.dropout = 0.5

# # Learning Variables     
# self.epochs = 30
# self.batchSize = 1000

# Fold: 1, Epoch: 30, Validation Accuracy= 83.10000

# Confusion Matrix CrossValid Set
# Predicted    0    1   All
# True                     
# 0          359   28   387
# 1          141  472   613
# All        500  500  1000

# hid1 = dropoutProb=0.5
# hid1 = dropoutProb=0.75
# hid1 = dropoutProb=0.75


ax = plt.figure(figsize=(40,20), facecolor='w', edgecolor='k')
legend = []
for layer, wghtchng_arr in out.items():
#     print (layer)
    prcntg_cnhg = []
    for num, chng in enumerate(wghtchng_arr[1:len(wghtchng_arr)]):
#         print (wghtchng_arr[num], chng,  abs(wghtchng_arr[num] - chng), (100* (chng/wghtchng_arr[num])), 100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
        prcntg_cnhg.append(100*(abs(chng-wghtchng_arr[num])/wghtchng_arr[num]))
    plt.plot(prcntg_cnhg)
    
    legend.append(layer) 
#     print ('')
    
plt.legend(legend, loc='upper right', fontsize=20)
plt.show()
